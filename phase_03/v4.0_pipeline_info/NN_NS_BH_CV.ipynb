# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt

# %%
data_bh = pd.read_csv('processed_data/BH.csv')
#display(data_bh)
display(data_bh.describe())
data_ns = pd.read_csv('processed_data/NS.csv')
#display(data_ns)
display(data_ns.describe())


data_pulsar = pd.read_csv('processed_data/PULSAR.csv')
display(data_pulsar.describe())
data_cv = pd.read_csv('processed_data/CV.csv')
data_cv.describe()
data = pd.concat([data_bh , data_ns , data_cv ] , axis=0)
#display(data)
data =  data.sample(frac=1)
max_flux = 13
min_flux = 22
data = data[data['flux_aper']>max_flux]
data = data[data['flux_aper']<min_flux]
data = data[data['flux_aper_lolim']<min_flux]
data = data[data['flux_aper_hilim']>(max_flux-1)]
display(data.describe())
data_class = data[['class']]
data_val = data.drop(columns=['index' , 'livetime' , 'gti_obs' , 'significance' , 'likelihood' , 'class'])
#display(data_val)
import missingno as msno
msno.matrix(data_val)
plt.show()
'''
rows = []
for d in data_val:
    rows.append(d)
print(rows)


from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
for r in rows:
    try:
        data_val[[r]] = imputer.fit_transform(data_val[[r]])
    except:
        print(r)
'''
data_val = data_val.replace(np.nan , 0)

for d in data_val:
    mean = np.mean(data_val[d])
    var = np.var(data_val[d])
    data_val[d] = (data_val[d]-mean)/var
    data_val[d] = data_val[d] / np.amax(data_val[d])
msno.matrix(data_val)
plt.show()
# Out:
#              index       livetime  significance     likelihood  \
# count  1100.000000    1100.000000   1100.000000    1100.000000
# mean     22.041818   50940.248364     47.953209   32843.961425
# std      22.213786   47492.166901     81.006175  112967.932302
# min       0.000000    4256.000000      1.840000      11.367330
# 25%       3.000000   17980.825000      9.200000     103.916100
# 50%      10.000000   37958.300000     17.390000     251.705800
# 75%      40.000000   69249.500000     44.060000    4017.937000
# max      73.000000  184208.000000    337.000000  462011.400000
#
#        var_inter_sigma  var_inter_prob  var_inter_index     var_max  \
# count     1.095000e+03     1095.000000      1095.000000  546.000000
# mean      1.012944e-04        0.770570         4.911416    0.871517
# std       1.430027e-04        0.223751         1.966590   20.079430
# min       6.731750e-08        0.221500         0.000000    0.000084
# 25%       5.171680e-07        0.604000         3.400000    0.000444
# 50%       5.134500e-05        0.807400         5.000000    0.002233
# 75%       8.803350e-05        0.998500         7.000000    0.005484
# max       4.811690e-04        1.000000         8.000000  469.200000
#
#           var_min    var_mean  ...  flux_brems_lolim  flux_brems_hilim  \
# count  546.000000  546.000000  ...        142.000000        142.000000
# mean     0.007131    0.010304  ...         12.906908         12.705068
# std      0.023738    0.061340  ...          0.841372          0.733658
# min      0.000024    0.000057  ...         10.999566         10.982967
# 25%      0.000243    0.000267  ...         12.496114         12.406270
# 50%      0.001183    0.001257  ...         13.083125         12.871781
# 75%      0.004266    0.004745  ...         13.433798         13.052468
# max      0.230371    1.325500  ...         14.608183         14.233364
#
#        brems_kt_hilim  brems_kt_lolim  brems_nh_hilim  brems_nh_lolim  \
# count    1.240000e+02      142.000000      142.000000      136.000000
# mean     8.396005e+05        4.731831      982.101089      754.218486
# std      9.348448e+06        9.576549      810.726794      576.530659
# min      1.425000e+00        1.008000        0.648700        0.083260
# 25%      2.655500e+00        1.730000       66.050000       58.615000
# 50%      4.668500e+00        2.728000     1071.000000      762.000000
# 75%      1.016500e+01        4.646000     1560.750000     1348.250000
# max      1.041000e+08       81.320000     3373.000000     1920.000000
#
#        bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  bb_nh_lolim
# count   142.000000   142.000000   142.000000   114.000000
# mean      2.137308     0.913699   749.999731   627.709211
# std      10.319842     0.433529   643.352664   400.918749
# min       0.402400     0.360300     0.100100    10.730000
# 25%       0.812675     0.693575    26.907500   393.550000
# 50%       0.892800     0.811000   791.300000   597.000000
# 75%       1.502000     1.033500  1224.750000  1029.250000
# max     123.800000     3.754000  2830.000000  1481.000000
#
# [8 rows x 66 columns]
#              index       livetime  significance     likelihood  \
# count  1268.000000    1268.000000   1268.000000   1.268000e+03
# mean     21.215300   20853.597003     83.881743            inf
# std      29.084807   23101.444868    117.400880            inf
# min       0.000000     916.000000      1.000000   9.494117e+00
# 25%       2.000000    7462.700000     17.270000   1.117242e+03
# 50%       9.000000    9636.400000     44.360000   1.542845e+04
# 75%      30.000000   26801.300000     90.710000   3.953709e+04
# max     150.000000  173023.700000    519.420000  1.797693e+308
#
#        var_inter_sigma  var_inter_prob  var_inter_index       var_max  \
# count     1.235000e+03     1235.000000      1235.000000   1028.000000
# mean      7.395187e-04        0.855801         6.468637     27.822399
# std       1.908386e-03        0.168945         1.687557    465.766260
# min       1.910500e-08        0.085000         0.000000      0.000150
# 25%       4.102500e-05        0.800000         6.400000      0.005506
# 50%       1.436754e-04        0.870250         6.400000      0.018155
# 75%       2.423574e-04        1.000000         8.000000      0.056987
# max       8.676740e-03        1.000000         8.000000  10250.004202
#
#            var_min     var_mean  ...  flux_brems_lolim  flux_brems_hilim  \
# count  1028.000000  1028.000000  ...        657.000000        657.000000
# mean      0.051117     0.358502  ...         12.139128         12.069728
# std       0.154987     6.091575  ...          0.664334          0.625338
# min       0.000068     0.000105  ...          9.791021          9.788346
# 25%       0.003110     0.003948  ...         11.672437         11.602408
# 50%       0.013687     0.015543  ...         12.269945         12.209363
# 75%       0.042755     0.050996  ...         12.499078         12.428058
# max       2.448138   137.204179  ...         14.538201         13.800519
#
#        brems_kt_hilim  brems_kt_lolim  brems_nh_hilim  brems_nh_lolim  \
# count      319.000000      657.000000      653.000000      596.000000
# mean       356.270855       33.044725      296.014043      259.522077
# std       5393.592765       30.757195      660.429729      560.822326
# min          0.197500        0.173200        0.035380        0.083460
# 25%          1.302000        4.405000       43.780000       31.437500
# 50%          5.539000       19.300000       67.400000       51.295000
# 75%         21.180000       60.930000      213.400000      192.200000
# max      96120.000000       99.720000     4861.000000     4430.000000
#
#        bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  bb_nh_lolim
# count   657.000000   657.000000   657.000000   274.000000
# mean      2.774100     1.077449   185.580538   328.543648
# std      19.176036     0.859778   496.567227   509.319533
# min       0.159500     0.121100     0.007671     0.000000
# 25%       0.791200     0.759100     1.182000    48.527500
# 50%       1.262000     1.112000     3.586000   105.900000
# 75%       1.448000     1.247000   118.600000   218.475000
# max     327.500000    13.540000  3227.000000  2502.000000
#
# [8 rows x 66 columns]
#            index       livetime  significance    likelihood  var_inter_sigma  \
# count  95.000000      95.000000     95.000000     95.000000     6.400000e+01
# mean    3.800000   38167.429474     34.787368  13917.093891     1.569417e-05
# std     6.295219   34566.563684     43.706247  22823.233977     2.432501e-05
# min     0.000000    3903.900000      1.840000     23.550950     3.031800e-07
# 25%     0.000000   10162.000000      5.690000    390.680900     4.354550e-07
# 50%     1.000000   24735.600000     12.860000    767.561600     1.856350e-06
# 75%     4.000000   49106.450000     34.310000   7690.349500     1.984400e-05
# max    24.000000  166935.300000    144.290000  62909.280000     8.061540e-05
#
#        var_inter_prob  var_inter_index     var_max    var_min   var_mean  ...  \
# count       64.000000        64.000000   91.000000  91.000000  91.000000  ...
# mean         0.549704         3.207812   10.811307   0.008486   0.027849  ...
# std          0.237813         1.819018  103.045688   0.014996   0.183337  ...
# min          0.099000         0.000000    0.000150   0.000068   0.000105  ...
# 25%          0.435812         2.062500    0.001266   0.000715   0.000823  ...
# 50%          0.594000         3.200000    0.003089   0.001824   0.002029  ...
# 75%          0.782800         5.000000    0.012217   0.011797   0.012088  ...
# max          0.900000         6.200000  983.002387   0.073643   1.751740  ...
#
#        flux_brems_lolim  flux_brems_hilim  brems_kt_hilim  brems_kt_lolim  \
# count         40.000000         40.000000       32.000000       40.000000
# mean          12.745523         12.679084      172.910084       15.949073
# std            0.599896          0.555087      809.731605       25.729744
# min           11.726999         11.693146        0.522700        0.409700
# 25%           12.286735         12.255141        5.523500        4.222000
# 50%           12.535139         12.505852        6.167500        5.092500
# 75%           13.355166         13.203847        7.161000        6.587500
# max           13.901702         13.773916     4544.000000       93.450000
#
#        brems_nh_hilim  brems_nh_lolim  bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  \
# count       40.000000       21.000000    40.000000    40.000000    40.000000
# mean        65.215895       94.668162     1.084760     0.857302    18.581310
# std        103.320202       91.493272     1.148652     0.680336    37.163859
# min          0.733300        0.296400     0.185600     0.163100     0.104400
# 25%          2.864000       35.960000     0.588850     0.525050     0.361625
# 50%         18.955000       71.940000     0.634600     0.582650     1.045500
# 75%         98.405000      145.400000     0.866600     0.817975    17.155000
# max        519.700000      379.300000     5.770000     3.038000   182.100000
#
#        bb_nh_lolim
# count    13.000000
# mean     25.214215
# std      28.506009
# min       0.242800
# 25%       4.938000
# 50%      11.790000
# 75%      40.620000
# max      87.780000
#
# [8 rows x 66 columns]
#              index       livetime  significance     likelihood  \
# count  3678.000000    3678.000000   3678.000000   3.678000e+03
# mean     18.603317   34215.611746     33.757920            inf
# std      25.111750   35987.299734     50.446422            inf
# min       0.000000     845.100000      1.110000   9.494117e+00
# 25%       2.000000    4691.100000      8.420000   1.481277e+02
# 50%       7.000000   24046.100000     16.780000   1.195218e+03
# 75%      25.000000   59044.600000     44.060000   6.448755e+03
# max     148.000000  184208.000000    376.060000  1.797693e+308
#
#        var_inter_sigma  var_inter_prob  var_inter_index       var_max  \
# count     3.592000e+03     3592.000000      3592.000000   2489.000000
# mean      1.060783e-04        0.657582         4.393736     11.598292
# std       6.688297e-04        0.305731         2.502342    299.689103
# min       1.910500e-08        0.000000         0.000000      0.000076
# 25%       6.739000e-07        0.420200         2.000000      0.000692
# 50%       3.769725e-06        0.725500         4.366667      0.002422
# 75%       7.302500e-05        0.984000         6.500000      0.005536
# max       8.676740e-03        1.000000         8.000000  10250.004202
#
#            var_min     var_mean  ...  flux_brems_lolim  flux_brems_hilim  \
# count  2489.000000  2489.000000  ...        340.000000        340.000000
# mean      0.002391     0.128651  ...         13.379106         13.211251
# std       0.003046     3.916888  ...          0.406943          0.372601
# min       0.000024     0.000043  ...         12.529296         12.381847
# 25%       0.000354     0.000401  ...         13.084720         12.925824
# 50%       0.001247     0.001575  ...         13.349444         13.194064
# 75%       0.003155     0.003975  ...         13.599594         13.428408
# max       0.026985   137.204179  ...         15.045131         14.233364
#
#        brems_kt_hilim  brems_kt_lolim  brems_nh_hilim  brems_nh_lolim  \
# count    2.830000e+02      340.000000      340.000000      268.000000
# mean     3.679069e+05        5.625854      380.878346      317.023997
# std      6.188099e+06        9.273255      701.635530      489.117236
# min      1.975000e-01        0.173200        0.200000        0.000000
# 25%      1.480000e+00        1.168250        9.236000        8.602750
# 50%      4.543000e+00        2.799000       32.155000       55.840000
# 75%      1.035000e+01        5.184000      296.100000      494.000000
# max      1.041000e+08       58.690000     3648.000000     2417.000000
#
#        bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  bb_nh_lolim
# count   340.000000   340.000000    340.00000   131.000000
# mean      1.303416     0.680825    272.14996   399.545763
# std       6.715359     0.448225    560.12571   399.320107
# min       0.164800     0.157600      0.10010     0.000000
# 25%       0.454525     0.393300      0.83180    47.405000
# 50%       0.655300     0.559900      2.93500   359.100000
# 75%       1.144500     0.878125    151.50000   649.000000
# max     123.800000     3.754000   3039.00000  1907.000000
#
# [8 rows x 66 columns]

# %%
data_bh_clean = data[data_class['class']=='BH']
display(data_bh_clean.describe())
data_ns_clean = data[data_class['class']=='NS']
display(data_ns_clean.describe())
data_cv_clean = data[data_class['class']=='CV']
display(data_cv_clean.describe())
# Out:
#             index       livetime  significance     likelihood  \
# count  796.000000     796.000000    796.000000     796.000000
# mean    18.555276   59260.201759     46.622513   27289.139340
# std     21.202544   50076.799352     74.071758  101572.411605
# min      0.000000    4256.000000      1.840000      11.367330
# 25%      3.000000   24700.650000      9.200000     137.327400
# 50%      8.000000   43414.800000     19.730000    1102.030500
# 75%     33.000000   75682.200000     44.060000    5983.389000
# max     73.000000  184208.000000    337.000000  462011.400000
#
#        var_inter_sigma  var_inter_prob  var_inter_index     var_max  \
# count     7.910000e+02      791.000000       791.000000  497.000000
# mean      7.551177e-05        0.734335         4.718732    0.947729
# std       1.285902e-04        0.223744         2.083093   21.046333
# min       6.731750e-08        0.221500         0.000000    0.000084
# 25%       3.872220e-07        0.604000         3.333333    0.000412
# 50%       1.049000e-05        0.750000         5.000000    0.001228
# 75%       8.405500e-05        0.993600         6.400000    0.004533
# max       4.811690e-04        1.000000         8.000000  469.200000
#
#           var_min    var_mean  ...  flux_brems_lolim  flux_brems_hilim  \
# count  497.000000  497.000000  ...         97.000000         97.000000
# mean     0.002233    0.005149  ...         13.367372         13.098299
# std      0.002867    0.059430  ...          0.447970          0.400984
# min      0.000024    0.000057  ...         12.529296         12.381847
# 25%      0.000234    0.000251  ...         13.054384         12.862013
# 50%      0.000720    0.000751  ...         13.196065         13.010283
# 75%      0.003709    0.004099  ...         13.708853         13.236872
# max      0.020860    1.325500  ...         14.608183         14.233364
#
#        brems_kt_hilim  brems_kt_lolim  brems_nh_hilim  brems_nh_lolim  \
# count    8.300000e+01       97.000000       97.000000       91.000000
# mean     1.254333e+06        3.798299      953.398378      671.005935
# std      1.142645e+07        2.911864      863.956793      532.835546
# min      1.425000e+00        1.008000        0.648700        0.083260
# 25%      3.454500e+00        1.982000       20.980000       55.345000
# 50%      5.169000e+00        2.775000      943.100000      691.500000
# 75%      1.093500e+01        4.402000     1357.000000      996.250000
# max      1.041000e+08       14.810000     3373.000000     1920.000000
#
#        bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  bb_nh_lolim
# count    97.000000    97.000000    97.000000    71.000000
# mean      2.591902     0.892127   722.084885   568.135634
# std      12.470169     0.440354   680.011271   325.162649
# min       0.402400     0.360300     0.100100    10.730000
# 25%       0.790100     0.619600     2.034000   399.250000
# 50%       1.071000     0.818800   724.500000   534.000000
# 75%       1.546000     1.050000  1021.000000   779.150000
# max     123.800000     3.754000  2830.000000  1481.000000
#
# [8 rows x 66 columns]
#             index       livetime  significance     likelihood  \
# count  525.000000     525.000000    525.000000   5.250000e+02
# mean    17.384762   24320.138095     43.440438            inf
# std     26.843989   25381.653316     72.019709            inf
# min      0.000000    1079.800000      2.000000   9.494117e+00
# 25%      1.000000    7630.100000      8.280000   1.262790e+02
# 50%      4.000000   16963.200000     18.690000   1.514287e+03
# 75%     23.000000   30496.900000     54.890000   1.891644e+04
# max    148.000000  166689.200000    376.060000  1.797693e+308
#
#        var_inter_sigma  var_inter_prob  var_inter_index       var_max  \
# count     5.080000e+02      508.000000       508.000000    382.000000
# mean      5.304217e-04        0.821295         6.076903     74.312510
# std       1.709003e-03        0.197488         2.003516    762.406171
# min       1.910500e-08        0.085000         0.000000      0.000150
# 25%       4.770912e-06        0.800000         5.800000      0.001534
# 50%       7.363700e-05        0.870250         6.400000      0.003631
# 75%       1.733950e-04        0.996962         7.750000      0.006830
# max       8.676740e-03        1.000000         8.000000  10250.004202
#
#           var_min    var_mean  ...  flux_brems_lolim  flux_brems_hilim  \
# count  382.000000  382.000000  ...         72.000000         72.000000
# mean     0.003086    0.819357  ...         13.262219         13.108236
# std      0.002961    9.980804  ...          0.336155          0.278752
# min      0.000068    0.000105  ...         12.734946         12.587036
# 25%      0.000803    0.001011  ...         13.060846         12.907630
# 50%      0.002297    0.002640  ...         13.221632         13.096834
# 75%      0.004392    0.005094  ...         13.401210         13.249979
# max      0.016812  137.204179  ...         14.538201         13.800519
#
#        brems_kt_hilim  brems_kt_lolim  brems_nh_hilim  brems_nh_lolim  \
# count       54.000000       72.000000       72.000000       70.000000
# mean         2.751124        8.823951      378.085389      265.293133
# std          4.543564       17.117354      776.124295      513.508183
# min          0.197500        0.173200        1.143000        0.382300
# 25%          0.809600        0.710775       60.495000       44.315000
# 50%          1.192000        1.150500      116.900000       74.960000
# 75%          1.940000        4.384000      203.300000      164.750000
# max         21.180000       58.690000     3648.000000     2417.000000
#
#        bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  bb_nh_lolim
# count    72.000000    72.000000    72.000000    55.000000
# mean      0.855344     0.616681   291.901313   217.838309
# std       0.759932     0.374247   652.054220   401.692893
# min       0.164800     0.157600     0.439500     0.000000
# 25%       0.400625     0.335425    17.417500    27.560000
# 50%       0.547800     0.460400    71.240000    79.670000
# 75%       1.186000     0.957200   151.500000   115.800000
# max       4.173000     1.580000  3039.000000  1907.000000
#
# [8 rows x 66 columns]
#              index       livetime  significance     likelihood  \
# count  2357.000000    2357.000000   2357.000000    2357.000000
# mean     18.890963   27961.742427     27.256631    8116.714840
# std      25.919057   27548.194934     29.114209   21267.144294
# min       0.000000     845.100000      1.110000      13.080590
# 25%       3.000000    3987.300000      7.940000     205.234300
# 50%       7.000000    5734.600000     16.470000    1195.218000
# 75%      23.000000   59044.600000     33.190000    4533.021000
# max     106.000000  147712.000000    195.010000  211455.100000
#
#        var_inter_sigma  var_inter_prob  var_inter_index      var_max  \
# count     2.293000e+03     2293.000000      2293.000000  1610.000000
# mean      2.261195e-05        0.594835         3.908729     0.006055
# std       4.347898e-05        0.329624         2.554855     0.021106
# min       8.412000e-08        0.000000         0.000000     0.000076
# 25%       6.739000e-07        0.334500         1.600000     0.000766
# 50%       2.416440e-06        0.603800         3.800000     0.002290
# 75%       1.526825e-05        0.984000         6.400000     0.005520
# max       2.510300e-04        1.000000         8.000000     0.496227
#
#            var_min     var_mean  ...  flux_brems_lolim  flux_brems_hilim  \
# count  1610.000000  1610.000000  ...        171.000000        171.000000
# mean      0.002275     0.002893  ...         13.434977         13.318698
# std       0.003099     0.003876  ...          0.400885          0.360845
# min       0.000036     0.000043  ...         12.686344         12.649171
# 25%       0.000372     0.000429  ...         13.218821         13.116298
# 50%       0.001163     0.001495  ...         13.455808         13.354676
# 75%       0.002533     0.003414  ...         13.663540         13.554141
# max       0.026985     0.030770  ...         15.045131         14.072065
#
#        brems_kt_hilim  brems_kt_lolim  brems_nh_hilim  brems_nh_lolim  \
# count      146.000000       171.00000      171.000000      107.000000
# mean        53.870860         5.31597       57.291502       49.816560
# std        528.999237         6.16330      127.468575       92.110263
# min          0.349500         0.30960        0.200000        0.000000
# 25%          1.383000         1.01100        6.027000        3.307000
# 50%          5.329000         3.65200       10.920000       11.450000
# 75%         12.240000         5.51900       25.730000       18.905000
# max       6398.000000        33.13000      541.100000      308.000000
#
#        bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  bb_nh_lolim
# count   171.000000   171.000000   171.000000     5.000000
# mean      0.761181     0.587971     8.607357     4.351600
# std       0.736815     0.443553    37.353408     3.548554
# min       0.176600     0.165700     0.104500     1.148000
# 25%       0.365400     0.304000     0.547600     2.089000
# 50%       0.588200     0.471800     1.060000     2.089000
# 75%       0.716450     0.620900     2.452500     8.216000
# max       3.331000     2.229000   222.200000     8.216000
#
# [8 rows x 66 columns]

# %%
def split_data(x,y,frac):
    split_no = int(len(y)*frac )
    x_train = x[:split_no]
    x_test = x[split_no:]
    y_train = y[:split_no]
    y_test = y[split_no:]
    return (x_train , y_train) , (x_test , y_test)

x = data_val.to_numpy()
y = data_class.to_numpy()
(x_train , y_train) , (x_test , y_test) =  split_data(x, y, 0.8)
print(x_train.shape , y_train.shape)
print(x_test.shape , y_test.shape)
# Out:
# (3519, 62) (3519, 1)
# (880, 62) (880, 1)

# %% [markdown]
# # Neural Network

# %%
def class_to_int(label , cl):
    temp = []
    for i in range(len(label)):
        #print(label[i])
        for j in range(len(cl)):
            if(label[i]==cl[j]):
                temp.append(j) 
    return temp
classes = ['BH' ,'NS' , 'CV' ]
y_train_int = class_to_int(y_train, classes)
y_test_int = class_to_int(y_train, classes)
one_hot_y_train =  to_categorical(y_train_int)
one_hot_y_test =  to_categorical(y_test_int)
#for y_i , y_j in zip(y_train , one_hot_y_train):
##    print(y_i , y_j)

# %%
np.random.seed(903378735)
def model_gen(shape , input_len):

    inputs =  keras.Input(shape=(input_len,))
    dense =  layers.Dense(64, activation='relu')
    x = dense(inputs)
    #x =  layers.BatchNormalization(axis=-1)(x)
    #x = layers.Dropout(0.3)(x)
    for s in shape:
        x = layers.Dense(s, activation='relu')(x)
    #x =  layers.BatchNormalization(axis=-1)(x)
    outputs = layers.Dense(3 , activation='softmax')(x)
    model = keras.Model(inputs=inputs , outputs=outputs , name='trial_model')
    np.random.seed(903378735)
    model.compile(
        loss = "categorical_crossentropy",
        optimizer = keras.optimizers.Adam(learning_rate=0.0005),
        metrics = ["accuracy"],
    )
    return model
model = model_gen([32,32,16,8] , x_train.shape[1])
history = model.fit(x_train, one_hot_y_train, batch_size=128, epochs=70, validation_split=0.2)
# Out:
# 2021-09-15 16:22:18.552058: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-15 16:22:18.552310: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-09-15 16:22:18.552698: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2021-09-15 16:22:18.806553: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-09-15 16:22:18.825542: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 1800000000 Hz
# Epoch 1/70
# 22/22 [==============================] - 3s 51ms/step - loss: 1.0336 - accuracy: 0.6124 - val_loss: 0.9402 - val_accuracy: 0.5881
# Epoch 2/70
# 22/22 [==============================] - 1s 25ms/step - loss: 0.9066 - accuracy: 0.5905 - val_loss: 0.8343 - val_accuracy: 0.5881
# Epoch 3/70
# 22/22 [==============================] - 0s 22ms/step - loss: 0.7941 - accuracy: 0.6095 - val_loss: 0.7848 - val_accuracy: 0.6278
# Epoch 4/70
# 22/22 [==============================] - 0s 16ms/step - loss: 0.7466 - accuracy: 0.6620 - val_loss: 0.7395 - val_accuracy: 0.7131
# Epoch 5/70
# 22/22 [==============================] - 0s 15ms/step - loss: 0.7127 - accuracy: 0.7172 - val_loss: 0.6972 - val_accuracy: 0.7514
# Epoch 6/70
# 22/22 [==============================] - 0s 18ms/step - loss: 0.6736 - accuracy: 0.7503 - val_loss: 0.6522 - val_accuracy: 0.7685
# Epoch 7/70
# 22/22 [==============================] - 1s 28ms/step - loss: 0.6207 - accuracy: 0.7743 - val_loss: 0.6100 - val_accuracy: 0.7784
# Epoch 8/70
# 22/22 [==============================] - 1s 28ms/step - loss: 0.5969 - accuracy: 0.7809 - val_loss: 0.5771 - val_accuracy: 0.7812
# Epoch 9/70
# 22/22 [==============================] - 0s 21ms/step - loss: 0.5873 - accuracy: 0.7676 - val_loss: 0.5560 - val_accuracy: 0.7855
# Epoch 10/70
# 22/22 [==============================] - 0s 16ms/step - loss: 0.5426 - accuracy: 0.7826 - val_loss: 0.5281 - val_accuracy: 0.7869
# Epoch 11/70
# 22/22 [==============================] - 0s 15ms/step - loss: 0.5313 - accuracy: 0.7925 - val_loss: 0.5161 - val_accuracy: 0.7912
# Epoch 12/70
# 22/22 [==============================] - 0s 17ms/step - loss: 0.5116 - accuracy: 0.7982 - val_loss: 0.5059 - val_accuracy: 0.7841
# Epoch 13/70
# 22/22 [==============================] - 0s 17ms/step - loss: 0.4754 - accuracy: 0.8114 - val_loss: 0.4906 - val_accuracy: 0.8040
# Epoch 14/70
# 22/22 [==============================] - 0s 16ms/step - loss: 0.4935 - accuracy: 0.8069 - val_loss: 0.4872 - val_accuracy: 0.8040
# Epoch 15/70
# 22/22 [==============================] - 0s 15ms/step - loss: 0.4571 - accuracy: 0.8232 - val_loss: 0.4778 - val_accuracy: 0.8026
# Epoch 16/70
# 22/22 [==============================] - 1s 25ms/step - loss: 0.4512 - accuracy: 0.8326 - val_loss: 0.4701 - val_accuracy: 0.8097
# Epoch 17/70
# 22/22 [==============================] - 0s 13ms/step - loss: 0.4491 - accuracy: 0.8289 - val_loss: 0.4620 - val_accuracy: 0.8111
# Epoch 18/70
# 22/22 [==============================] - 0s 19ms/step - loss: 0.4268 - accuracy: 0.8333 - val_loss: 0.4495 - val_accuracy: 0.8182
# Epoch 19/70
# 22/22 [==============================] - 1s 27ms/step - loss: 0.4141 - accuracy: 0.8404 - val_loss: 0.4427 - val_accuracy: 0.8168
# Epoch 20/70
# 22/22 [==============================] - 1s 25ms/step - loss: 0.4188 - accuracy: 0.8363 - val_loss: 0.4435 - val_accuracy: 0.8267
# Epoch 21/70
# 22/22 [==============================] - 1s 27ms/step - loss: 0.4021 - accuracy: 0.8418 - val_loss: 0.4335 - val_accuracy: 0.8239
# Epoch 22/70
# 22/22 [==============================] - 0s 21ms/step - loss: 0.3926 - accuracy: 0.8507 - val_loss: 0.4261 - val_accuracy: 0.8253
# Epoch 23/70
# 22/22 [==============================] - 0s 17ms/step - loss: 0.3905 - accuracy: 0.8599 - val_loss: 0.4222 - val_accuracy: 0.8295
# Epoch 24/70
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3925 - accuracy: 0.8520 - val_loss: 0.4198 - val_accuracy: 0.8224
# Epoch 25/70
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3818 - accuracy: 0.8599 - val_loss: 0.4170 - val_accuracy: 0.8281
# Epoch 26/70
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3409 - accuracy: 0.8766 - val_loss: 0.4131 - val_accuracy: 0.8324
# Epoch 27/70
# 22/22 [==============================] - 1s 24ms/step - loss: 0.3692 - accuracy: 0.8620 - val_loss: 0.4128 - val_accuracy: 0.8267
# Epoch 28/70
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3619 - accuracy: 0.8690 - val_loss: 0.4246 - val_accuracy: 0.8239
# Epoch 29/70
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3584 - accuracy: 0.8693 - val_loss: 0.4044 - val_accuracy: 0.8395
# Epoch 30/70
# 22/22 [==============================] - 0s 15ms/step - loss: 0.3463 - accuracy: 0.8745 - val_loss: 0.4064 - val_accuracy: 0.8338
# Epoch 31/70
# 22/22 [==============================] - 0s 20ms/step - loss: 0.3190 - accuracy: 0.8859 - val_loss: 0.4046 - val_accuracy: 0.8281
# Epoch 32/70
# 22/22 [==============================] - 0s 15ms/step - loss: 0.3282 - accuracy: 0.8816 - val_loss: 0.3965 - val_accuracy: 0.8395
# Epoch 33/70
# 22/22 [==============================] - 0s 13ms/step - loss: 0.3229 - accuracy: 0.8827 - val_loss: 0.4014 - val_accuracy: 0.8565
# Epoch 34/70
# 22/22 [==============================] - 0s 21ms/step - loss: 0.3237 - accuracy: 0.8830 - val_loss: 0.4014 - val_accuracy: 0.8295
# Epoch 35/70
# 22/22 [==============================] - 1s 31ms/step - loss: 0.3322 - accuracy: 0.8696 - val_loss: 0.3942 - val_accuracy: 0.8324
# Epoch 36/70
# 22/22 [==============================] - 1s 36ms/step - loss: 0.3177 - accuracy: 0.8838 - val_loss: 0.3998 - val_accuracy: 0.8409
# Epoch 37/70
# 22/22 [==============================] - 1s 55ms/step - loss: 0.2954 - accuracy: 0.8894 - val_loss: 0.3964 - val_accuracy: 0.8381
# Epoch 38/70
# 22/22 [==============================] - 1s 27ms/step - loss: 0.3284 - accuracy: 0.8790 - val_loss: 0.3914 - val_accuracy: 0.8452
# Epoch 39/70
# 22/22 [==============================] - 1s 30ms/step - loss: 0.3083 - accuracy: 0.8831 - val_loss: 0.3995 - val_accuracy: 0.8452
# Epoch 40/70
# 22/22 [==============================] - 0s 19ms/step - loss: 0.2922 - accuracy: 0.8895 - val_loss: 0.3983 - val_accuracy: 0.8395
# Epoch 41/70
# 22/22 [==============================] - 1s 25ms/step - loss: 0.3099 - accuracy: 0.8855 - val_loss: 0.3960 - val_accuracy: 0.8381
# Epoch 42/70
# 22/22 [==============================] - 1s 24ms/step - loss: 0.2957 - accuracy: 0.8856 - val_loss: 0.3938 - val_accuracy: 0.8409
# Epoch 43/70
# 22/22 [==============================] - 1s 25ms/step - loss: 0.2992 - accuracy: 0.8881 - val_loss: 0.3894 - val_accuracy: 0.8466
# Epoch 44/70
# 22/22 [==============================] - 0s 20ms/step - loss: 0.2901 - accuracy: 0.9025 - val_loss: 0.3889 - val_accuracy: 0.8509
# Epoch 45/70
# 22/22 [==============================] - 0s 21ms/step - loss: 0.2929 - accuracy: 0.8920 - val_loss: 0.3899 - val_accuracy: 0.8395
# Epoch 46/70
# 22/22 [==============================] - 1s 25ms/step - loss: 0.2760 - accuracy: 0.8989 - val_loss: 0.3903 - val_accuracy: 0.8509
# Epoch 47/70
# 22/22 [==============================] - 0s 22ms/step - loss: 0.2733 - accuracy: 0.8959 - val_loss: 0.3891 - val_accuracy: 0.8466
# Epoch 48/70
# 22/22 [==============================] - 1s 27ms/step - loss: 0.2763 - accuracy: 0.8977 - val_loss: 0.3857 - val_accuracy: 0.8494
# Epoch 49/70
# 22/22 [==============================] - 0s 20ms/step - loss: 0.2622 - accuracy: 0.9015 - val_loss: 0.3888 - val_accuracy: 0.8480
# Epoch 50/70
# 22/22 [==============================] - 1s 25ms/step - loss: 0.2766 - accuracy: 0.8982 - val_loss: 0.3910 - val_accuracy: 0.8466
# Epoch 51/70
# 22/22 [==============================] - 0s 23ms/step - loss: 0.2658 - accuracy: 0.9007 - val_loss: 0.3950 - val_accuracy: 0.8423
# Epoch 52/70
# 22/22 [==============================] - 1s 27ms/step - loss: 0.2795 - accuracy: 0.8971 - val_loss: 0.3813 - val_accuracy: 0.8438
# Epoch 53/70
# 22/22 [==============================] - 1s 26ms/step - loss: 0.2506 - accuracy: 0.9114 - val_loss: 0.3875 - val_accuracy: 0.8466
# Epoch 54/70
# 22/22 [==============================] - 1s 25ms/step - loss: 0.2650 - accuracy: 0.9034 - val_loss: 0.3861 - val_accuracy: 0.8494
# Epoch 55/70
# 22/22 [==============================] - 1s 25ms/step - loss: 0.2655 - accuracy: 0.8959 - val_loss: 0.3917 - val_accuracy: 0.8466
# Epoch 56/70
# 22/22 [==============================] - 1s 28ms/step - loss: 0.2440 - accuracy: 0.9045 - val_loss: 0.3797 - val_accuracy: 0.8523
# Epoch 57/70
# 22/22 [==============================] - 0s 18ms/step - loss: 0.2662 - accuracy: 0.8981 - val_loss: 0.3889 - val_accuracy: 0.8494
# Epoch 58/70
# 22/22 [==============================] - 1s 24ms/step - loss: 0.2507 - accuracy: 0.9086 - val_loss: 0.3855 - val_accuracy: 0.8509
# Epoch 59/70
# 22/22 [==============================] - 1s 29ms/step - loss: 0.2522 - accuracy: 0.9019 - val_loss: 0.3901 - val_accuracy: 0.8480
# Epoch 60/70
# 22/22 [==============================] - 1s 28ms/step - loss: 0.2601 - accuracy: 0.8993 - val_loss: 0.3850 - val_accuracy: 0.8480
# Epoch 61/70
# 22/22 [==============================] - 1s 24ms/step - loss: 0.2474 - accuracy: 0.9043 - val_loss: 0.4058 - val_accuracy: 0.8480
# Epoch 62/70
# 22/22 [==============================] - 1s 22ms/step - loss: 0.2459 - accuracy: 0.9091 - val_loss: 0.3871 - val_accuracy: 0.8594
# Epoch 63/70
# 22/22 [==============================] - 0s 21ms/step - loss: 0.2564 - accuracy: 0.9076 - val_loss: 0.3864 - val_accuracy: 0.8565
# Epoch 64/70
# 22/22 [==============================] - 1s 26ms/step - loss: 0.2218 - accuracy: 0.9131 - val_loss: 0.3877 - val_accuracy: 0.8537
# Epoch 65/70
# 22/22 [==============================] - 0s 21ms/step - loss: 0.2407 - accuracy: 0.9091 - val_loss: 0.3954 - val_accuracy: 0.8523
# Epoch 66/70
# 22/22 [==============================] - 1s 28ms/step - loss: 0.2464 - accuracy: 0.9077 - val_loss: 0.3994 - val_accuracy: 0.8537
# Epoch 67/70
# 22/22 [==============================] - 1s 24ms/step - loss: 0.2366 - accuracy: 0.9102 - val_loss: 0.3849 - val_accuracy: 0.8594
# Epoch 68/70
# 22/22 [==============================] - 0s 21ms/step - loss: 0.2283 - accuracy: 0.9097 - val_loss: 0.3991 - val_accuracy: 0.8636
# Epoch 69/70
# 22/22 [==============================] - 1s 31ms/step - loss: 0.2194 - accuracy: 0.9178 - val_loss: 0.3978 - val_accuracy: 0.8523
# Epoch 70/70
# 22/22 [==============================] - 1s 30ms/step - loss: 0.2419 - accuracy: 0.9163 - val_loss: 0.3903 - val_accuracy: 0.8622

# %%
hist = history.history
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(hist['accuracy'] , label = 'accuracy' , color='k')
plt.plot(hist['val_accuracy'] , label = 'val_accuracy' , color='crimson')
plt.xlabel('No of epochs')
plt.legend()
plt.subplot(1,2,2)
plt.plot(hist['loss'] , label = 'loss' , color='k')
plt.plot(hist['val_loss'] , label='val_loss' , color='crimson')
plt.xlabel("No of Epochs")
plt.legend()
#plt.savefig('plots/bn_model_level_0_rows.png')
plt.show()

# %% [markdown]
# # CNN

# %%
#from tensorflow.keras.layers import Flatten
#from tensorflow.keras.layers.convolutional import Conv2D
#from tensorflow.keras.layers.pooling import MaxPooling2D
visible = layers.Input(shape=(62,1))
#x = layers.BatchNormalization(axis=-1)(visible)
x = layers.Conv1D(60, kernel_size=4, activation='relu')(visible)
x = layers.MaxPool1D(pool_size=(2))(x)

x = layers.Conv1D(32, kernel_size=4, activation='relu')(x)
x = layers.MaxPool1D(pool_size=(2))(x)
x = layers.Conv1D(16, kernel_size=4, activation='relu')(x)
x = layers.MaxPooling1D(pool_size=(2))(x)
#x = layers.Conv1D(32, kernel_size=4, activation='relu')(x)
x = layers.MaxPooling1D(pool_size=(2))(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation='relu')(x)
#x = layers.Dense(10, activation='relu')(x)
output = layers.Dense(3, activation='sigmoid')(x)
model_cnn = keras.Model(inputs=visible, outputs=output)
# summarize layers
#print(model_cnn.summary())
model_cnn.compile(
        loss = "categorical_crossentropy",
        optimizer = keras.optimizers.Adam(learning_rate=0.0005),
        metrics = ["accuracy"],
    )
history = model_cnn.fit(x_train, one_hot_y_train, batch_size=64, epochs=40, validation_split=0.2)
# Out:
# Epoch 1/40
# 44/44 [==============================] - 6s 77ms/step - loss: 1.0009 - accuracy: 0.6079 - val_loss: 0.8742 - val_accuracy: 0.5881
# Epoch 2/40
# 44/44 [==============================] - 2s 53ms/step - loss: 0.8633 - accuracy: 0.6086 - val_loss: 0.8020 - val_accuracy: 0.6534
# Epoch 3/40
# 44/44 [==============================] - 2s 37ms/step - loss: 0.7602 - accuracy: 0.6656 - val_loss: 0.7341 - val_accuracy: 0.7188
# Epoch 4/40
# 44/44 [==============================] - 2s 45ms/step - loss: 0.7396 - accuracy: 0.7038 - val_loss: 0.6954 - val_accuracy: 0.7074
# Epoch 5/40
# 44/44 [==============================] - 3s 59ms/step - loss: 0.6599 - accuracy: 0.7398 - val_loss: 0.6661 - val_accuracy: 0.7401
# Epoch 6/40
# 44/44 [==============================] - 3s 68ms/step - loss: 0.6357 - accuracy: 0.7503 - val_loss: 0.6432 - val_accuracy: 0.7543
# Epoch 7/40
# 44/44 [==============================] - 3s 69ms/step - loss: 0.6150 - accuracy: 0.7621 - val_loss: 0.6128 - val_accuracy: 0.7713
# Epoch 8/40
# 44/44 [==============================] - 2s 50ms/step - loss: 0.5991 - accuracy: 0.7686 - val_loss: 0.5983 - val_accuracy: 0.7628
# Epoch 9/40
# 44/44 [==============================] - 2s 53ms/step - loss: 0.6035 - accuracy: 0.7566 - val_loss: 0.5709 - val_accuracy: 0.7798
# Epoch 10/40
# 44/44 [==============================] - 2s 50ms/step - loss: 0.5561 - accuracy: 0.7724 - val_loss: 0.5563 - val_accuracy: 0.7855
# Epoch 11/40
# 44/44 [==============================] - 2s 39ms/step - loss: 0.5438 - accuracy: 0.7906 - val_loss: 0.5400 - val_accuracy: 0.7841
# Epoch 12/40
# 44/44 [==============================] - 2s 54ms/step - loss: 0.5190 - accuracy: 0.7895 - val_loss: 0.5497 - val_accuracy: 0.7926
# Epoch 13/40
# 44/44 [==============================] - 3s 61ms/step - loss: 0.5152 - accuracy: 0.8048 - val_loss: 0.5150 - val_accuracy: 0.8082
# Epoch 14/40
# 44/44 [==============================] - 3s 57ms/step - loss: 0.4904 - accuracy: 0.8056 - val_loss: 0.5019 - val_accuracy: 0.8097
# Epoch 15/40
# 44/44 [==============================] - 2s 46ms/step - loss: 0.4731 - accuracy: 0.8210 - val_loss: 0.4964 - val_accuracy: 0.8168
# Epoch 16/40
# 44/44 [==============================] - 3s 75ms/step - loss: 0.4830 - accuracy: 0.8131 - val_loss: 0.4895 - val_accuracy: 0.8168
# Epoch 17/40
# 44/44 [==============================] - 5s 103ms/step - loss: 0.4766 - accuracy: 0.8180 - val_loss: 0.4891 - val_accuracy: 0.7997
# Epoch 18/40
# 44/44 [==============================] - 5s 110ms/step - loss: 0.4600 - accuracy: 0.8287 - val_loss: 0.4849 - val_accuracy: 0.8153
# Epoch 19/40
# 44/44 [==============================] - 5s 113ms/step - loss: 0.4467 - accuracy: 0.8303 - val_loss: 0.4908 - val_accuracy: 0.8040
# Epoch 20/40
# 44/44 [==============================] - 5s 110ms/step - loss: 0.4379 - accuracy: 0.8276 - val_loss: 0.4692 - val_accuracy: 0.8182
# Epoch 21/40
# 44/44 [==============================] - 5s 120ms/step - loss: 0.4196 - accuracy: 0.8423 - val_loss: 0.4668 - val_accuracy: 0.8097
# Epoch 22/40
# 44/44 [==============================] - 5s 116ms/step - loss: 0.4123 - accuracy: 0.8467 - val_loss: 0.4580 - val_accuracy: 0.8139
# Epoch 23/40
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4254 - accuracy: 0.8390 - val_loss: 0.4612 - val_accuracy: 0.8097
# Epoch 24/40
# 44/44 [==============================] - 2s 35ms/step - loss: 0.4260 - accuracy: 0.8441 - val_loss: 0.4501 - val_accuracy: 0.8125
# Epoch 25/40
# 44/44 [==============================] - 2s 36ms/step - loss: 0.4087 - accuracy: 0.8440 - val_loss: 0.4454 - val_accuracy: 0.8196
# Epoch 26/40
# 44/44 [==============================] - 2s 51ms/step - loss: 0.3868 - accuracy: 0.8620 - val_loss: 0.4841 - val_accuracy: 0.8168
# Epoch 27/40
# 44/44 [==============================] - 2s 49ms/step - loss: 0.4156 - accuracy: 0.8429 - val_loss: 0.4615 - val_accuracy: 0.8097
# Epoch 28/40
# 44/44 [==============================] - 2s 50ms/step - loss: 0.3791 - accuracy: 0.8587 - val_loss: 0.4461 - val_accuracy: 0.8267
# Epoch 29/40
# 44/44 [==============================] - 2s 39ms/step - loss: 0.3754 - accuracy: 0.8578 - val_loss: 0.4388 - val_accuracy: 0.8210
# Epoch 30/40
# 44/44 [==============================] - 2s 35ms/step - loss: 0.3711 - accuracy: 0.8677 - val_loss: 0.4341 - val_accuracy: 0.8253
# Epoch 31/40
# 44/44 [==============================] - 2s 44ms/step - loss: 0.3726 - accuracy: 0.8624 - val_loss: 0.4292 - val_accuracy: 0.8267
# Epoch 32/40
# 44/44 [==============================] - 2s 48ms/step - loss: 0.3544 - accuracy: 0.8692 - val_loss: 0.4287 - val_accuracy: 0.8281
# Epoch 33/40
# 44/44 [==============================] - 1s 33ms/step - loss: 0.3796 - accuracy: 0.8592 - val_loss: 0.4469 - val_accuracy: 0.8182
# Epoch 34/40
# 44/44 [==============================] - 2s 42ms/step - loss: 0.3758 - accuracy: 0.8587 - val_loss: 0.4295 - val_accuracy: 0.8267
# Epoch 35/40
# 44/44 [==============================] - 1s 23ms/step - loss: 0.3516 - accuracy: 0.8654 - val_loss: 0.4352 - val_accuracy: 0.8210
# Epoch 36/40
# 44/44 [==============================] - 1s 23ms/step - loss: 0.3708 - accuracy: 0.8645 - val_loss: 0.4320 - val_accuracy: 0.8267
# Epoch 37/40
# 44/44 [==============================] - 1s 23ms/step - loss: 0.3681 - accuracy: 0.8680 - val_loss: 0.4495 - val_accuracy: 0.8125
# Epoch 38/40
# 44/44 [==============================] - 2s 35ms/step - loss: 0.3657 - accuracy: 0.8599 - val_loss: 0.4181 - val_accuracy: 0.8324
# Epoch 39/40
# 44/44 [==============================] - 2s 49ms/step - loss: 0.3250 - accuracy: 0.8828 - val_loss: 0.4325 - val_accuracy: 0.8338
# Epoch 40/40
# 44/44 [==============================] - 1s 32ms/step - loss: 0.3564 - accuracy: 0.8707 - val_loss: 0.4299 - val_accuracy: 0.8295

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(x_train)
print(y_pred)
cf_matrix = confusion_matrix(one_hot_y_train ,  y_pred)
print(cf_matrix)
# Out:
# [[6.0959475e-04 6.8257243e-05 9.9932218e-01]
#  [3.6171490e-01 2.3982221e-02 6.1430287e-01]
#  [4.3283859e-03 2.2672111e-01 7.6895052e-01]
#  ...
#  [5.4476350e-03 9.9930897e-02 8.9462149e-01]
#  [9.9394011e-01 6.0519185e-03 7.9550964e-06]
#  [9.0634378e-05 9.7862500e-01 2.1284420e-02]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_11099/2827194891.py in <module>
#       2 y_pred = model.predict(x_train)
#       3 print(y_pred)
# ----> 4 cf_matrix = confusion_matrix(one_hot_y_train ,  y_pred)
#       5 print(cf_matrix)
#
# ~/miniconda3/envs/ciao-4.13/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/miniconda3/envs/ciao-4.13/lib/python3.8/site-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     297
#     298     """
# --> 299     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     300     if y_type not in ("binary", "multiclass"):
#     301         raise ValueError("%s is not supported" % y_type)
#
# ~/miniconda3/envs/ciao-4.13/lib/python3.8/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      90
#      91     if len(y_type) > 1:
# ---> 92         raise ValueError("Classification metrics can't handle a mix of {0} "
#      93                          "and {1} targets".format(type_true, type_pred))
#      94
#
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and continuous-multioutput targets
