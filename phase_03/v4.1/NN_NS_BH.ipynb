# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt

# %%
#display(data)
def filter_data(data):
    
    max_flux = 12
    min_flux = 26
    data = data[data['flux_aper']>max_flux]
    data = data[data['flux_aper']<min_flux]
    data = data[data['flux_aper_lolim']<min_flux]
    data = data[data['flux_aper_hilim']>(max_flux-2)]
    data = data[data['significance']>2]
    data = data.sample(frac=1)
    display(data.describe())
    data_class = data[['class']]
    data_id = data['src_id']
    data_name = data['src_name']
    data_val = data.drop(columns=['index' , 'livetime' , 'gti_obs' , 'significance' , 'likelihood' , 'class' ,'src_id' ,'src_name'])
    data_sig = data[['significance']]
    #display(data_val)
    import missingno as msno
    msno.matrix(data_val)
    plt.show()

    data_val = data_val.replace(np.nan , 0)

    for d in data_val:
        mean = np.mean(data_val[d])
        var = np.var(data_val[d])
        data_val[d] = (data_val[d]-mean)/var
        data_val[d] = data_val[d] / np.amax(data_val[d])
    #msno.matrix(data_val)
    #plt.show()
    return data , data_val , data_class , data_id , data_sig

# %%
train_bh = pd.read_csv('processed_data/BH_train.csv')
train_bh = train_bh.sample(frac=1)
#display(data_bh)
display(train_bh.describe())
train_ns = pd.read_csv('processed_data/NS_train.csv')
train_ns = train_ns.sample(frac=1)
#display(data_ns)
display(train_ns.describe())


train_pulsar = pd.read_csv('processed_data/PULSAR.csv')
display(train_pulsar.describe())
train_cv = pd.read_csv('processed_data/CV.csv')
train_cv.describe()
train_cv= train_cv.sample(frac=1)
train = pd.concat([train_bh , train_ns ] , axis=0)
train =  train.sample(frac=1)

train_data ,  data_val , data_class , data_id , data_sig = filter_data(train)
# Out:
#             index       livetime  significance     likelihood  \
# count  178.000000     178.000000    178.000000     178.000000
# mean    15.955056   54006.798315    144.960225  186409.489936
# std     20.396582   50232.118451    157.307164  225226.368097
# min      0.000000    4256.000000      1.840000      11.367330
# 25%      2.000000   18909.425000     12.970000    1205.131000
# 50%      6.000000   38737.400000     23.630000    3822.529000
# 75%     25.750000   69689.200000    337.000000  462011.400000
# max     70.000000  184208.000000    337.000000  462011.400000
#
#        var_inter_sigma  var_inter_prob  var_inter_index     var_max  \
# count     1.750000e+02      175.000000       175.000000  123.000000
# mean      2.014916e-04        0.795570         5.881714    0.021851
# std       2.334703e-04        0.171788         1.968811    0.044911
# min       1.352975e-07        0.302750         0.750000    0.000105
# 25%       5.171680e-07        0.822000         5.200000    0.000396
# 50%       9.064600e-06        0.830200         7.000000    0.001471
# 75%       4.811690e-04        0.847800         7.000000    0.010398
# max       4.811690e-04        1.000000         8.000000    0.231332
#
#           var_min    var_mean  ...  flux_brems_lolim  flux_brems_hilim  \
# count  123.000000  123.000000  ...         43.000000         43.000000
# mean     0.020576    0.021014  ...         12.279440         12.205298
# std      0.044475    0.044613  ...          1.026341          0.948997
# min      0.000057    0.000061  ...         10.999566         10.982967
# 25%      0.000240    0.000246  ...         11.371631         11.351689
# 50%      0.000690    0.000742  ...         11.849858         11.816730
# 75%      0.006612    0.008171  ...         13.088610         13.031108
# max      0.230371    0.230462  ...         14.354381         14.233364
#
#        brems_kt_hilim  brems_kt_lolim  brems_nh_hilim  brems_nh_lolim  \
#
# count  95.000000      95.000000     95.000000     95.000000     6.400000e+01
# mean    3.800000   38167.429474     34.787368  13917.093891     1.569417e-05
# std     6.295219   34566.563684     43.706247  22823.233977     2.432501e-05
# min     0.000000    3903.900000      1.840000     23.550950     3.031800e-07
# 25%     0.000000   10162.000000      5.690000    390.680900     4.354550e-07
# 50%     1.000000   24735.600000     12.860000    767.561600     1.856350e-06
# 75%     4.000000   49106.450000     34.310000   7690.349500     1.984400e-05
# max    24.000000  166935.300000    144.290000  62909.280000     8.061540e-05
#
#        var_inter_prob  var_inter_index     var_max    var_min   var_mean  ...  \
# count       64.000000        64.000000   91.000000  91.000000  91.000000  ...
# mean         0.549704         3.207812   10.811307   0.008486   0.027849  ...
# std          0.237813         1.819018  103.045688   0.014996   0.183337  ...
# min          0.099000         0.000000    0.000150   0.000068   0.000105  ...
# 25%          0.435812         2.062500    0.001266   0.000715   0.000823  ...
# 50%          0.594000         3.200000    0.003089   0.001824   0.002029  ...
# 75%          0.782800         5.000000    0.012217   0.011797   0.012088  ...
# max          0.900000         6.200000  983.002387   0.073643   1.751740  ...
#
#        flux_brems_lolim  flux_brems_hilim  brems_kt_hilim  brems_kt_lolim  \
# count         40.000000         40.000000       32.000000       40.000000
# mean          12.745523         12.679084      172.910084       15.949073
# std            0.599896          0.555087      809.731605       25.729744
# min           11.726999         11.693146        0.522700        0.409700
# 25%           12.286735         12.255141        5.523500        4.222000
# 50%           12.535139         12.505852        6.167500        5.092500
# 75%           13.355166         13.203847        7.161000        6.587500
# max           13.901702         13.773916     4544.000000       93.450000
#
#        brems_nh_hilim  brems_nh_lolim  bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  \
# count       40.000000       21.000000    40.000000    40.000000    40.000000
# mean        65.215895       94.668162     1.084760     0.857302    18.581310
# std        103.320202       91.493272     1.148652     0.680336    37.163859
# min          0.733300        0.296400     0.185600     0.163100     0.104400
# 25%          2.864000       35.960000     0.588850     0.525050     0.361625
# 50%         18.955000       71.940000     0.634600     0.582650     1.045500
# 75%         98.405000      145.400000     0.866600     0.817975    17.155000
# max        519.700000      379.300000     5.770000     3.038000   182.100000
#
#        bb_nh_lolim
# count    13.000000
# mean     25.214215
# std      28.506009
# min       0.242800
# 25%       4.938000
# 50%      11.790000
# 75%      40.620000
# max      87.780000
#
# [8 rows x 66 columns]
#             index       livetime  significance     likelihood  \
# count  436.000000     436.000000    436.000000   4.360000e+02
# mean    17.809633   33533.693119     74.466101            inf
# std     23.511269   39790.159100    112.466350            inf
# min      0.000000     977.000000      2.110000   1.136733e+01
# 25%      2.000000    5077.625000     12.970000   4.582053e+02
# 50%      7.000000   24046.100000     28.020000   1.934920e+03
# 75%     24.250000   39663.475000     49.260000   1.181523e+04
# max     94.000000  184208.000000    476.940000  1.797693e+308
#
#        var_inter_sigma  var_inter_prob  var_inter_index     var_max  \
# count     3.960000e+02      396.000000       396.000000  311.000000
# mean      4.507791e-04        0.839529         6.158502    0.015672
# std       1.810711e-03        0.202917         2.165424    0.068593
# min       3.593717e-08        0.126000         0.000000    0.000105
# 25%       1.131475e-06        0.772250         4.500000    0.000722
# 50%       7.351000e-06        0.859000         7.000000    0.002258
# 75%       1.065084e-04        1.000000         8.000000    0.007477
# max       2.225360e-02        1.000000         8.000000    1.128588
#
#           var_min    var_mean  ...  flux_brems_lolim  flux_brems_hilim  \
# count  311.000000  311.000000  ...         72.000000         72.000000
# mean     0.007871    0.009661  ...         12.688031         12.601176
# std      0.019712    0.021791  ...          0.702601          0.636277
# min      0.000057    0.000061  ...         11.472370         11.449283
# 25%      0.000468    0.000504  ...         12.177783         12.134664
# 50%      0.001331    0.001496  ...         12.479616         12.434255
# 75%      0.004337    0.005858  ...         13.210228         13.079791
# max      0.203490    0.203719  ...         14.354381         14.233364
#
#        brems_kt_hilim  brems_kt_lolim  brems_nh_hilim  brems_nh_lolim  \
# count       70.000000       72.000000       72.000000       70.000000
# mean         3.135317        2.580017      203.834010      172.177632
# std          4.184190        4.614479      432.506747      383.192570
# min          0.357500        0.289700        0.648700        0.083260
# 25%          0.740250        0.654100       19.342500       16.647500
# 50%          1.428000        1.181000       44.400000       36.825000
# 75%          4.183500        2.724750       78.575000       58.615000
# max         24.980000       32.540000     1627.000000     1485.000000
#
#        bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  bb_nh_lolim
# count    72.000000    72.000000    72.000000    44.000000
# mean      0.561328     0.487911   145.161122   184.236659
# std       0.336814     0.261147   343.087309   359.124767
# min       0.216200     0.189000     0.077480     0.000000
# 25%       0.326350     0.288000     0.991300    15.187500
# 50%       0.441850     0.390700    22.065000    21.760000
# 75%       0.772400     0.689075    38.960000    75.015000
# max       2.187000     1.651000  1299.000000  1169.000000
#
# [8 rows x 96 columns]

# %%
train_data[['flux_aper_hilim' , 'flux_aper_lolim' ,'flux_aper']].describe()
# Out:
#        flux_aper_hilim  flux_aper_lolim   flux_aper
# count       436.000000       436.000000  436.000000
# mean         13.893939        14.458790   14.152057
# std           0.788264         1.090452    0.890480
# min          11.997434        12.022661   12.009448
# 25%          13.373786        13.772354   13.603988
# 50%          13.908669        14.432731   14.193013
# 75%          14.414897        15.178032   14.741801
# max          15.619355        17.809276   16.652865

# %%
data_bh_clean = train_data[data_class['class']=='BH']
display(data_bh_clean.describe())
data_ns_clean = train_data[data_class['class']=='NS']
display(data_ns_clean.describe())
# Out:
#             index       livetime  significance     likelihood  \
# count  139.000000     139.000000    139.000000     139.000000
# mean    11.201439   62067.446043    123.827338  155204.757680
# std     16.216461   53473.631829    150.886301  216634.472279
# min      0.000000    4490.400000      2.110000      11.367330
# 25%      1.000000   24613.300000     13.950000    1205.131000
# 50%      5.000000   40580.400000     17.390000    1457.845000
# 75%     10.500000   75682.200000    337.000000  462011.400000
# max     70.000000  184208.000000    337.000000  462011.400000
#
#        var_inter_sigma  var_inter_prob  var_inter_index     var_max  \
# count     1.360000e+02      136.000000       136.000000  103.000000
# mean      1.689480e-04        0.784533         5.682721    0.005435
# std       2.254513e-04        0.173522         2.016436    0.013078
# min       1.352975e-07        0.302750         0.750000    0.000105
# 25%       5.171680e-07        0.678612         4.125000    0.000343
# 50%       1.771040e-06        0.830200         7.000000    0.000632
# 75%       4.811690e-04        0.847800         7.000000    0.003474
# max       4.811690e-04        1.000000         8.000000    0.085673
#
#           var_min    var_mean  ...  flux_brems_lolim  flux_brems_hilim  \
# count

#
#        bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  bb_nh_lolim
# count    48.000000    48.000000    48.000000    29.000000
# mean      0.471777     0.418546    38.278848    42.355966
# std       0.346231     0.275468    96.542713    83.090430
# min       0.216200     0.189000     0.077480     0.000000
# 25%       0.285475     0.274125     1.045750    14.900000
# 50%       0.347050     0.307300    19.980000    20.850000
# 75%       0.514500     0.471000    29.612500    27.270000
# max       2.187000     1.651000   659.700000   455.500000
#
# [8 rows x 96 columns]

# %%
def split_data(x,y,s,id,frac):
    split_no = int(len(y)*frac )
    x_train = x[:split_no]
    x_test = x[split_no:]
    y_train = y[:split_no]
    y_test = y[split_no:]
    s_train = s[:split_no]
    s_test = s[split_no:]
    id_train = id[:split_no]
    id_test = id[split_no:]
    return (x_train , y_train , s_train , id_train ) , (x_test , y_test , s_test , id_test)

x = data_val.to_numpy()
y = data_class.to_numpy()
s = data_sig.to_numpy()
s = s/np.amax(s)
#s = [float(si) for si in s]
(x_train , y_train , s_train , id_train) , (x_test , y_test , s_test , id_test) =  split_data(x, y,s, data_id , 1)
print(x_train.shape , y_train.shape)
print(x_test.shape , y_test.shape)
# Out:
# (436, 92) (436, 1)
# (0, 92) (0, 1)

# %% [markdown]
# # Neural Network

# %%
def class_to_int(label , cl):
    temp = []
    for i in range(len(label)):
        #print(label[i])
        for j in range(len(cl)):
            if(label[i]==cl[j]):
                temp.append(j) 
    return temp
classes = ['BH' ,'NS' ]
y_train_int = class_to_int(y_train, classes)
#y_test_int = class_to_int(y_test, classes)
one_hot_y_train =  to_categorical(y_train_int)
#one_hot_y_test =  to_categorical(y_test_int)
#for y_i , y_j in zip(y_train , one_hot_y_train):
##    print(y_i , y_j)

# %%
desc_class = pd.DataFrame()
y_class_ser = (np.asarray(y_train).reshape(len(y_train)))
desc_class.insert(0, 'cl', y_class_ser)
ns_n = desc_class.value_counts()['NS']
bh_n= desc_class.value_counts()['BH']
print(ns_n , bh_n)
# Out:
# 297 139

# %%
def model_gen(shape , input_len):

    inputs =  keras.Input(shape=(input_len,))
    dense =  layers.Dense(32, activation='relu')
    x = dense(inputs)
    #x =  layers.BatchNormalization(axis=-1)(x)
    
    x = layers.Dense(32, activation='relu')(x)
    x = layers.Dense(32, activation='relu')(x)
    #x =  layers.BatchNormalization(axis=-1)(x)
    #x = layers.Dropout(0.3)(x)
    x = layers.Dense(16, activation='relu')(x)
    #x = layers.Dense(4, activation='relu')(x)
    #x =  layers.BatchNormalization(axis=-1)(x)
    #x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(2 , activation='softmax')(x)
    model = keras.Model(inputs=inputs , outputs=outputs , name='trial_model')
    model.compile(
        loss = "categorical_crossentropy",
        optimizer = keras.optimizers.Adam(learning_rate=0.0005),
        metrics = ["accuracy"],
    )
    return model
model = model_gen([32,32,16,8] , x_train.shape[1])
class_weight = {0: (ns_n/(ns_n+bh_n)),
                1: (bh_n/(ns_n+bh_n))}
history = model.fit(x_train, one_hot_y_train, batch_size=32, epochs=70, validation_split=0.2 , class_weight=class_weight , sample_weight=s_train)
# Out:
# 2021-10-06 01:22:50.169799: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-10-06 01:22:50.170130: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-06 01:22:50.170535: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2021-10-06 01:22:50.316187: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-10-06 01:22:50.334682: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 1800000000 Hz
# Epoch 1/70
# 11/11 [==============================] - 3s 128ms/step - loss: 0.0537 - accuracy: 0.3347 - val_loss: 0.0872 - val_accuracy: 0.2500
# Epoch 2/70
# 11/11 [==============================] - 0s 35ms/step - loss: 0.0479 - accuracy: 0.3704 - val_loss: 0.0854 - val_accuracy: 0.2500
# Epoch 3/70
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0437 - accuracy: 0.3235 - val_loss: 0.0832 - val_accuracy: 0.2614
# Epoch 4/70
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0375 - accuracy: 0.3311 - val_loss: 0.0807 - val_accuracy: 0.2955
# Epoch 5/70
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0371 - accuracy: 0.3622 - val_loss: 0.0783 - val_accuracy: 0.3864
# Epoch 6/70
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0343 - accuracy: 0.4742 - val_loss: 0.0762 - val_accuracy: 0.4545
# Epoch 7/70
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0324 - accuracy: 0.5572 - val_loss: 0.0733 - val_accuracy: 0.5227
# Epoch 8/70
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0335 - accuracy: 0.5152 - val_loss: 0.0709 - val_accuracy: 0.5341
# Epoch 9/70
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0301 - accuracy: 0.5731 - val_loss: 0.0724 - val_accuracy: 0.5455
# Epoch 10/70
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0316 - accuracy: 0.6088 - val_loss: 0.0674 - val_accuracy: 0.5227
# Epoch 11/70
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0246 - accuracy: 0.5712 - val_loss: 0.0644 - val_accuracy: 0.5227
# Epoch 12/70
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0259 - accuracy: 0.5919 - val_loss: 0.0633 - val_accuracy: 0.5227
# Epoch 13/70
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0240 - accuracy: 0.6131 - val_loss: 0.0629 - val_accuracy: 0.5227
# Epoch 14/70
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0201 - accuracy: 0.6083 - val_loss: 0.0583 - val_accuracy: 0.5455
# Epoch 15/70
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0196 - accuracy: 0.6261 - val_loss: 0.0534 - val_accuracy: 0.5682
# Epoch 16/70
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0170 - accuracy: 0.6178 - val_loss: 0.0548 - val_accuracy: 0.5682
# Epoch 17/70
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0167 - accuracy: 0.6773 - val_loss: 0.0532 - val_accuracy: 0.5795
# Epoch 18/70
# 11/11 [==============================] - 1s 102ms/step - loss: 0.0173 - accuracy: 0.6644 - val_loss: 0.0462 - val_accuracy: 0.6477
# Epoch 19/70
# 11/11 [==============================] - 0s 35ms/step - loss: 0.0147 - accuracy: 0.7022 - val_loss: 0.0456 - val_accuracy: 0.6818
# Epoch 20/70
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0129 - accuracy: 0.7148 - val_loss: 0.0434 - val_accuracy: 0.6932
# Epoch 21/70
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0130 - accuracy: 0.7589 - val_loss: 0.0371 - val_accuracy: 0.7273
# Epoch 22/70
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0116 - accuracy: 0.7607 - val_loss: 0.0371 - val_accuracy: 0.7273
# Epoch 23/70
# 11/11 [==============================] - 0s 34ms/step - loss: 0.0094 - accuracy: 0.8184 - val_loss: 0.0331 - val_accuracy: 0.7273
# Epoch 24/70
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0117 - accuracy: 0.7823 - val_loss: 0.0288 - val_accuracy: 0.8068
# Epoch 25/70
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0098 - accuracy: 0.8209 - val_loss: 0.0312 - val_accuracy: 0.7614
# Epoch 26/70
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0097 - accuracy: 0.8624 - val_loss: 0.0255 - val_accuracy: 0.8068
# Epoch 27/70
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0084 - accuracy: 0.8831 - val_loss: 0.0240 - val_accuracy: 0.8182
# Epoch 28/70
# 11/11 [==============================] - 0s 46ms/step - loss: 0.0072 - accuracy: 0.8734 - val_loss: 0.0244 - val_accuracy: 0.8182
# Epoch 29/70
# 11/11 [==============================] - 0s 41ms/step - loss: 0.
# 11/11 [==============================] - 0s 34ms/step - loss: 0.0034 - accuracy: 0.9256 - val_loss: 0.0137 - val_accuracy: 0.8636
# Epoch 57/70
# 11/11 [==============================] - 0s 49ms/step - loss: 0.0027 - accuracy: 0.9478 - val_loss: 0.0129 - val_accuracy: 0.8750
# Epoch 58/70
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0027 - accuracy: 0.9398 - val_loss: 0.0143 - val_accuracy: 0.8636
# Epoch 59/70
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0031 - accuracy: 0.9268 - val_loss: 0.0127 - val_accuracy: 0.8864
# Epoch 60/70
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0025 - accuracy: 0.9507 - val_loss: 0.0133 - val_accuracy: 0.8636
# Epoch 61/70
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0027 - accuracy: 0.9493 - val_loss: 0.0141 - val_accuracy: 0.8750
# Epoch 62/70
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0021 - accuracy: 0.9436 - val_loss: 0.0133 - val_accuracy: 0.8750
# Epoch 63/70
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0020 - accuracy: 0.9522 - val_loss: 0.0132 - val_accuracy: 0.8750
# Epoch 64/70
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0019 - accuracy: 0.9573 - val_loss: 0.0140 - val_accuracy: 0.8750
# Epoch 65/70
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0021 - accuracy: 0.9467 - val_loss: 0.0120 - val_accuracy: 0.8864
# Epoch 66/70
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0022 - accuracy: 0.9453 - val_loss: 0.0133 - val_accuracy: 0.8636
# Epoch 67/70
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0018 - accuracy: 0.9466 - val_loss: 0.0135 - val_accuracy: 0.8636
# Epoch 68/70
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0021 - accuracy: 0.9463 - val_loss: 0.0128 - val_accuracy: 0.8750
# Epoch 69/70
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0018 - accuracy: 0.9577 - val_loss: 0.0132 - val_accuracy: 0.8750
# Epoch 70/70
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0020 - accuracy: 0.9492 - val_loss: 0.0131 - val_accuracy: 0.8750

# %%
#from tensorflow.keras.layers import Flatten
#from tensorflow.keras.layers.convolutional import Conv2D
#from tensorflow.keras.layers.pooling import MaxPooling2D
visible = layers.Input(shape=(92,1))
#x = layers.BatchNormalization(axis=-1)(visible)
x = layers.Conv1D(60, kernel_size=4, activation='relu')(visible)
x = layers.MaxPool1D(pool_size=(2))(x)

x = layers.Conv1D(32, kernel_size=4, activation='relu')(x)
x = layers.MaxPool1D(pool_size=(2))(x)
x = layers.Conv1D(16, kernel_size=4, activation='relu')(x)
x = layers.MaxPooling1D(pool_size=(2))(x)
#x = layers.Conv1D(32, kernel_size=4, activation='relu')(x)
x = layers.MaxPooling1D(pool_size=(2))(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation='relu')(x)
#x = layers.Dense(10, activation='relu')(x)
output = layers.Dense(2, activation='sigmoid')(x)
model_cnn = keras.Model(inputs=visible, outputs=output)
# summarize layers
#print(model_cnn.summary())
model_cnn.compile(
        loss = "categorical_crossentropy",
        optimizer = keras.optimizers.Adam(learning_rate=0.0005),
        metrics = ["accuracy"],
    )
history = model_cnn.fit(x_train, one_hot_y_train, batch_size=128, epochs=80, validation_split=0.2)
# Out:
# Epoch 1/80
# 3/3 [==============================] - 3s 609ms/step - loss: 0.7053 - accuracy: 0.3626 - val_loss: 0.6954 - val_accuracy: 0.5227
# Epoch 2/80
# 3/3 [==============================] - 0s 164ms/step - loss: 0.6889 - accuracy: 0.5582 - val_loss: 0.6815 - val_accuracy: 0.7500
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(hist['accuracy'] , label = 'accuracy' , color='k')
plt.plot(hist['val_accuracy'] , label = 'val_accuracy' , color='crimson')
plt.xlabel('No of epochs')
plt.legend()
plt.subplot(1,2,2)
plt.plot(hist['loss'] , label = 'loss' , color='k')
plt.plot(hist['val_loss'] , label='val_loss' , color='crimson')
plt.xlabel("No of Epochs")
plt.legend()
#plt.savefig('plots/NS_BH.png')
plt.show()

# %%
model.save('models/NN_NS_BH.mdl')
#np.save('test_data/NN_NS_BH.cv' , x_test)
#np.save('test_data/NN_NS_BH_label.cv' , one_hot_y_test)
# Out:
# 2021-09-28 16:09:59.981835: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: models/NN_NS_BH.mdl/assets

# %%
import seaborn as sns

# %%
# %reload_ext autoreload

# %%
# %autoreload 2
#from my_utils.score import test_func , conf_matrix
from my_utils.print_lines import *

# %%
font = {'size'   : 14}
plt.rc('font', **font)

# %%
def conf_matrix(model ,x, oh_yt , plot=0):
    '''
    return confusion matrix
    Parameters :
        model -  Keras model
        x - test/training data
        oh_yt =  one hot encoded test labels
    '''
    y_pred_prob = model.predict(x)
    #y_pred=  [np.argmax(yi) for yi in y_pred]
    y_pred = []
    for yi in y_pred_prob:
        temp = [0]*len(yi)
        temp[np.argmax(yi)] = 1
        y_pred.append(temp)
    y_pred =  np.asarray(y_pred)
    #print(y)
    cf = np.matmul(oh_yt.T , y_pred)
    return cf

# %%
cf = conf_matrix(model , x_train, one_hot_y_train)
c = np.asarray([[ci /sum(c_row) for ci in c_row] for c_row in cf])
fig , ax = plt.subplots(nrows=1 , ncols=2 , figsize=(12,4)) 
#ax = 
sns.heatmap(c, annot=True, fmt='g', ax=ax[0]);  #annot=True to annotate cells, ftm='g' to disable scientific notation
sns.heatmap(cf, annot=True, fmt='g', ax=ax[1]); 
# labels, title and ticks
for a in ax:
    a.set_xlabel('Predicted labels')
    a.set_ylabel('True labels'); 
    #ax[0].set_title('Confusion Matrix Test Data'); 
    a.xaxis.set_ticklabels(['BH', 'NS']); 
    a.yaxis.set_ticklabels(['BH', 'NS'])
plt.suptitle('confusion matrix on train data')
#plt.savefig('plots/cf_ns_bh_test.jpg')
plt.show()
plt.close()

# %% [markdown]
# ## TEST

# %%
test_bh = pd.read_csv('processed_data/BH_test.csv')
display(test_bh.describe())
test_ns = pd.read_csv('processed_data/NS_test.csv')
test_pulsar = pd.read_csv('processed_data/PULSAR.csv')
test_cv = pd.read_csv('processed_data/CV.csv')
test = pd.concat([test_bh , test_ns ] , axis=0)
test = test.sample(frac=1)
test_data , t_val , t_class , t_id , t_sig = filter_data(test)


t_class_int = class_to_int(t_class.to_numpy(),  classes)
#y_test_int = class_to_int(y_test, classes)
one_hot_t_class =  to_categorical(t_class_int)
x_test = t_val.to_numpy()
display(t_val.describe())
one_hot_y_test =  to_categorical(t_class_int)
print(one_hot_y_test.shape)
#for y_i , y_j in zip(y_train , one_hot_y_train):
##    print(y_i , y_j)
# Out:
#            index       livetime  significance     likelihood  var_inter_sigma  \
# count  32.000000      32.000000     32.000000      32.000000     3.200000e+01
# mean    3.781250   74257.984375     47.182187   34247.608181     8.815325e-04
# std     2.744312   63221.523341     64.813123   63213.009603     1.655440e-03
# min     0.000000    4256.000000      4.580000      82.894680     4.139120e-07
# 25%     1.750000   15043.050000      4.580000      82.894680     4.139120e-07
# 50%     3.500000   57983.550000     16.290000    1238.383000     1.426325e-06
# 75%     6.000000  129113.000000     26.510000    4017.937000     9.395600e-05
# max     9.000000  184208.000000    166.940000  151803.000000     3.960122e-03
#
#        var_inter_prob  var_inter_index    var_max    var_min   var_mean  ...  \
# count       32.000000        32.000000  23.000000  23.000000  23.000000  ...
# mean         0.863113         5.981250   0.609907   0.340178   0.461090  ...
# std          0.105178         1.132635   1.214688   0.881511   0.985913  ...
# min          0.761000         4.800000   0.000190   0.000065   0.000137  ...
# 25%          0.761000         4.800000   0.000335   0.000190   0.000196  ...
# 50%          0.807400         5.500000   0.000475   0.000300   0.000307  ...
# 75%          0.992800         7.200000   0.614308   0.091091   0.397784  ...
# max          0.997200         7.600000   4.403000   3.219000   3.219000  ...
#
#        flux_brems_lolim  flux_brems_hilim  brems_kt_hilim  brems_kt_lolim  \
# count          5.000000          5.000000        3.000000        5.000000
# mean          11.243918         11.211909      138.095333       36.092600
# std            0.612477          0.602681      133.554931       33.140291
# min           10.713993         10.694434        1.686000        1.523000
# 25%           11.014978         10.990124       72.843000       16.290000
# 50%           11.068237         11.033905      144.000000       21.710000
# 75%           11.119701         11.085921      206.300000       59.620000
# max           12.302683         12.255160      268.600000       81.320000
#
#        brems_nh_hilim  brems_nh_lolim  bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  \
# count        5.000000        5.000000     5.000000     5.000000     5.000000
# mean      1047.746200      958.628400     2.105700     1.708460   794.187800
# std        585.095119      534.325368     1.155831     0.692874   449.828726
# min          9.731000        5.142000     0.770500     0.732300     1.439000
# 25%       1205.000000     1143.000000     1.872000     1.632000   870.100000
# 50%       1290.000000     1184.000000     1.886000     1.675000   982.400000
# 75%       1319.000000     1219.000000     2.036000     1.821000  1055.000000
# max       1415.000000     1242.000000     3.964000     2.682000  1062.000000
#
#        bb_nh_lolim
# count       4.0000
# mean      887.1250
# std        88.3377
# min       777.3000
# 25%       844.2000
# 50%       892.0500
# 75%       934.9750
# max       987.1000
#
# [8 rows x 96 columns]
#           index       livetime  significance    likelihood  var_inter_sigma  \
# count  35.00000      35.000000     35.000000     35.000000     3.500000e+01
# mean    2.60000   58672.694286     15.409143   1934.018203     5.239268e-05
# std     2.58047   59599.310896     11.054052   3820.019408     9.665966e-05
# min     0.00000    1079.800000      4.580000     82.894680     3.118000e-08
# 25%     1.00000   11296.650000      6.980000    140.316400     4.139120e-07
# 50%     2.00000   36445.900000     16.290000    289.506100     5.484750e-06
# 75%     4.00000   75682.200000     16.720000   1238.383000     8.867133e-05
# max     9.00000  184208.000000     49.440000  16287.030000     3.924485e-04
#
#        var_inter_prob  var_inter_index    var_max    var_min   var_mean  ...  \
# count       35.000000        35.000000  28.000000  28.000000  28.000000  ...
# mean         0.826643         5.557143   0.016824   0.005761   0.007337  ...
# std          0.167324         1.644233   0.052208   0.017553   0.018741  ...
# min          0.270500         1.500000   0.000190   0.000065   0.000137  ...
# 25%          0.794000         4.800000   0.000389   0.000192   0.000203  ...
# 50%          0.807400         4.800000   0.000827   0.000447   0.000487  ...
# 75%          0.997200         7.600000   0.004526   0.003072   0.004281  ...
# max          1.000000         8.000000   0.264078   0.091976   0.092224  ...
#
#        flux_brems_lolim  flux_brems_hilim  brems_kt_hilim  brems_kt_lolim  \
# 50%    6.571568e-02  ...     -1.960306e-01     -1.981752e-01   -5.602454e-02
# 75%    3.036062e-01  ...     -1.960306e-01     -1.981752e-01   -5.602454e-02
# max    1.000000e+00  ...      1.000000e+00      1.000000e+00    1.000000e+00
#
#        brems_kt_lolim  brems_nh_hilim  brems_nh_lolim   bb_kt_hilim  \
# count    3.500000e+01    3.500000e+01    3.500000e+01  3.500000e+01
# mean    -1.863589e-17   -3.568574e-18   -1.288652e-17  1.566207e-17
# std      1.747097e-01    1.750482e-01    1.745840e-01  1.742221e-01
# min     -3.572641e-02   -3.655824e-02   -3.314637e-02 -3.179590e-02
# 25%     -3.572641e-02   -3.655824e-02   -3.314637e-02 -3.179590e-02
# 50%     -3.572641e-02   -3.655824e-02   -3.314637e-02 -3.179590e-02
# 75%     -3.572641e-02   -3.655824e-02   -3.314637e-02 -3.179590e-02
# max      1.000000e+00    1.000000e+00    1.000000e+00  1.000000e+00
#
#         bb_kt_lolim   bb_nh_hilim   bb_nh_lolim
# count  3.500000e+01  3.500000e+01  3.500000e+01
# mean  -2.061843e-17  6.071532e-18 -5.749369e-18
# std    2.079215e-01  1.741136e-01  1.740023e-01
# min   -6.816478e-02 -3.102927e-02 -2.941176e-02
# 25%   -6.816478e-02 -3.102927e-02 -2.941176e-02
# 50%   -6.816478e-02 -3.102927e-02 -2.941176e-02
# 75%   -6.816478e-02 -3.102927e-02 -2.941176e-02
# max    1.000000e+00  1.000000e+00  1.000000e+00
#
# [8 rows x 92 columns]
# (35, 2)

# %%
cf = conf_matrix(model , x_test, one_hot_y_test)
c = np.asarray([[ci /sum(c_row) for ci in c_row] for c_row in cf])
fig , ax = plt.subplots(nrows=1 , ncols=2 , figsize=(12,4)) 
#ax = 
sns.heatmap(c, annot=True, fmt='g', ax=ax[0]);  #annot=True to annotate cells, ftm='g' to disable scientific notation
sns.heatmap(cf, annot=True, fmt='g', ax=ax[1]); 
# labels, title and ticks
for a in ax:
    a.set_xlabel('Predicted labels')
    a.set_ylabel('True labels')
    #ax[0].set_title('Confusion Matrix Test Data'); 
    a.xaxis.set_ticklabels(['BH', 'NS']) 
    a.yaxis.set_ticklabels(['BH', 'NS'])
plt.suptitle('confusion matrix on test data')
#plt.savefig('plots/cf_ns_bh_test.jpg')
plt.show()
plt.close()

# %%
y_test_pred_prob =  model.predict(x_test)
y_test_pred = []
for yi in y_test_pred_prob:
    temp = [0]*len(yi)
    temp[np.argmax(yi)] = 1
    y_test_pred.append(temp)
y_test_pred =  np.asarray(y_test_pred)
miss_cl_data = pd.DataFrame()
missed_src = []
for yp , yh , si ,  y_prob in zip(y_test_pred , one_hot_y_test , t_id , y_test_pred_prob):
    chk = np.dot(yp,yh)
    if(chk<1):
        #print(y_prob,  si)
        data_sneak = test[test['src_id'] == si]
        display(data_sneak)
        miss_cl_data = miss_cl_data.append(data_sneak)
        missed_src.append(si)
miss_src_cnt =  pd.DataFrame()
miss_src_cnt.insert(0,'src' ,missed_src)
miss_src_cnt = miss_src_cnt['src'].value_counts()
display(miss_src_cnt)
display(miss_cl_data)
#missed_src_count = missed_src.count_val()
# Out:
#     index class  src_id              src_name  livetime  significance  \
# 10      3    BH  BH0009  SAX J1819.3-2525       18284.8         26.51
# 9       2    BH  BH0009  SAX J1819.3-2525        9209.3         26.51
# 7       0    BH  BH0009  SAX J1819.3-2525       25256.9         26.51
# 11      4    BH  BH0009  SAX J1819.3-2525       36445.9         26.51
# 8       1    BH  BH0009  SAX J1819.3-2525        4256.0         26.51
#
#     likelihood              gti_obs  var_inter_sigma  var_inter_prob  ...  \
# 10    4017.937  2004-07-30T18:26:28         0.000094          0.9972  ...
# 9     4017.937  2004-07-17T11:09:06         0.000094          0.9972  ...
# 7     4017.937  2002-10-21T03:50:49         0.000094          0.9972  ...
# 11    4017.937  2004-08-10T04:39:07         0.000094          0.9972  ...
# 8     4017.937  2002-08-05T04:22:47         0.000094          0.9972  ...
#
#     flux_brems_lolim  flux_brems_hilim  brems_kt_hilim  brems_kt_lolim  \
# 10               NaN               NaN             NaN             NaN
# 9          12.302683          12.25516             NaN           81.32
# 7                NaN               NaN             NaN             NaN
# 11               NaN               NaN             NaN             NaN
# 8                NaN               NaN             NaN             NaN
#
#     brems_nh_hilim  brems_nh_lolim  bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  \
# 10             NaN             NaN          NaN          NaN          NaN
# 9            9.731           5.142        3.964        2.682        1.439
# 7              NaN             NaN          NaN          NaN          NaN
# 11             NaN             NaN          NaN          NaN          NaN
# 8              NaN             NaN          NaN          NaN          NaN
#
#     bb_nh_lolim
# 10          NaN
# 9           NaN
# 7           NaN
# 11          NaN
# 8           NaN
#
# [5 rows x 100 columns]
#    index class  src_id              src_name  livetime  significance  \
# 5      0    NS  NS0059  J1749-2808              1079.8          6.98
# 6      1    NS  NS0059  J1749-2808             24403.2          6.98
#
#    likelihood              gti_obs  var_inter_sigma  var_inter_prob  ...  \
# 5     241.424  2010-04-25T12:41:05     3.118000e-08          0.2705  ...
# 6     241.424  2012-07-30T02:38:34     3.118000e-08          0.2705  ...
#
#    flux_brems_lolim  flux_brems_hilim  brems_kt_hilim  brems_kt_lolim  \
# 5               NaN               NaN             NaN             NaN
# 6               NaN               NaN             NaN             NaN
#
#    brems_nh_hilim  brems_nh_lolim  bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  \
# 5             NaN             NaN          NaN          NaN          NaN
# 6             NaN             NaN          NaN          NaN          NaN
#
#    bb_nh_lolim
# 5          NaN
# 6          NaN
#
# [2 rows x 100 columns]
#     index class  src_id              src_name  livetime  significance  \
# 20      8    BH  BH0017  CXOU J100510.9-07453   69686.1          4.58
# 12      0    BH  BH0017  CXOU J100510.9-07453   40580.4          4.58
# 15      3    BH  BH0017  CXOU J100510.9-07453   75554.3          4.58
# 14      2    BH  BH0017  CXOU J100510.9-07453  171955.9          4.58
# 18      6    BH  BH0017  CXOU J100510.9-07453  160215.7          4.58
# 19      7    BH  BH0017  CXOU J100510.9-07453  119470.1          4.58
# 21      9    BH  BH0017  CXOU J100510.9-07453   46277.9          4.58
# 13      1    BH  BH0017  CXOU J100510.9-07453   75682.2          4.58
# 17      5    BH  BH0017  CXOU J100510.9-07453  158013.8          4.58
# 16      4    BH  BH0017  CXOU J100510.9-07453  184208.0          4.58
#
#     likelihood              gti_obs  var_inter_sigma  var_inter_prob  ...  \
# 20    82.89468  2012-04-06T18:15:48         0.000001           0.761  ...
# 12    82.89468  2010-01-27T01:02:52         0.000001           0.761  ...
# 15    82.89468  2012-01-26T22:21:59         0.000001           0.761  ...
# 14    82.89468  2012-01-18T14:26:38         0.000001           0.761  ...
# 18    82.89468  2012-01-21T08:54:47         0.000001           0.761  ...
# 19    82.89468  2012-04-04T03:00:56         0.000001           0.761  ...
# 21    82.89468  2012-04-05T19:03:53         0.000001           0.761  ...
# 13    82.89468  2010-01-29T14:46:35         0.000001           0.761  ...
# 17    82.89468  2012-02-03T10:00:00         0.000001           0.761  ...
# 16    82.89468  2012-01-31T15:24:33         0.000001           0.761  ...
#
#     flux_brems_lolim  flux_brems_hilim  brems_kt_hilim  brems_kt_lolim  \
# 20               NaN               NaN             NaN             NaN
# 12               NaN               NaN             NaN             NaN
# 15               NaN               NaN             NaN             NaN
# 14               NaN               NaN             NaN             NaN
# 18               NaN               NaN             NaN             NaN
# 19               NaN               NaN             NaN             NaN
# 21               NaN               NaN             NaN             NaN
# 13               NaN               NaN             NaN             NaN
# 17               NaN               NaN             NaN             NaN
# 16               NaN               NaN             NaN             NaN
#
#     brems_nh_hilim  brems_nh_lolim  bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  \
# 20             NaN             NaN          NaN          NaN          NaN
# 12             NaN             NaN          NaN          NaN          NaN
# 15             NaN             NaN          NaN          NaN          NaN
# 14             NaN             NaN          NaN          NaN          NaN
# 18             NaN             NaN          NaN          NaN          NaN
# 19             NaN             NaN          NaN          NaN          NaN
# 21             NaN             NaN          NaN          NaN          NaN
# 13             NaN             NaN          NaN          NaN          NaN
# 17             NaN             NaN          NaN          NaN          NaN
# 16             NaN             NaN          NaN          NaN          NaN
#
#     bb_nh_lolim
# 20          NaN
# 12          NaN
# 15          NaN
# 14          NaN
# 18          NaN
# 19          NaN
# 21          NaN
# 13          NaN
# 17          NaN
# 16          NaN
#
# [10 rows x 100 columns]
#     index class  src_id              src_name  livetime  significance  \
# 10      3    BH  BH0009  SAX J1819.3-2525       18284.8         26.51
# 9       2    BH  BH0009  SAX J1819.3-2525        9209.3         26.51
# 7       0    BH  BH0009  SAX J1819.3-2525       25256.9         26.51
# 11      4    BH  BH0009  SAX J1819.3-2525       36445.9         26.51
# 8       1    BH  BH0009  SAX J1819.3-2525        4256.0         26.51
#
#     likelihood              gti_obs  var_inter_sigma  var_inter_prob  ...  \
# 10    4017.937  2004-07-30T18:26:28         0.000094          0.9972  ...
# 9     4017.937  2004-07-17T11:09:06         0.000094          0.9972  ...
# 7     4017.937  2002-10-21T03:50:49         0.000094          0.9972  ...
# 11    4017.937  2004-08-10T04:39:07         0.000094          0.9972  ...
# 8     4017.937  2002-08-05T04:22:47         0.000094          0.9972  ...
#
#     flux_brems_lolim  flux_brems_hilim  brems_kt_hilim  brems_kt_lolim  \
# 10               NaN               NaN             NaN             NaN
# 9          12.302683          12.25516             NaN           81.32
# 7                NaN               NaN             NaN             NaN
# 11               NaN               NaN             NaN             NaN
# 8                NaN               NaN             NaN             NaN
#
#     brems_nh_hilim  brems_nh_lolim  bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  \
# 10             NaN             NaN          NaN          NaN          NaN
# 9            9.731           5.142        3.964        2.682        1.439
# 7              NaN             NaN          NaN          NaN          NaN
# 11             NaN             NaN          NaN          NaN          NaN
# 8              NaN             NaN          NaN          NaN          NaN
#
#     bb_nh_lolim
# 10          NaN
# 9           NaN
# 7           NaN
# 11          NaN
# 8           NaN
#
# [5 rows x 100 columns]
#     index class  src_id              src_name  livetime  significance  \
# 20      8    BH  BH0017  CXOU J100510.9-07453   69686.1          4.58
# 12      0    BH  BH0017  CXOU J100510.9-07453   40580.4          4.58
# 15      3    BH  BH0017  CXOU J100510.9-07453   75554.3          4.58
# 14      2    BH  BH0017  CXOU J100510.9-07453  171955.9          4.58
# 18      6    BH  BH0017  CXOU J100510.9-07453  160215.7          4.58
# 19      7    BH  BH0017  CXOU J100510.9-07453  119470.1          4.58
# 21      9    BH  BH0017  CXOU J100510.9-07453   46277.9          4.58
# 13      1    BH  BH0017  CXOU J100510.9-07453   75682.2          4.58
# 17      5    BH  BH0017  CXOU J100510.9-07453  158013.8          4.58
# 16      4    BH  BH0017  CXOU J100510.9-07453  184208.0          4.58
#
#     likelihood              gti_obs  var_inter_sigma  var_inter_prob  ...  \
# 20    82.89468  2012-04-06T18:15:48         0.000001           0.761  ...
# 12    82.89468  2010-01-27T01:02:52         0.000001           0.761  ...
# 15    82.89468  2012-01-26T22:21:59         0.000001           0.761  ...
# 14    82.89468  2012-01-18T14:26:38         0.000001           0.761  ...
# 18    82.89468  2012-01-21T08:54:47         0.000001           0.761  ...
# 19    82.89468  2012-04-04T03:00:56         0.000001           0.761  ...
# 21    82.89468  2012-04-05T19:03:53         0.000001           0.761  ...
# 13    82.89468  2010-01-29T14:46:35         0.000001           0.761  ...
# 17    82.89468  2012-02-03T10:00:00         0.000001           0.761  ...
# 16    82.89468  2012-01-31T15:24:33         0.000001           0.761  ...
#
#     flux_brems_lolim  flux_brems_hilim  brems_kt_hilim  brems_kt_lolim  \
# 20               NaN               NaN             NaN             NaN
# 12               NaN               NaN             NaN             NaN
# 15               NaN               NaN             NaN             NaN
# 14               NaN               NaN             NaN             NaN
# 18               NaN               NaN             NaN             NaN
# 19               NaN               NaN             NaN             NaN
# 21               NaN               NaN             NaN             NaN
# 13               NaN               NaN             NaN             NaN
# 17               NaN               NaN             NaN             NaN
# 16               NaN               NaN             NaN             NaN
#
#     brems_nh_hilim  brems_nh_lolim  bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  \
# 20             NaN             NaN          NaN          NaN          NaN
# 12             NaN             NaN          NaN          NaN          NaN
# 15             NaN             NaN          NaN          NaN          NaN
# 14             NaN             NaN          NaN          NaN          NaN
# 18             NaN             NaN          NaN          NaN          NaN
# 19             NaN             NaN          NaN          NaN          NaN
# 21             NaN             NaN          NaN          NaN          NaN
# 13             NaN             NaN          NaN          NaN          NaN
# 17             NaN             NaN          NaN          NaN          NaN
# 16             NaN             NaN          NaN          NaN          NaN
#
#     bb_nh_lolim
# 20          NaN
# 12          NaN
# 15          NaN
# 14          NaN
# 18          NaN
# 19          NaN
# 21          NaN
# 13          NaN
# 17          NaN
# 16          NaN
#
# [10 rows x 100 columns]
#     index class  src_id              src_name  livetime  significance  \
# 8       1    NS  NS0068  SAXWFC J1744.9-2921.   19724.6          9.04
# 10      3    NS  NS0068  SAXWFC J1744.9-2921.   97909.1          9.04
# 7       0    NS  NS0068  SAXWFC J1744.9-2921.   11481.5          9.04
# 11      4    NS  NS0068  SAXWFC J1744.9-2921.   11111.8          9.04
# 9       2    NS  NS0068  SAXWFC J1744.9-2921.   19291.8          9.04
# 12      5    NS  NS0068  SAXWFC J1744.9-2921.   36668.9          9.04
#
#     likelihood              gti_obs  var_inter_sigma  var_inter_prob  ...  \
# 8     140.3164  2006-10-31T04:15:03         0.000005           0.794  ...
# 10    140.3164  2005-07-22T02:13:10         0.000005           0.794  ...
# 7     140.3164  2001-07-19T10:12:01         0.000005           0.794  ...
# 11    140.3164  2001-07-19T06:51:51         0.000005           0.794  ...
# 9     140.3164  2007-02-19T02:06:10         0.000005           0.794  ...
# 12    140.3164  2007-04-25T14:28:01         0.000005           0.794  ...
#
#     flux_brems_lolim  flux_brems_hilim  brems_kt_hilim  brems_kt_lolim  \
# 8                NaN               NaN             NaN             NaN
# 10         13.462055         13.212823             NaN           4.289
# 7                NaN               NaN             NaN             NaN
# 11               NaN               NaN             NaN             NaN
# 9                NaN               NaN             NaN             NaN
# 12               NaN               NaN             NaN             NaN
#
#     brems_nh_hilim  brems_nh_lolim  bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  \
# 8              NaN             NaN          NaN          NaN          NaN
# 10          1712.0           788.2        83.13        1.312       1211.0
# 7              NaN             NaN          NaN          NaN          NaN
# 11             NaN             NaN          NaN          NaN          NaN
# 9              NaN             NaN          NaN          NaN          NaN
# 12             NaN             NaN          NaN          NaN          NaN
#
#     bb_nh_lolim
# 8           NaN
# 10        136.2
# 7           NaN
# 11          NaN
# 9           NaN
# 12          NaN
#
# [6 rows x 100 columns]
#     index class  src_id              src_name  livetime  significance  \
# 10      3    BH  BH0009  SAX J1819.3-2525       18284.8         26.51
# 9       2    BH  BH0009  SAX J1819.3-2525        9209.3         26.51
# 7       0    BH  BH0009  SAX J1819.3-2525       25256.9         26.51
# 11      4    BH  BH0009  SAX J1819.3-2525       36445.9         26.51
# 8       1    BH  BH0009  SAX J1819.3-2525        4256.0         26.51
#
#     likelihood              gti_obs  var_inter_sigma  var_inter_prob  ...  \
# 10    4017.937  2004-07-30T18:26:28         0.000094          0.9972  ...
# 9     4017.937  2004-07-17T11:09:06         0.000094          0.9972  ...
# 7     4017.937  2002-10-21T03:50:49         0.000094          0.9972  ...
# 11    4017.937  2004-08-10T04:39:07         0.000094          0.9972  ...
# 8     4017.937  2002-08-05T04:22:47         0.000094          0.9972  ...
#
#     flux_brems_lolim  flux_brems_hilim  brems_kt_hilim  brems_kt_lolim  \
# 10               NaN               NaN             NaN             NaN
# 9          12.302683          12.25516             NaN           81.32
# 7                NaN               NaN             NaN             NaN
# 11               NaN               NaN             NaN             NaN
# 8                NaN               NaN             NaN             NaN
#
#     brems_nh_hilim  brems_nh_lolim  bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  \
# 10             NaN             NaN          NaN          NaN          NaN
# 9            9.731           5.142        3.964        2.682        1.439
# 7              NaN             NaN          NaN          NaN          NaN
# 11             NaN             NaN          NaN          NaN          NaN
# 8              NaN             NaN          NaN          NaN          NaN
#
#     bb_nh_lolim
# 10          NaN
# 9           NaN
# 7           NaN
# 11          NaN
# 8           NaN
#
# [5 rows x 100 columns]
#     index class  src_id              src_name  livetime  significance  \
# 14      1    NS  NS0077  1WGA J1747.4-3002      30547.7         17.15
# 13      0    NS  NS0077  1WGA J1747.4-3002      29715.4         17.15
#
#     likelihood              gti_obs  var_inter_sigma  var_inter_prob  ...  \
# 14    289.5061  2013-07-25T23:01:10         0.000392         0.88125  ...
# 13    289.5061  2013-03-28T19:40:21         0.000392         0.88125  ...
#
#     flux_brems_lolim  flux_brems_hilim  brems_kt_hilim  brems_kt_lolim  \
# 14         13.236497         13.056456           23.47           3.287
# 13         13.218245         13.056407           35.72           4.278
#
#     brems_nh_hilim  brems_nh_lolim  bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  \
# 14           87.67           40.63        1.023       0.7393        29.89
# 13          104.70           51.10        1.142       0.8692        32.29
#
#     bb_nh_lolim
# 14          NaN
# 13          NaN
#
# [2 rows x 100 columns]
#     index class  src_id              src_name  livetime  significance  \
# 8       1    NS  NS0068  SAXWFC J1744.9-2921.   19724.6          9.04
# 10      3    NS  NS0068  SAXWFC J1744.9-2921.   97909.1          9.04
# 7       0    NS  NS0068  SAXWFC J1744.9-2921.   11481.5          9.04
# 11      4    NS  NS0068  SAXWFC J1744.9-2921.   11111.8          9.04
# 9       2    NS  NS0068  SAXWFC J1744.9-2921.   19291.8          9.04
# 12      5    NS  NS0068  SAXWFC J1744.9-2921.   36668.9          9.04
#
#     likelihood              gti_obs  var_inter_sigma  var_inter_prob  ...  \
# 8     140.3164  2006-10-31T04:15:03         0.000005           0.794  ...
# 10    140.3164  2005-07-22T02:13:10         0.000005           0.794  ...
# 7     140.3164  2001-07-19T10:12:01         0.000005           0.794  ...
# 11    140.3164  2001-07-19T06:51:51         0.000005           0.794  ...
# 9     140.3164  2007-02-19T02:06:10         0.000005           0.794  ...
# 12    140.3164  2007-04-25T14:28:01         0.000005           0.794  ...
#
#     flux_brems_lolim  flux_brems_hilim  brems_kt_hilim  brems_kt_lolim  \
# 8                NaN               NaN             NaN             NaN
# 10         13.462055         13.212823             NaN           4.289
# 7                NaN               NaN             NaN             NaN
# 11               NaN               NaN             NaN             NaN
# 9                NaN               NaN             NaN             NaN
# 12               NaN               NaN             NaN             NaN
#
#     brems_nh_hilim  brems_nh_lolim  bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  \
# 8              NaN             NaN          NaN          NaN          NaN
# 10          1712.0           788.2        83.13        1.312       1211.0
# 7              NaN             NaN          NaN          NaN          NaN
# 11             NaN             NaN          NaN          NaN          NaN
# 9              NaN             NaN          NaN          NaN          NaN
# 12             NaN             NaN          NaN          NaN          NaN
#
#     bb_nh_lolim
# 8           NaN
# 10        136.2
# 7           NaN
# 11          NaN
# 9           NaN
# 12          NaN
#
# [6 rows x 100 columns]
#     index class  src_id              src_name  livetime  significance  \
# 10      3    BH  BH0009  SAX J1819.3-2525       18284.8         26.51
# 9       2    BH  BH0009  SAX J1819.3-2525        9209.3         26.51
# 7       0    BH  BH0009  SAX J1819.3-2525       25256.9         26.51
# 11      4    BH  BH0009  SAX J1819.3-2525       36445.9         26.51
# 8       1    BH  BH0009  SAX J1819.3-2525        4256.0         26.51
#
#     likelihood              gti_obs  var_inter_sigma  var_inter_prob  ...  \
# 10    4017.937  2004-07-30T18:26:28         0.000094          0.9972  ...
# 9     4017.937  2004-07-17T11:09:06         0.000094          0.9972  ...
# 7     4017.937  2002-10-21T03:50:49         0.000094          0.9972  ...
# 11    4017.937  2004-08-10T04:39:07         0.000094          0.9972  ...
# 8     4017.937  2002-08-05T04:22:47         0.000094          0.9972  ...
#
#     flux_brems_lolim  flux_brems_hilim  brems_kt_hilim  brems_kt_lolim  \
# 10               NaN               NaN             NaN             NaN
# 9          12.302683          12.25516             NaN           81.32
# 7                NaN               NaN             NaN             NaN
# 11               NaN               NaN             NaN             NaN
# 8                NaN               NaN             NaN             NaN
#
#     brems_nh_hilim  brems_nh_lolim  bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  \
# 10             NaN             NaN          NaN          NaN          NaN
# 9            9.731           5.142        3.964        2.682        1.439
# 7              NaN             NaN          NaN          NaN          NaN
# 11             NaN             NaN          NaN          NaN          NaN
# 8              NaN             NaN          NaN          NaN          NaN
#
#     bb_nh_lolim
# 10          NaN
# 9           NaN
# 7           NaN
# 11          NaN
# 8           NaN
#
# [5 rows x 100 columns]
#     index class  src_id              src_name  livetime  significance  \
# 14      1    NS  NS0077  1WGA J1747.4-3002      30547.7         17.15
# 13      0    NS  NS0077  1WGA J1747.4-3002      29715.4         17.15
#
#     likelihood              gti_obs  var_inter_sigma  var_inter_prob  ...  \
# 14    289.5061  2013-07-25T23:01:10         0.000392         0.88125  ...
# 13    289.5061  2013-03-28T19:40:21         0.000392         0.88125  ...
#
#     flux_brems_lolim  flux_brems_hilim  brems_kt_hilim  brems_kt_lolim  \
# 14         13.236497         13.056456           23.47           3.287
# 13         13.218245         13.056407           35.72           4.278
#
#     brems_nh_hilim  brems_nh_lolim  bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  \
# 14           87.67           40.63        1.023       0.7393        29.89
# 13          104.70           51.10        1.142       0.8692        32.29
#
#     bb_nh_lolim
# 14          NaN
# 13          NaN
#
# [2 rows x 100 columns]
# BH0009    4
# BH0017    2
# NS0068    2
# NS0077    2
# NS0059    1
# Name: src, dtype: int64
#     index class  src_id              src_name  livetime  significance  \
# 10      3    BH  BH0009  SAX J1819.3-2525       18284.8         26.51
# 9       2    BH  BH0009  SAX J1819.3-2525        9209.3         26.51
# 7       0    BH  BH0009  SAX J1819.3-2525       25256.9         26.51
# 11      4    BH  BH0009  SAX J1819.3-2525       36445.9         26.51
# 8       1    BH  BH0009  SAX J1819.3-2525        4256.0         26.51
# 5       0    NS  NS0059  J1749-2808              1079.8          6.98
# 6       1    NS  NS0059  J1749-2808             24403.2          6.98
# 20      8    BH  BH0017  CXOU J100510.9-07453   69686.1          4.58
# 12      0    BH  BH0017  CXOU J100510.9-07453   40580.4          4.58
# 15      3    BH  BH0017  CXOU J100510.9-07453   75554.3          4.58
# 14      2    BH  BH0017  CXOU J100510.9-07453  171955.9          4.58
# 18      6    BH  BH0017  CXOU J100510.9-07453  160215.7          4.58
# 19      7    BH  BH0017  CXOU J100510.9-07453  119470.1          4.58
# 21      9    BH  BH0017  CXOU J100510.9-07453   46277.9          4.58
# 13      1    BH  BH0017  CXOU J100510.9-07453   75682.2          4.58
# 17      5    BH  BH0017  CXOU J100510.9-07453  158013.8          4.58
# 16      4    BH  BH0017  CXOU J100510.9-07453  184208.0          4.58
# 10      3    BH  BH0009  SAX J1819.3-2525       18284.8         26.51
# 9       2    BH  BH0009  SAX J1819.3-2525        9209.3         26.51
# 7       0    BH  BH0009  SAX J1819.3-2525       25256.9         26.51
# 11      4    BH  BH0009  SAX J1819.3-2525       36445.9         26.51
# 8       1    BH  BH0009  SAX J1819.3-2525        4256.0         26.51
# 20      8    BH  BH0017  CXOU J100510.9-07453   69686.1          4.58
# 8    140.31640  2006-10-31T04:15:03     5.484750e-06         0.79400  ...
# 10   140.31640  2005-07-22T02:13:10     5.484750e-06         0.79400  ...
# 7    140.31640  2001-07-19T10:12:01     5.484750e-06         0.79400  ...
# 11   140.31640  2001-07-19T06:51:51     5.484750e-06         0.79400  ...
# 9    140.31640  2007-02-19T02:06:10     5.484750e-06         0.79400  ...
# 12   140.31640  2007-04-25T14:28:01     5.484750e-06         0.79400  ...
# 10  4017.93700  2004-07-30T18:26:28     9.395600e-05         0.99720  ...
# 9   4017.93700  2004-07-17T11:09:06     9.395600e-05         0.99720  ...
# 7   4017.93700  2002-10-21T03:50:49     9.395600e-05         0.99720  ...
# 11  4017.93700  2004-08-10T04:39:07     9.395600e-05         0.99720  ...
# 8   4017.93700  2002-08-05T04:22:47     9.395600e-05         0.99720  ...
# 14   289.50610  2013-07-25T23:01:10     3.924485e-04         0.88125  ...
# 13   289.50610  2013-03-28T19:40:21     3.924485e-04         0.88125  ...
#
#     flux_brems_lolim  flux_brems_hilim  brems_kt_hilim  brems_kt_lolim  \
# 10               NaN               NaN             NaN             NaN
# 9          12.302683         12.255160             NaN          81.320
# 7                NaN               NaN             NaN             NaN
# 11               NaN               NaN             NaN             NaN
# 8                NaN               NaN             NaN             NaN
# 5                NaN               NaN             NaN             NaN
# 6                NaN               NaN             NaN             NaN
# 20               NaN               NaN             NaN             NaN
# 12               NaN               NaN             NaN             NaN
# 15               NaN               NaN             NaN             NaN
# 14               NaN               NaN             NaN             NaN
# 18               NaN               NaN             NaN             NaN
# 19               NaN               NaN             NaN             NaN
# 21               NaN               NaN             NaN             NaN
# 13               NaN               NaN             NaN             NaN
# 17               NaN               NaN             NaN             NaN
# 16               NaN               NaN             NaN             NaN
# 10               NaN               NaN             NaN             NaN
# 9          12.302683         12.255160             NaN          81.320
# 7                NaN               NaN             NaN             NaN
# 11               NaN               NaN             NaN             NaN
# 8                NaN               NaN             NaN             NaN
# 20               NaN               NaN             NaN             NaN
# 12               NaN               NaN             NaN             NaN
# 15               NaN               NaN             NaN             NaN
# 14               NaN               NaN             NaN             NaN
# 18               NaN               NaN             NaN             NaN
# 19               NaN               NaN             NaN             NaN
# 21               NaN               NaN             NaN             NaN
# 13               NaN               NaN             NaN             NaN
# 17               NaN               NaN             NaN             NaN
# 16               NaN               NaN             NaN             NaN
# 8                NaN               NaN             NaN             NaN
# 10         13.462055         13.212823             NaN           4.289
# 7                NaN               NaN             NaN             NaN
# 11               NaN               NaN             NaN             NaN
# 9                NaN               NaN             NaN             NaN
# 12               NaN               NaN             NaN             NaN
# 10               NaN               NaN             NaN             NaN
# 9          12.302683         12.255160             NaN          81.320
# 7                NaN               NaN             NaN             NaN
# 11               NaN               NaN             NaN             NaN
# 8                NaN               NaN             NaN             NaN
# 14         13.236497         13.056456           23.47           3.287
# 13         13.218245         13.056407           35.72           4.278
# 8                NaN               NaN             NaN             NaN
# 10         13.462055         13.212823             NaN           4.289
# 7                NaN               NaN             NaN             NaN
# 11               NaN               NaN             NaN             NaN
# 9                NaN               NaN             NaN             NaN
# 12               NaN               NaN             NaN             NaN
# 10               NaN               NaN             NaN             NaN
# 9          12.302683         12.255160             NaN          81.320
# 7                NaN               NaN             NaN             NaN
# 11               NaN               NaN             NaN             NaN
# 8                NaN               NaN             NaN             NaN
# 14         13.236497         13.056456           23.47           3.287
# 13         13.218245         13.056407           35.72           4.278
#
#     brems_nh_hilim  brems_nh_lolim  bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  \
# 10             NaN             NaN          NaN          NaN          NaN
# 9            9.731           5.142        3.964       2.6820        1.439
# 7              NaN             NaN          NaN          NaN          NaN
# 11             NaN             NaN          NaN          NaN          NaN
# 8              NaN             NaN          NaN          NaN          NaN
# 5              NaN             NaN          NaN          NaN          NaN
# 6              NaN             NaN          NaN          NaN          NaN
# 20             NaN             NaN          NaN          NaN          NaN
# 12             NaN             NaN          NaN          NaN          NaN
# 15             NaN             NaN          NaN          NaN          NaN
# 14             NaN             NaN          NaN          NaN          NaN
# 18             NaN             NaN          NaN          NaN          NaN
# 19             NaN             NaN          NaN          NaN          NaN
# 21             NaN             NaN          NaN          NaN          NaN
# 13             NaN             NaN          NaN          NaN          NaN
# 17             NaN             NaN          NaN          NaN          NaN
# 16             NaN             NaN          NaN          NaN          NaN
# 10             NaN             NaN          NaN          NaN          NaN
# 9            9.731           5.142        3.964       2.6820        1.439
# 7              NaN             NaN          NaN          NaN          NaN
# 11             NaN             NaN          NaN          NaN          NaN
# 8              NaN             NaN          NaN          NaN          NaN
# 20             NaN             NaN          NaN          NaN          NaN
# 12             NaN             NaN          NaN          NaN          NaN
# 15             NaN             NaN          NaN          NaN          NaN
# 14             NaN             NaN          NaN          NaN          NaN
# 18             NaN             NaN          NaN          NaN          NaN
# 19             NaN             NaN          NaN          NaN          NaN
# 21             NaN             NaN          NaN          NaN          NaN
# 13             NaN             NaN          NaN          NaN          NaN
# 17             NaN             NaN          NaN          NaN          NaN
# 16             NaN             NaN          NaN          NaN          NaN
# 8              NaN             NaN          NaN          NaN          NaN
# 10        1712.000         788.200       83.130       1.3120     1211.000
# 7              NaN             NaN          NaN          NaN          NaN
# 11             NaN             NaN          NaN          NaN          NaN
# 9              NaN             NaN          NaN          NaN          NaN
# 12             NaN             NaN          NaN          NaN          NaN
# 10             NaN             NaN          NaN          NaN          NaN
# 9            9.731           5.142        3.964       2.6820        1.439
# 7              NaN             NaN          NaN          NaN          NaN
# 11             NaN             NaN          NaN          NaN          NaN
# 8              NaN             NaN          NaN          NaN          NaN
# 14          87.670          40.630        1.023       0.7393       29.890
# 13         104.700          51.100        1.142       0.8692       32.290
# 8              NaN             NaN          NaN          NaN          NaN
# 10        1712.000         788.200       83.130       1.3120     1211.000
# 7              NaN             NaN          NaN          NaN          NaN
# 11             NaN             NaN          NaN          NaN          NaN
# 9              NaN             NaN          NaN          NaN          NaN
# 12             NaN             NaN          NaN          NaN          NaN
# 10             NaN             NaN          NaN          NaN          NaN
# 9            9.731           5.142        3.964       2.6820        1.439
# 7              NaN             NaN          NaN          NaN          NaN
# 11             NaN             NaN          NaN          NaN          NaN
# 8              NaN             NaN          NaN          NaN          NaN
# 14          87.670          40.630        1.023       0.7393       29.890
# 13         104.700          51.100        1.142       0.8692       32.290
#
#     bb_nh_lolim
# 10          NaN
# 9           NaN
# 7           NaN
# 11          NaN
# 8           NaN
# 5           NaN
# 6           NaN
# 20          NaN
# 12          NaN
# 15          NaN
# 14          NaN
# 18          NaN
# 19          NaN
# 21          NaN
# 13          NaN
# 17          NaN
# 16          NaN
# 10          NaN
# 9           NaN
# 7           NaN
# 11          NaN
# 8           NaN
# 20          NaN
# 12          NaN
# 15          NaN
# 14          NaN
# 18          NaN
# 19          NaN
# 21          NaN
# 13          NaN
# 17          NaN
# 16          NaN
# 8           NaN
# 10        136.2
# 7           NaN
# 11          NaN
# 9           NaN
# 12          NaN
# 10          NaN
# 9           NaN
# 7           NaN
# 11          NaN
# 8           NaN
# 14          NaN
# 13          NaN
# 8           NaN
# 10        136.2
# 7           NaN
# 11          NaN
# 9           NaN
# 12          NaN
# 10          NaN
# 9           NaN
# 7           NaN
# 11          NaN
# 8           NaN
# 14          NaN
# 13          NaN
#
# [58 rows x 100 columns]

# %%
data_sneak = test[test['src_id'] == 'NS0061']
display(data_sneak)
# Out:
# Empty DataFrame
# Columns: [index, class, src_id, src_name, livetime, significance, likelihood, gti_obs, var_inter_sigma, var_inter_prob, var_inter_index, var_max, var_min, var_mean, var_sigma, kp_prob, ks_prob, var_prob, var_index, flux_aper_hilim, flux_aper_lolim, flux_aper, photflux_aper_hilim, photflux_aper_lolim, photflux_aper, photflux_aper_b, photflux_aper_h, photflux_aper_m, photflux_aper_u, photflux_aper_s, photflux_aper_lolim_b, photflux_aper_lolim_h, photflux_aper_lolim_m, photflux_aper_lolim_u, photflux_aper_lolim_s, photflux_aper_hilim_b, photflux_aper_hilim_h, photflux_aper_hilim_m, photflux_aper_hilim_u, photflux_aper_hilim_s, flux_aper_b, flux_aper_h, flux_aper_m, flux_aper_u, flux_aper_s, flux_aper_lolim_b, flux_aper_lolim_h, flux_aper_lolim_m, flux_aper_lolim_u, flux_aper_lolim_s, flux_aper_hilim_b, flux_aper_hilim_h, flux_aper_hilim_m, flux_aper_hilim_u, flux_aper_hilim_s, hard_hm, hard_hs, hard_ms, flux_powlaw, powlaw_gamma, powlaw_nh, powlaw_ampl, powlaw_stat, flux_bb, flux_bb_hilim, flux_bb_lolim, bb_kt, bb_nh, bb_ampl, bb_stat, flux_brems, brems_kt, brems_nh, brems_stat, hard_hm_hilim, hard_hm_lolim, hard_hs_hilim, hard_hs_lolim, hard_ms_hilim, hard_ms_lolim, flux_powlaw_hilim, flux_powlaw_lolim, powlaw_gamma_hilim, powlaw_gamma_lolim, powlaw_nh_hilim, powlaw_nh_lolim, powlaw_ampl_hilim, powlaw_ampl_lolim, bb_ampl_lolim, bb_ampl_hilim, flux_brems_lolim, flux_brems_hilim, brems_kt_hilim, brems_kt_lolim, brems_nh_hilim, brems_nh_lolim, bb_kt_hilim, bb_kt_lolim, bb_nh_hilim, bb_nh_lolim]
# Index: []
#
# [0 rows x 100 columns]
