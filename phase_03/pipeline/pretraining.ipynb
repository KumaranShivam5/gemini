# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt

# %%
def filter_data(data_sent):
    data = data_sent.copy()
    max_flux = -12
    min_flux = 26
    data = data[data['flux_aper']<max_flux]

    data = data[data['significance']>2]
    data_class = data[['class']]

    data_sig = data['significance']
    data_id = data['src_id']
    data_name = data['src_n']
    obs_info_params = [ 'livetime','likelihood','pileup_flag','mstr_sat_src_flag','mstr_streak_src_flag'   ,'gti_obs' , 'flux_significance_b'  , 'flux_significance_m' , 'flux_significance_s' , 'flux_significance_h' , 'flux_significance_u'    ]
    data_val = data.drop(columns=obs_info_params).reset_index(drop=True)
    return data_val

# %%
def extract_data(data_sent , impute_fn = '',reduce_fn = ' ' , rf_impute=False):
    data = data_sent.copy()
    data = data.sample(frac=1)
    data = filter_data(data)
    #display(data)
    data_id = data[['class' ,'src_n' , 'src_id' ,'significance' , 'obs']]
    data_id = data_id.reset_index(drop=True)
    data_val = data.drop(['index' , 'class' ,'src_n' , 'src_id' ,'significance'] , axis=1)
    data_val = reduce_fn(data_val)
    #return data_val , data_id
    if(rf_impute):
        data_val = impute_fn(data_val , data_id)
    else:
        data_val = impute_fn(data_val)
    data_val = data_val.reset_index(drop=True)
    data_reduced = pd.concat([data_id , data_val] , axis=1)
    return(data_reduced)

def no_impute(data_sent):
    return data_sent

def median_impute(data_send):
    data = data_send.copy()
    for d in data:
        data.fillna((data[d].median()), inplace=True)
    return data

def mean_impute(data_sent):
    data = data_sent.copy()
    for d in data:
        #mean = np.mean(data[d])
        data.fillna((data[d].mean()), inplace=True)
    return data 



def zero_impute(data_sent):
    data= data_sent.copy()
    data = data.replace(np.nan , 0)
    return data

def norm_data(data_sent):
    data = data_sent.copy()
    #data.replace()
    for d in data:
        max_val = np.amax(data[d])
        min_val =  np.amin(data[d])
        data[d] = (data[d]-min_val)/(max_val-min_val)
    return data


def do_nothing(data_sent):
    return data_sent

def std_data(data_sent):
    data = data_sent.copy()
    for d in data:
        mean =  np.mean(data[d])
        std = np.sqrt(np.var(data[d]))
        data[d] = (data[d]-mean)/std 
    return data

# %%
train_bh = pd.read_csv('processed_data/BH_.csv')
train_bh = train_bh.sample(frac=1)

train_ns = pd.read_csv('processed_data/NS_.csv' )
train_ns = train_ns.sample(frac=1)

train = pd.concat([train_bh , train_ns ] , axis=0)
obs_id = ['OBS_'+str(i) for i in range(len(train))]
train.insert( 0 , 'obs_id' , obs_id)
train =  train.sample(frac=1).reset_index(drop=True)

# %% [markdown]
# ## Random Forest Imputer

# %%
from MissingValuesHandler.missing_data_handler import RandomForestImputer

# %%
train.head(1)
# Out:
#    index class                 src_n  src_id  livetime  significance  \
# 0     78    NS  CIR X-1               NS0017   98723.3        117.03
#
#    likelihood  pileup_flag  mstr_sat_src_flag  mstr_streak_src_flag  ...  \
# 0     90631.7        False              False                 False  ...
#
#   bb_ampl_lolim  bb_ampl_hilim  bb_stat  brems_kt  brems_kt_hilim  \
# 0      0.000019       0.000022    2.112     100.0             NaN
#
#    brems_kt_lolim  brems_nh  brems_nh_hilim  brems_nh_lolim  brems_stat
# 0           98.54     358.3           364.6           352.1       3.067
#
# [1 rows x 108 columns]

# %%
d , i = extract_data(train , reduce_fn=norm_data) 
data = pd.concat([i , d] , axis=1)
data = data.drop(columns=['src_n' , 'src_id' , 'significance'])

# %%
rf_imputer = RandomForestImputer(
    data=data , 
    target_variable_name='class' , 
    forbidden_features_list=[]
)

# %%
rf_imputer.set_ensemble_model_parameters(n_estimators=100 , additional_estimators=20)
new_data =  rf_imputer.train(sample_size = 0.3 , path_to_save_dataset='processed_data/rf_imp.csv')
# Out:
# WARNING:tensorflow:5 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ff27dd3e6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ff29450a620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# - 19562 VALUE(S) CONVERGED!
# - 0 VALUE(S) REMAINING!
#
# - ALL VALUES CONVERGED!
#
# - TOTAL ITERATIONS: 5
#
# - NEW DATASET SAVED in: processed_data/rf_imp.csv

# %%
def rf_impute(d, i ):
    data = pd.concat([i , d] , axis=1)
    data = data.drop(columns=['src_n' , 'src_id' , 'significance'])
    rf_imputer = RandomForestImputer(
        data=data , 
        target_variable_name='class' , 
        forbidden_features_list=[]
    )
    rf_imputer.set_ensemble_model_parameters(n_estimators=100 , additional_estimators=20)
    new_data =  rf_imputer.train(sample_size = 0.3 , path_to_save_dataset='processed_data/rf_imp.csv')
    new_data = new_data.drop(columns= ['class'])
    return new_data

# %%
train_data = extract_data(train ,  impute_fn= rf_impute , reduce_fn= norm_data , rf_impute=True ).reset_index(drop=True)
train_data.index.name = 'index'
display(train_data.describe())
train_data.to_csv('processed_data/train_norm_rf_impute')
# Out:
# - 19562 VALUE(S) CONVERGED!
# - 0 VALUE(S) REMAINING!
#
# - ALL VALUES CONVERGED!
#
# - TOTAL ITERATIONS: 5
#
# - NEW DATASET SAVED in: processed_data/rf_imp.csv
#        significance  flux_aper_hilim_s  flux_aper_hilim_u  flux_aper_hilim_m  \
# count    460.000000         460.000000         460.000000         460.000000
# mean      70.680500           0.405772           0.299390           0.412578
# std      109.946267           0.221633           0.242112           0.202805
# min        2.110000           0.000000           0.000000           0.000000
# 25%       11.120000           0.270218           0.000000           0.286216
# 50%       23.470000           0.381014           0.295346           0.402127
# 75%       49.260000           0.555333           0.531809           0.533815
# max      376.060000           1.000000           1.000000           1.000000
#
#        flux_aper_hilim_h  flux_aper_hilim_b  flux_aper_lolim_s  \
# count         460.000000         460.000000         460.000000
# mean            0.475729           0.497027           0.330700
# std             0.201697           0.194583           0.293861
# min             0.000000           0.000000           0.000000
# 25%             0.324350           0.358846           0.000000
# 50%             0.502370           0.504328           0.363721
# 75%             0.615238           0.626640           0.549342
# max             1.000000           1.000000           1.000000
#
#        flux_aper_lolim_u  flux_aper_lolim_m  flux_aper_lolim_h  ...  \
# count         460.000000         460.000000         460.000000  ...
# mean            0.073759           0.336558           0.396229  ...
# std             0.183519           0.276541           0.268479  ...
# min             0.000000           0.000000           0.000000  ...
# 25%             0.000000           0.000000           0.175331  ...
# 50%             0.000000           0.360282           0.437503  ...
# 75%             0.000000           0.552846           0.599765  ...
# max             1.000000           1.000000           1.000000  ...
#
#        bb_ampl_lolim  bb_ampl_hilim     bb_stat    brems_kt  brems_kt_hilim  \
# count     460.000000     460.000000  460.000000  460.000000      460.000000
# mean        0.010463       0.014765    0.022803    0.010732        0.014849
# std         0.063088       0.078496    0.079581    0.085034        0.077365
# min         0.000000       0.000000    0.000000    0.000000        0.000000
# 25%         0.000000       0.000000    0.000000    0.000000        0.000000
# 50%         0.000000       0.000000    0.000000    0.000000        0.000000
# 75%         0.000000       0.000000    0.000000    0.000000        0.000000
# max         1.000000       1.000000    1.000000    1.000000        1.000000
#
#        brems_kt_lolim    brems_nh  brems_nh_hilim  brems_nh_lolim  brems_stat
# count      460.000000  460.000000      460.000000      460.000000  460.000000
# mean         0.006533    0.011490        0.012215        0.010280    0.012353
# std          0.052629    0.075177        0.080658        0.068562    0.059748
# min          0.000000    0.000000        0.000000        0.000000    0.000000
# 25%          0.000000    0.000000        0.000000        0.000000    0.000000
# 50%          0.000000    0.000000        0.000000        0.000000    0.000000
# 75%          0.000000    0.000000        0.000000        0.000000    0.000000
# max          1.000000    1.000000        1.000000        1.000000    1.000000
#
# [8 rows x 93 columns]

# %%
import seaborn as sns

# %%
sns.displot(
    data = new_data , 
    x = 'photflux_aper_lolim' , 
    kind = 'kde' ,
    hue = 'class'
)
plt.show()

# %%
sns.displot(
    data = new_data , 
    x = 'photflux_aper_lolim' , 
    kind = 'kde' ,
    hue = 'class'
)
plt.show()

# %% [markdown]
# ## Correlation imputation scheme

# %%
from tqdm import tqdm

# %%
def corr_impute(data_sent):
    '''
    calculate fearure correlation with each other
    for every sample , for each feature 
    '''
    corr_mat = data_sent.corr().values
    slope_mat , int_mat = linear_reg(data_sent)
    #return 
    data = data_sent.copy()
    r , c = data_sent.shape
    for ri in (range(r)):
        for ci in (range(c)):
            if(np.isnan(data.iloc[ri , ci])): 
                temp = np.abs(corr_mat[ci])
                temp[ci] = 0 
                corr_index = np.argsort(temp)[::-1]
                for cm in corr_index:
                    xi = data.iloc[ri , cm]
                    if(np.isnan(xi)): 
                        print(ri , ci , cm , 'going to next corr')
                        continue
                    else : 
                        val = xi*slope_mat[ci , cm] + int_mat[ci , cm]
                        data.iloc[ri , ci] = val
                        break
    print(data.shape)
    return data
from scipy.stats import linregress
def linear_reg(data_sent):
    
    data = data_sent.copy()
    rows = data.columns
    c = data_sent.shape[1]
    slope_mat =  np.zeros(shape=(c,c))
    int_mat = np.zeros(shape= (c,c))
    for ri in range(len(rows)):
        for ci in range(len(rows)):
            data_now = data[[rows[ri] , rows[ci]]]
            data_now = data_now.dropna(axis=0,how='any').values
            x  , y = data_now[:,0] , data_now[:,1]
            reg = linregress(data_now)
            slope_mat[ri ,ci] = reg.slope
            int_mat[ri,ci] = reg.intercept

    slope_mat = np.asmatrix(slope_mat)
    int_mat = np.asmatrix(int_mat)
    print(slope_mat[:10, :10])
    print(int_mat[:10, :10])
    return slope_mat , int_mat
#print(type(train.iloc[1,2]))
#display(train.iloc[])

# %%
train_data = extract_data(train , median_impute , norm_data).reset_index(drop=True)
train_data.index.name = 'index'
display(train_data.describe())
train_data.to_csv('processed_data/train_norm_median_impute')

train_data = extract_data(train , mean_impute , norm_data).reset_index(drop=True)
train_data.index.name = 'index'
display(train_data.describe())
train_data.to_csv('processed_data/train_norm_mean_impute')

train_data = extract_data(train , zero_impute , norm_data).reset_index(drop=True)
train_data.index.name = 'index'
display(train_data.describe())
train_data.to_csv('processed_data/train_norm_zero_impute')

train_data = extract_data(train , no_impute , norm_data).reset_index(drop=True)
train_data.index.name = 'index'
display(train_data.describe())
train_data.to_csv('processed_data/train_norm_no_impute')

train_data = extract_data(train , corr_impute , norm_data).reset_index(drop=True)
train_data.index.name = 'index'
display(train_data.describe())
train_data.to_csv('processed_data/train_norm_corr_impute')
# Out:
#        significance  flux_aper_hilim_s  flux_aper_hilim_u  flux_aper_hilim_m  \
# count    460.000000         460.000000         460.000000         460.000000
# mean      70.680500           0.432186           0.399933           0.436436
# std      109.946267           0.193170           0.166272           0.173786
# min        2.110000           0.000000           0.000000           0.000000
# 25%       11.120000           0.309677           0.297512           0.313406
# 50%       23.470000           0.391946           0.391946           0.402127
# 75%       49.260000           0.555333           0.531809           0.533815
# max      376.060000           1.000000           1.000000           1.000000
#
#        flux_aper_hilim_h  flux_aper_hilim_b  flux_aper_lolim_s  \
# count         460.000000         460.000000         460.000000
# mean            0.486806           0.502991           0.471289
# std             0.185332           0.185008           0.169059
# min             0.000000           0.000000           0.000000
# 25%             0.358979           0.368118           0.391946
# 50%             0.502370           0.504328           0.391946
# 75%             0.615238           0.626640           0.549342
# max             1.000000           1.000000           1.000000
#
#        flux_aper_lolim_u  flux_aper_lolim_m  flux_aper_lolim_h  ...  \
# count         460.000000         460.000000         460.000000  ...
# mean            0.399244           0.456698           0.482287  ...
# std             0.085081           0.167799           0.173541  ...
# min             0.000000           0.000000           0.000000  ...
# 25%             0.391946           0.391382           0.391946  ...
# 50%             0.391946           0.391946           0.437503  ...
# 75%             0.391946           0.552846           0.599765  ...
# max             1.000000           1.000000           1.000000  ...
#
#        flux_brems  flux_brems_lolim  flux_brems_hilim    brems_kt  \
# count  460.000000        460.000000        460.000000  460.000000
# mean     0.366822          0.365752          0.367300    0.354110
# std      0.111591          0.111370          0.111445    0.128678
# min      0.000000          0.000000          0.000000    0.000000
# 25%      0.391946          0.391946          0.391946    0.391946
# 50%      0.391946          0.391946          0.391946    0.391946
# 75%      0.391946          0.391946          0.391946    0.391946
# max      1.000000          1.000000          1.000000    1.000000
#
#        brems_kt_hilim  brems_kt_lolim    brems_nh  brems_nh_hilim  \
# count      460.000000      460.000000  460.000000      460.000000
# mean         0.361636        0.349912    0.354869        0.355594
# std          0.106576        0.122419    0.120236        0.121704
# min          0.000000        0.000000    0.000000        0.000000
# 25%          0.391946        0.391946    0.391946        0.391946
# 50%          0.391946        0.391946    0.391946        0.391946
# 75%          0.391946        0.391946    0.391946        0.391946
# max          1.000000        1.000000    1.000000        1.000000
#
#        brems_nh_lolim  brems_stat
# count      460.000000  460.000000
# mean         0.356215    0.355732
# std          0.116295    0.108540
# min          0.000000    0.000000
# 25%          0.391946    0.391946
# 50%          0.391946    0.391946
# 75%          0.391946    0.391946
# max          1.000000    1.000000
#
# [8 rows x 93 columns]
#        significance  flux_aper_hilim_s  flux_aper_hilim_u  flux_aper_hilim_m  \
# count    460.000000         460.000000         460.000000         460.000000
# mean      70.680500           0.435094           0.411001           0.439062
# std      109.946267           0.192867           0.166808           0.173418
# min        2.110000           0.000000           0.000000           0.000000
# 25%       11.120000           0.309677           0.297512           0.313406
# 50%       23.470000           0.414513           0.435094           0.419350
# 75%       49.260000           0.555333           0.531809           0.533815
# max      376.060000           1.000000           1.000000           1.000000
#
#        flux_aper_hilim_h  flux_aper_hilim_b  flux_aper_lolim_s  \
# count         460.000000         460.000000         460.000000
# mean            0.488025           0.503648           0.486766
# std             0.184844           0.184688           0.162938
# min             0.000000           0.000000           0.000000
# 25%             0.358979           0.368118           0.435094
# 50%             0.502370           0.504328           0.435094
# 75%             0.615238           0.626640           0.549342
# max             1.000000           1.000000           1.000000
#
#        flux_aper_lolim_u  flux_aper_lolim_m  flux_aper_lolim_h  ...  \
# count         460.000000         460.000000         460.000000  ...
# mean            0.435076           0.469924           0.491760  ...
# std             0.083531           0.163819           0.169472  ...
# min             0.000000           0.000000           0.000000  ...
# 25%             0.435094           0.391382           0.416628  ...
# 50%             0.435094           0.435094           0.437503  ...
# 75%             0.435094           0.552846           0.599765  ...
# max             1.000000           1.000000           1.000000  ...
#
#        flux_brems  flux_brems_lolim  flux_brems_hilim    brems_kt  \
# count  460.000000        460.000000        460.000000  460.000000
# mean     0.404623          0.403553          0.405101    0.391912
# std      0.120659          0.120791          0.120374    0.140097
# min      0.000000          0.000000          0.000000    0.000000
# 25%      0.435094          0.435094          0.435094    0.435094
# 50%      0.435094          0.435094          0.435094    0.435094
# 75%      0.435094          0.435094          0.435094    0.435094
# max      1.000000          1.000000          1.000000    1.000000
#
#        brems_kt_hilim  brems_kt_lolim    brems_nh  brems_nh_hilim  \
# count      460.000000      460.000000  460.000000      460.000000
# mean         0.399813        0.387714    0.392670        0.393395
# std          0.117762        0.135550    0.132169        0.133299
# min          0.000000        0.000000    0.000000        0.000000
# 25%          0.435094        0.435094    0.435094        0.435094
# 50%          0.435094        0.435094    0.435094        0.435094
# 75%          0.435094        0.435094    0.435094        0.435094
# max          1.000000        1.000000    1.000000        1.000000
#
#        brems_nh_lolim  brems_stat
# count      460.000000  460.000000
# mean         0.394298    0.393533
# std          0.128239    0.121356
# min          0.000000    0.000000
# 25%          0.435094    0.435094
# 50%          0.435094    0.435094
# 75%          0.435094    0.435094
# max          1.000000    1.000000
#
# [8 rows x 93 columns]
#        significance  flux_aper_hilim_s  flux_aper_hilim_u  flux_aper_hilim_m  \
# count    460.000000         460.000000         460.000000         460.000000
# mean      70.680500           0.405772           0.299390           0.412578
# std      109.946267           0.221633           0.242112           0.202805
# min        2.110000           0.000000           0.000000           0.000000
# 25%       11.120000           0.270218           0.000000           0.286216
# 50%       23.470000           0.381014           0.295346           0.402127
# 75%       49.260000           0.555333           0.531809           0.533815
# max      376.060000           1.000000           1.000000           1.000000
#
#        flux_aper_hilim_h  flux_aper_hilim_b  flux_aper_lolim_s  \
# count         460.000000         460.000000         460.000000
# mean            0.475729           0.497027           0.330700
# std             0.201697           0.194583           0.293861
# min             0.000000           0.000000           0.000000
# 25%             0.324350           0.358846           0.000000
# 50%             0.502370           0.504328           0.363721
# 75%             0.615238           0.626640           0.549342
# max             1.000000           1.000000           1.000000
#
#        flux_aper_lolim_u  flux_aper_lolim_m  flux_aper_lolim_h  ...  \
# count         460.000000         460.000000         460.000000  ...
# mean            0.073759           0.336558           0.396229  ...
# std             0.183519           0.276541           0.268479  ...
# min             0.000000           0.000000           0.000000  ...
# 25%             0.000000           0.000000           0.175331  ...
# 50%             0.000000           0.360282           0.437503  ...
# 75%             0.000000           0.552846           0.599765  ...
# max             1.000000           1.000000           1.000000  ...
#
#        flux_brems  flux_brems_lolim  flux_brems_hilim    brems_kt  \
# count  460.000000        460.000000        460.000000  460.000000
# mean     0.023443          0.022373          0.023921    0.010732
# std      0.108967          0.105301          0.110320    0.085034
# min      0.000000          0.000000          0.000000    0.000000
# 25%      0.000000          0.000000          0.000000    0.000000
# 50%      0.000000          0.000000          0.000000    0.000000
# 75%      0.000000          0.000000          0.000000    0.000000
# max      1.000000          1.000000          1.000000    1.000000
#
#        brems_kt_hilim  brems_kt_lolim    brems_nh  brems_nh_hilim  \
# count      460.000000      460.000000  460.000000      460.000000
# mean         0.014849        0.006533    0.011490        0.012215
# std          0.077365        0.052629    0.075177        0.080658
# min          0.000000        0.000000    0.000000        0.000000
# 25%          0.000000        0.000000    0.000000        0.000000
# 50%          0.000000        0.000000    0.000000        0.000000
# 75%          0.000000        0.000000    0.000000        0.000000
# max          1.000000        1.000000    1.000000        1.000000
#
#        brems_nh_lolim  brems_stat
# count      460.000000  460.000000
# mean         0.010280    0.012353
# std          0.068562    0.059748
# min          0.000000    0.000000
# 25%          0.000000    0.000000
# 50%          0.000000    0.000000
# 75%          0.000000    0.000000
# max          1.000000    1.000000
#
# [8 rows x 93 columns]
#        significance  flux_aper_hilim_s  flux_aper_hilim_u  flux_aper_hilim_m  \
# count    460.000000         429.000000         342.000000         432.000000
# mean      70.680500           0.435094           0.402689           0.439319
# std      109.946267           0.199729           0.192830           0.178960
# min        2.110000           0.000000           0.000000           0.000000
# 25%       11.120000           0.294773           0.231368           0.307207
# 50%       23.470000           0.391946           0.396486           0.408714
# 75%       49.260000           0.569852           0.572477           0.554868
# max      376.060000           1.000000           1.000000           1.000000
#
#        flux_aper_hilim_h  flux_aper_hilim_b  flux_aper_lolim_s  \
# count         447.000000         453.000000         295.000000
# mean            0.489565           0.504707           0.515667
# std             0.187294           0.185914           0.197767
# min             0.000000           0.000000           0.000000
# 25%             0.351314           0.366169           0.384478
# 50%             0.508516           0.506154           0.483627
# 75%             0.618260           0.629241           0.659338
# max             1.000000           1.000000           1.000000
#
#        flux_aper_lolim_u  flux_aper_lolim_m  flux_aper_lolim_h  ...  \
# count          78.000000         319.000000         359.000000  ...
# mean            0.434988           0.485319           0.507703  ...
# std             0.203943           0.194834           0.188846  ...
# min             0.000000           0.000000           0.000000  ...
# 25%             0.299916           0.343379           0.373355  ...
# 50%             0.443376           0.466397           0.515729  ...
# 75%             0.576804           0.638826           0.630503  ...
# max             1.000000           1.000000           1.000000  ...
#
#        flux_brems  flux_brems_lolim  flux_brems_hilim   brems_kt  \
# count   57.000000         57.000000         57.000000  57.000000
# mean     0.189189          0.180554          0.193049   0.086606
# std      0.255747          0.248626          0.257919   0.229300
# min      0.000000          0.000000          0.000000   0.000000
# 25%      0.036211          0.029144          0.039309   0.004473
# 50%      0.059665          0.056840          0.060551   0.020767
# 75%      0.225896          0.210331          0.232454   0.041313
# max      1.000000          1.000000          1.000000   1.000000
#
#        brems_kt_hilim  brems_kt_lolim   brems_nh  brems_nh_hilim  \
# count       53.000000       57.000000  57.000000       57.000000
# mean         0.128881        0.052726   0.092727        0.098580
# std          0.194559        0.142209   0.196609        0.211325
# min          0.000000        0.000000   0.000000        0.000000
# 25%          0.013922        0.004971   0.009932        0.014095
# 50%          0.064800        0.020885   0.026950        0.025612
# 75%          0.135214        0.039631   0.043906        0.050849
# max          1.000000        1.000000   1.000000        1.000000
#
#        brems_nh_lolim  brems_stat
# count       54.000000   57.000000
# mean         0.087569    0.099692
# std          0.183887    0.142819
# min          0.000000    0.000000
# 25%          0.014085    0.048054
# 50%          0.026496    0.071503
# 75%          0.041475    0.113665
# max          1.000000    1.000000
#
# [8 rows x 93 columns]
# [[1.         0.48830433 0.77076353 0.50288367 0.6156728  0.96179021
#   0.41180594 0.75821139 0.40376858 0.56006084]
#  [0.55097621 1.         0.4238594  0.51779134 0.47459605 0.46751035
#   1.12014374 0.33370366 0.28543721 0.30953251]
#  [0.91999337 0.4583204  1.         0.73729362 0.8274013  0.77476592
#   0.31984995 1.0455034  0.67409682 0.77766833]
#  [0.55770661 0.51129842 0.67870855 1.         0.92047467 0.56917108
#   0.42783345 0.65240308 1.07007512 0.82641776]
#  [0.71840908 0.49310348 0.78316774 0.97334774 1.         0.72623308
#   0.45274353 0.82879844 1.08411276 1.00228233]
#  [0.90242502 0.47195688 0.80533203 0.66851728 0.79668913 1.
#   0.58505069 0.81499608 0.62632989 0.75696213]
#  [0.54318952 0.74623758 0.43268497 0.54551973 0.57512131 0.6264544
#   1.         0.53643523 0.579333   0.53804015]
#  [0.8239531  0.31801196 0.85041434 0.68181646 0.76164684 0.72260323
#   0.31902073 1.         0.68187895 0.74788484]
#  [0.4935917  0.25960746 0.59544891 0.81154154 0.76258145 0.50549311
#   0.38754563 0.61982017 1.         0.80181592]
#  [0.70764253 0.33882019 0.79007827 0.84677493 0.87192561 0.75690194
#   0.53232788 0.88713165 1.02273408 1.        ]]
# [[ 0.00000000e+00  1.78941601e-01  1.04586079e-01  2.70200320e-01
#    2.44022962e-01  3.94288649e-02  1.94911358e-01  1.36789261e-01
#    3.28950720e-01  2.79918611e-01]
#  [ 2.38308659e-01  0.00000000e+00  2.79809382e-01  2.84331026e-01
#    3.28353534e-01  3.63079831e-01 -7.32327519e-02  3.67096071e-01
#    3.93268123e-01  4.12479418e-01]
#  [ 3.21508254e-02  1.97938872e-01  0.00000000e+00  1.67876677e-01
#    1.48892694e-01  1.50636261e-01  2.61057706e-01 -1.99941155e-02
#    1.92079784e-01  1.78500273e-01]
#  [ 1.62906770e-01  1.50990794e-01  1.06836991e-01  0.00000000e+00
#    6.35240332e-02  2.49609223e-01  2.18621179e-01  1.65867583e-01
#   -6.29591512e-02  1.12635453e-01]
#  [ 6.72075004e-02  1.46537216e-01  3.78386123e-02 -1.11162151e-02
#    0.00000000e+00  1.44206700e-01  1.76585957e-01  4.65678998e-02
#   -9.78819219e-02 -6.90790534e-03]
#  [ 2.98072580e-02  1.27304340e-01  6.05171525e-02  1.25088290e-01
#    1.00542595e-01  0.00000000e+00  4.65765761e-02  8.19429710e-02
#    1.73392646e-01  1.48351377e-01]
#  [ 3.46700310e-01  1.29105860e-01  3.44663689e-01  2.63981709e-01
#    3.20575694e-01  3.83304820e-01  0.00000000e+00  3.43457438e-01
#    2.83230449e-01  3.84970466e-01]
#  [ 6.34292799e-02  2.30146441e-01  7.05981334e-02  1.63625466e-01
#    1.59444234e-01  1.64917675e-01  2.37442433e-01  0.00000000e+00
#    1.70555586e-01  1.86693289e-01]
#  [ 1.99570559e-01  2.81401250e-01  1.67043184e-01  1.21269585e-01
#    1.71111532e-01  2.90853934e-01  2.29073171e-01  1.90416217e-01
#    0.00000000e+00  1.49631177e-01]
#  [ 7.03025832e-02  2.21557507e-01  3.39192400e-02  5.47586920e-02
#    7.25809246e-02  1.15314679e-01  1.06181512e-01  1.59256036e-04
#   -6.15343532e-02  0.00000000e+00]]
# 0 6 11 going to next corr
# 0 8 23 going to next corr
# 0 8 13 going to next corr
# 0 21 26 going to next corr
# 0 56 57 going to next corr
# 0 56 83 going to next corr
# 0 56 82 going to next corr
# 0 56 84 going to next corr
# 0 56 71 going to next corr
# 0 56 58 going to next corr
# 0 56 69 going to next corr
# 0 56 70 going to next corr
# 0 59 61 going to next corr
# 0 59 60 going to next corr
# 0 62 77 going to next corr
# 0 62 90 going to next corr
# 0 62 88 going to next corr
# 0 62 76 going to next corr
# 0 62 64 going to next corr
# 0 62 63 going to next corr
# 0 62 75 going to next corr
# 0 62 89 going to next corr
# 0 62 65 going to next corr
# 0 62 67 going to next corr
# 0 63 75 going to next corr
# 0 63 89 going to next corr
# 0 63 88 going to next corr
# 0 63 90 going to next corr
# 0 63 77 going to next corr
# 0 64 76 going to next corr
# 0 65 67 going to next corr
# 0 65 66 going to next corr
# 0 65 76 going to next corr
# 0 71 82 going to next corr
# 0 71 83 going to next corr
# 0 71 84 going to next corr
# 0 72 74 going to next corr
# 0 72 85 going to next corr
# 0 73 86 going to next corr
# 0 73 89 going to next corr
# 0 78 79 going to next corr
# 0 78 80 going to next corr
# 0 78 91 going to next corr
# 0 82 84 going to next corr
# 0 82 83 going to next corr
# 0 88 90 going to next corr
# 1 1 11 going to next corr
# 1 1 6 going to next corr
# 1 1 16 going to next corr
# 1 1 26 going to next corr
# 1 6 11 going to next corr
# 1 16 26 going to next corr
# 1 21 26 going to next corr
# 1 56 57 going to next corr
# 1 56 83 going to next corr
# 1 56 82 going to next corr
# 1 56 84 going to next corr
# 1 56 71 going to next corr
# 1 56 58 going to next corr
# 1 56 69 going to next corr
# 1 56 70 going to next corr
# 1 59 61 going to next corr
# 1 59 60 going to next corr
# 1 62 77 going to next corr
# 1 62 90 going to next corr
# 1 62 88 going to next corr
# 1 62 76 going to next corr
# 1 62 64 going to next corr
# 1 62 63 going to next corr
# 1 62 75 going to next corr
# 1 62 89 going to next corr
# 1 62 65 going to next corr
# 1 62 67 going to next corr
# 1 63 75 going to next corr
# 1 63 89 going to next corr
# 1 63 88 going to next corr
# 1 63 90 going to next corr
# 1 63 77 going to next corr
# 1 64 76 going to next corr
# 1 65 67 going to next corr
# 1 65 66 going to next corr
# 1 65 76 going to next corr
# 1 71 82 going to next corr
# 1 71 83 going to next corr
# 1 71 84 going to next corr
# 1 72 74 going to next corr
# 1 72 85 going to next corr
# 1 73 86 going to next corr
# 1 73 89 going to next corr
# 1 78 79 going to next corr
# 1 78 80 going to next corr
# 1 78 91 going to next corr
# 1 82 84 going to next corr
# 1 82 83 going to next corr
# 1 88 90 going to next corr
# 2 0 10 going to next corr
# 2 3 13 going to next corr
# 2 5 20 going to next corr
# 2 5 10 going to next corr
# 2 5 25 going to next corr
# 2 6 11 going to next corr
# 2 8 23 going to next corr
# 2 8 13 going to next corr
# 2 21 26 going to next corr
# 2 56 57 going to next corr
# 2 56 83 going to next corr
# 2 56 82 going to next corr
# 2 56 84 going to next corr
# 2 56 71 going to next corr
# 2 56 58 going to next corr
# 2 56 69 going to next corr
# 2 56 70 going to next corr
# 2 59 61 going to next corr
# 2 59 60 going to next corr
# 2 62 77 going to next corr
# 2 62 90 going to next corr
# 2 62 88 going to next corr
# 2 62 76 going to next corr
# 2 62 64 going to next corr
# 2 62 63 going to next corr
# 2 62 75 going to next corr
# 2 62 89 going to next corr
# 2 62 65 going to next corr
# 2 62 67 going to next corr
# 2 63 75 going to next corr
# 2 63 89 going to next corr
# 2 63 88 going to next corr
# 2 63 90 going to next corr
# 2 63 77 going to next corr
# 2 64 76 going to next corr
# 2 65 67 going to next corr
# 2 65 66 going to next corr
# 2 65 76 going to next corr
# 2 71 82 going to next corr
# 2 71 83 going to next corr
# 2 71 84 going to next corr
# 2 72 74 going to next corr
# 2 72 85 going to next corr
# 2 73 86 going to next corr
# 2 73 89 going to next corr
# 2 78 79 going to next corr
# 2 78 80 going to next corr
# 2 78 91 going to next corr
# 2 82 84 going to next corr
# 2 82 83 going to next corr
# 2 88 90 going to next corr
# 3 5 20 going to next corr
# 3 5 10 going to next corr
# 3 5 25 going to next corr
# 3 6 11 going to next corr
# 3 21 26 going to next corr
# 3 36 37 going to next corr
# 3 36 87 going to next corr
# 3 36 39 going to next corr
# 3 36 38 going to next corr
# 3 36 68 going to next corr
# 3 36 91 going to next corr
# 3 36 81 going to next corr
# 3 36 74 going to next corr
# 3 36 40 going to next corr
# 3 36 70 going to next corr
# 3 36 85 going to next corr
# 3 36 43 going to next corr
# 3 38 39 going to next corr
# 3 40 43 going to next corr
# 3 40 87 going to next corr
# 3 40 68 going to next corr
# 3 40 81 going to next corr
# 3 40 74 going to next corr
# 3 40 70 going to next corr
# 3 40 91 going to next corr
# 3 40 72 going to next corr
# 3 40 85 going to next corr
# 3 40 69 going to next corr
# 3 40 58 going to next corr
# 3 40 56 going to next corr
# 3 40 57 going to next corr
# 3 40 41 going to next corr
# 3 40 83 going to next corr
# 3 41 42 going to next corr
# 3 41 58 going to next corr
# 3 41 56 going to next corr
# 3 41 57 going to next corr
# 3 41 83 going to next corr
# 3 41 82 going to next corr
# 3 41 84 going to next corr
# 3 41 71 going to next corr
# 3 41 69 going to next corr
# 3 41 70 going to next corr
# 3 56 57 going to next corr
# 3 56 83 going to next corr
# 3 56 82 going to next corr
# 3 56 84 going to next corr
# 3 56 71 going to next corr
# 3 56 58 going to next corr
# 3 56 69 going to next corr
# 3 56 70 going to next corr
# 3 59 61 going to next corr
# 3 59 60 going to next corr
# 3 62 77 going to next corr
# 3 62 90 going to next corr
# 3 62 88 going to next corr
# 3 62 76 going to next corr
# 3 62 64 going to next corr
# 3 62 63 going to next corr
# 3 62 75 going to next corr
# 3 62 89 going to next corr
# 3 62 65 going to next corr
# 3 62 67 going to next corr
# 3 63 75 going to next corr
# 3 63 89 going to next corr
# 3 63 88 going to next corr
# 3 63 90 going to next corr
# 3 63 77 going to next corr
# 3 64 76 going to next corr
# 3 65 67 going to next corr
# 3 65 66 going to next corr
# 3 65 76 going to next corr
# 3 71 82 going to next corr
# 3 71 83 going to next corr
# 3 71 84 going to next corr
# 3 72 74 going to next corr
# 3 72 85 going to next corr
# 3 73 86 going to next corr
# 3 73 89 going to next corr
# 3 78 79 going to next corr
# 3 78 80 going to next corr
# 3 78 91 going to next corr
# 3 82 84 going to next corr
# 3 82 83 going to next corr
# 3 88 90 going to next corr
# 4 56 57 going to next corr
# 4 56 83 going to next corr
# 4 56 82 going to next corr
# 4 56 84 going to next corr
# 4 56 71 going to next corr
# 4 56 58 going to next corr
# 4 56 69 going to next corr
# 4 56 70 going to next corr
# 4 59 61 going to next corr
# 4 59 60 going to next corr
# 4 62 77 going to next corr
# 4 62 90 going to next corr
# 4 62 88 going to next corr
# 4 62 76 going to next corr
# 4 62 64 going to next corr
# 4 62 63 going to next corr
# 4 62 75 going to next corr
# 4 62 89 going to next corr
# 4 62 65 going to next corr
# 4 62 67 going to next corr
# 4 63 75 going to next corr
# 4 63 89 going to next corr
# 4 63 88 going to next corr
# 4 63 90 going to next corr
# 4 63 77 going to next corr
# 4 64 76 going to next corr
# 4 65 67 going to next corr
# 4 65 66 going to next corr
# 4 65 76 going to next corr
# 4 71 82 going to next corr
# 4 71 83 going to next corr
# 4 71 84 going to next corr
# 4 72 74 going to next corr
# 4 72 85 going to next corr
# 4 73 86 going to next corr
# 4 73 89 going to next corr
# 4 78 79 going to next corr
# 4 78 80 going to next corr
# 4 78 91 going to next corr
# 4 82 84 going to next corr
# 4 82 83 going to next corr
# 4 88 90 going to next corr
# 5 6 11 going to next corr
# 5 56 57 going to next corr
# 5 56 83 going to next corr
# 5 56 82 going to next corr
# 5 56 84 going to next corr
# 5 56 71 going to next corr
# 5 56 58 going to next corr
# 5 56 69 going to next corr
# 5 56 70 going to next corr
# 5 59 61 going to next corr
# 5 59 60 going to next corr
# 5 62 77 going to next corr
# 5 62 90 going to next corr
# 5 62 88 going to next corr
# 5 62 76 going to next corr
# 5 62 64 going to next corr
# 5 62 63 going to next corr
# 5 62 75 going to next corr
# 5 62 89 going to next corr
# 5 62 65 going to next corr
# 5 62 67 going to next corr
# 5 63 75 going to next corr
# 5 63 89 going to next corr
# 5 63 88 going to next corr
# 5 63 90 going to next corr
# 5 63 77 going to next corr
# 5 64 76 going to next corr
# 5 65 67 going to next corr
# 5 65 66 going to next corr
# 5 65 76 going to next corr
# 5 71 82 going to next corr
# 5 71 83 going to next corr
# 5 71 84 going to next corr
# 5 72 74 going to next corr
# 5 72 85 going to next corr
# 5 73 86 going to next corr
# 5 73 89 going to next corr
# 5 78 79 going to next corr
# 5 78 80 going to next corr
# 5 78 91 going to next corr
# 5 82 84 going to next corr
# 5 82 83 going to next corr
# 5 88 90 going to next corr
# 6 5 20 going to next corr
# 6 5 10 going to next corr
# 6 5 25 going to next corr
# 6 6 11 going to next corr
# 6 7 22 going to next corr
# 6 7 12 going to next corr
# 6 7 27 going to next corr
# 6 21 26 going to next corr
# 6 36 37 going to next corr
# 6 36 87 going to next corr
# 6 36 39 going to next corr
# 6 36 38 going to next corr
# 6 36 68 going to next corr
# 6 36 91 going to next corr
# 6 36 81 going to next corr
# 6 36 74 going to next corr
# 6 36 40 going to next corr
# 6 36 70 going to next corr
# 6 36 85 going to next corr
# 6 36 43 going to next corr
# 6 38 39 going to next corr
# 6 40 43 going to next corr
# 6 40 87 going to next corr
# 6 40 68 going to next corr
# 6 40 81 going to next corr
# 6 40 74 going to next corr
# 6 40 70 going to next corr
# 6 40 91 going to next corr
# 6 40 72 going to next corr
# 6 40 85 going to next corr
# 6 40 69 going to next corr
# 6 40 58 going to next corr
# 6 40 56 going to next corr
# 6 40 57 going to next corr
# 6 40 41 going to next corr
# 6 40 83 going to next corr
# 6 41 42 going to next corr
# 6 41 58 going to next corr
# 6 41 56 going to next corr
# 6 41 57 going to next corr
# 6 41 83 going to next corr
# 6 41 82 going to next corr
# 6 41 84 going to next corr
# 6 41 71 going to next corr
# 6 41 69 going to next corr
# 6 41 70 going to next corr
# 6 56 57 going to next corr
# 6 56 83 going to next corr
# 6 56 82 going to next corr
# 6 56 84 going to next corr
# 6 56 71 going to next corr
# 6 56 58 going to next corr
# 6 56 69 going to next corr
# 6 56 70 going to next corr
# 6 59 61 going to next corr
# 6 59 60 going to next corr
# 6 62 77 going to next corr
# 6 62 90 going to next corr
# 6 62 88 going to next corr
# 6 62 76 going to next corr
# 6 62 64 going to next corr
# 6 62 63 going to next corr
# 6 62 75 going to next corr
# 6 62 89 going to next corr
# 6 62 65 going to next corr
# 6 62 67 going to next corr
# 6 63 75 going to next corr
# 6 63 89 going to next corr
# 6 63 88 going to next corr
# 6 63 90 going to next corr
# 6 63 77 going to next corr
# 6 64 76 going to next corr
# 6 65 67 going to next corr
# 6 65 66 going to next corr
# 6 65 76 going to next corr
# 6 71 82 going to next corr
# 6 71 83 going to next corr
# 6 71 84 going to next corr
# 6 72 74 going to next corr
# 6 72 85 going to next corr
# 6 73 86 going to next corr
# 6 73 89 going to next corr
# 6 78 79 going to next corr
# 6 78 80 going to next corr
# 6 78 91 going to next corr
# 6 82 84 going to next corr
# 6 82 83 going to next corr
# 6 88 90 going to next corr
# 7 6 11 going to next corr
# 7 21 26 going to next corr
# 7 56 57 going to next corr
# 7 56 83 going to next corr
# 7 56 82 going to next corr
# 7 56 84 going to next corr
# 7 56 71 going to next corr
# 7 56 58 going to next corr
# 7 56 69 going to next corr
# 7 56 70 going to next corr
# 7 59 61 going to next corr
# 7 59 60 going to next corr
# 7 62 77 going to next corr
# 7 62 90 going to next corr
# 7 62 88 going to next corr
# 7 62 76 going to next corr
# 7 62 64 going to next corr
# 7 62 63 going to next corr
# 7 62 75 going to next corr
# 7 62 89 going to next corr
# 7 62 65 going to next corr
# 7 62 67 going to next corr
# 7 63 75 going to next corr
# 7 63 89 going to next corr
# 7 63 88 going to next corr
# 7 63 90 going to next corr
# 7 63 77 going to next corr
# 7 64 76 going to next corr
# 7 65 67 going to next corr
# 7 65 66 going to next corr
# 7 65 76 going to next corr
# 7 71 82 going to next corr
# 7 71 83 going to next corr
# 7 71 84 going to next corr
# 7 72 74 going to next corr
# 7 72 85 going to next corr
# 7 73 86 going to next corr
# 7 73 89 going to next corr
# 7 78 79 going to next corr
# 7 78 80 going to next corr
# 7 78 91 going to next corr
# 7 82 84 going to next corr
# 7 82 83 going to next corr
# 7 88 90 going to next corr
# 8 44 45 going to next corr
# 8 46 84 going to next corr
# 8 46 76 going to next corr
# 8 46 82 going to next corr
# 8 46 90 going to next corr
# 8 46 83 going to next corr
# 8 46 69 going to next corr
# 8 46 88 going to next corr
# 8 46 57 going to next corr
# 8 46 70 going to next corr
# 8 46 71 going to next corr
# 8 46 56 going to next corr
# 8 46 77 going to next corr
# 8 46 89 going to next corr
# 8 46 62 going to next corr
# 8 46 64 going to next corr
# 8 46 74 going to next corr
# 8 46 75 going to next corr
# 8 46 58 going to next corr
# 8 46 63 going to next corr
# 8 46 72 going to next corr
# 8 56 57 going to next corr
# 8 56 83 going to next corr
# 8 56 82 going to next corr
# 8 56 84 going to next corr
# 8 56 71 going to next corr
# 8 56 58 going to next corr
# 8 56 69 going to next corr
# 8 56 70 going to next corr
# 8 59 61 going to next corr
# 8 59 60 going to next corr
# 8 62 77 going to next corr
# 8 62 90 going to next corr
# 8 62 88 going to next corr
# 8 62 76 going to next corr
# 8 62 64 going to next corr
# 8 62 63 going to next corr
# 8 62 75 going to next corr
# 8 62 89 going to next corr
# 8 62 65 going to next corr
# 8 62 67 going to next corr
# 8 63 75 going to next corr
# 8 63 89 going to next corr
# 8 63 88 going to next corr
# 8 63 90 going to next corr
# 8 63 77 going to next corr
# 8 64 76 going to next corr
# 8 65 67 going to next corr
# 8 65 66 going to next corr
# 8 65 76 going to next corr
# 8 71 82 going to next corr
# 8 71 83 going to next corr
# 8 71 84 going to next corr
# 8 72 74 going to next corr
# 8 72 85 going to next corr
# 8 73 86 going to next corr
# 8 73 89 going to next corr
# 8 78 79 going to next corr
# 8 78 80 going to next corr
# 8 78 91 going to next corr
# 8 82 84 going to next corr
# 8 82 83 going to next corr
# 8 88 90 going to next corr
# 9 6 11 going to next corr
# 9 21 26 going to next corr
# 9 56 57 going to next corr
# 9 56 83 going to next corr
# 9 56 82 going to next corr
# 9 56 84 going to next corr
# 9 56 71 going to next corr
# 9 56 58 going to next corr
# 9 56 69 going to next corr
# 9 56 70 going to next corr
# 9 59 61 going to next corr
# 9 59 60 going to next corr
# 9 62 77 going to next corr
# 9 62 90 going to next corr
# 9 62 88 going to next corr
# 9 62 76 going to next corr
# 9 62 64 going to next corr
# 9 62 63 going to next corr
# 9 62 75 going to next corr
# 9 62 89 going to next corr
# 9 62 65 going to next corr
# 9 62 67 going to next corr
# 9 63 75 going to next corr
# 9 63 89 going to next corr
# 9 63 88 going to next corr
# 9 63 90 going to next corr
# 9 63 77 going to next corr
# 9 64 76 going to next corr
# 9 65 67 going to next corr
# 9 65 66 going to next corr
# 9 65 76 going to next corr
# 9 71 82 going to next corr
# 9 71 83 going to next corr
# 9 71 84 going to next corr
# 9 72 74 going to next corr
# 9 72 85 going to next corr
# 9 73 86 going to next corr
# 9 73 89 going to next corr
# 9 78 79 going to next corr
# 9 78 80 going to next corr
# 9 78 91 going to next corr
# 9 82 84 going to next corr
# 9 82 83 going to next corr
# 9 88 90 going to next corr
# 10 6 11 going to next corr
# 10 21 26 going to next corr
# 10 56 57 going to next corr
# 10 56 83 going to next corr
# 10 56 82 going to next corr
# 10 56 84 going to next corr
# 10 56 71 going to next corr
# 10 56 58 going to next corr
# 10 56 69 going to next corr
# 10 56 70 going to next corr
# 10 59 61 going to next corr
# 10 59 60 going to next corr
# 10 62 77 going to next corr
# 10 62 90 going to next corr
# 10 62 88 going to next corr
# 10 62 76 going to next corr
# 10 62 64 going to next corr
# 10 62 63 going to next corr
# 10 62 75 going to next corr
# 10 62 89 going to next corr
# 10 62 65 going to next corr
# 10 62 67 going to next corr
# 10 63 75 going to next corr
# 10 63 89 going to next corr
# 10 63 88 going to next corr
# 10 63 90 going to next corr
# 10 63 77 going to next corr
# 10 64 76 going to next corr
# 10 65 67 going to next corr
# 10 65 66 going to next corr
# 10 65 76 going to next corr
# 10 71 82 going to next corr
# 10 71 83 going to next corr
# 10 71 84 going to next corr
# 10 72 74 going to next corr
# 10 72 85 going to next corr
# 10 73 86 going to next corr
# 10 73 89 going to next corr
# 10 78 79 going to next corr
# 10 78 80 going to next corr
# 10 78 91 going to next corr
# 10 82 84 going to next corr
# 10 82 83 going to next corr
# 10 88 90 going to next corr
# 11 5 20 going to next corr
# 11 5 10 going to next corr
# 11 5 25 going to next corr
# 11 6 11 going to next corr
# 11 7 22 going to next corr
# 11 7 12 going to next corr
# 11 7 27 going to next corr
# 11 21 26 going to next corr
# 11 36 37 going to next corr
# 11 36 87 going to next corr
# 11 36 39 going to next corr
# 11 36 38 going to next corr
# 11 36 68 going to next corr
# 11 36 91 going to next corr
# 11 36 81 going to next corr
# 11 36 74 going to next corr
# 11 36 40 going to next corr
# 11 36 70 going to next corr
# 11 36 85 going to next corr
# 11 36 43 going to next corr
# 11 38 39 going to next corr
# 11 40 43 going to next corr
# 11 40 87 going to next corr
# 11 40 68 going to next corr
# 11 40 81 going to next corr
# 11 40 74 going to next corr
# 11 40 70 going to next corr
# 11 40 91 going to next corr
# 11 40 72 going to next corr
# 11 40 85 going to next corr
# 11 40 69 going to next corr
# 11 40 58 going to next corr
# 11 40 56 going to next corr
# 11 40 57 going to next corr
# 11 40 41 going to next corr
# 11 40 83 going to next corr
# 11 41 42 going to next corr
# 11 41 58 going to next corr
# 11 41 56 going to next corr
# 11 41 57 going to next corr
# 11 41 83 going to next corr
# 11 41 82 going to next corr
# 11 41 84 going to next corr
# 11 41 71 going to next corr
# 11 41 69 going to next corr
# 11 41 70 going to next corr
# 11 56 57 going to next corr
# 11 56 83 going to next corr
# 11 56 82 going to next corr
# 11 56 84 going to next corr
# 11 56 71 going to next corr
# 11 56 58 going to next corr
# 11 56 69 going to next corr
# 11 56 70 going to next corr
# 11 59 61 going to next corr
# 11 59 60 going to next corr
# 11 62 77 going to next corr
# 11 62 90 going to next corr
# 11 62 88 going to next corr
# 11 62 76 going to next corr
# 11 62 64 going to next corr
# 11 62 63 going to next corr
# 11 62 75 going to next corr
# 11 62 89 going to next corr
# 11 62 65 going to next corr
# 11 62 67 going to next corr
# 11 63 75 going to next corr
# 11 63 89 going to next corr
# 11 63 88 going to next corr
# 11 63 90 going to next corr
# 11 63 77 going to next corr
# 11 64 76 going to next corr
# 11 65 67 going to next corr
# 11 65 66 going to next corr
# 11 65 76 going to next corr
# 11 71 82 going to next corr
# 11 71 83 going to next corr
# 11 71 84 going to next corr
# 11 72 74 going to next corr
# 11 72 85 going to next corr
# 11 73 86 going to next corr
# 11 73 89 going to next corr
# 11 78 79 going to next corr
# 11 78 80 going to next corr
# 11 78 91 going to next corr
# 11 82 84 going to next corr
# 11 82 83 going to next corr
# 11 88 90 going to next corr
# 12 6 11 going to next corr
# 12 8 23 going to next corr
# 12 8 13 going to next corr
# 12 21 26 going to next corr
# 12 56 57 going to next corr
# 12 56 83 going to next corr
# 12 56 82 going to next corr
# 12 56 84 going to next corr
# 12 56 71 going to next corr
# 12 56 58 going to next corr
# 12 56 69 going to next corr
# 12 56 70 going to next corr
# 12 59 61 going to next corr
# 12 59 60 going to next corr
# 12 62 77 going to next corr
# 12 62 90 going to next corr
# 12 62 88 going to next corr
# 12 62 76 going to next corr
# 12 62 64 going to next corr
# 12 62 63 going to next corr
# 12 62 75 going to next corr
# 12 62 89 going to next corr
# 12 62 65 going to next corr
# 12 62 67 going to next corr
# 12 63 75 going to next corr
# 12 63 89 going to next corr
# 12 63 88 going to next corr
# 12 63 90 going to next corr
# 12 63 77 going to next corr
# 12 64 76 going to next corr
# 12 65 67 going to next corr
# 12 65 66 going to next corr
# 12 65 76 going to next corr
# 12 71 82 going to next corr
# 12 71 83 going to next corr
# 12 71 84 going to next corr
# 12 72 74 going to next corr
# 12 72 85 going to next corr
# 12 73 86 going to next corr
# 12 73 89 going to next corr
# 12 78 79 going to next corr
# 12 78 80 going to next corr
# 12 78 91 going to next corr
# 12 82 84 going to next corr
# 12 82 83 going to next corr
# 12 88 90 going to next corr
# 13 6 11 going to next corr
# 13 21 26 going to next corr
# 13 56 57 going to next corr
# 13 56 83 going to next corr
# 13 56 82 going to next corr
# 13 56 84 going to next corr
# 13 56 71 going to next corr
# 13 56 58 going to next corr
# 13 56 69 going to next corr
# 13 56 70 going to next corr
# 13 59 61 going to next corr
# 13 59 60 going to next corr
# 13 62 77 going to next corr
# 13 62 90 going to next corr
# 13 62 88 going to next corr
# 13 62 76 going to next corr
# 13 62 64 going to next corr
# 13 62 63 going to next corr
# 13 62 75 going to next corr
# 13 62 89 going to next corr
# 13 62 65 going to next corr
# 13 62 67 going to next corr
# 13 63 75 going to next corr
# 13 63 89 going to next corr
# 13 63 88 going to next corr
# 13 63 90 going to next corr
# 13 63 77 going to next corr
# 13 64 76 going to next corr
# 13 65 67 going to next corr
# 13 65 66 going to next corr
# 13 65 76 going to next corr
# 13 71 82 going to next corr
# 13 71 83 going to next corr
# 13 71 84 going to next corr
# 13 72 74 going to next corr
# 13 72 85 going to next corr
# 13 73 86 going to next corr
# 13 73 89 going to next corr
# 13 78 79 going to next corr
# 13 78 80 going to next corr
# 13 78 91 going to next corr
# 13 82 84 going to next corr
# 13 82 83 going to next corr
# 13 88 90 going to next corr
# 14 6 11 going to next corr
# 14 8 23 going to next corr
# 14 8 13 going to next corr
# 14 56 57 going to next corr
# 14 56 83 going to next corr
# 14 56 82 going to next corr
# 14 56 84 going to next corr
# 14 56 71 going to next corr
# 14 56 58 going to next corr
# 14 56 69 going to next corr
# 14 56 70 going to next corr
# 14 59 61 going to next corr
# 14 59 60 going to next corr
# 14 62 77 going to next corr
# 14 62 90 going to next corr
# 14 62 88 going to next corr
# 14 62 76 going to next corr
# 14 62 64 going to next corr
# 14 62 63 going to next corr
# 14 62 75 going to next corr
# 14 62 89 going to next corr
# 14 62 65 going to next corr
# 14 62 67 going to next corr
# 14 63 75 going to next corr
# 14 63 89 going to next corr
# 14 63 88 going to next corr
# 14 63 90 going to next corr
# 14 63 77 going to next corr
# 14 64 76 going to next corr
# 14 65 67 going to next corr
# 14 65 66 going to next corr
# 14 65 76 going to next corr
# 14 71 82 going to next corr
# 14 71 83 going to next corr
# 14 71 84 going to next corr
# 14 72 74 going to next corr
# 14 72 85 going to next corr
# 14 73 86 going to next corr
# 14 73 89 going to next corr
# 14 78 79 going to next corr
# 14 78 80 going to next corr
# 14 78 91 going to next corr
# 14 82 84 going to next corr
# 14 82 83 going to next corr
# 14 88 90 going to next corr
# 15 6 11 going to next corr
# 15 21 26 going to next corr
# 15 56 57 going to next corr
# 15 56 83 going to next corr
# 15 56 82 going to next corr
# 15 56 84 going to next corr
# 15 56 71 going to next corr
# 15 56 58 going to next corr
# 15 56 69 going to next corr
# 15 56 70 going to next corr
# 15 59 61 going to next corr
# 15 59 60 going to next corr
# 15 62 77 going to next corr
# 15 62 90 going to next corr
# 15 62 88 going to next corr
# 15 62 76 going to next corr
# 15 62 64 going to next corr
# 15 62 63 going to next corr
# 15 62 75 going to next corr
# 15 62 89 going to next corr
# 15 62 65 going to next corr
# 15 62 67 going to next corr
# 15 63 75 going to next corr
# 15 63 89 going to next corr
# 15 63 88 going to next corr
# 15 63 90 going to next corr
# 15 63 77 going to next corr
# 15 64 76 going to next corr
# 15 65 67 going to next corr
# 15 65 66 going to next corr
# 15 65 76 going to next corr
# 15 71 82 going to next corr
# 15 71 83 going to next corr
# 15 71 84 going to next corr
# 15 72 74 going to next corr
# 15 72 85 going to next corr
# 15 73 86 going to next corr
# 15 73 89 going to next corr
# 15 78 79 going to next corr
# 15 78 80 going to next corr
# 15 78 91 going to next corr
# 15 82 84 going to next corr
# 15 82 83 going to next corr
# 15 88 90 going to next corr
# 16 8 23 going to next corr
# 16 8 13 going to next corr
# 16 56 57 going to next corr
# 16 56 83 going to next corr
# 16 56 82 going to next corr
# 16 56 84 going to next corr
# 16 56 71 going to next corr
# 16 56 58 going to next corr
# 16 56 69 going to next corr
# 16 56 70 going to next corr
# 16 59 61 going to next corr
# 16 59 60 going to next corr
# 16 62 77 going to next corr
# 16 62 90 going to next corr
# 16 62 88 going to next corr
# 16 62 76 going to next corr
# 16 62 64 going to next corr
# 16 62 63 going to next corr
# 16 62 75 going to next corr
# 16 62 89 going to next corr
# 16 62 65 going to next corr
# 16 62 67 going to next corr
# 16 63 75 going to next corr
# 16 63 89 going to next corr
# 16 63 88 going to next corr
# 16 63 90 going to next corr
# 16 63 77 going to next corr
# 16 64 76 going to next corr
# 16 65 67 going to next corr
# 16 65 66 going to next corr
# 16 65 76 going to next corr
# 16 71 82 going to next corr
# 16 71 83 going to next corr
# 16 71 84 going to next corr
# 16 72 74 going to next corr
# 16 72 85 going to next corr
# 16 73 86 going to next corr
# 16 73 89 going to next corr
# 16 78 79 going to next corr
# 16 78 80 going to next corr
# 16 78 91 going to next corr
# 16 82 84 going to next corr
# 16 82 83 going to next corr
# 16 88 90 going to next corr
# 17 1 11 going to next corr
# 17 1 6 going to next corr
# 17 1 16 going to next corr
# 17 1 26 going to next corr
# 17 6 11 going to next corr
# 17 16 26 going to next corr
# 17 21 26 going to next corr
# 17 56 57 going to next corr
# 17 56 83 going to next corr
# 17 56 82 going to next corr
# 17 56 84 going to next corr
# 17 56 71 going to next corr
# 17 56 58 going to next corr
# 17 56 69 going to next corr
# 17 56 70 going to next corr
# 17 59 61 going to next corr
# 17 59 60 going to next corr
# 17 62 77 going to next corr
# 17 62 90 going to next corr
# 17 62 88 going to next corr
# 17 62 76 going to next corr
# 17 62 64 going to next corr
# 17 62 63 going to next corr
# 17 62 75 going to next corr
# 17 62 89 going to next corr
# 17 62 65 going to next corr
# 17 62 67 going to next corr
# 17 63 75 going to next corr
# 17 63 89 going to next corr
# 17 63 88 going to next corr
# 17 63 90 going to next corr
# 17 63 77 going to next corr
# 17 64 76 going to next corr
# 17 65 67 going to next corr
# 17 65 66 going to next corr
# 17 65 76 going to next corr
# 17 71 82 going to next corr
# 17 71 83 going to next corr
# 17 71 84 going to next corr
# 17 72 74 going to next corr
# 17 72 85 going to next corr
# 17 73 86 going to next corr
# 17 73 89 going to next corr
# 17 78 79 going to next corr
# 17 78 80 going to next corr
# 17 78 91 going to next corr
# 17 82 84 going to next corr
# 17 82 83 going to next corr
# 17 88 90 going to next corr
# 18 6 11 going to next corr
# 18 8 23 going to next corr
# 18 21 26 going to next corr
# 18 36 37 going to next corr
# 18 36 87 going to next corr
# 18 36 39 going to next corr
# 18 36 38 going to next corr
# 18 36 68 going to next corr
# 18 36 91 going to next corr
# 18 36 81 going to next corr
# 18 36 74 going to next corr
# 18 36 40 going to next corr
# 18 36 70 going to next corr
# 18 36 85 going to next corr
# 18 36 43 going to next corr
# 18 38 39 going to next corr
# 18 40 43 going to next corr
# 18 40 87 going to next corr
# 18 40 68 going to next corr
# 18 40 81 going to next corr
# 18 40 74 going to next corr
# 18 40 70 going to next corr
# 18 40 91 going to next corr
# 18 40 72 going to next corr
# 18 40 85 going to next corr
# 18 40 69 going to next corr
# 18 40 58 going to next corr
# 18 40 56 going to next corr
# 18 40 57 going to next corr
# 18 40 41 going to next corr
# 18 40 83 going to next corr
# 18 41 42 going to next corr
# 18 41 58 going to next corr
# 18 41 56 going to next corr
# 18 41 57 going to next corr
# 18 41 83 going to next corr
# 18 41 82 going to next corr
# 18 41 84 going to next corr
# 18 41 71 going to next corr
# 18 41 69 going to next corr
# 18 41 70 going to next corr
# 18 56 57 going to next corr
# 18 56 83 going to next corr
# 18 56 82 going to next corr
# 18 56 84 going to next corr
# 18 56 71 going to next corr
# 18 56 58 going to next corr
# 18 56 69 going to next corr
# 18 56 70 going to next corr
# 18 59 61 going to next corr
# 18 59 60 going to next corr
# 18 62 77 going to next corr
# 18 62 90 going to next corr
# 18 62 88 going to next corr
# 18 62 76 going to next corr
# 18 62 64 going to next corr
# 18 62 63 going to next corr
# 18 62 75 going to next corr
# 18 62 89 going to next corr
# 18 62 65 going to next corr
# 18 62 67 going to next corr
# 18 63 75 going to next corr
# 18 63 89 going to next corr
# 18 63 88 going to next corr
# 18 63 90 going to next corr
# 18 63 77 going to next corr
# 18 64 76 going to next corr
# 18 65 67 going to next corr
# 18 65 66 going to next corr
# 18 65 76 going to next corr
# 18 71 82 going to next corr
# 18 71 83 going to next corr
# 18 71 84 going to next corr
# 18 72 74 going to next corr
# 18 72 85 going to next corr
# 18 73 86 going to next corr
# 18 73 89 going to next corr
# 18 78 79 going to next corr
# 18 78 80 going to next corr
# 18 78 91 going to next corr
# 18 82 84 going to next corr
# 18 82 83 going to next corr
# 18 88 90 going to next corr
# 19 5 20 going to next corr
# 19 5 10 going to next corr
# 19 5 25 going to next corr
# 19 6 11 going to next corr
# 19 7 22 going to next corr
# 19 7 12 going to next corr
# 19 7 27 going to next corr
# 19 21 26 going to next corr
# 19 24 34 going to next corr
# 19 36 37 going to next corr
# 19 36 87 going to next corr
# 19 36 39 going to next corr
# 19 36 38 going to next corr
# 19 36 68 going to next corr
# 19 36 91 going to next corr
# 19 36 81 going to next corr
# 19 36 74 going to next corr
# 19 36 40 going to next corr
# 19 36 70 going to next corr
# 19 36 85 going to next corr
# 19 36 43 going to next corr
# 19 38 39 going to next corr
# 19 40 43 going to next corr
# 19 40 87 going to next corr
# 19 40 68 going to next corr
# 19 40 81 going to next corr
# 19 40 74 going to next corr
# 19 40 70 going to next corr
# 19 40 91 going to next corr
# 19 40 72 going to next corr
# 19 40 85 going to next corr
# 19 40 69 going to next corr
# 19 40 58 going to next corr
# 19 40 56 going to next corr
# 19 40 57 going to next corr
# 19 40 41 going to next corr
# 19 40 83 going to next corr
# 19 41 42 going to next corr
# 19 41 58 going to next corr
# 19 41 56 going to next corr
# 19 41 57 going to next corr
# 19 41 83 going to next corr
# 19 41 82 going to next corr
# 19 41 84 going to next corr
# 19 41 71 going to next corr
# 19 41 69 going to next corr
# 19 41 70 going to next corr
# 19 56 57 going to next corr
# 19 56 83 going to next corr
# 19 56 82 going to next corr
# 19 56 84 going to next corr
# 19 56 71 going to next corr
# 19 56 58 going to next corr
# 19 56 69 going to next corr
# 19 56 70 going to next corr
# 19 59 61 going to next corr
# 19 59 60 going to next corr
# 19 62 77 going to next corr
# 19 62 90 going to next corr
# 19 62 88 going to next corr
# 19 62 76 going to next corr
# 19 62 64 going to next corr
# 19 62 63 going to next corr
# 19 62 75 going to next corr
# 19 62 89 going to next corr
# 19 62 65 going to next corr
# 19 62 67 going to next corr
# 19 63 75 going to next corr
# 19 63 89 going to next corr
# 19 63 88 going to next corr
# 19 63 90 going to next corr
# 19 63 77 going to next corr
# 19 64 76 going to next corr
# 19 65 67 going to next corr
# 19 65 66 going to next corr
# 19 65 76 going to next corr
# 19 71 82 going to next corr
# 19 71 83 going to next corr
# 19 71 84 going to next corr
# 19 72 74 going to next corr
# 19 72 85 going to next corr
# 19 73 86 going to next corr
# 19 73 89 going to next corr
# 19 78 79 going to next corr
# 19 78 80 going to next corr
# 19 78 91 going to next corr
# 19 82 84 going to next corr
# ...
# 451 40 58 going to next corr
# 451 40 56 going to next corr
# 451 40 57 going to next corr
# 451 40 41 going to next corr
# 451 40 83 going to next corr
# 451 41 42 going to next corr
# 451 41 58 going to next corr
# 451 41 56 going to next corr
# 451 41 57 going to next corr
# 451 41 83 going to next corr
# 451 41 82 going to next corr
# 451 41 84 going to next corr
# 451 41 71 going to next corr
# 451 41 69 going to next corr
# 451 41 70 going to next corr
# 451 56 57 going to next corr
# 451 56 83 going to next corr
# 451 56 82 going to next corr
# 451 56 84 going to next corr
# 451 56 71 going to next corr
# 451 56 58 going to next corr
# 451 56 69 going to next corr
# 451 56 70 going to next corr
# 451 59 61 going to next corr
# 451 59 60 going to next corr
# 451 62 77 going to next corr
# 451 62 90 going to next corr
# 451 62 88 going to next corr
# 451 62 76 going to next corr
# 451 62 64 going to next corr
# 451 62 63 going to next corr
# 451 62 75 going to next corr
# 451 62 89 going to next corr
# 451 62 65 going to next corr
# 451 62 67 going to next corr
# 451 63 75 going to next corr
# 451 63 89 going to next corr
# 451 63 88 going to next corr
# 451 63 90 going to next corr
# 451 63 77 going to next corr
# 451 64 76 going to next corr
# 451 65 67 going to next corr
# 451 65 66 going to next corr
# 451 65 76 going to next corr
# 451 71 82 going to next corr
# 451 71 83 going to next corr
# 451 71 84 going to next corr
# 451 72 74 going to next corr
# 451 72 85 going to next corr
# 451 73 86 going to next corr
# 451 73 89 going to next corr
# 451 78 79 going to next corr
# 451 78 80 going to next corr
# 451 78 91 going to next corr
# 451 82 84 going to next corr
# 451 82 83 going to next corr
# 451 88 90 going to next corr
# 452 1 11 going to next corr
# 452 1 6 going to next corr
# 452 5 20 going to next corr
# 452 6 11 going to next corr
# 452 7 22 going to next corr
# 452 7 12 going to next corr
# 452 7 27 going to next corr
# 452 24 34 going to next corr
# 452 24 29 going to next corr
# 452 36 37 going to next corr
# 452 36 87 going to next corr
# 452 36 39 going to next corr
# 452 36 38 going to next corr
# 452 36 68 going to next corr
# 452 36 91 going to next corr
# 452 36 81 going to next corr
# 452 36 74 going to next corr
# 452 36 40 going to next corr
# 452 36 70 going to next corr
# 452 36 85 going to next corr
# 452 36 43 going to next corr
# 452 38 39 going to next corr
# 452 40 43 going to next corr
# 452 40 87 going to next corr
# 452 40 68 going to next corr
# 452 40 81 going to next corr
# 452 40 74 going to next corr
# 452 40 70 going to next corr
# 452 40 91 going to next corr
# 452 40 72 going to next corr
# 452 40 85 going to next corr
# 452 40 69 going to next corr
# 452 40 58 going to next corr
# 452 40 56 going to next corr
# 452 40 57 going to next corr
# 452 40 41 going to next corr
# 452 40 83 going to next corr
# 452 41 42 going to next corr
# 452 41 58 going to next corr
# 452 41 56 going to next corr
# 452 41 57 going to next corr
# 452 41 83 going to next corr
# 452 41 82 going to next corr
# 452 41 84 going to next corr
# 452 41 71 going to next corr
# 452 41 69 going to next corr
# 452 41 70 going to next corr
# 452 56 57 going to next corr
# 452 56 83 going to next corr
# 452 56 82 going to next corr
# 452 56 84 going to next corr
# 452 56 71 going to next corr
# 452 56 58 going to next corr
# 452 56 69 going to next corr
# 452 56 70 going to next corr
# 452 59 61 going to next corr
# 452 59 60 going to next corr
# 452 62 77 going to next corr
# 452 62 90 going to next corr
# 452 62 88 going to next corr
# 452 62 76 going to next corr
# 452 62 64 going to next corr
# 452 62 63 going to next corr
# 452 62 75 going to next corr
# 452 62 89 going to next corr
# 452 62 65 going to next corr
# 452 62 67 going to next corr
# 452 63 75 going to next corr
# 452 63 89 going to next corr
# 452 63 88 going to next corr
# 452 63 90 going to next corr
# 452 63 77 going to next corr
# 452 64 76 going to next corr
# 452 65 67 going to next corr
# 452 65 66 going to next corr
# 452 65 76 going to next corr
# 452 71 82 going to next corr
# 452 71 83 going to next corr
# 452 71 84 going to next corr
# 452 72 74 going to next corr
# 452 72 85 going to next corr
# 452 73 86 going to next corr
# 452 73 89 going to next corr
# 452 78 79 going to next corr
# 452 78 80 going to next corr
# 452 78 91 going to next corr
# 452 82 84 going to next corr
# 452 82 83 going to next corr
# 452 88 90 going to next corr
# 453 6 11 going to next corr
# 453 21 26 going to next corr
# 453 56 57 going to next corr
# 453 56 83 going to next corr
# 453 56 82 going to next corr
# 453 56 84 going to next corr
# 453 56 71 going to next corr
# 453 56 58 going to next corr
# 453 56 69 going to next corr
# 453 56 70 going to next corr
# 453 59 61 going to next corr
# 453 59 60 going to next corr
# 453 62 77 going to next corr
# 453 62 90 going to next corr
# 453 62 88 going to next corr
# 453 62 76 going to next corr
# 453 62 64 going to next corr
# 453 62 63 going to next corr
# 453 62 75 going to next corr
# 453 62 89 going to next corr
# 453 62 65 going to next corr
# 453 62 67 going to next corr
# 453 63 75 going to next corr
# 453 63 89 going to next corr
# 453 63 88 going to next corr
# 453 63 90 going to next corr
# 453 63 77 going to next corr
# 453 64 76 going to next corr
# 453 65 67 going to next corr
# 453 65 66 going to next corr
# 453 65 76 going to next corr
# 453 71 82 going to next corr
# 453 71 83 going to next corr
# 453 71 84 going to next corr
# 453 72 74 going to next corr
# 453 72 85 going to next corr
# 453 73 86 going to next corr
# 453 73 89 going to next corr
# 453 78 79 going to next corr
# 453 78 80 going to next corr
# 453 78 91 going to next corr
# 453 82 84 going to next corr
# 453 82 83 going to next corr
# 453 88 90 going to next corr
# 454 6 11 going to next corr
# 454 56 57 going to next corr
# 454 56 83 going to next corr
# 454 56 82 going to next corr
# 454 56 84 going to next corr
# 454 56 71 going to next corr
# 454 56 58 going to next corr
# 454 56 69 going to next corr
# 454 56 70 going to next corr
# 454 59 61 going to next corr
# 454 59 60 going to next corr
# 454 62 77 going to next corr
# 454 62 90 going to next corr
# 454 62 88 going to next corr
# 454 62 76 going to next corr
# 454 62 64 going to next corr
# 454 62 63 going to next corr
# 454 62 75 going to next corr
# 454 62 89 going to next corr
# 454 62 65 going to next corr
# 454 62 67 going to next corr
# 454 63 75 going to next corr
# 454 63 89 going to next corr
# 454 63 88 going to next corr
# 454 63 90 going to next corr
# 454 63 77 going to next corr
# 454 64 76 going to next corr
# 454 65 67 going to next corr
# 454 65 66 going to next corr
# 454 65 76 going to next corr
# 454 71 82 going to next corr
# 454 71 83 going to next corr
# 454 71 84 going to next corr
# 454 72 74 going to next corr
# 454 72 85 going to next corr
# 454 73 86 going to next corr
# 454 73 89 going to next corr
# 454 78 79 going to next corr
# 454 78 80 going to next corr
# 454 78 91 going to next corr
# 454 82 84 going to next corr
# 454 82 83 going to next corr
# 454 88 90 going to next corr
# 455 6 11 going to next corr
# 455 7 22 going to next corr
# 455 7 12 going to next corr
# 455 7 27 going to next corr
# 455 8 23 going to next corr
# 455 8 13 going to next corr
# 455 21 26 going to next corr
# 455 56 57 going to next corr
# 455 56 83 going to next corr
# 455 56 82 going to next corr
# 455 56 84 going to next corr
# 455 56 71 going to next corr
# 455 56 58 going to next corr
# 455 56 69 going to next corr
# 455 56 70 going to next corr
# 455 59 61 going to next corr
# 455 59 60 going to next corr
# 455 62 77 going to next corr
# 455 62 90 going to next corr
# 455 62 88 going to next corr
# 455 62 76 going to next corr
# 455 62 64 going to next corr
# 455 62 63 going to next corr
# 455 62 75 going to next corr
# 455 62 89 going to next corr
# 455 62 65 going to next corr
# 455 62 67 going to next corr
# 455 63 75 going to next corr
# 455 63 89 going to next corr
# 455 63 88 going to next corr
# 455 63 90 going to next corr
# 455 63 77 going to next corr
# 455 64 76 going to next corr
# 455 65 67 going to next corr
# 455 65 66 going to next corr
# 455 65 76 going to next corr
# 455 71 82 going to next corr
# 455 71 83 going to next corr
# 455 71 84 going to next corr
# 455 72 74 going to next corr
# 455 72 85 going to next corr
# 455 73 86 going to next corr
# 455 73 89 going to next corr
# 455 78 79 going to next corr
# 455 78 80 going to next corr
# 455 78 91 going to next corr
# 455 82 84 going to next corr
# 455 82 83 going to next corr
# 455 88 90 going to next corr
# 456 1 11 going to next corr
# 456 1 6 going to next corr
# 456 6 11 going to next corr
# 456 21 26 going to next corr
# 456 56 57 going to next corr
# 456 56 83 going to next corr
# 456 56 82 going to next corr
# 456 56 84 going to next corr
# 456 56 71 going to next corr
# 456 56 58 going to next corr
# 456 56 69 going to next corr
# 456 56 70 going to next corr
# 456 59 61 going to next corr
# 456 59 60 going to next corr
# 456 62 77 going to next corr
# 456 62 90 going to next corr
# 456 62 88 going to next corr
# 456 62 76 going to next corr
# 456 62 64 going to next corr
# 456 62 63 going to next corr
# 456 62 75 going to next corr
# 456 62 89 going to next corr
# 456 62 65 going to next corr
# 456 62 67 going to next corr
# 456 63 75 going to next corr
# 456 63 89 going to next corr
# 456 63 88 going to next corr
# 456 63 90 going to next corr
# 456 63 77 going to next corr
# 456 64 76 going to next corr
# 456 65 67 going to next corr
# 456 65 66 going to next corr
# 456 65 76 going to next corr
# 456 71 82 going to next corr
# 456 71 83 going to next corr
# 456 71 84 going to next corr
# 456 72 74 going to next corr
# 456 72 85 going to next corr
# 456 73 86 going to next corr
# 456 73 89 going to next corr
# 456 78 79 going to next corr
# 456 78 80 going to next corr
# 456 78 91 going to next corr
# 456 82 84 going to next corr
# 456 82 83 going to next corr
# 456 88 90 going to next corr
# 457 1 11 going to next corr
# 457 1 6 going to next corr
# 457 1 16 going to next corr
# 457 1 26 going to next corr
# 457 6 11 going to next corr
# 457 16 26 going to next corr
# 457 21 26 going to next corr
# 457 56 57 going to next corr
# 457 56 83 going to next corr
# 457 56 82 going to next corr
# 457 56 84 going to next corr
# 457 56 71 going to next corr
# 457 56 58 going to next corr
# 457 56 69 going to next corr
# 457 56 70 going to next corr
# 457 59 61 going to next corr
# 457 59 60 going to next corr
# 457 62 77 going to next corr
# 457 62 90 going to next corr
# 457 62 88 going to next corr
# 457 62 76 going to next corr
# 457 62 64 going to next corr
# 457 62 63 going to next corr
# 457 62 75 going to next corr
# 457 62 89 going to next corr
# 457 62 65 going to next corr
# 457 62 67 going to next corr
# 457 63 75 going to next corr
# 457 63 89 going to next corr
# 457 63 88 going to next corr
# 457 63 90 going to next corr
# 457 63 77 going to next corr
# 457 64 76 going to next corr
# 457 65 67 going to next corr
# 457 65 66 going to next corr
# 457 65 76 going to next corr
# 457 71 82 going to next corr
# 457 71 83 going to next corr
# 457 71 84 going to next corr
# 457 72 74 going to next corr
# 457 72 85 going to next corr
# 457 73 86 going to next corr
# 457 73 89 going to next corr
# 457 78 79 going to next corr
# 457 78 80 going to next corr
# 457 78 91 going to next corr
# 457 82 84 going to next corr
# 457 82 83 going to next corr
# 457 88 90 going to next corr
# 459 0 10 going to next corr
# 459 1 11 going to next corr
# 459 1 6 going to next corr
# 459 3 13 going to next corr
# 459 5 20 going to next corr
# 459 5 10 going to next corr
# 459 5 25 going to next corr
# 459 6 11 going to next corr
# 459 8 23 going to next corr
# 459 8 13 going to next corr
# 459 21 26 going to next corr
# 459 56 57 going to next corr
# 459 56 83 going to next corr
# 459 56 82 going to next corr
# 459 56 84 going to next corr
# 459 56 71 going to next corr
# 459 56 58 going to next corr
# 459 56 69 going to next corr
# 459 56 70 going to next corr
# 459 59 61 going to next corr
# 459 59 60 going to next corr
# 459 62 77 going to next corr
# 459 62 90 going to next corr
# 459 62 88 going to next corr
# 459 62 76 going to next corr
# 459 62 64 going to next corr
# 459 62 63 going to next corr
# 459 62 75 going to next corr
# 459 62 89 going to next corr
# 459 62 65 going to next corr
# 459 62 67 going to next corr
# 459 63 75 going to next corr
# 459 63 89 going to next corr
# 459 63 88 going to next corr
# 459 63 90 going to next corr
# 459 63 77 going to next corr
# 459 64 76 going to next corr
# 459 65 67 going to next corr
# 459 65 66 going to next corr
# 459 65 76 going to next corr
# 459 71 82 going to next corr
# 459 71 83 going to next corr
# 459 71 84 going to next corr
# 459 72 74 going to next corr
# 459 72 85 going to next corr
# 459 73 86 going to next corr
# 459 73 89 going to next corr
# 459 78 79 going to next corr
# 459 78 80 going to next corr
# 459 78 91 going to next corr
# 459 82 84 going to next corr
# 459 82 83 going to next corr
# 459 88 90 going to next corr
# (460, 92)
#        significance  flux_aper_hilim_s  flux_aper_hilim_u  flux_aper_hilim_m  \
# count    460.000000         460.000000         460.000000         460.000000
# mean      70.680500           0.428578           0.420357           0.433920
# std      109.946267           0.198401           0.200715           0.182517
# min        2.110000           0.000000           0.000000          -0.000767
# 25%       11.120000           0.286660           0.243411           0.302125
# 50%       23.470000           0.390999           0.430555           0.407365
# 75%       49.260000           0.561875           0.589274           0.553205
# max      376.060000           1.000000           1.000000           1.000000
#
#        flux_aper_hilim_h  flux_aper_hilim_b  flux_aper_lolim_s  \
# count         460.000000         460.000000         460.000000
# mean            0.481062           0.504533           0.436517
# std             0.192136           0.185377           0.208229
# min             0.000000           0.000000          -0.082395
# 25%             0.326932           0.365424           0.293230
# 50%             0.502370           0.505772           0.426510
# 75%             0.615238           0.627824           0.558226
# max             1.000000           1.000000           1.000000
#
#        flux_aper_lolim_u  flux_aper_lolim_m  flux_aper_lolim_h  ...  \
# count         460.000000         460.000000         460.000000  ...
# mean            0.434097           0.435983           0.465390  ...
# std             0.164964           0.193531           0.195705  ...
# min             0.000000          -0.029526           0.000000  ...
# 25%             0.298375           0.300438           0.304614  ...
# 50%             0.441569           0.409963           0.466873  ...
# 75%             0.569438           0.559324           0.600996  ...
# max             1.000000           1.000000           1.000000  ...
#
#        flux_brems  flux_brems_lolim  flux_brems_hilim    brems_kt  \
# count  460.000000        460.000000        460.000000  460.000000
# mean     0.251453          0.259866          0.248030    0.612394
# std      0.284852          0.291700          0.282629    0.284747
# min      0.000000          0.000000          0.000000    0.000000
# 25%      0.040732          0.045360          0.038345    0.452352
# 50%      0.052287          0.056642          0.050388    0.655933
# 75%      0.550404          0.569200          0.543390    0.814252
# max      1.000000          1.000000          1.000000    1.085012
#
#        brems_kt_hilim  brems_kt_lolim    brems_nh  brems_nh_hilim  \
# count      460.000000      460.000000  460.000000      460.000000
# mean         0.093594        0.852212    0.732214        0.689055
# std          0.070030        0.415186    0.298392        0.279563
# min          0.000000        0.000000    0.000000        0.000000
# 25%          0.069422        0.608091    0.658813        0.618561
# 50%          0.090041        0.916857    0.758004        0.712205
# 75%          0.107216        1.151447    0.940119        0.882975
# max          1.000000        1.560725    1.111106        1.043694
#
#        brems_nh_lolim  brems_stat
# count      460.000000  460.000000
# mean         0.795208    0.659974
# std          0.326928    0.229451
# min          0.000000    0.000000
# 25%          0.717195    0.654979
# 50%          0.825719    0.711883
# 75%          1.018479    0.785485
# max          1.209083    1.000000
#
# [8 rows x 93 columns]
