# %%
import numpy as np 
from matplotlib import pyplot as plt 
import seaborn as sns 
from tqdm import tqdm 
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import RandomForestClassifier  , AdaBoostClassifier , GradientBoostingClassifier
from sklearn.metrics import precision_score , recall_score 
import xgboost as xgb 
import pandas as pd 
import sklearn.neighbors._base
from os import sys
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
from missingpy import MissForest 
from sklearn.metrics import confusion_matrix , ConfusionMatrixDisplay
sns.set_style('whitegrid')
# %load_ext autoreload
# %autoreload 2
sns.set_style('whitegrid')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def details(data_sent , comments = ''):
    if(comments):
        print(comments)
    sp = (data_sent.isna().sum().sum())/ data.size
    print('________________________________________________')
    print('Sparsity in the data : {:.2f}'.format(sp))
    num_rows = data_sent.shape
    print('Data shape' , num_rows)
    #display(data_sent['class'].value_counts())
    print('Number of sources : ')
    cl = data_sent['class'].unique()
    for c in cl:
        num_src = len(data_sent[data_sent['class']==c]['src_id'].unique())
        num_obs = len(data_sent[data_sent['class']==c])
        print(c ,' \t ' , num_src , '\t' , num_obs)

# %%
from features import phot_flux , en_flux , hard, powlaw_fit , bb_fit , brems_fit , intra_obs_var , inter_ob_var , info_col , phot_flux_hilim , phot_flux_lolim , en_flux_hilim , en_flux_lolim

# %%
feat_to_use = info_col + phot_flux + phot_flux_hilim + phot_flux_lolim + en_flux + en_flux_hilim + en_flux_lolim + powlaw_fit +bb_fit +hard+ intra_obs_var +inter_ob_var 

# use only independent features small subset
from features import small_ind_subset
feat_to_use = info_col + small_ind_subset  
data_cv = pd.read_csv('filtered_data/cv_new_data.csv' , index_col='obs_id')[feat_to_use]
data_cv.insert(0 , 'class' , ['CV']*len(data_cv))
data_lx  =  pd.read_csv('filtered_data/lmxb_data.csv' , index_col = 'obs_id')[feat_to_use]
data_lx.insert(0 , 'class' , ['LX']*len(data_lx))

# %% [markdown]
# ### Add old pulsar data also

# %%
data_pl_old  =  pd.read_csv('filtered_data/pl_old_data.csv' , index_col = 'obs_id')[feat_to_use]
data_pl_old.insert(0 , 'class' , ['PL']*len(data_pl_old))
data_pl_new  =  pd.read_csv('filtered_data/pl_new_data.csv' , index_col = 'obs_id')[feat_to_use]
data_pl_new.insert(0 , 'class' , ['PL']*len(data_pl_new))

# %%
data = pd.concat([data_cv , data_pl_new , data_lx] , axis=0)
data
# Out:
#               class   src_id  num_obs                    src_n  \
# obs_id
# CV_0_obs_0       CV     CV_0       25  CSS120424:125906+242634
# CV_0_obs_1       CV     CV_0       25  CSS120424:125906+242634
# CV_0_obs_2       CV     CV_0       25  CSS120424:125906+242634
# CV_0_obs_3       CV     CV_0       25  CSS120424:125906+242634
# CV_0_obs_4       CV     CV_0       25  CSS120424:125906+242634
# ...             ...      ...      ...                      ...
# LMXB_86_obs_0    LX  LMXB_86        1    SAX_J1810.8-2609_____
# LMXB_90_obs_0    LX  LMXB_90        1    XTE_J2123-058________
# LMXB_91_obs_0    LX  LMXB_91        1    XB_1732-304__________
# LMXB_92_obs_0    LX  LMXB_92        1    BW_ANT_______________
# LMXB_94_obs_0    LX  LMXB_94        1    J1748-3607___________
#
#                                  name         ra        dec  livetime  \
# obs_id
# CV_0_obs_0      2CXO J004247.1+411619   10.69654  41.272150    4103.7
# CV_0_obs_1      2CXO J004247.1+411619   10.69654  41.272150    3907.5
# CV_0_obs_2      2CXO J004247.1+411619   10.69654  41.272150    3907.5
# CV_0_obs_3      2CXO J004247.1+411619   10.69654  41.272150    3904.6
# CV_0_obs_4      2CXO J004247.1+411619   10.69654  41.272150    3907.5
# ...                               ...        ...        ...       ...
# LMXB_86_obs_0   2CXO J181044.4-260901  272.68530 -26.150370   31871.5
# LMXB_90_obs_0   2CXO J212314.5-054753  320.81060  -5.798128   17705.1
# LMXB_91_obs_0   2CXO J173547.0-302858  263.94590 -30.482820   18855.8
# LMXB_92_obs_0   2CXO J092920.1-312303  142.33410 -31.384270   24445.9
# LMXB_94_obs_0   2CXO J174813.1-360758  267.05470 -36.132810   15794.5
#
#                significance   likelihood  ...  flux_aper_lolim_h  \
# obs_id                                    ...
# CV_0_obs_0            52.93  16618.73000  ...       3.537000e-16
# CV_0_obs_1            52.93  16618.73000  ...       0.000000e+00
# CV_0_obs_2            52.93  16618.73000  ...       3.499000e-16
# CV_0_obs_3            52.93  16618.73000  ...       2.078000e-15
# CV_0_obs_4            52.93  16618.73000  ...       0.000000e+00
# ...                     ...          ...  ...                ...
# LMXB_86_obs_0          9.29    512.97550  ...       4.687000e-15
# LMXB_90_obs_0          4.06    132.76700  ...       9.107000e-16
# LMXB_91_obs_0          4.89    114.24570  ...       7.144000e-16
# LMXB_92_obs_0          3.70     75.53454  ...       2.083000e-15
# LMXB_94_obs_0          3.09     50.50810  ...                NaN
#
#                var_inter_index_h  flux_aper_lolim_s  var_mean_b  var_sigma_b  \
# obs_id
# CV_0_obs_0                   NaN       0.000000e+00         NaN          NaN
# CV_0_obs_1                   NaN       0.000000e+00         NaN          NaN
# CV_0_obs_2                   NaN       0.000000e+00         NaN          NaN
# CV_0_obs_3                   NaN       0.000000e+00         NaN          NaN
# CV_0_obs_4                   NaN       0.000000e+00         NaN          NaN
# ...                          ...                ...         ...          ...
# LMXB_86_obs_0                NaN       5.489000e-15    0.003456     0.000029
# LMXB_90_obs_0                NaN       2.231000e-15    0.001171     0.000255
# LMXB_91_obs_0                NaN       1.277000e-16    0.001623     0.000211
# LMXB_92_obs_0                NaN       7.353000e-16    0.000740     0.000201
# LMXB_94_obs_0                NaN       1.068000e-15    0.000782     0.000061
#
#                ks_prob_b  var_prob_b  var_inter_index_s  var_inter_index_m  \
# obs_id
# CV_0_obs_0           NaN         NaN                5.0                NaN
# CV_0_obs_1           NaN         NaN                5.0                NaN
# CV_0_obs_2           NaN         NaN                5.0                NaN
# CV_0_obs_3           NaN         NaN                5.0                NaN
# CV_0_obs_4           NaN         NaN                5.0                NaN
# ...                  ...         ...                ...                ...
# LMXB_86_obs_0      0.829       0.084                NaN                NaN
# LMXB_90_obs_0      0.265       0.807                NaN                NaN
# LMXB_91_obs_0      0.735       0.451                NaN                5.0
# LMXB_92_obs_0      0.940       0.607                NaN                NaN
# LMXB_94_obs_0      0.134       0.380                NaN                NaN
#
#                var_inter_sigma_u
# obs_id
# CV_0_obs_0                   NaN
# CV_0_obs_1                   NaN
# CV_0_obs_2                   NaN
# CV_0_obs_3                   NaN
# CV_0_obs_4                   NaN
# ...                          ...
# LMXB_86_obs_0                NaN
# LMXB_90_obs_0                NaN
# LMXB_91_obs_0                NaN
# LMXB_92_obs_0                NaN
# LMXB_94_obs_0                NaN
#
# [3103 rows x 29 columns]

# %%
data['class'].value_counts()
# Out:
# CV    1582
# PL    1000
# LX     521
# Name: class, dtype: int64

# %%
sp = [] 
for f in feat_to_use:
    #print(f)
    na = data[feat_to_use][f].isna().value_counts()
    try:
        sp.append(float(1-na[0]/(na[0]+na[1])))
    except:
        sp.append(0)
sp =  np.asarray(sp)
sparsity = pd.DataFrame(
    {
        "feat" : feat_to_use ,
        "sp_val" :sp
    }
).sort_values(by='sp_val' , ascending=False).reset_index(drop=True)
sparsity
# Out:
#                  feat    sp_val
# 0   var_inter_sigma_u  0.476636
# 1          var_prob_b  0.399291
# 2           ks_prob_b  0.398646
# 3         var_sigma_b  0.398646
# 4          var_mean_b  0.398646
# 5   flux_aper_hilim_u  0.353851
# 6   var_inter_index_h  0.212053
# 7   var_inter_index_s  0.194328
# 8   var_inter_index_m  0.185305
# 9   var_inter_sigma_s  0.184015
# 10  var_inter_sigma_m  0.179504
# 11  flux_aper_lolim_s  0.169836
# 12  flux_aper_lolim_h  0.167902
# 13  flux_aper_lolim_m  0.163068
# 14  var_inter_index_b  0.138253
# 15   var_inter_prob_b  0.126329
# 16            hard_ms  0.063487
# 17            hard_hs  0.056719
# 18            hard_hm  0.041573
# 19                dec  0.000000
# 20              src_n  0.000000
# 21               name  0.000000
# 22                 ra  0.000000
# 23         likelihood  0.000000
# 24           livetime  0.000000
# 25       significance  0.000000
# 26            num_obs  0.000000
# 27             src_id  0.000000

# %%
sparse_feat = sparsity[sparsity['sp_val']>0.5].sort_values(by='sp_val').reset_index(drop=True)
sparse_feat = sparse_feat['feat'].to_list()
#sparse_feat

# %%
dense_feat = sparsity[sparsity['sp_val']<0.5].sort_values(by='sp_val').reset_index(drop=True)
dense_feat = dense_feat['feat'].to_list()
#dense_feat

# %%
data_use = data[dense_feat+['class']]
details(data , 'Before removing sparse columns')
details(data_use , 'After removing sparse columns')
# Out:
# Before removing sparse columns
# ________________________________________________
# Sparsity in the data : 0.15
# Data shape (3103, 29)
# Number of sources :
# CV  	  184 	 1582
# PL  	  178 	 1000
# LX  	  58 	 521
# After removing sparse columns
# ________________________________________________
# Sparsity in the data : 0.15
# Data shape (3103, 29)
# Number of sources :
# CV  	  184 	 1582
# PL  	  178 	 1000
# LX  	  58 	 521

# %%
flux_feat = phot_flux + phot_flux_lolim + phot_flux_hilim + en_flux + en_flux_lolim + en_flux_hilim
flux_feat_avail = list(set(flux_feat) & set(dense_feat))
def take_log(data_sent):
    x_train_log = data_sent.copy()
    for f in flux_feat_avail[:]:
        x_train_log.loc[:,f] = -(np.log10(x_train_log.loc[:,f]))
    x_train_log = x_train_log.replace(-np.inf , np.nan)
    x_train_log = x_train_log.replace(np.inf , np.nan)
    return x_train_log

# %%
df_log = take_log(data_use)
df_log
# Out:
# /home/kumaran/.local/lib/python3.6/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                 src_id  significance  livetime   likelihood         ra  \
# obs_id
# CV_0_obs_0        CV_0         52.93    4103.7  16618.73000   10.69654
# CV_0_obs_1        CV_0         52.93    3907.5  16618.73000   10.69654
# CV_0_obs_2        CV_0         52.93    3907.5  16618.73000   10.69654
# CV_0_obs_3        CV_0         52.93    3904.6  16618.73000   10.69654
# CV_0_obs_4        CV_0         52.93    3907.5  16618.73000   10.69654
# ...                ...           ...       ...          ...        ...
# LMXB_86_obs_0  LMXB_86          9.29   31871.5    512.97550  272.68530
# LMXB_90_obs_0  LMXB_90          4.06   17705.1    132.76700  320.81060
# LMXB_91_obs_0  LMXB_91          4.89   18855.8    114.24570  263.94590
# LMXB_92_obs_0  LMXB_92          3.70   24445.9     75.53454  142.33410
# LMXB_94_obs_0  LMXB_94          3.09   15794.5     50.50810  267.05470
#
#                                  name                    src_n        dec  \
# obs_id
# CV_0_obs_0      2CXO J004247.1+411619  CSS120424:125906+242634  41.272150
# CV_0_obs_1      2CXO J004247.1+411619  CSS120424:125906+242634  41.272150
# CV_0_obs_2      2CXO J004247.1+411619  CSS120424:125906+242634  41.272150
# CV_0_obs_3      2CXO J004247.1+411619  CSS120424:125906+242634  41.272150
# CV_0_obs_4      2CXO J004247.1+411619  CSS120424:125906+242634  41.272150
# ...                               ...                      ...        ...
# LMXB_86_obs_0   2CXO J181044.4-260901    SAX_J1810.8-2609_____ -26.150370
# LMXB_90_obs_0   2CXO J212314.5-054753    XTE_J2123-058________  -5.798128
# LMXB_91_obs_0   2CXO J173547.0-302858    XB_1732-304__________ -30.482820
# LMXB_92_obs_0   2CXO J092920.1-312303    BW_ANT_______________ -31.384270
# LMXB_94_obs_0   2CXO J174813.1-360758    J1748-3607___________ -36.132810
#
#                num_obs  hard_hm  ...  var_inter_index_m  var_inter_index_s  \
# obs_id                           ...
# CV_0_obs_0          25   0.9994  ...                NaN                5.0
# CV_0_obs_1          25   0.9994  ...                NaN                5.0
# CV_0_obs_2          25   0.9994  ...                NaN                5.0
# CV_0_obs_3          25   0.9994  ...                NaN                5.0
# CV_0_obs_4          25  -0.9994  ...                NaN                5.0
# ...                ...      ...  ...                ...                ...
# LMXB_86_obs_0        1  -0.2124  ...                NaN                NaN
# LMXB_90_obs_0        1   0.2711  ...                NaN                NaN
# LMXB_91_obs_0        1  -0.6034  ...                5.0                NaN
# LMXB_92_obs_0        1   0.3310  ...                NaN                NaN
# LMXB_94_obs_0        1  -0.9994  ...                NaN                NaN
#
#                var_inter_index_h  flux_aper_hilim_u  var_mean_b  var_sigma_b  \
# obs_id
# CV_0_obs_0                   NaN          13.177505         NaN          NaN
# CV_0_obs_1                   NaN          12.648397         NaN          NaN
# CV_0_obs_2                   NaN          12.947306         NaN          NaN
# CV_0_obs_3                   NaN          13.064140         NaN          NaN
# CV_0_obs_4                   NaN          13.072989         NaN          NaN
# ...                          ...                ...         ...          ...
# LMXB_86_obs_0                NaN          14.159831    0.003456     0.000029
# LMXB_90_obs_0                NaN          14.612610    0.001171     0.000255
# LMXB_91_obs_0                NaN          15.247567    0.001623     0.000211
# LMXB_92_obs_0                NaN          14.335264    0.000740     0.000201
# LMXB_94_obs_0                NaN                NaN    0.000782     0.000061
#
#                ks_prob_b  var_prob_b  var_inter_sigma_u  class
# obs_id
# CV_0_obs_0           NaN         NaN                NaN     CV
# CV_0_obs_1           NaN         NaN                NaN     CV
# CV_0_obs_2           NaN         NaN                NaN     CV
# CV_0_obs_3           NaN         NaN                NaN     CV
# CV_0_obs_4           NaN         NaN                NaN     CV
# ...                  ...         ...                ...    ...
# LMXB_86_obs_0      0.829       0.084                NaN     LX
# LMXB_90_obs_0      0.265       0.807                NaN     LX
# LMXB_91_obs_0      0.735       0.451                NaN     LX
# LMXB_92_obs_0      0.940       0.607                NaN     LX
# LMXB_94_obs_0      0.134       0.380                NaN     LX
#
# [3103 rows x 29 columns]

# %% [markdown]
# # All obs Imputation

# %%
info_col_cl = info_col + ['class']

# %%
data_id = df_log[info_col_cl]
data_val = df_log.drop(columns = info_col_cl)
rf_imputer = MissForest(verbose=0 , decreasing=True)
new_data = rf_imputer.fit_transform(data_val)
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4

# %%
new_imp_data =  pd.DataFrame(new_data , columns = data_val.columns.to_list()  , index=data_val.index.to_list())
new_imp_data.index.name = 'obs_id'

# %%
data_imp_v2 = pd.concat([data_id , new_imp_data] , axis=1)
data_imp_v2
# Out:
#                 src_id  num_obs                    src_n  \
# obs_id
# CV_0_obs_0        CV_0       25  CSS120424:125906+242634
# CV_0_obs_1        CV_0       25  CSS120424:125906+242634
# CV_0_obs_2        CV_0       25  CSS120424:125906+242634
# CV_0_obs_3        CV_0       25  CSS120424:125906+242634
# CV_0_obs_4        CV_0       25  CSS120424:125906+242634
# ...                ...      ...                      ...
# LMXB_86_obs_0  LMXB_86        1    SAX_J1810.8-2609_____
# LMXB_90_obs_0  LMXB_90        1    XTE_J2123-058________
# LMXB_91_obs_0  LMXB_91        1    XB_1732-304__________
# LMXB_92_obs_0  LMXB_92        1    BW_ANT_______________
# LMXB_94_obs_0  LMXB_94        1    J1748-3607___________
#
#                                  name         ra        dec  livetime  \
# obs_id
# CV_0_obs_0      2CXO J004247.1+411619   10.69654  41.272150    4103.7
# CV_0_obs_1      2CXO J004247.1+411619   10.69654  41.272150    3907.5
# CV_0_obs_2      2CXO J004247.1+411619   10.69654  41.272150    3907.5
# CV_0_obs_3      2CXO J004247.1+411619   10.69654  41.272150    3904.6
# CV_0_obs_4      2CXO J004247.1+411619   10.69654  41.272150    3907.5
# ...                               ...        ...        ...       ...
# LMXB_86_obs_0   2CXO J181044.4-260901  272.68530 -26.150370   31871.5
# LMXB_90_obs_0   2CXO J212314.5-054753  320.81060  -5.798128   17705.1
# LMXB_91_obs_0   2CXO J173547.0-302858  263.94590 -30.482820   18855.8
# LMXB_92_obs_0   2CXO J092920.1-312303  142.33410 -31.384270   24445.9
# LMXB_94_obs_0   2CXO J174813.1-360758  267.05470 -36.132810   15794.5
#
#                significance   likelihood class  ...  var_inter_sigma_s  \
# obs_id                                          ...
# CV_0_obs_0            52.93  16618.73000    CV  ...       2.546000e-05
# CV_0_obs_1            52.93  16618.73000    CV  ...       2.546000e-05
# CV_0_obs_2            52.93  16618.73000    CV  ...       2.546000e-05
# CV_0_obs_3            52.93  16618.73000    CV  ...       2.546000e-05
# CV_0_obs_4            52.93  16618.73000    CV  ...       2.546000e-05
# ...                     ...          ...   ...  ...                ...
# LMXB_86_obs_0          9.29    512.97550    LX  ...       3.385778e-06
# LMXB_90_obs_0          4.06    132.76700    LX  ...       2.082304e-07
# LMXB_91_obs_0          4.89    114.24570    LX  ...       5.992000e-09
# LMXB_92_obs_0          3.70     75.53454    LX  ...       1.579263e-07
# LMXB_94_obs_0          3.09     50.50810    LX  ...       1.247337e-06
#
#                var_inter_index_m  var_inter_index_s  var_inter_index_h  \
# obs_id
# CV_0_obs_0                  5.00               5.00               5.00
# CV_0_obs_1                  4.95               5.00               4.96
# CV_0_obs_2                  5.00               5.00               5.00
# CV_0_obs_3                  5.00               5.00               5.00
# CV_0_obs_4                  5.00               5.00               5.00
# ...                          ...                ...                ...
# LMXB_86_obs_0               2.25               4.96               1.61
# LMXB_90_obs_0               2.33               3.43               1.81
# LMXB_91_obs_0               5.00               3.26               1.44
# LMXB_92_obs_0               2.90               2.94               2.10
# LMXB_94_obs_0               1.63               4.58               2.64
#
#                flux_aper_hilim_u  var_mean_b  var_sigma_b  ks_prob_b  \
# obs_id
# CV_0_obs_0             13.177505    0.001794     0.000458    0.74518
# CV_0_obs_1             12.648397    0.008160     0.002223    0.48396
# CV_0_obs_2             12.947306    0.002150     0.000759    0.73545
# CV_0_obs_3             13.064140    0.002382     0.000756    0.72550
# CV_0_obs_4             13.072989    0.001926     0.000656    0.76392
# ...                          ...         ...          ...        ...
# LMXB_86_obs_0          14.159831    0.003456     0.000029    0.82900
# LMXB_90_obs_0          14.612610    0.001171     0.000255    0.26500
# LMXB_91_obs_0          15.247567    0.001623     0.000211    0.73500
# LMXB_92_obs_0          14.335264    0.000740     0.000201    0.94000
# LMXB_94_obs_0          14.477531    0.000782     0.000061    0.13400
#
#                var_prob_b  var_inter_sigma_u
# obs_id
# CV_0_obs_0        0.66810       9.663672e-05
# CV_0_obs_1        0.46334       1.006484e-04
# CV_0_obs_2        0.61051       9.534336e-05
# CV_0_obs_3        0.55735       9.695378e-05
# CV_0_obs_4        0.68356       7.274384e-05
# ...                   ...                ...
# LMXB_86_obs_0     0.08400       3.013343e-06
# LMXB_90_obs_0     0.80700       6.861258e-07
# LMXB_91_obs_0     0.45100       8.933566e-07
# LMXB_92_obs_0     0.60700       6.592942e-07
# LMXB_94_obs_0     0.38000       4.809987e-06
#
# [3103 rows x 29 columns]

# %%
data_imp_v2.to_csv('imputed_data/small-feat-subset-new-data.csv')
