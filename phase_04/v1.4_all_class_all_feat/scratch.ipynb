# %%
import pandas as pd

# %%
cv = pd.read_csv('cv_xrb.csv').iloc[: , 1:][['feat_name']].rename({'feat_name' : 'cv-xrb'} , axis=1)
pl = pd.read_csv('cv_pulsar.csv').iloc[: , 1:][['feat_name']].rename({'feat_name' : 'cv-pulsar'} , axis=1)
xrb = pd.read_csv('xrb_pulsar.csv').iloc[: , 1:][['feat_name']].rename({'feat_name' : 'pulsar-xrb'} , axis=1)
ns = pd.read_csv('ns_bh.csv').iloc[: , 1:][['feat_name']].rename({'feat_name' : 'ns-bh'} , axis=1)
df =  pd.concat([cv , xrb , pl , ns] , axis=1)
df
# Out:
#                    cv-xrb             pulsar-xrb              cv-pulsar  \
# 0                 var_max               var_mean               var_mean
# 1               var_sigma              var_sigma                var_max
# 2                 var_min                var_max              var_sigma
# 3                var_mean                var_min              var_index
# 4               var_index              var_index          hard_hm_hilim
# 5           hard_hm_hilim                hard_hs          hard_hs_hilim
# 6           hard_ms_lolim          hard_hs_hilim                hard_hs
# 7                 hard_ms          hard_hm_hilim               var_prob
# 8     photflux_aper_lolim          hard_hs_lolim                hard_hm
# 9                 hard_hm        photflux_aper_h                var_min
# 10  photflux_aper_lolim_b          hard_ms_lolim  photflux_aper_hilim_b
# 11          hard_hs_hilim               var_prob  photflux_aper_lolim_b
# 12        photflux_aper_b          hard_ms_hilim      flux_aper_lolim_h
# 13  photflux_aper_hilim_b  photflux_aper_hilim_h          hard_hs_lolim
# 14                hard_hs  photflux_aper_lolim_h        photflux_aper_b
# 15  photflux_aper_hilim_s      flux_aper_hilim_b          hard_hm_lolim
# 16            flux_aper_u            flux_aper_u  photflux_aper_hilim_s
# 17        photflux_aper_u                hard_hm  photflux_aper_lolim_s
# 18          photflux_aper                hard_ms    photflux_aper_lolim
# 19  photflux_aper_lolim_m      flux_aper_lolim_b        photflux_aper_s
# 20        photflux_aper_s  photflux_aper_lolim_m          hard_ms_hilim
# 21    photflux_aper_hilim      flux_aper_lolim_m          photflux_aper
# 22          hard_hm_lolim        flux_aper_lolim        photflux_aper_h
# 23  photflux_aper_lolim_s            flux_aper_b  photflux_aper_lolim_h
# 24               var_prob      flux_aper_lolim_h      flux_aper_hilim_h
# 25        photflux_aper_m        photflux_aper_m          hard_ms_lolim
# 26  photflux_aper_lolim_u          hard_hm_lolim  photflux_aper_lolim_m
# 27  photflux_aper_hilim_h            flux_aper_m      flux_aper_hilim_s
# 28      flux_aper_hilim_m        flux_aper_hilim            flux_aper_h
# 29      flux_aper_lolim_m      flux_aper_hilim_h  photflux_aper_lolim_u
# 30  photflux_aper_hilim_m  photflux_aper_hilim_m      flux_aper_lolim_b
# 31            flux_aper_m    photflux_aper_hilim      flux_aper_lolim_s
# 32          hard_hs_lolim        photflux_aper_u  photflux_aper_hilim_h
# 33      flux_aper_lolim_u  photflux_aper_lolim_s      flux_aper_lolim_m
# 34  photflux_aper_hilim_u        photflux_aper_b        flux_aper_lolim
# 35        flux_aper_lolim  photflux_aper_hilim_b            flux_aper_s
# 36          hard_ms_hilim  photflux_aper_lolim_b                hard_ms
# 37      flux_aper_lolim_s    photflux_aper_lolim            flux_aper_m
# 38        photflux_aper_h            flux_aper_h      flux_aper_lolim_u
# 39        flux_aper_hilim            flux_aper_s        photflux_aper_m
# 40      flux_aper_hilim_s          photflux_aper            flux_aper_u
# 41              flux_aper              flux_aper    photflux_aper_hilim
# 42            flux_aper_s        photflux_aper_s                ks_prob
# 43                kp_prob      flux_aper_hilim_s                kp_prob
# 44      flux_aper_lolim_b  photflux_aper_hilim_s      flux_aper_hilim_u
# 45            flux_aper_b      flux_aper_lolim_s  photflux_aper_hilim_m
# 46      flux_aper_hilim_h  photflux_aper_lolim_u      flux_aper_hilim_m
# 47      flux_aper_hilim_b      flux_aper_hilim_m            flux_aper_b
# 48  photflux_aper_lolim_h                kp_prob              flux_aper
# 49      flux_aper_hilim_u                ks_prob      flux_aper_hilim_b
# 50                ks_prob      flux_aper_hilim_u        flux_aper_hilim
# 51            flux_aper_h      flux_aper_lolim_u  photflux_aper_hilim_u
# 52      flux_aper_lolim_h  photflux_aper_hilim_u        photflux_aper_u
#
#                     ns-bh
# 0               var_sigma
# 1                var_mean
# 2                 var_min
# 3           hard_hs_hilim
# 4                 var_max
# 5               var_index
# 6           hard_hm_hilim
# 7                 hard_hs
# 8       flux_aper_lolim_u
# 9                 hard_hm
# 10          hard_ms_lolim
# 11          hard_hs_lolim
# 12      flux_aper_hilim_s
# 13  photflux_aper_hilim_u
# 14        photflux_aper_u
# 15        photflux_aper_b
# 16          hard_ms_hilim
# 17    photflux_aper_hilim
# 18            flux_aper_u
# 19      flux_aper_lolim_m
# 20  photflux_aper_lolim_b
# 21  photflux_aper_hilim_s
# 22  photflux_aper_lolim_m
# 23      flux_aper_hilim_h
# 24      flux_aper_hilim_u
# 25            flux_aper_h
# 26  photflux_aper_lolim_s
# 27                hard_ms
# 28  photflux_aper_hilim_h
# 29        photflux_aper_h
# 30      flux_aper_lolim_b
# 31    photflux_aper_lolim
# 32      flux_aper_lolim_s
# 33  photflux_aper_hilim_b
# 34  photflux_aper_lolim_h
# 35        flux_aper_lolim
# 36            flux_aper_m
# 37        photflux_aper_m
# 38        photflux_aper_s
# 39  photflux_aper_lolim_u
# 40            flux_aper_s
# 41      flux_aper_hilim_b
# 42            flux_aper_b
# 43          photflux_aper
# 44  photflux_aper_hilim_m
# 45      flux_aper_hilim_m
# 46               var_prob
# 47      flux_aper_lolim_h
# 48        flux_aper_hilim
# 49          hard_hm_lolim
# 50                kp_prob
# 51              flux_aper
# 52                ks_prob

# %%
df = pd.DataFrame([cv , pl , xrb]  , columns=['CV' ,'PULSAR' , 'XRB'])
df
# Out:
#            CV  PULSAR  XRB
# feat_name NaN     NaN  NaN
# feat_name NaN     NaN  NaN
# feat_name NaN     NaN  NaN
