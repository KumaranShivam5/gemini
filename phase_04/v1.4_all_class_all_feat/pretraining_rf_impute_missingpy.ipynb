# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt 
from IPython.display import display
import seaborn as sns

# %% [markdown]
# ## Filter data

# %%
def filter_data(data_sent , max_flux= -12):
    data = data_sent.copy()
    max_flux = -12
    min_flux = 26
    data = data[data['flux_aper']<max_flux]

    data = data[data['significance']>2]
    data_class = data[['class']]

    data_sig = data['significance']
    data_id = data['src_id']
    data_name = data['src_n']
    obs_info_params = [ 'livetime','likelihood','pileup_flag','mstr_sat_src_flag','mstr_streak_src_flag'   ,'gti_obs' , 'flux_significance_b'  , 'flux_significance_m' , 'flux_significance_s' , 'flux_significance_h' , 'flux_significance_u'    ]
    data_val = data.drop(columns=obs_info_params)
    return data_val

def norm_data(data_sent):
    data = data_sent.copy()
    #data.replace()
    for d in data:
        max_val = np.amax(data[d])
        min_val =  np.amin(data[d])
        data[d] = (data[d]-min_val)/(max_val-min_val)
    return data
def std_data(data_sent):
    data = data_sent.copy()
    for d in data:
        mean =  np.mean(data[d])
        std = np.sqrt(np.var(data[d]))
        data[d] = (data[d]-mean)/std 
    return data
def do_nothing(data_sent):
    return data_sent

# %%
def extract_data(data_sent , impute_fn = '',reduce_fn = ' ' , rf_impute=False):
    data = data_sent.copy()
    data = data.sample(frac=1)
    data = filter_data(data)
    #display(data)
    data_id = data[[ 'class' ,'src_n' , 'src_id' ,'significance' , ]]
    data_id = data_id
    data_val = data.drop([ 'class' ,'src_n' , 'src_id' ,'significance' ,] , axis=1)
    data_val = reduce_fn(data_val)
    return data_val , data_id
    #if(rf_impute):
    #    data_val  , random_forest_imputer = impute_fn(data_val , data_id)
    #else:
    #    data_val = impute_fn(data_val)
    data_val = reduce_fn(data_val)
    data_val = data_val.reset_index(drop=True)
    data_reduced = pd.concat([data_id , data_val] , axis=1)
    if(rf_impute):
        return(data_reduced , random_forest_imputer)
    else:
        return data_reduced

# %% [markdown]
# ## Load data

# %% [markdown]
# Here we will impute each class seperately ,
# for testing we can pass given sample through each imputer and then combine the result

# %%
obj_class = 'TUC'

# %%
obj_class = 'BH'
train = pd.read_csv('../processed_data/'+obj_class+'_.csv' , index_col='obs_id')
train_bh = train.sample(frac=1)

obj_class = 'NS'
train = pd.read_csv('../processed_data/'+obj_class+'_.csv' , index_col='obs_id')
train_ns = train.sample(frac=1)

obj_class = 'PULSAR'
train = pd.read_csv('../processed_data/'+obj_class+'_.csv' , index_col='obs_id')
train_plsr = train.sample(frac=1)

obj_class = 'CV'
train = pd.read_csv('../processed_data/'+obj_class+'_.csv' , index_col='obs_id')
train_cv = train.sample(frac=1)

train = pd.concat([train_bh , train_ns , train_cv , train_plsr])

train
# Out:
#                 index   class                 src_n  src_id  livetime  \
# obs_id
# BH_OBS_170        170      BH  J1745-2900            BH0027   17827.6
# BH_OBS_182        182      BH  J1745-2900            BH0027   44955.8
# BH_OBS_66          66      BH  CXOU J100514.2-07423  BH0018  158013.8
# BH_OBS_4            4      BH  1E 1740.7-2942        BH0002   11611.1
# BH_OBS_61          61      BH  CXOU J100514.2-07423  BH0018   40580.4
# ...               ...     ...                   ...     ...       ...
# PULSAR_OBS_124    124  PULSAR        PSR J0908-4913  PL0027   34605.8
# PULSAR_OBS_176    176  PULSAR        PSR J1550-5418  PL0060   96515.8
# PULSAR_OBS_211    211  PULSAR         PSR J1741-205  PL0079   48783.7
# PULSAR_OBS_244    244  PULSAR        PSR J1745-2900  PL0081    5106.3
# PULSAR_OBS_278    278  PULSAR        PSR J1745-2900  PL0081   41453.3
#
#                 significance    likelihood  pileup_flag  mstr_sat_src_flag  \
# obs_id
# BH_OBS_170            337.00  462011.40000        False              False
# BH_OBS_182            337.00  462011.40000        False              False
# BH_OBS_66              16.29    1238.38300        False              False
# BH_OBS_4              166.94  151803.00000        False              False
# BH_OBS_61              16.29    1238.38300        False              False
# ...                      ...           ...          ...                ...
# PULSAR_OBS_124          3.24      28.19767        False              False
# PULSAR_OBS_176        122.14   80599.58000        False              False
# PULSAR_OBS_211         98.07   57964.79000        False              False
# PULSAR_OBS_244        107.91   21810.19000        False              False
# PULSAR_OBS_278        107.91   21810.19000        False              False
#
#                 mstr_streak_src_flag  ... bb_ampl_lolim  bb_ampl_hilim  \
# obs_id                                ...
# BH_OBS_170                     False  ...           NaN            NaN
# BH_OBS_182                     False  ...      0.002207       0.003062
# BH_OBS_66                      False  ...           NaN            NaN
# BH_OBS_4                       False  ...           NaN            NaN
# BH_OBS_61                      False  ...           NaN            NaN
# ...                              ...  ...           ...            ...
# PULSAR_OBS_124                 False  ...           NaN            NaN
# PULSAR_OBS_176                 False  ...      0.000374       0.000418
# PULSAR_OBS_211                 False  ...      0.003282       0.003774
# PULSAR_OBS_244                 False  ...           NaN            NaN
# PULSAR_OBS_278                 False  ...      0.000021       0.000075
#
#                 bb_stat  brems_kt  brems_kt_hilim  brems_kt_lolim  \
# obs_id
# BH_OBS_170          NaN       NaN             NaN             NaN
# BH_OBS_182        0.931     1.607           1.688           1.531
# BH_OBS_66           NaN       NaN             NaN             NaN
# BH_OBS_4            NaN       NaN             NaN             NaN
# BH_OBS_61           NaN       NaN             NaN             NaN
# ...                 ...       ...             ...             ...
# PULSAR_OBS_124      NaN       NaN             NaN             NaN
# PULSAR_OBS_176    3.345     6.400           6.874           5.986
# PULSAR_OBS_211    4.820     1.387           1.422           1.342
# PULSAR_OBS_244      NaN       NaN             NaN             NaN
# PULSAR_OBS_278    0.730     2.569           3.680           1.926
#
#                     brems_nh  brems_nh_hilim  brems_nh_lolim  brems_stat
# obs_id
# BH_OBS_170               NaN             NaN             NaN         NaN
# BH_OBS_182      1.530000e+03      1579.00000          1483.0       0.888
# BH_OBS_66                NaN             NaN             NaN         NaN
# BH_OBS_4                 NaN             NaN             NaN         NaN
# BH_OBS_61                NaN             NaN             NaN         NaN
# ...                      ...             ...             ...         ...
# PULSAR_OBS_124           NaN             NaN             NaN         NaN
# PULSAR_OBS_176  3.129000e+02       318.10000           307.8       2.120
# PULSAR_OBS_211  2.083000e-07         0.08261             NaN       1.707
# PULSAR_OBS_244           NaN             NaN             NaN         NaN
# PULSAR_OBS_278  9.493000e+02      1122.00000           807.6       0.726
#
# [1870 rows x 108 columns]

# %%
train['class'].value_counts()
# Out:
# CV        786
# PULSAR    445
# NS        440
# BH        199
# Name: class, dtype: int64

# %% [markdown]
# # RF imputer Missingpy

# %%
import sklearn.neighbors._base
from os import sys
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base

# %%
from missingpy import MissForest

# %%
def rf_impute(d, i ):
    data = pd.concat([i , d] , axis=1)
    data = data.drop(columns=['src_n' , 'src_id' , 'significance' ,])
    rf_imputer = MissForest(n_estimators=300 , n_jobs=-1 , class_weight="balanced")
    #new_data = d.drop(columns= ['class'])
    rf_imputer.fit(d)
    new_data = rf_imputer.transform(d)
    return new_data , rf_imputer

# %% [markdown]
# ## Zero imputer

# %%
def zero_impute(d , i ):
    data = pd.concat([i , d] , axis=1)
    data = data.drop(columns=['src_n' , 'src_id' , 'significance' ,])
    new_data = data.replace(np.nan , 0 )
    return new_data , 'ignore this string'

# %% [markdown]
# # Choose Features

# %%
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from features import features as feat 
all_feat = list(feat['info'])+list(feat['flux']['photon'])+list(feat['flux']['energy'])+list(feat['variability'])+list(feat['hardness'])+list(feat['model_fit']['powerlaw'])+list(feat['model_fit']['bb'])+list(feat['model_fit']['brems'])+list(feat['info_pre_filter'])

# %%
feat_to_drop = list(feat['model_fit']['powerlaw']) + list(feat['model_fit']['bb']) + list(feat['model_fit']['brems']) 
#feat_to_drop = []
feat_used = [item for item in all_feat if item not in feat_to_drop]

# %%
train[feat_used]
# Out:
#                 src_id  significance   class                 src_n  \
# obs_id
# BH_OBS_170      BH0027        337.00      BH  J1745-2900
# BH_OBS_182      BH0027        337.00      BH  J1745-2900
# BH_OBS_66       BH0018         16.29      BH  CXOU J100514.2-07423
# BH_OBS_4        BH0002        166.94      BH  1E 1740.7-2942
# BH_OBS_61       BH0018         16.29      BH  CXOU J100514.2-07423
# ...                ...           ...     ...                   ...
# PULSAR_OBS_124  PL0027          3.24  PULSAR        PSR J0908-4913
# PULSAR_OBS_176  PL0060        122.14  PULSAR        PSR J1550-5418
# PULSAR_OBS_211  PL0079         98.07  PULSAR         PSR J1741-205
# PULSAR_OBS_244  PL0081        107.91  PULSAR        PSR J1745-2900
# PULSAR_OBS_278  PL0081        107.91  PULSAR        PSR J1745-2900
#
#                 photflux_aper_lolim_m  photflux_aper_hilim_s  photflux_aper_b  \
# obs_id
# BH_OBS_170                        NaN              -6.213746        -5.550985
# BH_OBS_182                  -5.837734              -6.102758        -3.432151
# BH_OBS_66                   -6.971429              -6.332547        -6.138824
# BH_OBS_4                          NaN                    NaN              NaN
# BH_OBS_61                   -7.075566              -5.900665        -5.814458
# ...                               ...                    ...              ...
# PULSAR_OBS_124              -6.915781              -6.485984        -5.809388
# PULSAR_OBS_176              -4.253521              -5.400554        -3.213675
# PULSAR_OBS_211              -4.540608              -4.060381        -3.763211
# PULSAR_OBS_244                    NaN              -6.077223              NaN
# PULSAR_OBS_278              -6.798330              -6.787812        -4.749824
#
#                 photflux_aper_lolim_s  photflux_aper_hilim_h  photflux_aper_u  \
# obs_id
# BH_OBS_170                        NaN              -5.587036              NaN
# BH_OBS_182                  -6.476904              -3.482672        -5.171018
# BH_OBS_66                   -6.547447              -6.988853        -6.348141
# BH_OBS_4                          NaN              -1.865823              NaN
# BH_OBS_61                   -6.154778              -6.800519              NaN
# ...                               ...                    ...              ...
# PULSAR_OBS_124                    NaN              -6.007093              NaN
# PULSAR_OBS_176              -5.483994              -3.327810        -4.904831
# PULSAR_OBS_211              -4.084442              -4.704433        -3.574466
# PULSAR_OBS_244                    NaN                    NaN              NaN
# PULSAR_OBS_278                    NaN              -4.793984              NaN
#
#                 ...  flux_significance_u    likelihood  pileup_flag  \
# obs_id          ...
# BH_OBS_170      ...                 0.00  462011.40000        False
# BH_OBS_182      ...                 1.64  462011.40000        False
# BH_OBS_66       ...                 1.13    1238.38300        False
# BH_OBS_4        ...                  NaN  151803.00000        False
# BH_OBS_61       ...                 0.00    1238.38300        False
# ...             ...                  ...           ...          ...
# PULSAR_OBS_124  ...                 0.00      28.19767        False
# PULSAR_OBS_176  ...                 5.14   80599.58000        False
# PULSAR_OBS_211  ...                19.24   57964.79000        False
# PULSAR_OBS_244  ...                 0.00   21810.19000        False
# PULSAR_OBS_278  ...                 0.00   21810.19000        False
#
#                 flux_significance_b  flux_significance_m  flux_significance_h  \
# obs_id
# BH_OBS_170                     2.05                 0.90                 1.73
# BH_OBS_182                    66.22                 5.69                65.92
# BH_OBS_66                      5.41                 3.17                 1.58
# BH_OBS_4                        NaN                  NaN               166.39
# BH_OBS_61                      4.06                 1.79                 1.03
# ...                             ...                  ...                  ...
# PULSAR_OBS_124                 3.24                 1.79                 2.54
# PULSAR_OBS_176               122.14                47.92               111.88
# PULSAR_OBS_211                46.83                25.00                16.38
# PULSAR_OBS_244                  NaN                 0.00                  NaN
# PULSAR_OBS_278                12.22                 2.06                11.59
#
#                 mstr_streak_src_flag  mstr_sat_src_flag  livetime  \
# obs_id
# BH_OBS_170                     False              False   17827.6
# BH_OBS_182                     False              False   44955.8
# BH_OBS_66                      False              False  158013.8
# BH_OBS_4                       False              False   11611.1
# BH_OBS_61                      False              False   40580.4
# ...                              ...                ...       ...
# PULSAR_OBS_124                 False              False   34605.8
# PULSAR_OBS_176                 False              False   96515.8
# PULSAR_OBS_211                 False              False   48783.7
# PULSAR_OBS_244                 False              False    5106.3
# PULSAR_OBS_278                 False              False   41453.3
#
#                 flux_significance_s
# obs_id
# BH_OBS_170                     0.00
# BH_OBS_182                     2.49
# BH_OBS_66                      4.13
# BH_OBS_4                        NaN
# BH_OBS_61                      3.54
# ...                             ...
# PULSAR_OBS_124                 0.00
# PULSAR_OBS_176                10.43
# PULSAR_OBS_211                36.16
# PULSAR_OBS_244                 0.00
# PULSAR_OBS_278                 0.00
#
# [1870 rows x 71 columns]

# %%
sp = [] 
for f in feat_used:
    #print(f)
    na = train[feat_used][f].isna().value_counts()
    try:
        sp.append([f , 1-na[0]/(na[0]+na[1])])
    except:
        sp.append([f , 0])
sp =  np.asarray(sp)
sparsity = pd.DataFrame(sp , columns=['feat' , 'sparsity']).sort_values(by='sparsity' , ascending=False)

# %% [markdown]
# ## drop highly sparse features

# %%
sparsity
# Out:
#                      feat            sparsity
# 21      flux_aper_lolim_u  0.7240641711229947
# 29            flux_aper_u  0.7026737967914438
# 15  photflux_aper_lolim_u  0.6545454545454545
# 9         photflux_aper_u  0.6315508021390375
# 27      flux_aper_lolim_s  0.4080213903743316
# ..                    ...                 ...
# 63            pileup_flag                   0
# 1            significance                   0
# 3                   src_n                   0
# 60                gti_obs                   0
# 0                  src_id                   0
#
# [71 rows x 2 columns]

# %%
sparsity['sparsity'].astype(float)
# Out:
# 21    0.724064
# 29    0.702674
# 15    0.654545
# 9     0.631551
# 27    0.408021
#         ...
# 63    0.000000
# 1     0.000000
# 3     0.000000
# 60    0.000000
# 0     0.000000
# Name: sparsity, Length: 71, dtype: float64

# %%
feat_low_sparse = sparsity[sparsity['sparsity'].astype(float)<0.35]['feat'].to_list()
feat_low_sparse
# Out:
# ['photflux_aper_lolim_h',
#  'photflux_aper_h',
#  'flux_aper_lolim_b',
#  'photflux_aper_lolim_b',
#  'flux_aper_b',
#  'flux_aper_hilim_u',
#  'photflux_aper_b',
#  'flux_aper_lolim',
#  'photflux_aper_lolim',
#  'flux_aper',
#  'photflux_aper',
#  'var_inter_prob',
#  'var_inter_index',
#  'var_inter_sigma',
#  'flux_significance_u',
#  'photflux_aper_hilim_u',
#  'flux_aper_hilim_m',
#  'flux_aper_hilim_h',
#  'flux_aper_hilim_s',
#  'hard_ms_lolim',
#  'hard_ms_hilim',
#  'hard_ms',
#  'hard_hm_lolim',
#  'hard_hm',
#  'hard_hm_hilim',
#  'hard_hs',
#  'hard_hs_hilim',
#  'hard_hs_lolim',
#  'photflux_aper_hilim_m',
#  'flux_significance_m',
#  'flux_significance_s',
#  'photflux_aper_hilim_s',
#  'flux_aper_hilim_b',
#  'photflux_aper_hilim_h',
#  'flux_significance_h',
#  'flux_aper_hilim',
#  'photflux_aper_hilim_b',
#  'flux_significance_b',
#  'photflux_aper_hilim',
#  'class',
#  'livetime',
#  'mstr_sat_src_flag',
#  'mstr_streak_src_flag',
#  'likelihood',
#  'pileup_flag',
#  'significance',
#  'src_n',
#  'gti_obs',
#  'src_id']

# %%
train_set = train[feat_low_sparse]
train_set
# Out:
#                 photflux_aper_lolim_h  photflux_aper_h  flux_aper_lolim_b  \
# obs_id
# BH_OBS_170                  -6.161025        -5.785421         -14.157765
# BH_OBS_182                  -3.495937        -3.489053         -11.600153
# BH_OBS_66                   -7.637518        -7.201833         -14.961380
# BH_OBS_4                    -1.870955        -1.868381                NaN
# BH_OBS_61                         NaN        -7.090070         -14.825940
# ...                               ...              ...                ...
# PULSAR_OBS_124              -6.372839        -6.147947         -14.352128
# PULSAR_OBS_176              -3.335546        -3.331707         -11.404283
# PULSAR_OBS_211              -4.757459        -4.730254         -12.472241
# PULSAR_OBS_244                    NaN              NaN                NaN
# PULSAR_OBS_278              -4.869023        -4.830032         -12.955852
#
#                 photflux_aper_lolim_b  flux_aper_b  flux_aper_hilim_u  \
# obs_id
# BH_OBS_170                  -5.852015   -13.835647         -13.913640
# BH_OBS_182                  -3.439018   -11.593290         -14.895513
# BH_OBS_66                   -6.227532   -14.863279         -16.286762
# BH_OBS_4                          NaN          NaN                NaN
# BH_OBS_61                   -5.937042   -14.686766         -15.295935
# ...                               ...          ...                ...
# PULSAR_OBS_124              -5.970211   -14.191586                NaN
# PULSAR_OBS_176              -3.217241   -11.400663         -14.334607
# PULSAR_OBS_211              -3.772370   -12.462559         -12.318849
# PULSAR_OBS_244                    NaN          NaN         -13.663340
# PULSAR_OBS_278              -4.787014   -12.918293                NaN
#
#                 photflux_aper_b  flux_aper_lolim  photflux_aper_lolim  \
# obs_id
# BH_OBS_170            -5.550985       -14.610196            -6.377537
# BH_OBS_182            -3.432151       -11.994612            -3.861691
# BH_OBS_66             -6.138824       -15.404535            -6.679305
# BH_OBS_4                    NaN        -9.830620            -1.870955
# BH_OBS_61             -5.814458       -15.239804            -6.411117
# ...                         ...              ...                  ...
# PULSAR_OBS_124        -5.809388       -14.685906            -6.490475
# PULSAR_OBS_176        -3.213675       -11.799216            -3.643125
# PULSAR_OBS_211        -3.763211       -12.657258            -3.958599
# PULSAR_OBS_244              NaN              NaN                  NaN
# PULSAR_OBS_278        -4.749824       -13.262181            -5.221717
#
#                 flux_aper  ...   class  livetime  mstr_sat_src_flag  \
# obs_id                     ...
# BH_OBS_170     -14.256333  ...      BH   17827.6              False
# BH_OBS_182     -11.987612  ...      BH   44955.8              False
# BH_OBS_66      -15.260538  ...      BH  158013.8              False
# BH_OBS_4        -9.827981  ...      BH   11611.1              False
# BH_OBS_61      -15.078522  ...      BH   40580.4              False
# ...                   ...  ...     ...       ...                ...
# PULSAR_OBS_124 -14.487556  ...  PULSAR   34605.8              False
# PULSAR_OBS_176 -11.795263  ...  PULSAR   96515.8              False
# PULSAR_OBS_211 -12.639664  ...  PULSAR   48783.7              False
# PULSAR_OBS_244        NaN  ...  PULSAR    5106.3              False
# PULSAR_OBS_278 -13.222921  ...  PULSAR   41453.3              False
#
#                 mstr_streak_src_flag    likelihood  pileup_flag  significance  \
# obs_id
# BH_OBS_170                     False  462011.40000        False        337.00
# BH_OBS_182                     False  462011.40000        False        337.00
# BH_OBS_66                      False    1238.38300        False         16.29
# BH_OBS_4                       False  151803.00000        False        166.94
# BH_OBS_61                      False    1238.38300        False         16.29
# ...                              ...           ...          ...           ...
# PULSAR_OBS_124                 False      28.19767        False          3.24
# PULSAR_OBS_176                 False   80599.58000        False        122.14
# PULSAR_OBS_211                 False   57964.79000        False         98.07
# PULSAR_OBS_244                 False   21810.19000        False        107.91
# PULSAR_OBS_278                 False   21810.19000        False        107.91
#
#                                src_n              gti_obs  src_id
# obs_id
# BH_OBS_170      J1745-2900            2011-03-31T10:44:54  BH0027
# BH_OBS_182      J1745-2900            2014-04-28T03:04:50  BH0027
# BH_OBS_66       CXOU J100514.2-07423  2012-02-03T10:00:00  BH0018
# BH_OBS_4        1E 1740.7-2942        2001-07-21T11:42:23  BH0002
# BH_OBS_61       CXOU J100514.2-07423  2010-01-27T01:02:52  BH0018
# ...                              ...                  ...     ...
# PULSAR_OBS_124        PSR J0908-4913  2010-09-06T12:26:29  PL0027
# PULSAR_OBS_176        PSR J1550-5418  2011-06-02T17:44:53  PL0060
# PULSAR_OBS_211         PSR J1741-205  2010-05-21T02:44:36  PL0079
# PULSAR_OBS_244        PSR J1745-2900  2006-07-04T11:20:29  PL0081
# PULSAR_OBS_278        PSR J1745-2900  2014-07-16T23:01:21  PL0081
#
# [1870 rows x 49 columns]

# %%
data_val , data_id   = extract_data(train_set ,  impute_fn= rf_impute , reduce_fn= do_nothing , rf_impute=True )

# %%
data_val
# Out:
#                 photflux_aper_lolim_h  photflux_aper_h  flux_aper_lolim_b  \
# obs_id
# NS_OBS_359                  -4.252821        -4.243668         -12.282996
# BH_OBS_48                         NaN              NaN                NaN
# BH_OBS_147                  -6.217671        -5.585695         -14.399463
# PULSAR_OBS_178              -3.612432        -3.600153         -11.690157
# BH_OBS_17                   -5.755970        -5.630970         -13.882397
# ...                               ...              ...                ...
# NS_OBS_425                  -4.201073        -4.166470         -12.048323
# PULSAR_OBS_31               -5.761201        -5.619246         -13.793444
# NS_OBS_143                  -7.347754        -6.666553         -14.778586
# CV_OBS_2                    -6.363913        -6.118387         -14.238749
# PULSAR_OBS_53               -4.707744        -4.669789         -12.127145
#
#                 photflux_aper_lolim_b  flux_aper_b  flux_aper_hilim_u  \
# obs_id
# NS_OBS_359                  -3.812761   -12.277202         -13.917574
# BH_OBS_48                   -7.246111   -15.823619         -15.898597
# BH_OBS_147                  -6.007446   -13.700493         -13.549135
# PULSAR_OBS_178              -3.452841   -11.677988         -12.650334
# BH_OBS_17                   -5.571703   -13.771856         -15.361910
# ...                               ...          ...                ...
# NS_OBS_425                  -3.439018   -12.031424         -13.886057
# PULSAR_OBS_31               -5.298518   -13.695294                NaN
# NS_OBS_143                  -6.008198   -14.606425                NaN
# CV_OBS_2                    -5.483994   -14.058538                NaN
# PULSAR_OBS_53               -3.307417   -12.119529         -12.035976
#
#                 photflux_aper_b  flux_aper_lolim  photflux_aper_lolim  \
# obs_id
# NS_OBS_359            -3.807154       -12.675468            -4.253844
# BH_OBS_48             -6.854804       -16.699242            -7.535570
# BH_OBS_147            -5.437588       -14.792797            -6.497901
# PULSAR_OBS_178        -3.440812       -12.080142            -3.911181
# BH_OBS_17             -5.460924       -14.283990            -6.019642
# ...                         ...              ...                  ...
# NS_OBS_425            -3.422049       -12.451856            -3.904694
# PULSAR_OBS_31         -5.200384       -14.118061            -5.792398
# NS_OBS_143            -5.843451       -15.158747            -6.525551
# CV_OBS_2              -5.388277       -14.583817            -5.952865
# PULSAR_OBS_53         -3.299816       -12.265861            -3.441381
#
#                 flux_aper  ...  hard_hs  hard_hs_hilim  hard_hs_lolim  \
# obs_id                     ...
# NS_OBS_359     -12.667238  ...   0.3360         0.3504         0.3217
# BH_OBS_48      -16.053548  ...  -0.9806        -0.2692        -1.0000
# BH_OBS_147     -14.093881  ...   0.9994         1.0000         0.4291
# PULSAR_OBS_178 -12.058595  ...   0.9944         0.9975         0.9913
# BH_OBS_17      -14.162462  ...   0.9994         1.0000         0.9126
# ...                   ...  ...      ...            ...            ...
# NS_OBS_425     -12.427523  ...  -0.2274        -0.1780        -0.2755
# PULSAR_OBS_31  -13.985690  ...   0.5122         0.7289         0.2730
# NS_OBS_143     -14.893801  ...  -0.1037         0.3117        -0.5166
# CV_OBS_2       -14.373968  ...  -0.3648        -0.0893        -0.6015
# PULSAR_OBS_53  -12.253385  ...  -0.8520        -0.8401        -0.8626
#
#                 photflux_aper_hilim_m  photflux_aper_hilim_s  \
# obs_id
# NS_OBS_359                  -4.454569              -4.536704
# BH_OBS_48                   -7.722849              -6.737786
# BH_OBS_147                  -6.182567              -5.967381
# PULSAR_OBS_178              -4.734239              -5.915781
# BH_OBS_17                   -6.090658              -6.976748
# ...                               ...                    ...
# NS_OBS_425                  -3.979225              -3.938171
# PULSAR_OBS_31               -5.709743              -5.928486
# NS_OBS_143                  -6.108240              -6.331428
# CV_OBS_2                    -5.776764              -5.686766
# PULSAR_OBS_53                     NaN              -3.563519
#
#                 flux_aper_hilim_b  photflux_aper_hilim_h  flux_aper_hilim  \
# obs_id
# NS_OBS_359             -12.271890              -4.235301       -12.659647
# BH_OBS_48              -15.522589              -7.170375       -15.618750
# BH_OBS_147             -13.453334              -5.338471       -13.687484
# PULSAR_OBS_178         -11.666351              -3.588044       -12.038278
# BH_OBS_17              -13.688034              -5.534023       -14.063395
# ...                           ...                    ...              ...
# NS_OBS_425             -12.015113              -4.134422       -12.401757
# PULSAR_OBS_31          -13.619246              -5.518128       -13.887294
# NS_OBS_143             -14.483465              -6.413188       -14.732412
# CV_OBS_2               -13.937794              -5.969400       -14.206070
# PULSAR_OBS_53          -12.112495              -4.634887       -12.241561
#
#                 photflux_aper_hilim_b  photflux_aper_hilim
# obs_id
# NS_OBS_359                  -3.801618            -4.235704
# BH_OBS_48                   -6.652475            -6.392335
# BH_OBS_147                  -5.199352            -4.899624
# PULSAR_OBS_178              -3.429107            -3.880113
# BH_OBS_17                   -5.377268            -5.753935
# ...                               ...                  ...
# NS_OBS_425                  -3.405718            -3.824088
# PULSAR_OBS_31               -5.124476            -5.130405
# NS_OBS_143                  -5.730020            -6.046395
# CV_OBS_2                    -5.313900            -4.436386
# PULSAR_OBS_53               -3.292260            -3.417999
#
# [1294 rows x 34 columns]

# %%
data_id
# Out:
#                  class                   src_n  src_id  significance
# obs_id
# NS_OBS_359          NS    J1824-2452            NS0062         92.00
# BH_OBS_48           BH    CXOU J100506.7-07443  BH0014         11.41
# BH_OBS_147          BH    J1745-2900            BH0027        337.00
# PULSAR_OBS_178  PULSAR          PSR J1617-5055  PL0062         85.97
# BH_OBS_17           BH    IGR J17464-3213       BH0008          6.90
# ...                ...                     ...     ...           ...
# NS_OBS_425          NS    1WGA J1911.2+0035     NS0078         44.36
# PULSAR_OBS_31   PULSAR          PSR J0358+5413  PL0009         19.44
# NS_OBS_143          NS    KS 1731-260           NS0033         14.81
# CV_OBS_2            CV  [DSH2013] 24            CV0001          9.81
# PULSAR_OBS_53   PULSAR          PSR J0437-4715  PL0012        113.03
#
# [1294 rows x 4 columns]

# %%
data_val
# Out:
#                 photflux_aper_lolim_h  photflux_aper_h  flux_aper_lolim_b  \
# obs_id
# NS_OBS_359                  -4.252821        -4.243668         -12.282996
# BH_OBS_48                         NaN              NaN                NaN
# BH_OBS_147                  -6.217671        -5.585695         -14.399463
# PULSAR_OBS_178              -3.612432        -3.600153         -11.690157
# BH_OBS_17                   -5.755970        -5.630970         -13.882397
# ...                               ...              ...                ...
# NS_OBS_425                  -4.201073        -4.166470         -12.048323
# PULSAR_OBS_31               -5.761201        -5.619246         -13.793444
# NS_OBS_143                  -7.347754        -6.666553         -14.778586
# CV_OBS_2                    -6.363913        -6.118387         -14.238749
# PULSAR_OBS_53               -4.707744        -4.669789         -12.127145
#
#                 photflux_aper_lolim_b  flux_aper_b  flux_aper_hilim_u  \
# obs_id
# NS_OBS_359                  -3.812761   -12.277202         -13.917574
# BH_OBS_48                   -7.246111   -15.823619         -15.898597
# BH_OBS_147                  -6.007446   -13.700493         -13.549135
# PULSAR_OBS_178              -3.452841   -11.677988         -12.650334
# BH_OBS_17                   -5.571703   -13.771856         -15.361910
# ...                               ...          ...                ...
# NS_OBS_425                  -3.439018   -12.031424         -13.886057
# PULSAR_OBS_31               -5.298518   -13.695294                NaN
# NS_OBS_143                  -6.008198   -14.606425                NaN
# CV_OBS_2                    -5.483994   -14.058538                NaN
# PULSAR_OBS_53               -3.307417   -12.119529         -12.035976
#
#                 photflux_aper_b  flux_aper_lolim  photflux_aper_lolim  \
# obs_id
# NS_OBS_359            -3.807154       -12.675468            -4.253844
# BH_OBS_48             -6.854804       -16.699242            -7.535570
# BH_OBS_147            -5.437588       -14.792797            -6.497901
# PULSAR_OBS_178        -3.440812       -12.080142            -3.911181
# BH_OBS_17             -5.460924       -14.283990            -6.019642
# ...                         ...              ...                  ...
# NS_OBS_425            -3.422049       -12.451856            -3.904694
# PULSAR_OBS_31         -5.200384       -14.118061            -5.792398
# NS_OBS_143            -5.843451       -15.158747            -6.525551
# CV_OBS_2              -5.388277       -14.583817            -5.952865
# PULSAR_OBS_53         -3.299816       -12.265861            -3.441381
#
#                 flux_aper  ...  hard_hs  hard_hs_hilim  hard_hs_lolim  \
# obs_id                     ...
# NS_OBS_359     -12.667238  ...   0.3360         0.3504         0.3217
# BH_OBS_48      -16.053548  ...  -0.9806        -0.2692        -1.0000
# BH_OBS_147     -14.093881  ...   0.9994         1.0000         0.4291
# PULSAR_OBS_178 -12.058595  ...   0.9944         0.9975         0.9913
# BH_OBS_17      -14.162462  ...   0.9994         1.0000         0.9126
# ...                   ...  ...      ...            ...            ...
# NS_OBS_425     -12.427523  ...  -0.2274        -0.1780        -0.2755
# PULSAR_OBS_31  -13.985690  ...   0.5122         0.7289         0.2730
# NS_OBS_143     -14.893801  ...  -0.1037         0.3117        -0.5166
# CV_OBS_2       -14.373968  ...  -0.3648        -0.0893        -0.6015
# PULSAR_OBS_53  -12.253385  ...  -0.8520        -0.8401        -0.8626
#
#                 photflux_aper_hilim_m  photflux_aper_hilim_s  \
# obs_id
# NS_OBS_359                  -4.454569              -4.536704
# BH_OBS_48                   -7.722849              -6.737786
# BH_OBS_147                  -6.182567              -5.967381
# PULSAR_OBS_178              -4.734239              -5.915781
# BH_OBS_17                   -6.090658              -6.976748
# ...                               ...                    ...
# NS_OBS_425                  -3.979225              -3.938171
# PULSAR_OBS_31               -5.709743              -5.928486
# NS_OBS_143                  -6.108240              -6.331428
# CV_OBS_2                    -5.776764              -5.686766
# PULSAR_OBS_53                     NaN              -3.563519
#
#                 flux_aper_hilim_b  photflux_aper_hilim_h  flux_aper_hilim  \
# obs_id
# NS_OBS_359             -12.271890              -4.235301       -12.659647
# BH_OBS_48              -15.522589              -7.170375       -15.618750
# BH_OBS_147             -13.453334              -5.338471       -13.687484
# PULSAR_OBS_178         -11.666351              -3.588044       -12.038278
# BH_OBS_17              -13.688034              -5.534023       -14.063395
# ...                           ...                    ...              ...
# NS_OBS_425             -12.015113              -4.134422       -12.401757
# PULSAR_OBS_31          -13.619246              -5.518128       -13.887294
# NS_OBS_143             -14.483465              -6.413188       -14.732412
# CV_OBS_2               -13.937794              -5.969400       -14.206070
# PULSAR_OBS_53          -12.112495              -4.634887       -12.241561
#
#                 photflux_aper_hilim_b  photflux_aper_hilim
# obs_id
# NS_OBS_359                  -3.801618            -4.235704
# BH_OBS_48                   -6.652475            -6.392335
# BH_OBS_147                  -5.199352            -4.899624
# PULSAR_OBS_178              -3.429107            -3.880113
# BH_OBS_17                   -5.377268            -5.753935
# ...                               ...                  ...
# NS_OBS_425                  -3.405718            -3.824088
# PULSAR_OBS_31               -5.124476            -5.130405
# NS_OBS_143                  -5.730020            -6.046395
# CV_OBS_2                    -5.313900            -4.436386
# PULSAR_OBS_53               -3.292260            -3.417999
#
# [1294 rows x 34 columns]

# %%
new_data , random_forest_imputer = zero_impute(data_val, data_id)
#train_data.index.name = 'index'
#display(train_data.describe())
#train_data.to_csv('../processed_data/train_norm_rf_impute')

# %%
random_forest_imputer.transform(data_val)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-331-6b792afc942f> in <module>
# ----> 1 random_forest_imputer.transform(data_val)
#
# ~/.local/lib/python3.6/site-packages/missingpy/missforest.py in transform(self, X)
#     535
#     536         # Call missForest function to impute missing
# --> 537         X = self._miss_forest(X, mask)
#     538
#     539         # Return imputed dataset
#
# ~/.local/lib/python3.6/site-packages/missingpy/missforest.py in _miss_forest(self, Ximp, mask)
#     396                     Ximp[mis_rows, s] = ymis
#     397                 else:
# --> 398                     rf_regressor.fit(X=xobs, y=yobs)
#     399                     # 7. predict ymis(s) using xmis(x)
#     400                     ymis = rf_regressor.predict(xmis)
#
# ~/.local/lib/python3.6/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     391                     verbose=self.verbose, class_weight=self.class_weight,
#     392                     n_samples_bootstrap=n_samples_bootstrap)
# --> 393                 for i, t in enumerate(trees))
#     394
#     395             # Collect newly grown trees
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /usr/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
data_val
# Out:
#                 photflux_aper_lolim_h  photflux_aper_h  flux_aper_lolim_b  \
# obs_id
# NS_OBS_359                  -4.252821        -4.243668         -12.282996
# BH_OBS_48                         NaN              NaN                NaN
# BH_OBS_147                  -6.217671        -5.585695         -14.399463
# PULSAR_OBS_178              -3.612432        -3.600153         -11.690157
# BH_OBS_17                   -5.755970        -5.630970         -13.882397
# ...                               ...              ...                ...
# NS_OBS_425                  -4.201073        -4.166470         -12.048323
# PULSAR_OBS_31               -5.761201        -5.619246         -13.793444
# NS_OBS_143                  -7.347754        -6.666553         -14.778586
# CV_OBS_2                    -6.363913        -6.118387         -14.238749
# PULSAR_OBS_53               -4.707744        -4.669789         -12.127145
#
#                 photflux_aper_lolim_b  flux_aper_b  flux_aper_hilim_u  \
# obs_id
# NS_OBS_359                  -3.812761   -12.277202         -13.917574
# BH_OBS_48                   -7.246111   -15.823619         -15.898597
# BH_OBS_147                  -6.007446   -13.700493         -13.549135
# PULSAR_OBS_178              -3.452841   -11.677988         -12.650334
# BH_OBS_17                   -5.571703   -13.771856         -15.361910
# ...                               ...          ...                ...
# NS_OBS_425                  -3.439018   -12.031424         -13.886057
# PULSAR_OBS_31               -5.298518   -13.695294                NaN
# NS_OBS_143                  -6.008198   -14.606425                NaN
# CV_OBS_2                    -5.483994   -14.058538                NaN
# PULSAR_OBS_53               -3.307417   -12.119529         -12.035976
#
#                 photflux_aper_b  flux_aper_lolim  photflux_aper_lolim  \
# obs_id
# NS_OBS_359            -3.807154       -12.675468            -4.253844
# BH_OBS_48             -6.854804       -16.699242            -7.535570
# BH_OBS_147            -5.437588       -14.792797            -6.497901
# PULSAR_OBS_178        -3.440812       -12.080142            -3.911181
# BH_OBS_17             -5.460924       -14.283990            -6.019642
# ...                         ...              ...                  ...
# NS_OBS_425            -3.422049       -12.451856            -3.904694
# PULSAR_OBS_31         -5.200384       -14.118061            -5.792398
# NS_OBS_143            -5.843451       -15.158747            -6.525551
# CV_OBS_2              -5.388277       -14.583817            -5.952865
# PULSAR_OBS_53         -3.299816       -12.265861            -3.441381
#
#                 flux_aper  ...  hard_hs  hard_hs_hilim  hard_hs_lolim  \
# obs_id                     ...
# NS_OBS_359     -12.667238  ...   0.3360         0.3504         0.3217
# BH_OBS_48      -16.053548  ...  -0.9806        -0.2692        -1.0000
# BH_OBS_147     -14.093881  ...   0.9994         1.0000         0.4291
# PULSAR_OBS_178 -12.058595  ...   0.9944         0.9975         0.9913
# BH_OBS_17      -14.162462  ...   0.9994         1.0000         0.9126
# ...                   ...  ...      ...            ...            ...
# NS_OBS_425     -12.427523  ...  -0.2274        -0.1780        -0.2755
# PULSAR_OBS_31  -13.985690  ...   0.5122         0.7289         0.2730
# NS_OBS_143     -14.893801  ...  -0.1037         0.3117        -0.5166
# CV_OBS_2       -14.373968  ...  -0.3648        -0.0893        -0.6015
# PULSAR_OBS_53  -12.253385  ...  -0.8520        -0.8401        -0.8626
#
#                 photflux_aper_hilim_m  photflux_aper_hilim_s  \
# obs_id
# NS_OBS_359                  -4.454569              -4.536704
# BH_OBS_48                   -7.722849              -6.737786
# BH_OBS_147                  -6.182567              -5.967381
# PULSAR_OBS_178              -4.734239              -5.915781
# BH_OBS_17                   -6.090658              -6.976748
# ...                               ...                    ...
# NS_OBS_425                  -3.979225              -3.938171
# PULSAR_OBS_31               -5.709743              -5.928486
# NS_OBS_143                  -6.108240              -6.331428
# CV_OBS_2                    -5.776764              -5.686766
# PULSAR_OBS_53                     NaN              -3.563519
#
#                 flux_aper_hilim_b  photflux_aper_hilim_h  flux_aper_hilim  \
# obs_id
# NS_OBS_359             -12.271890              -4.235301       -12.659647
# BH_OBS_48              -15.522589              -7.170375       -15.618750
# BH_OBS_147             -13.453334              -5.338471       -13.687484
# PULSAR_OBS_178         -11.666351              -3.588044       -12.038278
# BH_OBS_17              -13.688034              -5.534023       -14.063395
# ...                           ...                    ...              ...
# NS_OBS_425             -12.015113              -4.134422       -12.401757
# PULSAR_OBS_31          -13.619246              -5.518128       -13.887294
# NS_OBS_143             -14.483465              -6.413188       -14.732412
# CV_OBS_2               -13.937794              -5.969400       -14.206070
# PULSAR_OBS_53          -12.112495              -4.634887       -12.241561
#
#                 photflux_aper_hilim_b  photflux_aper_hilim
# obs_id
# NS_OBS_359                  -3.801618            -4.235704
# BH_OBS_48                   -6.652475            -6.392335
# BH_OBS_147                  -5.199352            -4.899624
# PULSAR_OBS_178              -3.429107            -3.880113
# BH_OBS_17                   -5.377268            -5.753935
# ...                               ...                  ...
# NS_OBS_425                  -3.405718            -3.824088
# PULSAR_OBS_31               -5.124476            -5.130405
# NS_OBS_143                  -5.730020            -6.046395
# CV_OBS_2                    -5.313900            -4.436386
# PULSAR_OBS_53               -3.292260            -3.417999
#
# [1294 rows x 34 columns]

# %%
imp_data =  pd.DataFrame(new_data , columns = data_val.columns.to_list()  , index=data_val.index.to_list())
imp_data.index.name = 'obs_id'
#normalized_df=(imp_data-imp_data.mean())/imp_data.std()
#normalized_df.describe()
imp_data.describe()
# Out:
#        photflux_aper_lolim_h  photflux_aper_h  flux_aper_lolim_b  \
# count            1294.000000      1294.000000        1294.000000
# mean               -4.477548        -4.423483         -12.235548
# std                 2.429665         2.199707           4.261500
# min                -8.546376        -7.583193         -16.767766
# 25%                -6.141805        -5.853340         -14.328403
# 50%                -5.198391        -5.189746         -13.456677
# 75%                -4.093414        -4.126898         -12.381534
# max                 0.000000         0.000000           0.000000
#
#        photflux_aper_lolim_b  flux_aper_b  flux_aper_hilim_u  photflux_aper_b  \
# count            1294.000000  1294.000000        1294.000000      1294.000000
# mean               -4.650319   -12.465371         -10.149399        -4.647645
# std                 1.789903     3.675043           6.301840         1.512220
# min                -8.401647   -15.890759         -16.286762        -7.462055
# 25%                -5.800314   -14.106779         -14.514529        -5.614528
# 50%                -4.948664   -13.438814         -13.373113        -4.956840
# 75%                -3.835574   -12.475540           0.000000        -4.063514
# max                 0.000000     0.000000           0.000000         0.000000
#
#        flux_aper_lolim  photflux_aper_lolim    flux_aper  ...      hard_hs  \
# count      1294.000000          1294.000000  1294.000000  ...  1294.000000
# mean        -13.698346            -5.477593   -13.879990  ...     0.039110
# std           2.607420             1.439307     0.949797  ...     0.671970
# min         -17.980053            -9.566230   -16.724746  ...    -0.999400
# 25%         -14.883787            -6.389387   -14.538914  ...    -0.481575
# 50%         -14.019252            -5.559793   -13.911521  ...     0.000000
# 75%         -13.166267            -4.676824   -13.194663  ...     0.683000
# max           0.000000             0.000000   -12.009448  ...     0.999400
#
#        hard_hs_hilim  hard_hs_lolim  photflux_aper_hilim_m  \
# count    1294.000000    1294.000000            1294.000000
# mean        0.241775      -0.150744              -5.457383
# std         0.571450       0.630215               1.371327
# min        -0.965000      -1.000000              -7.858550
# 25%        -0.188975      -0.675550              -6.258416
# 50%         0.166150      -0.187400              -5.767894
# 75%         0.874775       0.302625              -4.941574
# max         1.000000       0.997500               0.000000
#
#        photflux_aper_hilim_s  flux_aper_hilim_b  photflux_aper_hilim_h  \
# count            1294.000000        1294.000000            1294.000000
# mean               -5.413043         -13.377132              -5.339389
# std                 1.258837           1.490269               1.116952
# min                -7.620694         -16.001523              -7.593119
# 25%                -6.202076         -14.092256              -6.033919
# 50%                -5.665346         -13.500591              -5.472118
# 75%                -4.873869         -12.850012              -4.772049
# max                 0.000000           0.000000               0.000000
#
#        flux_aper_hilim  photflux_aper_hilim_b  photflux_aper_hilim
# count      1294.000000            1294.000000          1294.000000
# mean        -13.653610              -4.896096            -5.051458
# std           0.816286               0.976932             0.804173
# min         -16.031949              -7.207678            -7.414567
# 25%         -14.200186              -5.563201            -5.667575
# 50%         -13.678510              -5.015812            -5.064710
# 75%         -13.108763              -4.360190            -4.429442
# max         -11.886136               0.000000             0.000000
#
# [8 rows x 34 columns]

# %%
data_id
# Out:
#                  class                   src_n  src_id  significance
# obs_id
# NS_OBS_359          NS    J1824-2452            NS0062         92.00
# BH_OBS_48           BH    CXOU J100506.7-07443  BH0014         11.41
# BH_OBS_147          BH    J1745-2900            BH0027        337.00
# PULSAR_OBS_178  PULSAR          PSR J1617-5055  PL0062         85.97
# BH_OBS_17           BH    IGR J17464-3213       BH0008          6.90
# ...                ...                     ...     ...           ...
# NS_OBS_425          NS    1WGA J1911.2+0035     NS0078         44.36
# PULSAR_OBS_31   PULSAR          PSR J0358+5413  PL0009         19.44
# NS_OBS_143          NS    KS 1731-260           NS0033         14.81
# CV_OBS_2            CV  [DSH2013] 24            CV0001          9.81
# PULSAR_OBS_53   PULSAR          PSR J0437-4715  PL0012        113.03
#
# [1294 rows x 4 columns]

# %%
processed_data_all = pd.concat([data_id , imp_data] , axis=1)
processed_data_all.to_csv('../processed_data/v4/'+'all'+'_zero_impute_std_no_model.csv')

# %%
processed_data_all
# Out:
#                  class                   src_n  src_id  significance  \
# obs_id
# NS_OBS_320          NS    XMMU J004414.0+41220  NS0047          6.53
# NS_OBS_194          NS    XMMU J004245.2+41172  NS0044         49.26
# NS_OBS_341          NS    J1748-2446            NS0057         18.31
# BH_OBS_136          BH    J1745-2900            BH0027        337.00
# CV_OBS_622          CV  CXOGLB J002410.6-72051  CV0090          6.98
# ...                ...                     ...     ...           ...
# PULSAR_OBS_391  PULSAR          PSR J1852+0040  PL0107         23.63
# CV_OBS_516          CV  CXOGLB J002406.0-72045  CV0081         25.99
# CV_OBS_674          CV  CXOGLB J002416.9-72042  CV0094         38.28
# NS_OBS_378          NS    SAXWFC J1747.0-2853.  NS0070          4.44
# PULSAR_OBS_37   PULSAR          PSR J0358+5413  PL0009         19.44
#
#                 photflux_aper_hilim_b  photflux_aper_lolim_h  \
# obs_id
# NS_OBS_320                   0.615725               0.197494
# NS_OBS_194                   0.995125               1.022972
# NS_OBS_341                  -0.609967              -0.127760
# BH_OBS_136                  -0.562312               0.121213
# CV_OBS_622                  -1.458075              -1.834396
# ...                               ...                    ...
# PULSAR_OBS_391               1.071520               1.153949
# CV_OBS_516                   0.104239              -0.055039
# CV_OBS_674                   0.288862               0.451699
# NS_OBS_378                  -1.396921              -0.707453
# PULSAR_OBS_37               -0.090974               0.314244
#
#                 photflux_aper_lolim_s  photflux_aper_lolim_m  photflux_aper_s  \
# obs_id
# NS_OBS_320                   1.077237              -0.399899         1.081690
# NS_OBS_194                   0.802394               1.066059         0.832256
# NS_OBS_341                  -1.006257              -0.421786        -1.255528
# BH_OBS_136                  -1.633314              -0.524249        -1.585227
# CV_OBS_622                  -0.917226              -1.187908        -0.964301
# ...                               ...                    ...              ...
# PULSAR_OBS_391               0.507329               1.356013         0.338459
# CV_OBS_516                   0.407600               0.293856         0.320572
# CV_OBS_674                   0.686725               0.660373         0.502106
# NS_OBS_378                  -0.596720              -1.215326        -0.625726
# PULSAR_OBS_37                0.297099               0.177382         0.097472
#
#                 photflux_aper_lolim_u  ...   kp_prob  hard_hs_lolim  \
# obs_id                                 ...
# NS_OBS_320                   1.955740  ... -1.444029      -1.177796
# NS_OBS_194                   0.494114  ...  0.274123       0.581473
# NS_OBS_341                  -0.635317  ... -0.643695       1.415875
# BH_OBS_136                  -0.853567  ... -0.299664       1.713639
# CV_OBS_622                  -1.017967  ... -0.012137      -0.950921
# ...                               ...  ...       ...            ...
# PULSAR_OBS_391              -0.344890  ...  0.087672       1.409876
# CV_OBS_516                  -0.226115  ...  0.179093      -0.534746
# CV_OBS_674                   0.078042  ...  1.101963      -0.004266
# NS_OBS_378                  -1.680173  ... -0.075750      -0.403383
# PULSAR_OBS_37                0.366902  ... -0.720681       0.287657
#
#                 hard_ms_lolim   hard_ms   hard_hs  hard_hs_hilim   hard_hm  \
# obs_id
# NS_OBS_320          -1.280950 -1.263447 -1.146647      -1.327829  0.611456
# NS_OBS_194           0.544759  0.448555  0.512744       0.528043  0.098624
# NS_OBS_341           1.697414  2.018979  1.425943       1.297444  0.417331
# BH_OBS_136           1.792868  2.018979  1.425943       1.297444  0.984854
# CV_OBS_622          -1.339282 -1.466049 -0.645620      -0.293854  1.336235
# ...                       ...       ...       ...            ...       ...
# PULSAR_OBS_391       2.216894  1.539675  1.082565       0.963051 -0.237557
# CV_OBS_516          -0.181324 -0.089508 -0.394958      -0.337599 -0.423120
# CV_OBS_674           0.322246  0.002029 -0.213091      -0.519057 -0.313914
# NS_OBS_378          -1.061346 -0.520157 -0.033387       0.275872  1.336235
# PULSAR_OBS_37       -0.146961 -0.244162  0.169365       0.060138  0.336431
#
#                 hard_hm_hilim  hard_hm_lolim  hard_ms_hilim
# obs_id
# NS_OBS_320           1.074376       0.213293      -1.889646
# NS_OBS_194           0.043683       0.319174       0.378500
# NS_OBS_341           0.689599       0.357676       1.817786
# BH_OBS_136           0.991877       1.427839       1.817786
# CV_OBS_622           1.283155       0.648559      -1.455522
# ...                       ...            ...            ...
# PULSAR_OBS_391      -0.607733       0.160353       1.336268
# CV_OBS_516          -0.264095      -0.575420      -0.179479
# CV_OBS_674          -0.646233       0.030601      -0.497753
# NS_OBS_378           1.283155       1.341210      -0.855976
# PULSAR_OBS_37        0.257961       0.660687      -0.592540
#
# [1294 rows x 60 columns]

# %%
import joblib 
joblib.dump(random_forest_imputer , 'forest/v3/all-imputer.joblib' , compress=3)
# Out:
# ['forest/v3/all-imputer.joblib']

# %% [markdown]
# ## Fill 47 TUC

# %%
tuc = pd.read_csv('../processed_data/v4/TUC_no_impute_std_no_model.csv' , index_col='obs_id')
tuc
# Out:
#              class                    src_n  src_id  significance  \
# obs_id
# TUC_OBS_2089   TUC  CXOGLB J002408.5-720708  TC0229          3.95
# TUC_OBS_1548   TUC  CXOGLB J002359.3-720448  TC0168          3.42
# TUC_OBS_1615   TUC  CXOGLB J002400.4-720448  TC0176          5.03
# TUC_OBS_217    TUC  CXOGLB J002409.1-720428  TC0023          5.64
# TUC_OBS_931    TUC  CXOGLB J002404.3-720501  TC0095         12.45
# ...            ...                      ...     ...           ...
# TUC_OBS_2095   TUC  CXOGLB J002408.6-720449  TC0230          3.40
# TUC_OBS_1193   TUC  CXOGLB J002415.1-720443  TC0120         10.66
# TUC_OBS_166    TUC  CXOGLB J002406.0-720501  TC0017          7.63
# TUC_OBS_989    TUC  CXOGLB J002406.5-720430  TC0102          3.41
# TUC_OBS_1399   TUC  CXOGLB J002353.3-720707  TC0147          4.87
#
#               photflux_aper_hilim_b  photflux_aper_lolim_h  \
# obs_id
# TUC_OBS_2089              -6.346981                    NaN
# TUC_OBS_1548              -6.027797                    NaN
# TUC_OBS_1615              -6.049976                    NaN
# TUC_OBS_217               -5.948847                    NaN
# TUC_OBS_931               -5.480041              -6.171920
# ...                             ...                    ...
# TUC_OBS_2095              -5.995249              -7.194567
# TUC_OBS_1193              -5.206140              -6.955852
# TUC_OBS_166               -5.586030                    NaN
# TUC_OBS_989               -6.056951              -7.981716
# TUC_OBS_1399              -6.244888                    NaN
#
#               photflux_aper_lolim_s  photflux_aper_lolim_m  photflux_aper_s  \
# obs_id
# TUC_OBS_2089              -7.272703              -7.575445        -6.904831
# TUC_OBS_1548              -7.331241              -7.079251        -6.650140
# TUC_OBS_1615              -6.510745              -8.014349        -6.345920
# TUC_OBS_217               -6.937794              -7.087884        -6.487716
# TUC_OBS_931               -6.233810              -6.422853        -6.112777
# ...                             ...                    ...              ...
# TUC_OBS_2095              -6.566070              -7.836242        -6.389872
# TUC_OBS_1193                    NaN                    NaN              NaN
# TUC_OBS_166               -6.807711                    NaN        -6.108853
# TUC_OBS_989               -6.960586              -6.891773        -6.691863
# TUC_OBS_1399                    NaN              -8.207538              NaN
#
#               photflux_aper_lolim_u  ...   kp_prob  hard_hs_lolim  \
# obs_id                               ...
# TUC_OBS_2089                    NaN  ...  0.790000        -1.0000
# TUC_OBS_1548                    NaN  ...  0.847000        -1.0000
# TUC_OBS_1615                    NaN  ...  0.886000        -1.0000
# TUC_OBS_217                     NaN  ...  0.858000        -1.0000
# TUC_OBS_931               -6.604848  ...  0.431250        -0.0793
# ...                             ...  ...       ...            ...
# TUC_OBS_2095                    NaN  ...  0.362000        -0.6864
# TUC_OBS_1193                    NaN  ...       NaN         0.0081
# TUC_OBS_166                     NaN  ...       NaN        -1.0000
# TUC_OBS_989                     NaN  ...  0.715667        -0.7464
# TUC_OBS_1399                    NaN  ...       NaN        -0.0219
#
#               hard_ms_lolim  hard_ms  hard_hs  hard_hs_hilim  hard_hm  \
# obs_id
# TUC_OBS_2089        -0.6015  -0.2498  -0.9994        -0.2555  -0.5721
# TUC_OBS_1548        -0.4878  -0.0962  -0.9994        -0.3766  -0.9994
# TUC_OBS_1615        -0.9275  -0.7883  -0.9994        -0.8176  -0.9994
# TUC_OBS_217         -0.6065  -0.2623  -0.9994        -0.5278  -0.9994
# TUC_OBS_931         -0.3741  -0.2186   0.0849         0.2430   0.2986
# ...                     ...      ...      ...            ...      ...
# TUC_OBS_2095        -0.8801  -0.7083  -0.4372        -0.1668   0.4110
# TUC_OBS_1193        -1.0000  -0.9994   0.9994         1.0000   0.9994
# TUC_OBS_166         -1.0000  -0.7146  -0.9994        -0.2355  -0.9994
# TUC_OBS_989         -0.2804  -0.0012  -0.4260        -0.0643  -0.4172
# TUC_OBS_1399        -0.0706   0.9994   0.9994         1.0000   0.3885
#
#               hard_hm_hilim  hard_hm_lolim  hard_ms_hilim
# obs_id
# TUC_OBS_2089        -0.0306        -1.0000         0.1355
# TUC_OBS_1548        -0.3604        -1.0000         0.3616
# TUC_OBS_1615        -0.1318        -1.0000        -0.6065
# TUC_OBS_217         -0.3716        -1.0000         0.1480
# TUC_OBS_931          0.4478         0.1368        -0.0581
# ...                     ...            ...            ...
# TUC_OBS_2095         0.7352         0.0119        -0.4866
# TUC_OBS_1193         1.0000         0.3254         0.0468
# TUC_OBS_166          0.1693        -1.0000        -0.0518
# TUC_OBS_989         -0.0806        -0.7314         0.2904
# TUC_OBS_1399         0.7639        -0.3579         1.0000
#
# [1572 rows x 60 columns]

# %%
info_col = ['src_n' , 'src_id' , 'significance' , 'class']
inter_obs_params = ['var_inter_prob' , 'var_inter_index' , 'var_inter_sigma']
id_data = tuc[info_col]
x_val = tuc.copy()
y_val = x_val['class']
x_val = x_val.drop(columns=info_col)
x_val
# Out:
#               photflux_aper_hilim_b  photflux_aper_lolim_h  \
# obs_id
# TUC_OBS_2089              -6.346981                    NaN
# TUC_OBS_1548              -6.027797                    NaN
# TUC_OBS_1615              -6.049976                    NaN
# TUC_OBS_217               -5.948847                    NaN
# TUC_OBS_931               -5.480041              -6.171920
# ...                             ...                    ...
# TUC_OBS_2095              -5.995249              -7.194567
# TUC_OBS_1193              -5.206140              -6.955852
# TUC_OBS_166               -5.586030                    NaN
# TUC_OBS_989               -6.056951              -7.981716
# TUC_OBS_1399              -6.244888                    NaN
#
#               photflux_aper_lolim_s  photflux_aper_lolim_m  photflux_aper_s  \
# obs_id
# TUC_OBS_2089              -7.272703              -7.575445        -6.904831
# TUC_OBS_1548              -7.331241              -7.079251        -6.650140
# TUC_OBS_1615              -6.510745              -8.014349        -6.345920
# TUC_OBS_217               -6.937794              -7.087884        -6.487716
# TUC_OBS_931               -6.233810              -6.422853        -6.112777
# ...                             ...                    ...              ...
# TUC_OBS_2095              -6.566070              -7.836242        -6.389872
# TUC_OBS_1193                    NaN                    NaN              NaN
# TUC_OBS_166               -6.807711                    NaN        -6.108853
# TUC_OBS_989               -6.960586              -6.891773        -6.691863
# TUC_OBS_1399                    NaN              -8.207538              NaN
#
#               photflux_aper_lolim_u  photflux_aper_h  photflux_aper_hilim_u  \
# obs_id
# TUC_OBS_2089                    NaN              NaN              -6.754734
# TUC_OBS_1548                    NaN              NaN              -5.742321
# TUC_OBS_1615                    NaN              NaN              -6.485984
# TUC_OBS_217                     NaN              NaN              -5.733063
# TUC_OBS_931               -6.604848        -6.048905              -6.010105
# ...                             ...              ...                    ...
# TUC_OBS_2095                    NaN        -6.803271              -6.550985
# TUC_OBS_1193                    NaN        -5.725380              -5.238222
# TUC_OBS_166                     NaN              NaN              -5.709743
# TUC_OBS_989                     NaN        -7.116566              -6.510463
# TUC_OBS_1399                    NaN              NaN              -5.659556
#
#               photflux_aper_hilim_s  photflux_aper_m  ...   kp_prob  \
# obs_id                                                ...
# TUC_OBS_2089              -6.708409        -7.098324  ...  0.790000
# TUC_OBS_1548              -6.396747        -6.653256  ...  0.847000
# TUC_OBS_1615              -6.232547        -7.254691  ...  0.886000
# TUC_OBS_217               -6.280172        -6.661942  ...  0.858000
# TUC_OBS_931               -6.022963        -6.295935  ...  0.431250
# ...                             ...              ...  ...       ...
# TUC_OBS_2095              -6.264960        -7.155026  ...  0.362000
# TUC_OBS_1193              -5.690796              NaN  ...       NaN
# TUC_OBS_166               -5.853562              NaN  ...       NaN
# TUC_OBS_989               -6.526951        -6.678816  ...  0.715667
# TUC_OBS_1399              -6.865504        -6.977159  ...       NaN
#
#               hard_hs_lolim  hard_ms_lolim  hard_ms  hard_hs  hard_hs_hilim  \
# obs_id
# TUC_OBS_2089        -1.0000        -0.6015  -0.2498  -0.9994        -0.2555
# TUC_OBS_1548        -1.0000        -0.4878  -0.0962  -0.9994        -0.3766
# TUC_OBS_1615        -1.0000        -0.9275  -0.7883  -0.9994        -0.8176
# TUC_OBS_217         -1.0000        -0.6065  -0.2623  -0.9994        -0.5278
# TUC_OBS_931         -0.0793        -0.3741  -0.2186   0.0849         0.2430
# ...                     ...            ...      ...      ...            ...
# TUC_OBS_2095        -0.6864        -0.8801  -0.7083  -0.4372        -0.1668
# TUC_OBS_1193         0.0081        -1.0000  -0.9994   0.9994         1.0000
# TUC_OBS_166         -1.0000        -1.0000  -0.7146  -0.9994        -0.2355
# TUC_OBS_989         -0.7464        -0.2804  -0.0012  -0.4260        -0.0643
# TUC_OBS_1399        -0.0219        -0.0706   0.9994   0.9994         1.0000
#
#               hard_hm  hard_hm_hilim  hard_hm_lolim  hard_ms_hilim
# obs_id
# TUC_OBS_2089  -0.5721        -0.0306        -1.0000         0.1355
# TUC_OBS_1548  -0.9994        -0.3604        -1.0000         0.3616
# TUC_OBS_1615  -0.9994        -0.1318        -1.0000        -0.6065
# TUC_OBS_217   -0.9994        -0.3716        -1.0000         0.1480
# TUC_OBS_931    0.2986         0.4478         0.1368        -0.0581
# ...               ...            ...            ...            ...
# TUC_OBS_2095   0.4110         0.7352         0.0119        -0.4866
# TUC_OBS_1193   0.9994         1.0000         0.3254         0.0468
# TUC_OBS_166   -0.9994         0.1693        -1.0000        -0.0518
# TUC_OBS_989   -0.4172        -0.0806        -0.7314         0.2904
# TUC_OBS_1399   0.3885         0.7639        -0.3579         1.0000
#
# [1572 rows x 56 columns]

# %%
tuc_filled = random_forest_imputer.transform(x_val)
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6

# %%
tuc_filled
# Out:
# array([[-6.34698055, -8.52903388, -7.2727028 , ..., -0.0306    ,
#         -1.        ,  0.1355    ],
#        [-6.02779716, -8.52981619, -7.33124146, ..., -0.3604    ,
#         -1.        ,  0.3616    ],
#        [-6.04997609, -8.52790598, -6.51074483, ..., -0.1318    ,
#         -1.        , -0.6065    ],
#        ...,
#        [-5.58603003, -7.35492122, -6.80771139, ...,  0.1693    ,
#         -1.        , -0.0518    ],
#        [-6.05695089, -7.98171569, -6.96058588, ..., -0.0806    ,
#         -0.7314    ,  0.2904    ],
#        [-6.24488773, -7.35078299, -7.97135522, ...,  0.7639    ,
#         -0.3579    ,  1.        ]])

# %%
imp_data =  pd.DataFrame(tuc_filled , columns = x_val.columns.to_list()  , index=x_val.index.to_list())
imp_data.index.name = 'obs_id'
normalized_df=(imp_data-imp_data.mean())/imp_data.std()
normalized_df.describe()

processed_data_all = pd.concat([id_data, normalized_df] , axis=1)
processed_data_all
processed_data_all.to_csv('../processed_data/v4/'+'tuc'+'_rf_impute_std_no_model.csv')
