# %% [markdown]
# # Load Modules

# %%
import numpy as np 
from matplotlib import pyplot as plt 
import seaborn as sns 
from tqdm import tqdm 
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import RandomForestClassifier  , AdaBoostClassifier , GradientBoostingClassifier
from sklearn.metrics import precision_score , recall_score 
import xgboost as xgb 
import pandas as pd 
import sklearn.neighbors._base
from os import sys
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
from missingpy import MissForest 
from sklearn.metrics import confusion_matrix , ConfusionMatrixDisplay
sns.set_style('whitegrid')
# %load_ext autoreload
# %autoreload 2
sns.set_style('whitegrid')
from IPython.display import display
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def details(data_sent , comments = ''):
    if(comments):
        print(comments)
    sp = (data_sent.isna().sum().sum())/ data_sent.size
    print('________________________________________________')
    print('Sparsity in the data : {:.2f}'.format(sp))
    num_rows = data_sent.shape
    print('Data shape' , num_rows)
    #display(data_sent['class'].value_counts())
    print('Number of sources : ')
    cl = data_sent['class'].unique()
    for c in cl:
        num_src = len(data_sent[data_sent['class']==c]['src_id'].unique())
        num_obs = len(data_sent[data_sent['class']==c])
        print(c ,' \t ' , num_src , '\t' , num_obs)

# %% [markdown]
# # Load Data

# %%
from features import phot_flux , en_flux , hard, powlaw_fit , bb_fit , brems_fit , intra_obs_var , inter_ob_var , info_col , phot_flux_hilim , phot_flux_lolim , en_flux_hilim , en_flux_lolim

# %%
feat_to_use = info_col + phot_flux + phot_flux_hilim + phot_flux_lolim + en_flux + en_flux_hilim + en_flux_lolim + powlaw_fit +bb_fit +hard+ intra_obs_var +inter_ob_var 
data_cv = pd.read_csv('filtered_data/cv_old_data.csv' , index_col='obs_id')[feat_to_use]
data_cv.insert(0 , 'class' , ['CV']*len(data_cv))
data_pl  =  pd.read_csv('filtered_data/pl_old_data.csv' , index_col = 'obs_id')[feat_to_use]
data_pl.insert(0 , 'class' , ['PL']*len(data_pl))
data_lx  =  pd.read_csv('filtered_data/lmxb_data.csv' , index_col = 'obs_id')[feat_to_use]
data_lx.insert(0 , 'class' , ['LX']*len(data_lx))

# %%
info_col_cl =  info_col+['class']

# %%
# sns.histplot(data_cv['num_obs'] , color='black' , alpha = 0.3)
# sns.histplot(data_pl['num_obs'] , color='crimson' ,  alpha = 0.3)
# sns.histplot(data_lx['num_obs'] , color = 'blue' ,  alpha = 0.3)
# plt.show()

# %%
data = pd.concat([data_cv , data_pl , data_lx] , axis=0)
data
# Out:
#               class   src_id  num_obs                    src_n  \
# obs_id
# CV_0_obs_0       CV     CV_0       33  [HPH2013]_176__________
# CV_0_obs_1       CV     CV_0       33  [HPH2013]_176__________
# CV_0_obs_2       CV     CV_0       33  [HPH2013]_176__________
# CV_0_obs_3       CV     CV_0       33  [HPH2013]_176__________
# CV_0_obs_4       CV     CV_0       33  [HPH2013]_176__________
# ...             ...      ...      ...                      ...
# LMXB_86_obs_0    LX  LMXB_86        1    SAX_J1810.8-2609_____
# LMXB_90_obs_0    LX  LMXB_90        1    XTE_J2123-058________
# LMXB_91_obs_0    LX  LMXB_91        1    XB_1732-304__________
# LMXB_92_obs_0    LX  LMXB_92        1    BW_ANT_______________
# LMXB_94_obs_0    LX  LMXB_94        1    J1748-3607___________
#
#                                  name         ra        dec  livetime  \
# obs_id
# CV_0_obs_0      2CXO J004245.0+411520   10.68773  41.255820    4903.5
# CV_0_obs_1      2CXO J004245.0+411520   10.68773  41.255820    3974.2
# CV_0_obs_2      2CXO J004245.0+411520   10.68773  41.255820    3907.5
# CV_0_obs_3      2CXO J004245.0+411520   10.68773  41.255820    3907.5
# CV_0_obs_4      2CXO J004245.0+411520   10.68773  41.255820    3907.5
# ...                               ...        ...        ...       ...
# LMXB_86_obs_0   2CXO J181044.4-260901  272.68530 -26.150370   31871.5
# LMXB_90_obs_0   2CXO J212314.5-054753  320.81060  -5.798128   17705.1
# LMXB_91_obs_0   2CXO J173547.0-302858  263.94590 -30.482820   18855.8
# LMXB_92_obs_0   2CXO J092920.1-312303  142.33410 -31.384270   24445.9
# LMXB_94_obs_0   2CXO J174813.1-360758  267.05470 -36.132810   15794.5
#
#                significance  likelihood  ...  var_inter_sigma_h  \
# obs_id                                   ...
# CV_0_obs_0            11.31   304.46460  ...                NaN
# CV_0_obs_1            11.31   304.46460  ...                NaN
# CV_0_obs_2            11.31   304.46460  ...                NaN
# CV_0_obs_3            11.31   304.46460  ...                NaN
# CV_0_obs_4            11.31   304.46460  ...                NaN
# ...                     ...         ...  ...                ...
# LMXB_86_obs_0          9.29   512.97550  ...                NaN
# LMXB_90_obs_0          4.06   132.76700  ...                NaN
# LMXB_91_obs_0          4.89   114.24570  ...       8.934000e-09
# LMXB_92_obs_0          3.70    75.53454  ...                NaN
# LMXB_94_obs_0          3.09    50.50810  ...                NaN
#
#                var_inter_index_m  var_inter_prob_m  var_inter_sigma_m  \
# obs_id
# CV_0_obs_0                   NaN               NaN                NaN
# CV_0_obs_1                   NaN               NaN                NaN
# CV_0_obs_2                   NaN               NaN                NaN
# CV_0_obs_3                   NaN               NaN                NaN
# CV_0_obs_4                   NaN               NaN                NaN
# ...                          ...               ...                ...
# LMXB_86_obs_0                NaN               NaN                NaN
# LMXB_90_obs_0                NaN               NaN                NaN
# LMXB_91_obs_0                5.0               0.8       1.257000e-07
# LMXB_92_obs_0                NaN               NaN                NaN
# LMXB_94_obs_0                NaN               NaN                NaN
#
#                var_inter_index_s  var_inter_prob_s  var_inter_sigma_s  \
# obs_id
# CV_0_obs_0                   NaN               NaN                NaN
# CV_0_obs_1                   NaN               NaN                NaN
# CV_0_obs_2                   NaN               NaN                NaN
# CV_0_obs_3                   NaN               NaN                NaN
# CV_0_obs_4                   NaN               NaN                NaN
# ...                          ...               ...                ...
# LMXB_86_obs_0                NaN               NaN                NaN
# LMXB_90_obs_0                NaN               NaN                NaN
# LMXB_91_obs_0                NaN             0.247       5.992000e-09
# LMXB_92_obs_0                NaN               NaN                NaN
# LMXB_94_obs_0                NaN               NaN                NaN
#
#                var_inter_index_u  var_inter_prob_u  var_inter_sigma_u
# obs_id
# CV_0_obs_0                   NaN               NaN                NaN
# CV_0_obs_1                   NaN               NaN                NaN
# CV_0_obs_2                   NaN               NaN                NaN
# CV_0_obs_3                   NaN               NaN                NaN
# CV_0_obs_4                   NaN               NaN                NaN
# ...                          ...               ...                ...
# LMXB_86_obs_0                NaN               NaN                NaN
# LMXB_90_obs_0                NaN               NaN                NaN
# LMXB_91_obs_0                NaN               NaN                NaN
# LMXB_92_obs_0                NaN               NaN                NaN
# LMXB_94_obs_0                NaN               NaN                NaN
#
# [1812 rows x 107 columns]

# %% [markdown]
# # Remove sparse columns

# %%
sp = [] 
for f in feat_to_use:
    #print(f)
    na = data[feat_to_use][f].isna().value_counts()
    try:
        sp.append(float(1-na[0]/(na[0]+na[1])))
    except:
        sp.append(0)
sp =  np.asarray(sp)
sparsity = pd.DataFrame(
    {
        "feat" : feat_to_use ,
        "sp_val" :sp
    }
).sort_values(by='sp_val' , ascending=False).reset_index(drop=True)
sparsity
# Out:
#             feat    sp_val
# 0    var_index_u  0.953091
# 1    var_index_s  0.878587
# 2    var_index_h  0.876380
# 3      kp_prob_u  0.871413
# 4      ks_prob_u  0.870861
# ..           ...       ...
# 101           ra  0.000000
# 102      num_obs  0.000000
# 103         name  0.000000
# 104        src_n  0.000000
# 105       src_id  0.000000
#
# [106 rows x 2 columns]

# %%
sparse_feat = sparsity[sparsity['sp_val']>0.5].sort_values(by='sp_val').reset_index(drop=True)
sparse_feat = sparse_feat['feat'].to_list()
#sparse_feat

# %%
dense_feat = sparsity[sparsity['sp_val']<0.5].sort_values(by='sp_val').reset_index(drop=True)
dense_feat = dense_feat['feat'].to_list()
#dense_feat

# %%
data_use = data[dense_feat+['class']]
details(data , 'Before removing sparse columns')
details(data_use , 'After removing sparse columns')
# Out:
# Before removing sparse columns
# ________________________________________________
# Sparsity in the data : 0.44
# Data shape (1812, 107)
# Number of sources :
# CV  	  60 	 994
# PL  	  92 	 297
# LX  	  58 	 521
# After removing sparse columns
# ________________________________________________
# Sparsity in the data : 0.23
# Data shape (1812, 58)
# Number of sources :
# CV  	  60 	 994
# PL  	  92 	 297
# LX  	  58 	 521

# %% [markdown]
# ## Take log

# %%
flux_feat = phot_flux + phot_flux_lolim + phot_flux_hilim + en_flux + en_flux_lolim + en_flux_hilim
flux_feat_avail = list(set(flux_feat) & set(dense_feat))
def take_log(data_sent):
    x_train_log = data_sent.copy()
    for f in flux_feat_avail[:]:
        x_train_log.loc[:,f] = -(np.log10(x_train_log.loc[:,f]))
    x_train_log = x_train_log.replace(-np.inf , np.nan)
    x_train_log = x_train_log.replace(np.inf , np.nan)
    return x_train_log

# %% [markdown]
# ## Take Log of flux columns

# %%
df_log = take_log(data_use)
details(df_log)
# Out:
# ________________________________________________
# Sparsity in the data : 0.23
# Data shape (1812, 58)
# Number of sources :
# CV  	  60 	 994
# PL  	  92 	 297
# LX  	  58 	 521

# %% [markdown]
# # all-obs imputation

# %% [markdown]
# ## Impute entire dataset

# %%
data_id = df_log[info_col_cl]
data_val = df_log.drop(columns = info_col_cl)

# %%
rf_imputer = MissForest(verbose=0 , decreasing=True)
new_data = rf_imputer.fit_transform(data_val)

# %%
df_log
# Out:
#                 src_id  livetime        dec  significance  \
# obs_id
# CV_0_obs_0        CV_0    4903.5  41.255820         11.31
# CV_0_obs_1        CV_0    3974.2  41.255820         11.31
# CV_0_obs_2        CV_0    3907.5  41.255820         11.31
# CV_0_obs_3        CV_0    3907.5  41.255820         11.31
# CV_0_obs_4        CV_0    3907.5  41.255820         11.31
# ...                ...       ...        ...           ...
# LMXB_86_obs_0  LMXB_86   31871.5 -26.150370          9.29
# LMXB_90_obs_0  LMXB_90   17705.1  -5.798128          4.06
# LMXB_91_obs_0  LMXB_91   18855.8 -30.482820          4.89
# LMXB_92_obs_0  LMXB_92   24445.9 -31.384270          3.70
# LMXB_94_obs_0  LMXB_94   15794.5 -36.132810          3.09
#
#                                  src_n         ra  num_obs  \
# obs_id
# CV_0_obs_0     [HPH2013]_176__________   10.68773       33
# CV_0_obs_1     [HPH2013]_176__________   10.68773       33
# CV_0_obs_2     [HPH2013]_176__________   10.68773       33
# CV_0_obs_3     [HPH2013]_176__________   10.68773       33
# CV_0_obs_4     [HPH2013]_176__________   10.68773       33
# ...                                ...        ...      ...
# LMXB_86_obs_0    SAX_J1810.8-2609_____  272.68530        1
# LMXB_90_obs_0    XTE_J2123-058________  320.81060        1
# LMXB_91_obs_0    XB_1732-304__________  263.94590        1
# LMXB_92_obs_0    BW_ANT_______________  142.33410        1
# LMXB_94_obs_0    J1748-3607___________  267.05470        1
#
#                                  name  likelihood  photflux_aper_hilim_b  ...  \
# obs_id                                                                    ...
# CV_0_obs_0      2CXO J004245.0+411520   304.46460                    NaN  ...
# CV_0_obs_1      2CXO J004245.0+411520   304.46460               5.909742  ...
# CV_0_obs_2      2CXO J004245.0+411520   304.46460               5.705754  ...
# CV_0_obs_3      2CXO J004245.0+411520   304.46460               5.847100  ...
# CV_0_obs_4      2CXO J004245.0+411520   304.46460               5.394264  ...
# ...                               ...         ...                    ...  ...
# LMXB_86_obs_0   2CXO J181044.4-260901   512.97550               4.904831  ...
# LMXB_90_obs_0   2CXO J212314.5-054753   132.76700               5.360115  ...
# LMXB_91_obs_0   2CXO J173547.0-302858   114.24570               5.235226  ...
# LMXB_92_obs_0   2CXO J092920.1-312303    75.53454               5.521289  ...
# LMXB_94_obs_0   2CXO J174813.1-360758    50.50810               5.499352  ...
#
#                photflux_aper_s  var_inter_index_h  var_inter_index_m  \
# obs_id
# CV_0_obs_0                 NaN                NaN                NaN
# CV_0_obs_1                 NaN                NaN                NaN
# CV_0_obs_2            5.808270                NaN                NaN
# CV_0_obs_3                 NaN                NaN                NaN
# CV_0_obs_4                 NaN                NaN                NaN
# ...                        ...                ...                ...
# LMXB_86_obs_0         5.338755                NaN                NaN
# LMXB_90_obs_0         5.737786                NaN                NaN
# LMXB_91_obs_0         6.466864                NaN                5.0
# LMXB_92_obs_0         6.135904                NaN                NaN
# LMXB_94_obs_0         5.922996                NaN                NaN
#
#                flux_aper_lolim_m  photflux_aper_lolim_m  flux_aper_s  \
# obs_id
# CV_0_obs_0                   NaN                    NaN          NaN
# CV_0_obs_1                   NaN                    NaN          NaN
# CV_0_obs_2                   NaN                    NaN    14.532244
# CV_0_obs_3                   NaN                    NaN          NaN
# CV_0_obs_4                   NaN                    NaN          NaN
# ...                          ...                    ...          ...
# LMXB_86_obs_0          14.444543               5.786217    14.189364
# LMXB_90_obs_0          15.478078               6.884057    14.499626
# LMXB_91_obs_0          14.373147               5.747875    15.291664
# LMXB_92_obs_0          15.357437               6.734946    14.902049
# LMXB_94_obs_0          15.286762               6.661344    14.767258
#
#                photflux_aper_lolim_s  flux_aper_lolim_s  var_inter_index_s  \
# obs_id
# CV_0_obs_0                       NaN                NaN                NaN
# CV_0_obs_1                       NaN                NaN                NaN
# CV_0_obs_2                       NaN          15.762708                NaN
# CV_0_obs_3                       NaN                NaN                NaN
# CV_0_obs_4                       NaN                NaN                NaN
# ...                              ...                ...                ...
# LMXB_86_obs_0               5.405497          14.260507                NaN
# LMXB_90_obs_0               5.889410          14.651500                NaN
# LMXB_91_obs_0               7.068949          15.893809                NaN
# LMXB_92_obs_0               6.357733          15.133535                NaN
# LMXB_94_obs_0               6.127087          14.971429                NaN
#
#                class
# obs_id
# CV_0_obs_0        CV
# CV_0_obs_1        CV
# CV_0_obs_2        CV
# CV_0_obs_3        CV
# CV_0_obs_4        CV
# ...              ...
# LMXB_86_obs_0     LX
# LMXB_90_obs_0     LX
# LMXB_91_obs_0     LX
# LMXB_92_obs_0     LX
# LMXB_94_obs_0     LX
#
# [1812 rows x 58 columns]

# %%
data_val
# Out:
#                photflux_aper_hilim_b  photflux_aper_hilim_h  \
# obs_id
# CV_0_obs_0                       NaN               6.216454
# CV_0_obs_1                  5.909742               6.069866
# CV_0_obs_2                  5.705754               6.072219
# CV_0_obs_3                  5.847100               5.934047
# CV_0_obs_4                  5.394264               5.727694
# ...                              ...                    ...
# LMXB_86_obs_0               4.904831               5.767512
# LMXB_90_obs_0               5.360115               6.096530
# LMXB_91_obs_0               5.235226               6.068542
# LMXB_92_obs_0               5.521289               5.987585
# LMXB_94_obs_0               5.499352               6.718285
#
#                flux_aper_hilim_b  photflux_aper_hilim_s  \
# obs_id
# CV_0_obs_0             14.167172               6.109803
# CV_0_obs_1             14.115658               5.768785
# CV_0_obs_2             14.388702               5.507379
# CV_0_obs_3             14.068339               5.826231
# CV_0_obs_4             13.890759               5.830914
# ...                          ...                    ...
# LMXB_86_obs_0          13.717831               5.280835
# LMXB_90_obs_0          14.123898               5.630970
# LMXB_91_obs_0          14.018997               6.232770
# LMXB_92_obs_0          14.134008               5.989700
# LMXB_94_obs_0          14.443095               5.784627
#
#                photflux_aper_hilim_m  hard_hs  hard_hm  flux_aper_hilim_s  \
# obs_id
# CV_0_obs_0                  6.322119  -0.9994   0.9994          14.861697
# CV_0_obs_1                       NaN  -0.9994      NaN          14.634699
# CV_0_obs_2                  6.132415  -0.9994   0.9994          14.244201
# CV_0_obs_3                  6.102483  -0.9994   0.9994          14.692290
# CV_0_obs_4                  5.903090   0.4247   0.9994          14.696588
# ...                              ...      ...      ...                ...
# LMXB_86_obs_0               5.614394  -0.5547  -0.2124          14.131414
# LMXB_90_obs_0               6.273844  -0.5609   0.2711          14.392867
# LMXB_91_obs_0               5.553152   0.2311  -0.6034          15.057545
# LMXB_92_obs_0               6.237547  -0.0075   0.3310          14.758703
# LMXB_94_obs_0               6.113227  -0.9994  -0.9994          14.628932
#
#                hard_ms  flux_aper_hilim_h  ...  var_prob_b  photflux_aper_s  \
# obs_id                                     ...
# CV_0_obs_0     -0.9994          14.231288  ...         NaN              NaN
# CV_0_obs_1         NaN          14.212256  ...         NaN              NaN
# CV_0_obs_2     -0.9994          14.144663  ...         NaN         5.808270
# CV_0_obs_3     -0.9994          14.076083  ...         NaN              NaN
# CV_0_obs_4     -0.9994          13.904134  ...         NaN              NaN
# ...                ...                ...  ...         ...              ...
# LMXB_86_obs_0  -0.3848          14.060930  ...       0.084         5.338755
# LMXB_90_obs_0  -0.7008          14.403843  ...       0.807         5.737786
# LMXB_91_obs_0   0.7295          14.464833  ...       0.451         6.466864
# LMXB_92_obs_0  -0.3310          14.240408  ...       0.607         6.135904
# LMXB_94_obs_0  -0.4172                NaN  ...       0.380         5.922996
#
#                var_inter_index_h  var_inter_index_m  flux_aper_lolim_m  \
# obs_id
# CV_0_obs_0                   NaN                NaN                NaN
# CV_0_obs_1                   NaN                NaN                NaN
# CV_0_obs_2                   NaN                NaN                NaN
# CV_0_obs_3                   NaN                NaN                NaN
# CV_0_obs_4                   NaN                NaN                NaN
# ...                          ...                ...                ...
# LMXB_86_obs_0                NaN                NaN          14.444543
# LMXB_90_obs_0                NaN                NaN          15.478078
# LMXB_91_obs_0                NaN                5.0          14.373147
# LMXB_92_obs_0                NaN                NaN          15.357437
# LMXB_94_obs_0                NaN                NaN          15.286762
#
#                photflux_aper_lolim_m  flux_aper_s  photflux_aper_lolim_s  \
# obs_id
# CV_0_obs_0                       NaN          NaN                    NaN
# CV_0_obs_1                       NaN          NaN                    NaN
# CV_0_obs_2                       NaN    14.532244                    NaN
# CV_0_obs_3                       NaN          NaN                    NaN
# CV_0_obs_4                       NaN          NaN                    NaN
# ...                              ...          ...                    ...
# LMXB_86_obs_0               5.786217    14.189364               5.405497
# LMXB_90_obs_0               6.884057    14.499626               5.889410
# LMXB_91_obs_0               5.747875    15.291664               7.068949
# LMXB_92_obs_0               6.734946    14.902049               6.357733
# LMXB_94_obs_0               6.661344    14.767258               6.127087
#
#                flux_aper_lolim_s  var_inter_index_s
# obs_id
# CV_0_obs_0                   NaN                NaN
# CV_0_obs_1                   NaN                NaN
# CV_0_obs_2             15.762708                NaN
# CV_0_obs_3                   NaN                NaN
# CV_0_obs_4                   NaN                NaN
# ...                          ...                ...
# LMXB_86_obs_0          14.260507                NaN
# LMXB_90_obs_0          14.651500                NaN
# LMXB_91_obs_0          15.893809                NaN
# LMXB_92_obs_0          15.133535                NaN
# LMXB_94_obs_0          14.971429                NaN
#
# [1812 rows x 48 columns]

# %%
new_imp_data =  pd.DataFrame(new_data , columns = data_val.columns.to_list()  , index=data_val.index.to_list())
new_imp_data.index.name = 'obs_id'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1673
# -> 1674         mgr = BlockManager(blocks, axes)
#    1675         mgr._consolidate_inplace()
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, do_integrity_check)
#     148         if do_integrity_check:
# --> 149             self._verify_integrity()
#     150
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/managers.py in _verify_integrity(self)
#     328             if block.shape[1:] != mgr_shape[1:]:
# --> 329                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     330         if len(self.items) != tot_items:
#
# ValueError: Shape of passed values is (1812, 48), indices imply (210, 48)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-4aca68c58dc3> in <module>
# ----> 1 new_imp_data =  pd.DataFrame(new_data , columns = data_val.columns.to_list()  , index=data_val.index.to_list())
#       2 new_imp_data.index.name = 'obs_id'
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     495                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     496             else:
# --> 497                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     498
#     499         # For data is list-like, or Iterable (will consume into list)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/construction.py in init_ndarray(values, index, columns, dtype, copy)
#     232         block_values = [values]
#     233
# --> 234     return create_block_manager_from_blocks(block_values, [columns, index])
#     235
#     236
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1679         blocks = [getattr(b, "values", b) for b in blocks]
#    1680         tot_items = sum(b.shape[0] for b in blocks)
# -> 1681         raise construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1682
#    1683
#
# ValueError: Shape of passed values is (1812, 48), indices imply (210, 48)

# %%
data_imp_v2 = pd.concat([data_id , new_imp_data] , axis=1)
data_imp_v2
# Out:
#                 src_id  num_obs                    src_n  \
# obs_id
# CV_0_obs_0        CV_0       33  [HPH2013]_176__________
# CV_0_obs_1        CV_0       33  [HPH2013]_176__________
# CV_0_obs_2        CV_0       33  [HPH2013]_176__________
# CV_0_obs_3        CV_0       33  [HPH2013]_176__________
# CV_0_obs_4        CV_0       33  [HPH2013]_176__________
# ...                ...      ...                      ...
# LMXB_86_obs_0  LMXB_86        1    SAX_J1810.8-2609_____
# LMXB_90_obs_0  LMXB_90        1    XTE_J2123-058________
# LMXB_91_obs_0  LMXB_91        1    XB_1732-304__________
# LMXB_92_obs_0  LMXB_92        1    BW_ANT_______________
# LMXB_94_obs_0  LMXB_94        1    J1748-3607___________
#
#                                  name         ra        dec  livetime  \
# obs_id
# CV_0_obs_0      2CXO J004245.0+411520   10.68773  41.255820    4903.5
# CV_0_obs_1      2CXO J004245.0+411520   10.68773  41.255820    3974.2
# CV_0_obs_2      2CXO J004245.0+411520   10.68773  41.255820    3907.5
# CV_0_obs_3      2CXO J004245.0+411520   10.68773  41.255820    3907.5
# CV_0_obs_4      2CXO J004245.0+411520   10.68773  41.255820    3907.5
# ...                               ...        ...        ...       ...
# LMXB_86_obs_0   2CXO J181044.4-260901  272.68530 -26.150370   31871.5
# LMXB_90_obs_0   2CXO J212314.5-054753  320.81060  -5.798128   17705.1
# LMXB_91_obs_0   2CXO J173547.0-302858  263.94590 -30.482820   18855.8
# LMXB_92_obs_0   2CXO J092920.1-312303  142.33410 -31.384270   24445.9
# LMXB_94_obs_0   2CXO J174813.1-360758  267.05470 -36.132810   15794.5
#
#                significance  likelihood class  ...  var_prob_b  \
# obs_id                                         ...
# CV_0_obs_0            11.31   304.46460    CV  ...     0.37225
# CV_0_obs_1            11.31   304.46460    CV  ...     0.66450
# CV_0_obs_2            11.31   304.46460    CV  ...     0.58393
# CV_0_obs_3            11.31   304.46460    CV  ...     0.62335
# CV_0_obs_4            11.31   304.46460    CV  ...     0.62721
# ...                     ...         ...   ...  ...         ...
# LMXB_86_obs_0          9.29   512.97550    LX  ...     0.08400
# LMXB_90_obs_0          4.06   132.76700    LX  ...     0.80700
# LMXB_91_obs_0          4.89   114.24570    LX  ...     0.45100
# LMXB_92_obs_0          3.70    75.53454    LX  ...     0.60700
# LMXB_94_obs_0          3.09    50.50810    LX  ...     0.38000
#
#                photflux_aper_s  var_inter_index_h  var_inter_index_m  \
# obs_id
# CV_0_obs_0            6.252377               5.03               5.38
# CV_0_obs_1            6.003964               7.06               5.22
# CV_0_obs_2            5.808270               6.91               5.32
# CV_0_obs_3            6.098587               6.92               5.32
# CV_0_obs_4            6.117570               6.88               5.17
# ...                        ...                ...                ...
# LMXB_86_obs_0         5.338755               5.00               5.05
# LMXB_90_obs_0         5.737786               5.01               5.10
# LMXB_91_obs_0         6.466864               3.00               5.00
# LMXB_92_obs_0         6.135904               5.01               5.12
# LMXB_94_obs_0         5.922996               5.03               5.22
#
#                flux_aper_lolim_m  photflux_aper_lolim_m  flux_aper_s  \
# obs_id
# CV_0_obs_0             14.780042               6.127175    15.049437
# CV_0_obs_1             14.738856               6.080562    14.859728
# CV_0_obs_2             14.839465               6.161259    14.532244
# CV_0_obs_3             14.836516               6.158179    14.901642
# CV_0_obs_4             14.737817               6.092001    14.908194
# ...                          ...                    ...          ...
# LMXB_86_obs_0          14.444543               5.786217    14.189364
# LMXB_90_obs_0          15.478078               6.884057    14.499626
# LMXB_91_obs_0          14.373147               5.747875    15.291664
# LMXB_92_obs_0          15.357437               6.734946    14.902049
# LMXB_94_obs_0          15.286762               6.661344    14.767258
#
#                photflux_aper_lolim_s  flux_aper_lolim_s  var_inter_index_s
# obs_id
# CV_0_obs_0                  6.476310          15.257587               4.25
# CV_0_obs_1                  6.594566          15.440023               4.30
# CV_0_obs_2                  7.031015          15.762708               4.30
# CV_0_obs_3                  6.629618          15.452589               4.31
# CV_0_obs_4                  6.605115          15.527400               4.32
# ...                              ...                ...                ...
# LMXB_86_obs_0               5.405497          14.260507               4.56
# LMXB_90_obs_0               5.889410          14.651500               4.56
# LMXB_91_obs_0               7.068949          15.893809               3.00
# LMXB_92_obs_0               6.357733          15.133535               4.54
# LMXB_94_obs_0               6.127087          14.971429               4.57
#
# [1812 rows x 58 columns]

# %%
data_imp_v2.to_csv('imputed_data/old-data-all-at-once-imp.csv')

# %%
data_imp_v2 = pd.read_csv('imputed_data/old-data-all-at-once-imp.csv' , index_col='obs_id')

# %%
details(data_imp_v2)
# Out:
# ________________________________________________
# Sparsity in the data : 0.00
# Data shape (1812, 58)
# Number of sources :
# CV  	  60 	 994
# PL  	  92 	 297
# LX  	  58 	 521

# %%
info_col_cl = info_col +['class']

# %%
data_id = data_imp_v2[info_col]
data_label = data_imp_v2['class']
data_val = data_imp_v2.drop(columns=['class']+info_col)

# %% [markdown]
# # Combine Obs

# %%
df_comb = pd.DataFrame()
for s in data_imp_v2['src_id'].unique()[:]:
    temp = data_imp_v2[data_imp_v2['src_id']==s]
    temp_id =  temp[info_col_cl]
    temp_val = temp.drop(columns=info_col_cl)
    temp_mean = temp_val.mean().to_frame().T
    temp_id_top = temp_id.iloc[0:1].reset_index()
    temp_final = pd.concat([temp_id_top , temp_mean] , axis=1).set_index('obs_id')
    df_comb = df_comb.append(temp_final)
display(df_comb)
# Out:
#                 src_id  num_obs                    src_n  \
# obs_id
# CV_0_obs_0        CV_0       33  [HPH2013]_176__________
# CV_1_obs_0        CV_1      104  [HPH2013]_142__________
# CV_2_obs_0        CV_2      102  [HPH2013]_169__________
# CV_3_obs_0        CV_3      102  XMMSL2_J004231.9+411621
# CV_4_obs_0        CV_4       97  [HPH2013]_205__________
# ...                ...      ...                      ...
# LMXB_86_obs_0  LMXB_86        1    SAX_J1810.8-2609_____
# LMXB_90_obs_0  LMXB_90        1    XTE_J2123-058________
# LMXB_91_obs_0  LMXB_91        1    XB_1732-304__________
# LMXB_92_obs_0  LMXB_92        1    BW_ANT_______________
# LMXB_94_obs_0  LMXB_94        1    J1748-3607___________
#
#                                  name         ra        dec  livetime  \
# obs_id
# CV_0_obs_0      2CXO J004245.0+411520   10.68773  41.255820    4903.5
# CV_1_obs_0      2CXO J004242.9+411543   10.67917  41.261980    4035.0
# CV_2_obs_0      2CXO J004244.3+411607   10.68489  41.268730    4035.0
# CV_3_obs_0      2CXO J004231.1+411621   10.62976  41.272670    4913.0
# CV_4_obs_0      2CXO J004248.7+411624   10.70297  41.273450    4881.4
# ...                               ...        ...        ...       ...
# LMXB_86_obs_0   2CXO J181044.4-260901  272.68530 -26.150370   31871.5
# LMXB_90_obs_0   2CXO J212314.5-054753  320.81060  -5.798128   17705.1
# LMXB_91_obs_0   2CXO J173547.0-302858  263.94590 -30.482820   18855.8
# LMXB_92_obs_0   2CXO J092920.1-312303  142.33410 -31.384270   24445.9
# LMXB_94_obs_0   2CXO J174813.1-360758  267.05470 -36.132810   15794.5
#
#                significance    likelihood class  ...  var_prob_b  \
# obs_id                                           ...
# CV_0_obs_0            11.31     304.46460    CV  ...    0.519053
# CV_1_obs_0            77.08   27912.78000    CV  ...    0.212598
# CV_2_obs_0            83.08   37399.46000    CV  ...    0.307392
# CV_3_obs_0           174.76  172643.30000    CV  ...    0.096272
# CV_4_obs_0            33.19    3870.74300    CV  ...    0.449750
# ...                     ...           ...   ...  ...         ...
# LMXB_86_obs_0          9.29     512.97550    LX  ...    0.084000
# LMXB_90_obs_0          4.06     132.76700    LX  ...    0.807000
# LMXB_91_obs_0          4.89     114.24570    LX  ...    0.451000
# LMXB_92_obs_0          3.70      75.53454    LX  ...    0.607000
# LMXB_94_obs_0          3.09      50.50810    LX  ...    0.380000
#
#                photflux_aper_s  var_inter_index_h  var_inter_index_m  \
# obs_id
# CV_0_obs_0            6.171487           5.201515           5.256667
# CV_1_obs_0            4.820819           6.000000           5.000000
# CV_2_obs_0            4.854613           8.000000           8.000000
# CV_3_obs_0            4.195978           7.000000           5.000000
# CV_4_obs_0            5.484190           6.000000           6.000000
# ...                        ...                ...                ...
# LMXB_86_obs_0         5.338755           5.010000           5.050000
# LMXB_90_obs_0         5.737786           5.000000           5.100000
# LMXB_91_obs_0         6.466864           3.000000           5.000000
# LMXB_92_obs_0         6.135904           5.000000           5.130000
# LMXB_94_obs_0         5.922996           5.160000           5.120000
#
#                flux_aper_lolim_m  photflux_aper_lolim_m  flux_aper_s  \
# obs_id
# CV_0_obs_0             14.979031               6.309536    14.976276
# CV_1_obs_0             13.739299               5.048415    13.652316
# CV_2_obs_0             14.149360               5.523214    13.530381
# CV_3_obs_0             12.952036               4.309032    12.978640
# CV_4_obs_0             14.697235               6.026592    14.305337
# ...                          ...                    ...          ...
# LMXB_86_obs_0          14.444543               5.786217    14.189364
# LMXB_90_obs_0          15.478078               6.884057    14.499626
# LMXB_91_obs_0          14.373147               5.747875    15.291664
# LMXB_92_obs_0          15.357437               6.734946    14.902049
# LMXB_94_obs_0          15.286762               6.661344    14.767258
#
#                photflux_aper_lolim_s  flux_aper_lolim_s  var_inter_index_s
# obs_id
# CV_0_obs_0                  6.707052          15.440544           4.211515
# CV_1_obs_0                  5.010062          13.844925           5.000000
# CV_2_obs_0                  5.077632          13.751917           8.000000
# CV_3_obs_0                  4.264402          13.047099           4.000000
# CV_4_obs_0                  6.029315          14.866403           6.000000
# ...                              ...                ...                ...
# LMXB_86_obs_0               5.405497          14.260507           4.450000
# LMXB_90_obs_0               5.889410          14.651500           4.460000
# LMXB_91_obs_0               7.068949          15.893809           3.000000
# LMXB_92_obs_0               6.357733          15.133535           4.440000
# LMXB_94_obs_0               6.127087          14.971429           4.480000
#
# [210 rows x 58 columns]

# %%
lh = df_comb[df_comb['likelihood']<1e100].sort_values(by='likelihood')['likelihood']
plt.hist(np.log(lh) ,density=True)
plt.show()

# %%
# Out:
# obs_id
# CV_0_obs_0       1.693641e-306
# CV_1_obs_0       1.552700e-304
# CV_2_obs_0       2.080414e-304
# CV_3_obs_0       9.603603e-304
# CV_4_obs_0       2.153172e-305
#                      ...
# LMXB_86_obs_0    2.853521e-306
# LMXB_90_obs_0    7.385410e-307
# LMXB_91_obs_0    6.355128e-307
# LMXB_92_obs_0    4.201749e-307
# LMXB_94_obs_0    2.809607e-307
# Name: likelihood, Length: 210, dtype: float64

# %%
plt.hist(np.log(df_comb['likelihood']))
# Out:
# (array([208.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   2.]),
#  array([  3.92213372,  74.50819163, 145.09424954, 215.68030745,
#         286.26636536, 356.85242327, 427.43848118, 498.02453909,
#         568.610597  , 639.19665491, 709.78271282]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Normalize

# %%
#data_imp_norm.to_csv('all_filled_norm.csv')

# %%
#data_imp_v2 = pd.read_csv('imputed_data/srcwise-imp_old-data.csv' , index_col = 'obs_id')

# %%
data_id = df_comb[info_col]
data_label = df_comb['class']
data_val = df_comb.drop(columns=['class']+info_col)
data_imp_norm = df_comb.copy()
for c in data_val.columns.to_list():
    data_imp_norm.loc[:,c] = (data_imp_norm.loc[:,c] - data_imp_norm.loc[:,c].mean()) / data_imp_norm.loc[:,c].std()
data_imp_norm
# Out:
#                 src_id  num_obs                    src_n  \
# obs_id
# CV_0_obs_0        CV_0       33  [HPH2013]_176__________
# CV_1_obs_0        CV_1      104  [HPH2013]_142__________
# CV_2_obs_0        CV_2      102  [HPH2013]_169__________
# CV_3_obs_0        CV_3      102  XMMSL2_J004231.9+411621
# CV_4_obs_0        CV_4       97  [HPH2013]_205__________
# ...                ...      ...                      ...
# LMXB_86_obs_0  LMXB_86        1    SAX_J1810.8-2609_____
# LMXB_90_obs_0  LMXB_90        1    XTE_J2123-058________
# LMXB_91_obs_0  LMXB_91        1    XB_1732-304__________
# LMXB_92_obs_0  LMXB_92        1    BW_ANT_______________
# LMXB_94_obs_0  LMXB_94        1    J1748-3607___________
#
#                                  name         ra        dec  livetime  \
# obs_id
# CV_0_obs_0      2CXO J004245.0+411520   10.68773  41.255820    4903.5
# CV_1_obs_0      2CXO J004242.9+411543   10.67917  41.261980    4035.0
# CV_2_obs_0      2CXO J004244.3+411607   10.68489  41.268730    4035.0
# CV_3_obs_0      2CXO J004231.1+411621   10.62976  41.272670    4913.0
# CV_4_obs_0      2CXO J004248.7+411624   10.70297  41.273450    4881.4
# ...                               ...        ...        ...       ...
# LMXB_86_obs_0   2CXO J181044.4-260901  272.68530 -26.150370   31871.5
# LMXB_90_obs_0   2CXO J212314.5-054753  320.81060  -5.798128   17705.1
# LMXB_91_obs_0   2CXO J173547.0-302858  263.94590 -30.482820   18855.8
# LMXB_92_obs_0   2CXO J092920.1-312303  142.33410 -31.384270   24445.9
# LMXB_94_obs_0   2CXO J174813.1-360758  267.05470 -36.132810   15794.5
#
#                significance    likelihood class  ...  var_prob_b  \
# obs_id                                           ...
# CV_0_obs_0            11.31     304.46460    CV  ...    0.701065
# CV_1_obs_0            77.08   27912.78000    CV  ...   -0.589881
# CV_2_obs_0            83.08   37399.46000    CV  ...   -0.190559
# CV_3_obs_0           174.76  172643.30000    CV  ...   -1.079908
# CV_4_obs_0            33.19    3870.74300    CV  ...    0.409124
# ...                     ...           ...   ...  ...         ...
# LMXB_86_obs_0          9.29     512.97550    LX  ...   -1.131602
# LMXB_90_obs_0          4.06     132.76700    LX  ...    1.914046
# LMXB_91_obs_0          4.89     114.24570    LX  ...    0.414391
# LMXB_92_obs_0          3.70      75.53454    LX  ...    1.071543
# LMXB_94_obs_0          3.09      50.50810    LX  ...    0.115302
#
#                photflux_aper_s  var_inter_index_h  var_inter_index_m  \
# obs_id
# CV_0_obs_0            0.730713          -0.320265          -0.153136
# CV_1_obs_0           -1.027547           0.162591          -0.311327
# CV_2_obs_0           -0.983555           1.372020           1.537661
# CV_3_obs_0           -1.840947           0.767305          -0.311327
# CV_4_obs_0           -0.163991           0.162591           0.305002
# ...                        ...                ...                ...
# LMXB_86_obs_0        -0.353313          -0.436077          -0.280511
# LMXB_90_obs_0         0.166134          -0.442124          -0.249694
# LMXB_91_obs_0         1.115226          -1.651553          -0.311327
# LMXB_92_obs_0         0.684393          -0.442124          -0.231204
# LMXB_94_obs_0         0.407234          -0.345370          -0.237368
#
#                flux_aper_lolim_m  photflux_aper_lolim_m  flux_aper_s  \
# obs_id
# CV_0_obs_0              0.794837               0.727087     0.814387
# CV_1_obs_0             -0.988111              -1.081884    -0.937379
# CV_2_obs_0             -0.398373              -0.400824    -1.098715
# CV_3_obs_0             -2.120331              -2.142465    -1.828737
# CV_4_obs_0              0.389566               0.321228    -0.073350
# ...                          ...                    ...          ...
# LMXB_86_obs_0           0.026151              -0.023570    -0.226797
# LMXB_90_obs_0           1.512552               1.551189     0.183719
# LMXB_91_obs_0          -0.076529              -0.078567     1.231685
# LMXB_92_obs_0           1.339049               1.337303     0.716175
# LMXB_94_obs_0           1.237407               1.231727     0.537830
#
#                photflux_aper_lolim_s  flux_aper_lolim_s  var_inter_index_s
# obs_id
# CV_0_obs_0                  1.057429           0.981106          -0.466188
# CV_1_obs_0                 -0.928226          -0.846571          -0.013983
# CV_2_obs_0                 -0.849163          -0.953106           1.706550
# CV_3_obs_0                 -1.800727          -1.760429          -0.587495
# CV_4_obs_0                  0.264406           0.323465           0.559528
# ...                              ...                ...                ...
# LMXB_86_obs_0              -0.465527          -0.370550          -0.329415
# LMXB_90_obs_0               0.100702           0.077308          -0.323679
# LMXB_91_obs_0               1.480886           1.500292          -1.161006
# LMXB_92_obs_0               0.648689           0.629448          -0.335150
# LMXB_94_obs_0               0.378809           0.443765          -0.312209
#
# [210 rows x 58 columns]

# %%
details(data_imp_norm)
# Out:
# ________________________________________________
# Sparsity in the data : 0.00
# Data shape (210, 58)
# Number of sources :
# CV  	  60 	 60
# PL  	  92 	 92
# LX  	  58 	 58

# %%
verbose = 0
val_acc = []
test_acc = []
for i in tqdm(range(10)):
    src_list = pd.DataFrame()
    class_to_select = ['CV' , 'LX' , 'PL']
    df = data_imp_norm.copy()
    for cl in class_to_select:
        src = df[df['class']==cl]['src_id'].value_counts().sort_values()
        #display(src)
        src = src.iloc[:int(len(src)*0.3)]
        src_select = src.sample(frac=0.9)
        src_id = src_select.index.to_list()
        src_obs = src_select.to_list()
        temp_src = pd.DataFrame({ 
            'src_id' : src_id , 
            'obs_count' : src_obs
        })
        src_list = src_list.append(temp_src)
    #src_list

    all_src = np.unique(df['src_id'].to_list())
    test_src = src_list['src_id'].to_list()
    train_src= list(set(all_src) - set(src_list['src_id']))
    # if(verbose):
    #     print('Total Number of ssources :' , len(all_src))
    #     print('Training_sources : ' , len(train_src) )
    #     print('Validation sources :' , len(test_src))

    # df = df.replace({
    #     "BH" :2 , 
    #     "NS" : 2 ,
    #     "CV" : 0 , 
    #     "PULSAR" : 1 
    # })


    df= df[df['class'].isin(class_to_select)]
    df 



    df_train  = df[df['src_id'].isin(train_src)]
    df_test = df[df['src_id'].isin(test_src)]

    df_train = df_train[df_train['class'].isin(class_to_select)]
    df_test = df_test[df_test['class'].isin(class_to_select)]

    if(verbose):
        details(df_train)
        details(df_test)

    train_id = df_train[info_col]
    train_label = df_train['class']
    train_value = df_train.drop(columns=['class']+info_col)


    i_val = df_test[info_col]
    y_val = df_test['class']
    x_val = df_test.drop(columns=['class']+info_col)

    clf = RandomForestClassifier(
        n_estimators = 100 , n_jobs=-1
    )
    #clf = AdaBoostClassifier(base_estimator=clf ,)
    #clf = xgb.XGBRFClassifier(n_componets=200)
    #clf = xgb.XGBClassifier()
    #x_train , x_test , y_train , y_test = train_test_split(train_value , train_label , test_size=0.1 , stratify=train_label, random_state=9)
    x_train , y_train = train_value , train_label
    clf.fit(x_train , y_train)
    v_sc = clf.score(x_val , y_val)
    test_sc = clf.score(x_train, y_train)
    val_acc.append(v_sc)
    test_acc.append(test_sc)
    #if(verbose):
    print(test_sc , v_sc)
# Out:
#  10%|█         | 1/10 [00:00<00:04,  1.91it/s]
# 0.9419354838709677 0.6727272727272727
#  20%|██        | 2/10 [00:01<00:04,  1.95it/s]
# 0.9483870967741935 0.6727272727272727
#  30%|███       | 3/10 [00:01<00:03,  1.95it/s]
# 0.9483870967741935 0.7090909090909091
#  40%|████      | 4/10 [00:02<00:03,  1.89it/s]
# 0.9483870967741935 0.6727272727272727
#  50%|█████     | 5/10 [00:02<00:02,  1.92it/s]
# 0.9419354838709677 0.7090909090909091
#  60%|██████    | 6/10 [00:03<00:02,  1.92it/s]
# 0.9483870967741935 0.7272727272727273
#  70%|███████   | 7/10 [00:03<00:01,  1.91it/s]
# 0.9483870967741935 0.7090909090909091
#  80%|████████  | 8/10 [00:04<00:01,  1.90it/s]
# 0.9483870967741935 0.6727272727272727
#  90%|█████████ | 9/10 [00:04<00:00,  1.80it/s]
# 0.9419354838709677 0.6909090909090909
# 100%|██████████| 10/10 [00:05<00:00,  1.88it/s]
# 0.9483870967741935 0.6363636363636364

# %%
score = pd.DataFrame({
    "Test Score" : test_acc, 
    "Validation Score" : val_acc
})*100
score.describe().loc[['mean' , 'std' , 'min', 'max' ]]
# Out:
#       Test Score  Validation Score
# mean   94.645161         68.727273
# std     0.311643          2.683145
# min    94.193548         63.636364
# max    94.838710         72.727273

# %%
sns.set(font_scale=1.3)
sns.set_style('whitegrid')
fig , ax = plt.subplots(nrows=1 , ncols=3 , figsize = (18 , 4))
sns.boxplot(data = score , ax = ax[0])
cf = confusion_matrix(y_train , clf.predict(x_train) ,)
sns.heatmap(cf , annot=True ,fmt = '.0f' , ax = ax[1] , xticklabels =class_to_select , yticklabels = class_to_select  , cmap='RdYlGn' ,)
cf = confusion_matrix(y_val , clf.predict(x_val) ,)
sns.heatmap(cf , annot=True ,fmt = '.0f' , ax = ax[2] , xticklabels=class_to_select, yticklabels = class_to_select , cmap='RdYlGn')
ax[1].set_title('Training CF')
ax[2].set_title('Validation CF')
for a in ax[1:]:
    a.set_xlabel('Predicted class')
    a.set_ylabel('True class')

plt.show()
#score

# %%
y_true , y_pred = y_val , clf.predict(x_val)

# %%
y_pred_prob = clf.predict_proba(x_val)

# %%
from sklearn.metrics import precision_score , recall_score , roc_auc_score

# %%
ps = precision_score(y_true , y_pred , average=None)
rc = recall_score(y_true , y_pred , average=None)
#auc = roc_auc_score(y_val_oh , y_pred_prob)
sc = pd.DataFrame(
    np.asarray([ps , rc]) , columns=['CV' , 'LX' , 'PL'] , index=['Precision' , 'Recall']
)
sc.index.name = 'type'
sc =sc.reset_index()
display(sc)
sc = sc.melt(id_vars=['type'] , value_vars = ['CV' , 'LX' , 'PL'])
sns.pointplot(
    data = sc , x = 'variable' , y = 'value' , hue = 'type' , join=False , ax=ax[3]
)
# Out:
#         type        CV        LX        PL
# 0  Precision  0.666667  0.611111  0.772727
# 1     Recall  0.625000  0.733333  0.708333
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-dc69eb6c0c1d> in <module>
#      10 sc = sc.melt(id_vars=['type'] , value_vars = ['CV' , 'LX' , 'PL'])
#      11 sns.pointplot(
# ---> 12     data = sc , x = 'variable' , y = 'value' , hue = 'type' , join=False , ax=ax[3]
#      13 )
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
pd.DataFrame({
    'feat' : x_train.columns.to_list() , 
    'val' : clf.feature_importances_
}).sort_values('val' , ascending=False).reset_index(drop=True)
# Out:
#                  feat       val
# 0     photflux_aper_m  0.149696
# 1    var_inter_prob_m  0.135717
# 2         flux_aper_m  0.081213
# 3   var_inter_sigma_h  0.063748
# 4    var_inter_prob_s  0.054214
# 5   var_inter_index_h  0.043667
# 6   var_inter_sigma_m  0.042827
# 7   var_inter_sigma_b  0.036619
# 8           var_min_b  0.033070
# 9    var_inter_prob_b  0.032857
# 10  var_inter_sigma_s  0.031830
# 11         var_prob_b  0.027510
# 12         var_mean_b  0.026091
# 13  var_inter_index_m  0.023149
# 14    photflux_aper_s  0.019986
# 15   var_inter_prob_h  0.019777
# 16  var_inter_index_b  0.019731
# 17          var_max_b  0.019040
# 18  var_inter_index_s  0.013960
# 19        var_sigma_b  0.013542
# 20    photflux_aper_u  0.013337
# 21          ks_prob_b  0.012396
# 22    photflux_aper_b  0.012178
# 23          kp_prob_b  0.011317
# 24            hard_hs  0.010960
# 25        flux_aper_h  0.009026
# 26            hard_ms  0.008911
# 27            hard_hm  0.008520
# 28        flux_aper_b  0.007053
# 29        flux_aper_u  0.006437
# 30        flux_aper_s  0.005997
# 31    photflux_aper_h  0.005625
