# %%
import pandas as pd 
from matplotlib import pyplot as plt 
import seaborn as sns 
from tqdm import tqdm

# %%
bh = pd.read_csv('imp_data/BH_src_imp.csv')
bh
# Out:
#          obs_id class                 src_n  src_id  significance  \
# 0      BH_OBS_2    BH  1A 0620-00            BH0001         23.63
# 1      BH_OBS_1    BH  1A 0620-00            BH0001         23.63
# 2      BH_OBS_0    BH  1A 0620-00            BH0001         23.63
# 3    BH_OBS_198    BH  CJ0422+32             BH0033          3.65
# 4     BH_OBS_48    BH  CXOU J100506.7-07443  BH0014         11.41
# ..          ...   ...                   ...     ...           ...
# 153   BH_OBS_33    BH  XTE J1550-564         BH0010         29.24
# 154   BH_OBS_38    BH  XTE J1550-564         BH0010         29.24
# 155   BH_OBS_32    BH  XTE J1550-564         BH0010         29.24
# 156   BH_OBS_39    BH  XTE J1650-500         BH0011         86.04
# 157   BH_OBS_40    BH  XTE J1859+226         BH0012          2.11
#
#      photflux_aper_hilim_b  photflux_aper_m  photflux_aper_lolim_h  \
# 0                -4.390512        -5.031004              -5.039054
# ...
