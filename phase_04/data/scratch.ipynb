# %%
import pandas as pd

# %%
df = pd.read_csv('pulsars/atnf_catalogue.csv' , comment='#' , delimiter=';' , index_col = 'INDEX' , na_values='*').iloc[: , :-1]
df
# Out:
#              NAME        PSRJ         RAJ         DECJ        RAJD      DECJD  \
# INDEX
# 1      J0002+6216  J0002+6216  00:02:58.1  +62:16:09.4    0.742375  62.269278
# 2      J0006+1834  J0006+1834  00:06:04.8    +18:34:59    1.520000  18.583056
# 3      J0007+7303  J0007+7303  00:07:01.7  +73:03:07.4    1.757083  73.052056
# 4        J0011+08    J0011+08    00:11:34       +08:10    2.891667   8.166667
# 5        B0011+47  J0014+4746  00:14:17.7  +47:46:33.4    3.573958  47.775944
# ...           ...         ...         ...          ...         ...        ...
# 3173   J2351+8533  J2351+8533    23:51:03  +85:33:20.6  357.763734  85.555735
# 3174     J2352+65    J2352+65       23:52          +65  358.000000  65.000000
# 3175     J2354-22    J2354-22    23:54:26    -22:51:53  358.608333 -22.864722
# 3176     B2351+61  J2354+6155  23:54:04.7  +61:55:46.8  358.519929  61.929679
# 3177   J2355+2246  J2355+2246  23:55:49.8    +22:46:17  358.957500  22.771389
#
# ...

# %%
df['BINCOMP'].value_counts()
# Out:
# He[san16]        11
# He                6
# He[hrs+07]        6
# He[rhs+05]        5
# He[lfl+06]        4
#                  ..
# He(?)[rhs+05]     1
# CO(?)[lsk+18]     1
# MS[lht14]         1
# NS[lsk+18]        1
# He[fsk+04]        1
# Name: BINCOMP, Length: 206, dtype: int64

# %%
type = df['PSR'].value_counts()
type
# Out:
# *                     2726
# RRAT                    80
# HE                      71
# NRAD                    62
# AXP,NRAD                19
#                       ...
# HE[wob+04,aaa+09f]       1
# HE[yhh94]                1
# HE[umw+93,ppp+09]        1
# HE[tst+01]               1
# HE[aaa+09]               1
# Name: PSR, Length: 114, dtype: int64

# %%
df[df['class']]
