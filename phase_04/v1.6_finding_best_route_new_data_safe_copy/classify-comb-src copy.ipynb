# %% [markdown]
# # Load Modules

# %%
import numpy as np 
from matplotlib import pyplot as plt 
import seaborn as sns 
from tqdm import tqdm 
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import RandomForestClassifier  , AdaBoostClassifier , GradientBoostingClassifier
from sklearn.metrics import precision_score , recall_score 
import xgboost as xgb 
import pandas as pd 
import sklearn.neighbors._base
from os import sys
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
from missingpy import MissForest 
from sklearn.metrics import confusion_matrix , ConfusionMatrixDisplay
sns.set_style('whitegrid')
# %load_ext autoreload
# %autoreload 2
sns.set_style('whitegrid')
from IPython.display import display
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def details(data_sent , comments = ''):
    if(comments):
        print(comments)
    sp = (data_sent.isna().sum().sum())/ data_sent.size
    print('________________________________________________')
    print('Sparsity in the data : {:.2f}'.format(sp))
    num_rows = data_sent.shape
    print('Data shape' , num_rows)
    #display(data_sent['class'].value_counts())
    print('Number of sources : ')
    cl = data_sent['class'].unique()
    for c in cl:
        num_src = len(data_sent[data_sent['class']==c]['src_id'].unique())
        num_obs = len(data_sent[data_sent['class']==c])
        print(c ,' \t ' , num_src , '\t' , num_obs)

# %% [markdown]
# # Load Data

# %%
from features import phot_flux , en_flux , hard, powlaw_fit , bb_fit , brems_fit , intra_obs_var , inter_ob_var , info_col , phot_flux_hilim , phot_flux_lolim , en_flux_hilim , en_flux_lolim

# %%
feat_to_use = info_col + phot_flux + phot_flux_hilim + phot_flux_lolim + en_flux + en_flux_hilim + en_flux_lolim + powlaw_fit +bb_fit +hard+ intra_obs_var +inter_ob_var 
data_cv = pd.read_csv('filtered_data/cv_old_data.csv' , index_col='obs_id')[feat_to_use]
data_cv.insert(0 , 'class' , ['CV']*len(data_cv))
data_pl  =  pd.read_csv('filtered_data/pl_old_data.csv' , index_col = 'obs_id')[feat_to_use]
data_pl.insert(0 , 'class' , ['PL']*len(data_pl))
data_lx  =  pd.read_csv('filtered_data/lmxb_data.csv' , index_col = 'obs_id')[feat_to_use]
data_lx.insert(0 , 'class' , ['LX']*len(data_lx))

# %%
info_col_cl =  info_col+['class']

# %%
# sns.histplot(data_cv['num_obs'] , color='black' , alpha = 0.3)
# sns.histplot(data_pl['num_obs'] , color='crimson' ,  alpha = 0.3)
# sns.histplot(data_lx['num_obs'] , color = 'blue' ,  alpha = 0.3)
# plt.show()

# %%
data = pd.concat([data_cv , data_pl , data_lx] , axis=0)
data
# Out:
#               class   src_id  num_obs                    src_n  \
# obs_id
# CV_0_obs_0       CV     CV_0       33  [HPH2013]_176__________
# CV_0_obs_1       CV     CV_0       33  [HPH2013]_176__________
# CV_0_obs_2       CV     CV_0       33  [HPH2013]_176__________
# CV_0_obs_3       CV     CV_0       33  [HPH2013]_176__________
# CV_0_obs_4       CV     CV_0       33  [HPH2013]_176__________
# ...             ...      ...      ...                      ...
# LMXB_86_obs_0    LX  LMXB_86        1    SAX_J1810.8-2609_____
# LMXB_90_obs_0    LX  LMXB_90        1    XTE_J2123-058________
# LMXB_91_obs_0    LX  LMXB_91        1    XB_1732-304__________
# LMXB_92_obs_0    LX  LMXB_92        1    BW_ANT_______________
# LMXB_94_obs_0    LX  LMXB_94        1    J1748-3607___________
#
#                                  name         ra        dec  livetime  \
# obs_id
# CV_0_obs_0      2CXO J004245.0+411520   10.68773  41.255820    4903.5
# CV_0_obs_1      2CXO J004245.0+411520   10.68773  41.255820    3974.2
# CV_0_obs_2      2CXO J004245.0+411520   10.68773  41.255820    3907.5
# CV_0_obs_3      2CXO J004245.0+411520   10.68773  41.255820    3907.5
# CV_0_obs_4      2CXO J004245.0+411520   10.68773  41.255820    3907.5
# ...                               ...        ...        ...       ...
# LMXB_86_obs_0   2CXO J181044.4-260901  272.68530 -26.150370   31871.5
# LMXB_90_obs_0   2CXO J212314.5-054753  320.81060  -5.798128   17705.1
# LMXB_91_obs_0   2CXO J173547.0-302858  263.94590 -30.482820   18855.8
# LMXB_92_obs_0   2CXO J092920.1-312303  142.33410 -31.384270   24445.9
# LMXB_94_obs_0   2CXO J174813.1-360758  267.05470 -36.132810   15794.5
#
#                significance  likelihood  ...  var_inter_sigma_h  \
# obs_id                                   ...
# CV_0_obs_0            11.31   304.46460  ...                NaN
# CV_0_obs_1            11.31   304.46460  ...                NaN
# CV_0_obs_2            11.31   304.46460  ...                NaN
# CV_0_obs_3            11.31   304.46460  ...                NaN
# CV_0_obs_4            11.31   304.46460  ...                NaN
# ...                     ...         ...  ...                ...
# LMXB_86_obs_0          9.29   512.97550  ...                NaN
# LMXB_90_obs_0          4.06   132.76700  ...                NaN
# LMXB_91_obs_0          4.89   114.24570  ...       8.934000e-09
# LMXB_92_obs_0          3.70    75.53454  ...                NaN
# LMXB_94_obs_0          3.09    50.50810  ...                NaN
#
#                var_inter_index_m  var_inter_prob_m  var_inter_sigma_m  \
# obs_id
# CV_0_obs_0                   NaN               NaN                NaN
# CV_0_obs_1                   NaN               NaN                NaN
# CV_0_obs_2                   NaN               NaN                NaN
# CV_0_obs_3                   NaN               NaN                NaN
# CV_0_obs_4                   NaN               NaN                NaN
# ...                          ...               ...                ...
# LMXB_86_obs_0                NaN               NaN                NaN
# LMXB_90_obs_0                NaN               NaN                NaN
# LMXB_91_obs_0                5.0               0.8       1.257000e-07
# LMXB_92_obs_0                NaN               NaN                NaN
# LMXB_94_obs_0                NaN               NaN                NaN
#
#                var_inter_index_s  var_inter_prob_s  var_inter_sigma_s  \
# obs_id
# CV_0_obs_0                   NaN               NaN                NaN
# CV_0_obs_1                   NaN               NaN                NaN
# CV_0_obs_2                   NaN               NaN                NaN
# CV_0_obs_3                   NaN               NaN                NaN
# CV_0_obs_4                   NaN               NaN                NaN
# ...                          ...               ...                ...
# LMXB_86_obs_0                NaN               NaN                NaN
# LMXB_90_obs_0                NaN               NaN                NaN
# LMXB_91_obs_0                NaN             0.247       5.992000e-09
# LMXB_92_obs_0                NaN               NaN                NaN
# LMXB_94_obs_0                NaN               NaN                NaN
#
#                var_inter_index_u  var_inter_prob_u  var_inter_sigma_u
# obs_id
# CV_0_obs_0                   NaN               NaN                NaN
# CV_0_obs_1                   NaN               NaN                NaN
# CV_0_obs_2                   NaN               NaN                NaN
# CV_0_obs_3                   NaN               NaN                NaN
# CV_0_obs_4                   NaN               NaN                NaN
# ...                          ...               ...                ...
# LMXB_86_obs_0                NaN               NaN                NaN
# LMXB_90_obs_0                NaN               NaN                NaN
# LMXB_91_obs_0                NaN               NaN                NaN
# LMXB_92_obs_0                NaN               NaN                NaN
# LMXB_94_obs_0                NaN               NaN                NaN
#
# [1812 rows x 107 columns]

# %% [markdown]
# # Remove sparse columns

# %%
sp = [] 
for f in feat_to_use:
    #print(f)
    na = data[feat_to_use][f].isna().value_counts()
    try:
        sp.append(float(1-na[0]/(na[0]+na[1])))
    except:
        sp.append(0)
sp =  np.asarray(sp)
sparsity = pd.DataFrame(
    {
        "feat" : feat_to_use ,
        "sp_val" :sp
    }
).sort_values(by='sp_val' , ascending=False).reset_index(drop=True)
sparsity
# Out:
#             feat    sp_val
# 0    var_index_u  0.953091
# 1    var_index_s  0.878587
# 2    var_index_h  0.876380
# 3      kp_prob_u  0.871413
# 4      ks_prob_u  0.870861
# ..           ...       ...
# 101           ra  0.000000
# 102      num_obs  0.000000
# 103         name  0.000000
# 104        src_n  0.000000
# 105       src_id  0.000000
#
# [106 rows x 2 columns]

# %%
sparse_feat = sparsity[sparsity['sp_val']>0.5].sort_values(by='sp_val').reset_index(drop=True)
sparse_feat = sparse_feat['feat'].to_list()
#sparse_feat

# %%
dense_feat = sparsity[sparsity['sp_val']<0.5].sort_values(by='sp_val').reset_index(drop=True)
dense_feat = dense_feat['feat'].to_list()
#dense_feat

# %%
data_use = data[dense_feat+['class']]
details(data , 'Before removing sparse columns')
details(data_use , 'After removing sparse columns')
# Out:
# Before removing sparse columns
# ________________________________________________
# Sparsity in the data : 0.44
# Data shape (1812, 107)
# Number of sources :
# CV  	  60 	 994
# PL  	  92 	 297
# LX  	  58 	 521
# After removing sparse columns
# ________________________________________________
# Sparsity in the data : 0.23
# Data shape (1812, 58)
# Number of sources :
# CV  	  60 	 994
# PL  	  92 	 297
# LX  	  58 	 521

# %% [markdown]
# ## Take log

# %%
flux_feat = phot_flux + phot_flux_lolim + phot_flux_hilim + en_flux + en_flux_lolim + en_flux_hilim
flux_feat_avail = list(set(flux_feat) & set(dense_feat))
def take_log(data_sent):
    x_train_log = data_sent.copy()
    for f in flux_feat_avail[:]:
        x_train_log.loc[:,f] = -(np.log10(x_train_log.loc[:,f]))
    x_train_log = x_train_log.replace(-np.inf , np.nan)
    x_train_log = x_train_log.replace(np.inf , np.nan)
    return x_train_log

# %% [markdown]
# ## Take Log of flux columns

# %%
df_log = take_log(data_use)
details(df_log)
# Out:
# ________________________________________________
# Sparsity in the data : 0.23
# Data shape (1812, 58)
# Number of sources :
# CV  	  60 	 994
# PL  	  92 	 297
# LX  	  58 	 521

# %% [markdown]
# # Combine Obs

# %%
df_comb = pd.DataFrame()
for s in df_log['src_id'].unique()[:]:
    temp = df_log[df_log['src_id']==s]
    temp_id =  temp[info_col_cl]
    temp_val = temp.drop(columns=info_col_cl)
    temp_mean = temp_val.mean().to_frame().T
    temp_id_top = temp_id.iloc[0:1].reset_index()
    temp_final = pd.concat([temp_id_top , temp_mean] , axis=1).set_index('obs_id')
    df_comb = df_comb.append(temp_final)
display(df_comb)
# Out:
#                 src_id  num_obs                    src_n  \
# obs_id
# CV_0_obs_0        CV_0       33  [HPH2013]_176__________
# CV_1_obs_0        CV_1      104  [HPH2013]_142__________
# CV_2_obs_0        CV_2      102  [HPH2013]_169__________
# CV_3_obs_0        CV_3      102  XMMSL2_J004231.9+411621
# CV_4_obs_0        CV_4       97  [HPH2013]_205__________
# ...                ...      ...                      ...
# LMXB_86_obs_0  LMXB_86        1    SAX_J1810.8-2609_____
# LMXB_90_obs_0  LMXB_90        1    XTE_J2123-058________
# LMXB_91_obs_0  LMXB_91        1    XB_1732-304__________
# LMXB_92_obs_0  LMXB_92        1    BW_ANT_______________
# LMXB_94_obs_0  LMXB_94        1    J1748-3607___________
#
#                                  name         ra        dec  livetime  \
# obs_id
# CV_0_obs_0      2CXO J004245.0+411520   10.68773  41.255820    4903.5
# CV_1_obs_0      2CXO J004242.9+411543   10.67917  41.261980    4035.0
# CV_2_obs_0      2CXO J004244.3+411607   10.68489  41.268730    4035.0
# CV_3_obs_0      2CXO J004231.1+411621   10.62976  41.272670    4913.0
# CV_4_obs_0      2CXO J004248.7+411624   10.70297  41.273450    4881.4
# ...                               ...        ...        ...       ...
# LMXB_86_obs_0   2CXO J181044.4-260901  272.68530 -26.150370   31871.5
# LMXB_90_obs_0   2CXO J212314.5-054753  320.81060  -5.798128   17705.1
# LMXB_91_obs_0   2CXO J173547.0-302858  263.94590 -30.482820   18855.8
# LMXB_92_obs_0   2CXO J092920.1-312303  142.33410 -31.384270   24445.9
# LMXB_94_obs_0   2CXO J174813.1-360758  267.05470 -36.132810   15794.5
#
#                significance    likelihood class  ...  var_prob_b  \
# obs_id                                           ...
# CV_0_obs_0            11.31     304.46460    CV  ...         NaN
# CV_1_obs_0            77.08   27912.78000    CV  ...    0.212598
# CV_2_obs_0            83.08   37399.46000    CV  ...    0.282921
# CV_3_obs_0           174.76  172643.30000    CV  ...    0.096272
# CV_4_obs_0            33.19    3870.74300    CV  ...    0.428198
# ...                     ...           ...   ...  ...         ...
# LMXB_86_obs_0          9.29     512.97550    LX  ...    0.084000
# LMXB_90_obs_0          4.06     132.76700    LX  ...    0.807000
# LMXB_91_obs_0          4.89     114.24570    LX  ...    0.451000
# LMXB_92_obs_0          3.70      75.53454    LX  ...    0.607000
# LMXB_94_obs_0          3.09      50.50810    LX  ...    0.380000
#
#                photflux_aper_s  var_inter_index_h  var_inter_index_m  \
# obs_id
# CV_0_obs_0            6.292813                NaN                NaN
# CV_1_obs_0            4.813647                6.0                5.0
# CV_2_obs_0            4.711767                8.0                8.0
# CV_3_obs_0            4.195978                7.0                5.0
# CV_4_obs_0            5.433450                6.0                6.0
# ...                        ...                ...                ...
# LMXB_86_obs_0         5.338755                NaN                NaN
# LMXB_90_obs_0         5.737786                NaN                NaN
# LMXB_91_obs_0         6.466864                NaN                5.0
# LMXB_92_obs_0         6.135904                NaN                NaN
# LMXB_94_obs_0         5.922996                NaN                NaN
#
#                flux_aper_lolim_m  photflux_aper_lolim_m  flux_aper_s  \
# obs_id
# CV_0_obs_0             16.143122               7.755970    14.958940
# CV_1_obs_0             13.739299               5.048415    13.644444
# CV_2_obs_0             14.009597               5.387293    13.391164
# CV_3_obs_0             12.952036               4.309032    12.978640
# CV_4_obs_0             14.682757               5.978879    14.252212
# ...                          ...                    ...          ...
# LMXB_86_obs_0          14.444543               5.786217    14.189364
# LMXB_90_obs_0          15.478078               6.884057    14.499626
# LMXB_91_obs_0          14.373147               5.747875    15.291664
# LMXB_92_obs_0          15.357437               6.734946    14.902049
# LMXB_94_obs_0          15.286762               6.661344    14.767258
#
#                photflux_aper_lolim_s  flux_aper_lolim_s  var_inter_index_s
# obs_id
# CV_0_obs_0                  7.336201          15.679727                NaN
# CV_1_obs_0                  4.998926          13.813302                5.0
# CV_2_obs_0                  4.909098          13.552852                8.0
# CV_3_obs_0                  4.264402          13.047099                4.0
# CV_4_obs_0                  5.959010          14.696868                6.0
# ...                              ...                ...                ...
# LMXB_86_obs_0               5.405497          14.260507                NaN
# LMXB_90_obs_0               5.889410          14.651500                NaN
# LMXB_91_obs_0               7.068949          15.893809                NaN
# LMXB_92_obs_0               6.357733          15.133535                NaN
# LMXB_94_obs_0               6.127087          14.971429                NaN
#
# [210 rows x 58 columns]

# %% [markdown]
# # all-obs imputation

# %% [markdown]
# ## Impute entire dataset

# %%
data_id = df_comb[info_col_cl]
data_val = df_comb.drop(columns = info_col_cl)
rf_imputer = MissForest(verbose=0 , decreasing=True)
new_data = rf_imputer.fit_transform(data_val)

# %%
new_imp_data =  pd.DataFrame(new_data , columns = data_val.columns.to_list()  , index=data_val.index.to_list())
new_imp_data.index.name = 'obs_id'

# %%
data_imp_v2 = pd.concat([data_id , new_imp_data] , axis=1)
data_imp_v2
# Out:
#                 src_id  num_obs                    src_n  \
# obs_id
# CV_0_obs_0        CV_0       33  [HPH2013]_176__________
# CV_1_obs_0        CV_1      104  [HPH2013]_142__________
# CV_2_obs_0        CV_2      102  [HPH2013]_169__________
# CV_3_obs_0        CV_3      102  XMMSL2_J004231.9+411621
# CV_4_obs_0        CV_4       97  [HPH2013]_205__________
# ...                ...      ...                      ...
# LMXB_86_obs_0  LMXB_86        1    SAX_J1810.8-2609_____
# LMXB_90_obs_0  LMXB_90        1    XTE_J2123-058________
# LMXB_91_obs_0  LMXB_91        1    XB_1732-304__________
# LMXB_92_obs_0  LMXB_92        1    BW_ANT_______________
# LMXB_94_obs_0  LMXB_94        1    J1748-3607___________
#
#                                  name         ra        dec  livetime  \
# obs_id
# CV_0_obs_0      2CXO J004245.0+411520   10.68773  41.255820    4903.5
# CV_1_obs_0      2CXO J004242.9+411543   10.67917  41.261980    4035.0
# CV_2_obs_0      2CXO J004244.3+411607   10.68489  41.268730    4035.0
# CV_3_obs_0      2CXO J004231.1+411621   10.62976  41.272670    4913.0
# CV_4_obs_0      2CXO J004248.7+411624   10.70297  41.273450    4881.4
# ...                               ...        ...        ...       ...
# LMXB_86_obs_0   2CXO J181044.4-260901  272.68530 -26.150370   31871.5
# LMXB_90_obs_0   2CXO J212314.5-054753  320.81060  -5.798128   17705.1
# LMXB_91_obs_0   2CXO J173547.0-302858  263.94590 -30.482820   18855.8
# LMXB_92_obs_0   2CXO J092920.1-312303  142.33410 -31.384270   24445.9
# LMXB_94_obs_0   2CXO J174813.1-360758  267.05470 -36.132810   15794.5
#
#                significance    likelihood class  ...  var_prob_b  \
# obs_id                                           ...
# CV_0_obs_0            11.31     304.46460    CV  ...    0.418232
# CV_1_obs_0            77.08   27912.78000    CV  ...    0.212598
# CV_2_obs_0            83.08   37399.46000    CV  ...    0.282921
# CV_3_obs_0           174.76  172643.30000    CV  ...    0.096272
# CV_4_obs_0            33.19    3870.74300    CV  ...    0.428198
# ...                     ...           ...   ...  ...         ...
# LMXB_86_obs_0          9.29     512.97550    LX  ...    0.084000
# LMXB_90_obs_0          4.06     132.76700    LX  ...    0.807000
# LMXB_91_obs_0          4.89     114.24570    LX  ...    0.451000
# LMXB_92_obs_0          3.70      75.53454    LX  ...    0.607000
# LMXB_94_obs_0          3.09      50.50810    LX  ...    0.380000
#
#                photflux_aper_s  var_inter_index_h  var_inter_index_m  \
# obs_id
# CV_0_obs_0            6.292813               5.44               5.41
# CV_1_obs_0            4.813647               6.00               5.00
# CV_2_obs_0            4.711767               8.00               8.00
# CV_3_obs_0            4.195978               7.00               5.00
# CV_4_obs_0            5.433450               6.00               6.00
# ...                        ...                ...                ...
# LMXB_86_obs_0         5.338755               5.12               5.08
# LMXB_90_obs_0         5.737786               5.30               5.40
# LMXB_91_obs_0         6.466864               3.09               5.00
# LMXB_92_obs_0         6.135904               5.18               5.09
# LMXB_94_obs_0         5.922996               5.35               5.38
#
#                flux_aper_lolim_m  photflux_aper_lolim_m  flux_aper_s  \
# obs_id
# CV_0_obs_0             16.143122               7.755970    14.958940
# CV_1_obs_0             13.739299               5.048415    13.644444
# CV_2_obs_0             14.009597               5.387293    13.391164
# CV_3_obs_0             12.952036               4.309032    12.978640
# CV_4_obs_0             14.682757               5.978879    14.252212
# ...                          ...                    ...          ...
# LMXB_86_obs_0          14.444543               5.786217    14.189364
# LMXB_90_obs_0          15.478078               6.884057    14.499626
# LMXB_91_obs_0          14.373147               5.747875    15.291664
# LMXB_92_obs_0          15.357437               6.734946    14.902049
# LMXB_94_obs_0          15.286762               6.661344    14.767258
#
#                photflux_aper_lolim_s  flux_aper_lolim_s  var_inter_index_s
# obs_id
# CV_0_obs_0                  7.336201          15.679727               4.94
# CV_1_obs_0                  4.998926          13.813302               5.00
# CV_2_obs_0                  4.909098          13.552852               8.00
# CV_3_obs_0                  4.264402          13.047099               4.00
# CV_4_obs_0                  5.959010          14.696868               6.00
# ...                              ...                ...                ...
# LMXB_86_obs_0               5.405497          14.260507               5.01
# LMXB_90_obs_0               5.889410          14.651500               5.02
# LMXB_91_obs_0               7.068949          15.893809               3.18
# LMXB_92_obs_0               6.357733          15.133535               4.98
# LMXB_94_obs_0               6.127087          14.971429               5.10
#
# [210 rows x 58 columns]

# %%
#data_imp_v2.to_csv('imputed_data/old-data-all-at-once-imp.csv')

# %%
#data_imp_v2 = pd.read_csv('imputed_data/old-data-all-at-once-imp.csv' , index_col='obs_id')

# %%
details(data_imp_v2)

# %%
data_id = data_imp_v2[info_col]
data_label = data_imp_v2['class']
data_val = data_imp_v2.drop(columns=['class']+info_col)

# %% [markdown]
# # Normalize

# %%
#data_imp_norm.to_csv('all_filled_norm.csv')

# %%
#data_imp_v2 = pd.read_csv('imputed_data/srcwise-imp_old-data.csv' , index_col = 'obs_id')

# %%
data_id = data_imp_v2[info_col]
data_label = data_imp_v2['class']
data_val = data_imp_v2.drop(columns=['class']+info_col)
data_imp_norm = data_imp_v2.copy()
for c in data_val.columns.to_list():
    data_imp_norm.loc[:,c] = (data_imp_norm.loc[:,c] - data_imp_norm.loc[:,c].mean()) / data_imp_norm.loc[:,c].std()
data_imp_norm
# Out:
#                 src_id  num_obs                    src_n  \
# obs_id
# CV_0_obs_0        CV_0       33  [HPH2013]_176__________
# CV_1_obs_0        CV_1      104  [HPH2013]_142__________
# CV_2_obs_0        CV_2      102  [HPH2013]_169__________
# CV_3_obs_0        CV_3      102  XMMSL2_J004231.9+411621
# CV_4_obs_0        CV_4       97  [HPH2013]_205__________
# ...                ...      ...                      ...
# LMXB_86_obs_0  LMXB_86        1    SAX_J1810.8-2609_____
# LMXB_90_obs_0  LMXB_90        1    XTE_J2123-058________
# LMXB_91_obs_0  LMXB_91        1    XB_1732-304__________
# LMXB_92_obs_0  LMXB_92        1    BW_ANT_______________
# LMXB_94_obs_0  LMXB_94        1    J1748-3607___________
#
#                                  name         ra        dec  livetime  \
# obs_id
# CV_0_obs_0      2CXO J004245.0+411520   10.68773  41.255820    4903.5
# CV_1_obs_0      2CXO J004242.9+411543   10.67917  41.261980    4035.0
# CV_2_obs_0      2CXO J004244.3+411607   10.68489  41.268730    4035.0
# CV_3_obs_0      2CXO J004231.1+411621   10.62976  41.272670    4913.0
# CV_4_obs_0      2CXO J004248.7+411624   10.70297  41.273450    4881.4
# ...                               ...        ...        ...       ...
# LMXB_86_obs_0   2CXO J181044.4-260901  272.68530 -26.150370   31871.5
# LMXB_90_obs_0   2CXO J212314.5-054753  320.81060  -5.798128   17705.1
# LMXB_91_obs_0   2CXO J173547.0-302858  263.94590 -30.482820   18855.8
# LMXB_92_obs_0   2CXO J092920.1-312303  142.33410 -31.384270   24445.9
# LMXB_94_obs_0   2CXO J174813.1-360758  267.05470 -36.132810   15794.5
#
#                significance    likelihood class  ...  var_prob_b  \
# obs_id                                           ...
# CV_0_obs_0            11.31     304.46460    CV  ...    0.267690
# CV_1_obs_0            77.08   27912.78000    CV  ...   -0.580517
# CV_2_obs_0            83.08   37399.46000    CV  ...   -0.290444
# CV_3_obs_0           174.76  172643.30000    CV  ...   -1.060346
# CV_4_obs_0            33.19    3870.74300    CV  ...    0.308798
# ...                     ...           ...   ...  ...         ...
# LMXB_86_obs_0          9.29     512.97550    LX  ...   -1.110964
# LMXB_90_obs_0          4.06     132.76700    LX  ...    1.871301
# LMXB_91_obs_0          4.89     114.24570    LX  ...    0.402855
# LMXB_92_obs_0          3.70      75.53454    LX  ...    1.046331
# LMXB_94_obs_0          3.09      50.50810    LX  ...    0.109991
#
#                photflux_aper_s  var_inter_index_h  var_inter_index_m  \
# obs_id
# CV_0_obs_0            0.942438          -0.148531          -0.058905
# CV_1_obs_0           -1.009128           0.207870          -0.314922
# CV_2_obs_0           -1.143545           1.480731           1.558375
# CV_3_obs_0           -1.824061           0.844300          -0.314922
# CV_4_obs_0           -0.191379           0.207870           0.309510
# ...                        ...                ...                ...
# LMXB_86_obs_0        -0.316316          -0.352188          -0.264967
# LMXB_90_obs_0         0.210153          -0.237631          -0.065149
# LMXB_91_obs_0         1.172075          -1.644142          -0.314922
# LMXB_92_obs_0         0.735418          -0.314003          -0.258723
# LMXB_94_obs_0         0.454513          -0.205809          -0.077638
#
#                flux_aper_lolim_m  photflux_aper_lolim_m  flux_aper_s  \
# obs_id
# CV_0_obs_0              1.931262               2.164930     0.797150
# CV_1_obs_0             -0.911551              -0.993073    -0.899867
# CV_2_obs_0             -0.591891              -0.597816    -1.226852
# CV_3_obs_0             -1.842586              -1.855464    -1.759421
# CV_4_obs_0              0.204203               0.092190    -0.115238
# ...                          ...                    ...          ...
# LMXB_86_obs_0          -0.077515              -0.132525    -0.196374
# LMXB_90_obs_0           1.144766               1.147959     0.204174
# LMXB_91_obs_0          -0.161949              -0.177245     1.226696
# LMXB_92_obs_0           1.002093               0.974041     0.723703
# LMXB_94_obs_0           0.918511               0.888195     0.549687
#
#                photflux_aper_lolim_s  flux_aper_lolim_s  var_inter_index_s
# obs_id
# CV_0_obs_0                  1.568175           1.125746          -0.222593
# CV_1_obs_0                 -0.873811          -0.816426          -0.184692
# CV_2_obs_0                 -0.967663          -1.087447           1.710357
# CV_3_obs_0                 -1.641242          -1.613725          -0.816375
# CV_4_obs_0                  0.129286           0.102998           0.446991
# ...                              ...                ...                ...
# LMXB_86_obs_0              -0.449025          -0.351072          -0.178375
# LMXB_90_obs_0               0.056567           0.055789          -0.172058
# LMXB_91_obs_0               1.288950           1.348516          -1.334355
# LMXB_92_obs_0               0.545871           0.557387          -0.197326
# LMXB_94_obs_0               0.304891           0.388702          -0.121524
#
# [210 rows x 58 columns]

# %%
details(data_imp_norm)
# Out:
# ________________________________________________
# Sparsity in the data : 0.00
# Data shape (210, 58)
# Number of sources :
# CV  	  60 	 60
# PL  	  92 	 92
# LX  	  58 	 58

# %%
verbose = 0
val_acc = []
test_acc = []
for i in tqdm(range(10)):
    src_list = pd.DataFrame()
    class_to_select = ['CV' , 'LX' , 'PL']
    df = data_imp_norm.copy()
    for cl in class_to_select:
        src = df[df['class']==cl]['src_id'].value_counts().sort_values()
        #display(src)
        src = src.iloc[:int(len(src)*0.3)]
        src_select = src.sample(frac=0.9)
        src_id = src_select.index.to_list()
        src_obs = src_select.to_list()
        temp_src = pd.DataFrame({ 
            'src_id' : src_id , 
            'obs_count' : src_obs
        })
        src_list = src_list.append(temp_src)
    #src_list

    all_src = np.unique(df['src_id'].to_list())
    test_src = src_list['src_id'].to_list()
    train_src= list(set(all_src) - set(src_list['src_id']))
    # if(verbose):
    #     print('Total Number of ssources :' , len(all_src))
    #     print('Training_sources : ' , len(train_src) )
    #     print('Validation sources :' , len(test_src))

    # df = df.replace({
    #     "BH" :2 , 
    #     "NS" : 2 ,
    #     "CV" : 0 , 
    #     "PULSAR" : 1 
    # })


    df= df[df['class'].isin(class_to_select)]
    df 



    df_train  = df[df['src_id'].isin(train_src)]
    df_test = df[df['src_id'].isin(test_src)]

    df_train = df_train[df_train['class'].isin(class_to_select)]
    df_test = df_test[df_test['class'].isin(class_to_select)]

    if(verbose):
        details(df_train)
        details(df_test)

    train_id = df_train[info_col]
    train_label = df_train['class']
    train_value = df_train.drop(columns=['class']+info_col)


    i_val = df_test[info_col]
    y_val = df_test['class']
    x_val = df_test.drop(columns=['class']+info_col)

    clf = RandomForestClassifier(
        n_estimators = 200 , n_jobs=-1
    )
    #clf = AdaBoostClassifier(base_estimator=clf ,)
    clf = xgb.XGBRFClassifier(n_componets=200)
    #clf = xgb.XGBClassifier()
    #x_train , x_test , y_train , y_test = train_test_split(train_value , train_label , test_size=0.1 , stratify=train_label, random_state=9)
    x_train , y_train = train_value , train_label
    clf.fit(x_train , y_train)
    v_sc = clf.score(x_val , y_val)
    test_sc = clf.score(x_train, y_train)
    val_acc.append(v_sc)
    test_acc.append(test_sc)
    #if(verbose):
    print(test_sc , v_sc)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/home/kumaran/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1226: UserWarning: Lable encoder will ot work in future-kumaran
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [04:03:23] WARNING: ../src/learner.cc:576:
# Parameters: { "n_componets" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#  10%|█         | 1/10 [00:00<00:04,  2.17it/s]
# [04:03:24] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9483870967741935 0.6545454545454545
# [04:03:24] WARNING: ../src/learner.cc:576:
# Parameters: { "n_componets" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# /home/kumaran/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1226: UserWarning: Lable encoder will ot work in future-kumaran
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#  20%|██        | 2/10 [00:00<00:03,  2.51it/s]
# [04:03:24] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9483870967741935 0.6181818181818182
# [04:03:24] WARNING: ../src/learner.cc:576:
# Parameters: { "n_componets" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# /home/kumaran/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1226: UserWarning: Lable encoder will ot work in future-kumaran
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#  30%|███       | 3/10 [00:01<00:03,  2.08it/s]
# [04:03:25] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9548387096774194 0.6545454545454545
# [04:03:25] WARNING: ../src/learner.cc:576:
# Parameters: { "n_componets" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# /home/kumaran/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1226: UserWarning: Lable encoder will ot work in future-kumaran
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#  40%|████      | 4/10 [00:01<00:02,  2.31it/s]
# [04:03:25] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9483870967741935 0.6727272727272727
# [04:03:25] WARNING: ../src/learner.cc:576:
# Parameters: { "n_componets" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# /home/kumaran/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1226: UserWarning: Lable encoder will ot work in future-kumaran
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#  50%|█████     | 5/10 [00:02<00:02,  2.36it/s]
# [04:03:25] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9483870967741935 0.6363636363636364
# [04:03:25] WARNING: ../src/learner.cc:576:
# Parameters: { "n_componets" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# /home/kumaran/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1226: UserWarning: Lable encoder will ot work in future-kumaran
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#  60%|██████    | 6/10 [00:02<00:01,  2.50it/s]
# [04:03:26] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9419354838709677 0.6545454545454545
# [04:03:26] WARNING: ../src/learner.cc:576:
# Parameters: { "n_componets" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# /home/kumaran/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1226: UserWarning: Lable encoder will ot work in future-kumaran
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#  70%|███████   | 7/10 [00:02<00:01,  2.56it/s]
# [04:03:26] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9548387096774194 0.6363636363636364
# [04:03:26] WARNING: ../src/learner.cc:576:
# Parameters: { "n_componets" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# /home/kumaran/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1226: UserWarning: Lable encoder will ot work in future-kumaran
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#  80%|████████  | 8/10 [00:03<00:00,  2.83it/s]
# [04:03:26] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9548387096774194 0.6181818181818182
# [04:03:26] WARNING: ../src/learner.cc:576:
# Parameters: { "n_componets" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# /home/kumaran/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1226: UserWarning: Lable encoder will ot work in future-kumaran
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#  90%|█████████ | 9/10 [00:03<00:00,  2.80it/s]
# [04:03:27] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9483870967741935 0.6363636363636364
# [04:03:27] WARNING: ../src/learner.cc:576:
# Parameters: { "n_componets" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# /home/kumaran/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1226: UserWarning: Lable encoder will ot work in future-kumaran
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 100%|██████████| 10/10 [00:03<00:00,  2.64it/s]
# [04:03:27] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9483870967741935 0.6727272727272727

# %%
score = pd.DataFrame({
    "Test Score" : test_acc, 
    "Validation Score" : val_acc
})*100
score.describe().loc[['mean' , 'std' , 'min', 'max' ]]
# Out:
#       Test Score  Validation Score
# mean   94.967742         64.545455
# std     0.408036          1.963861
# min    94.193548         61.818182
# max    95.483871         67.272727

# %%
sns.set(font_scale=1.3)
sns.set_style('whitegrid')
fig , ax = plt.subplots(nrows=1 , ncols=3 , figsize = (18 , 4))
sns.boxplot(data = score , ax = ax[0])
cf = confusion_matrix(y_train , clf.predict(x_train) ,)
sns.heatmap(cf , annot=True ,fmt = '.0f' , ax = ax[1] , xticklabels =class_to_select , yticklabels = class_to_select  , cmap='RdYlGn' ,)
cf = confusion_matrix(y_val , clf.predict(x_val) ,)
sns.heatmap(cf , annot=True ,fmt = '.0f' , ax = ax[2] , xticklabels=class_to_select, yticklabels = class_to_select , cmap='RdYlGn')
ax[1].set_title('Training CF')
ax[2].set_title('Validation CF')
for a in ax[1:]:
    a.set_xlabel('Predicted class')
    a.set_ylabel('True class')

plt.show()
#score

# %%
y_true , y_pred = y_val , clf.predict(x_val)

# %%
y_pred_prob = clf.predict_proba(x_val)

# %%
from sklearn.metrics import precision_score , recall_score , roc_auc_score

# %%
ps = precision_score(y_true , y_pred , average=None)
rc = recall_score(y_true , y_pred , average=None)
#auc = roc_auc_score(y_val_oh , y_pred_prob)
sc = pd.DataFrame(
    np.asarray([ps , rc]) , columns=['CV' , 'LX' , 'PL'] , index=['Precision' , 'Recall']
)
sc.index.name = 'type'
sc =sc.reset_index()
display(sc)
sc = sc.melt(id_vars=['type'] , value_vars = ['CV' , 'LX' , 'PL'])
sns.pointplot(
    data = sc , x = 'variable' , y = 'value' , hue = 'type' , join=False , ax=ax[3]
)
# Out:
#         type        CV     LX        PL
# 0  Precision  0.600000  0.375  0.709677
# 1     Recall  0.428571  0.400  0.916667
# <AxesSubplot:xlabel='variable', ylabel='value'>

# %%
pd.DataFrame({
    'feat' : x_train.columns.to_list() , 
    'val' : clf.feature_importances_
}).sort_values('val' , ascending=False).reset_index(drop=True)
# Out:
#                  feat       val
# 0     photflux_aper_m  0.149696
# 1    var_inter_prob_m  0.135717
# 2         flux_aper_m  0.081213
# 3   var_inter_sigma_h  0.063748
# 4    var_inter_prob_s  0.054214
# 5   var_inter_index_h  0.043667
# 6   var_inter_sigma_m  0.042827
# 7   var_inter_sigma_b  0.036619
# 8           var_min_b  0.033070
# 9    var_inter_prob_b  0.032857
# 10  var_inter_sigma_s  0.031830
# 11         var_prob_b  0.027510
# 12         var_mean_b  0.026091
# 13  var_inter_index_m  0.023149
# 14    photflux_aper_s  0.019986
# 15   var_inter_prob_h  0.019777
# 16  var_inter_index_b  0.019731
# 17          var_max_b  0.019040
# 18  var_inter_index_s  0.013960
# 19        var_sigma_b  0.013542
# 20    photflux_aper_u  0.013337
# 21          ks_prob_b  0.012396
# 22    photflux_aper_b  0.012178
# 23          kp_prob_b  0.011317
# 24            hard_hs  0.010960
# 25        flux_aper_h  0.009026
# 26            hard_ms  0.008911
# 27            hard_hm  0.008520
# 28        flux_aper_b  0.007053
# 29        flux_aper_u  0.006437
# 30        flux_aper_s  0.005997
# 31    photflux_aper_h  0.005625
