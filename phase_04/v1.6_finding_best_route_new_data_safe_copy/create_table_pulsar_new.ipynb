# %% [markdown]
# # Load Modules

# %%
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt 
from IPython.display import display
from tqdm import tqdm
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load Source list files

# %%
src_list = pd.read_csv('../source_list/pulsar_segmented_list.txt' , header=None , names = ['fname'] , na_values='NaN')['fname'].to_list()
src_list
source = pd.DataFrame()
for s in src_list[:]:
    temp = pd.read_csv('../source_list/pulsar_updated/'+s).iloc[: , 1:-1]
    source = source.append(temp)
source = source[source['num_obs']>0]
source = source.replace(np.nan , np.nan).sort_values('num_obs' , ascending=False).reset_index(drop=True)
display(source)
# Out:
#              NAME          PSRJ         RAJ         DECJ        RAJD  num_obs  \
# 0     J0024-7204W   J0024-7204W  00:24:06.0  -72:04:49.0    6.025242      543
# 1    J0024-7204aa  J0024-7204aa  00:24:05.6  -72:04:52.6    6.023625      534
# 2     J0024-7204V   J0024-7204V  00:24:05.6  -72:04:52.6    6.023625      534
# 3     J0024-7204Z   J0024-7204Z  00:24:06.0  -72:05:01.4    6.025171      483
# 4     J0024-7204O   J0024-7204O  00:24:04.6  -72:04:53.7    6.019386      466
# ..            ...           ...         ...          ...         ...      ...
# 260    J2017+3625    J2017+3625  20:17:55.8  +36:25:07.9  304.482667        1
# 261    J2017+0603    J2017+0603  20:17:22.7  +06:03:05.5  304.344605        1
# 262    J2012-2029    J2012-2029  20:12:46.6    -20:29:31  303.194167        1
# 263    J1810+1744    J1810+1744  18:10:37.2  +17:44:37.3  272.655333        1
# 264    J1816+4510    J1816+4510  18:16:35.9  +45:10:33.8  274.149726        1
#
#          DECJD     BINCOMP ASSOC_MOD  \
# 0   -72.080302  MS[egc+02]        GC
# 1   -72.081283         NaN        GC
# 2   -72.081283         NaN        GC
# 3   -72.083744         NaN        GC
# 4   -72.081602  UL[fck+03]        GC
# ..         ...         ...       ...
# 260  36.418861         NaN       GRS
# 261   6.051546  He[cgj+11]       GRS
# 262 -20.491944         NaN       NaN
# 263  17.743717  UL[hrm+11]       GRS
# 264  45.176073  MS[ssc+19]       GRS
#
#                                         ASSOC      SURVEY         PSR
# 0                       GC:47Tuc,XRS:[bgh+06]       pksgc         NaN
# 1                       GC:47Tuc,XRS:[bhc+17]        misc         NaN
# 2                                    GC:47Tuc       pksgc         NaN
# 3                       GC:47Tuc,XRS:[bhc+17]        misc         NaN
# 4                       GC:47Tuc,XRS:[bgh+06]       pksgc         NaN
# ..                                        ...         ...         ...
# 260  GRS:4FGL_J2017.9+3625[fermi21],XRS:[wcp+  FermiBlind        NRAD
# 261  GRS:4FGL_J2017.4+0602[fermi21],XRS:[pb15        misc          HE
# 262                                       NaN       gb350         NaN
# 263  GRS:4FGL_J1810.5+1744[fermi21],OPT:[bvr+  FermiAssoc          HE
# 264  GRS:4FGL_J1816.5+4510[fermi21],OPT:[kbv+       gbncc  HE[ksr+12]
#
# [265 rows x 12 columns]

# %%
source = source[source['num_obs']>0]
source = source.replace(np.nan , np.nan).sort_values('num_obs' , ascending=False).reset_index(drop=True)
display(source)
# Out:
#              NAME          PSRJ         RAJ         DECJ        RAJD  num_obs  \
# 0     J0024-7204W   J0024-7204W  00:24:06.0  -72:04:49.0    6.025242      543
# 1     J0024-7204V   J0024-7204V  00:24:05.6  -72:04:52.6    6.023625      534
# 2    J0024-7204aa  J0024-7204aa  00:24:05.6  -72:04:52.6    6.023625      534
# 3     J0024-7204Z   J0024-7204Z  00:24:06.0  -72:05:01.4    6.025171      483
# 4     J0024-7204O   J0024-7204O  00:24:04.6  -72:04:53.7    6.019386      466
# ..            ...           ...         ...          ...         ...      ...
# 260    J0251+2606    J0251+2606  02:51:02.5  +26:06:09.9   42.760640        1
# 261    J1417-4402    J1417-4402  14:17:30.6  -44:02:57.4  214.377500        1
# 262    J0248+6021    J0248+6021  02:48:18.6  +60:21:34.7   42.077571        1
# 263      B1451-68    J1456-6843  14:55:59.9  -68:43:39.5  223.999679        1
# 264    J1816+4510    J1816+4510  18:16:35.9  +45:10:33.8  274.149726        1
#
#          DECJD     BINCOMP ASSOC_MOD  \
# 0   -72.080302  MS[egc+02]        GC
# 1   -72.081283         NaN        GC
# 2   -72.081283         NaN        GC
# 3   -72.083744         NaN        GC
# 4   -72.081602  UL[fck+03]        GC
# ..         ...         ...       ...
# 260  26.102769  UL[cck+16]       GRS
# 261 -44.049278  MS[scc+15]       GRS
# 262  60.359644         NaN       GRS
# 263 -68.727639         NaN       NaN
# 264  45.176073  MS[ssc+19]       GRS
#
#                                         ASSOC                          SURVEY  \
# 0                       GC:47Tuc,XRS:[bgh+06]                           pksgc
# 1                                    GC:47Tuc                           pksgc
# 2                       GC:47Tuc,XRS:[bhc+17]                            misc
# 3                       GC:47Tuc,XRS:[bhc+17]                            misc
# 4                       GC:47Tuc,XRS:[bgh+06]                           pksgc
# ..                                        ...                             ...
# 260             GRS:4FGL_J0251.0+2605[drc+21]                      FermiAssoc
# 261  GRS:4FGL_J1417.6-4403[fermi21],XRS:[scc+                      FermiAssoc
# 262            GRS:4FGL_J0248.4+6021[fermi21]                            misc
# 263                                       NaN  mol1,mol2,pks70,pkssw,htru_pks
# 264  GRS:4FGL_J1816.5+4510[fermi21],OPT:[kbv+                           gbncc
#
#             PSR
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 260  HE[cck+16]
# 261          HE
# 262  HE[tpc+11]
# 263         NaN
# 264  HE[ksr+12]
#
# [265 rows x 12 columns]

# %% [markdown]
# # Read Chandra data files

# %%
ch_names = []
ch_ra = []
ch_dec = []
offset = []
src_id_list = [] 
n_obs_list = []
df_combined = pd.DataFrame()
for index in tqdm(range(len(source))):
    s = source['NAME'][index]
    df = pd.read_csv('../data/all_data/PULSAR_v2_all/'+s+'.csv' , index_col='index').sort_values('sepn').reset_index(drop=True)
    #display(df)
    top_match = df.loc[0]
    # Select only the source , which has highest cross-matching 
    # And create an array with this seperation value to be stored in original source list table
    # such that source list table have chandra source name , number of actual obs  and seperation.
    # Select all the obs of this cross match and append in all data file

    # Put actual source name , and give source id and obs id in this data
    df_select = df[df['name']==top_match['name']].reset_index(drop=True)
    n_obs_cur = len(df_select)
    obs_id = ['PL_'+str(index)+'_obs_'+str(i) for i in range(len(df_select))]
    src_id = ['PL_'+str(index)]*len(df_select)
    df_select.insert(0 ,'src_id' , src_id)
    df_select.insert(1 ,'obs_id' , obs_id)
    df_select.insert(2, 'num_obs' , [str(len(df_select))]*len(df_select))
    df_select.insert(3 , 'src_n' , [s]*len(df_select))
    top_row = df_select.iloc[0]
    ch_names.append(top_row['name'])
    ch_ra.append(top_row['ra'])
    ch_dec.append(top_row['dec'])
    offset.append(top_row['sepn'])
    n_obs_list.append(len(df_select))
    src_id_list.append('PL_'+str(index))
    #display(df_select)
    df_combined = df_combined.append(df_select)
source_updated = source.copy().reset_index(drop=True)
source_updated.insert(7 , 'chandra_name' , ch_names)
source_updated.insert(8 , 'ch_ra' , ch_ra)
source_updated.insert(9 , 'ch_dec' , ch_dec)
source_updated.insert(10 , 'xoffset' , offset)
source_updated.insert(11 , 'num_obs_used' , n_obs_list)
source_updated = source.reset_index(drop=True)
display(source_updated)
#display(df_combined)
df_combined = df_combined.reset_index(drop=True)
df_combined = df_combined.set_index('obs_id')
df_combined
# Out:
# 100%|██████████| 265/265 [00:23<00:00, 11.39it/s]
#              NAME          PSRJ         RAJ         DECJ        RAJD  num_obs  \
# 0     J0024-7204W   J0024-7204W  00:24:06.0  -72:04:49.0    6.025242      543
# 1     J0024-7204V   J0024-7204V  00:24:05.6  -72:04:52.6    6.023625      534
# 2    J0024-7204aa  J0024-7204aa  00:24:05.6  -72:04:52.6    6.023625      534
# 3     J0024-7204Z   J0024-7204Z  00:24:06.0  -72:05:01.4    6.025171      483
# 4     J0024-7204O   J0024-7204O  00:24:04.6  -72:04:53.7    6.019386      466
# ..            ...           ...         ...          ...         ...      ...
# 260    J0251+2606    J0251+2606  02:51:02.5  +26:06:09.9   42.760640        1
# 261    J1417-4402    J1417-4402  14:17:30.6  -44:02:57.4  214.377500        1
# 262    J0248+6021    J0248+6021  02:48:18.6  +60:21:34.7   42.077571        1
# 263      B1451-68    J1456-6843  14:55:59.9  -68:43:39.5  223.999679        1
# 264    J1816+4510    J1816+4510  18:16:35.9  +45:10:33.8  274.149726        1
#
#          DECJD     BINCOMP ASSOC_MOD  \
# 0   -72.080302  MS[egc+02]        GC
# 1   -72.081283         NaN        GC
# 2   -72.081283         NaN        GC
# 3   -72.083744         NaN        GC
# 4   -72.081602  UL[fck+03]        GC
# ..         ...         ...       ...
# 260  26.102769  UL[cck+16]       GRS
# 261 -44.049278  MS[scc+15]       GRS
# 262  60.359644         NaN       GRS
# 263 -68.727639         NaN       NaN
# 264  45.176073  MS[ssc+19]       GRS
#
#                                         ASSOC                          SURVEY  \
# 0                       GC:47Tuc,XRS:[bgh+06]                           pksgc
# 1                                    GC:47Tuc                           pksgc
# 2                       GC:47Tuc,XRS:[bhc+17]                            misc
# 3                       GC:47Tuc,XRS:[bhc+17]                            misc
# 4                       GC:47Tuc,XRS:[bgh+06]                           pksgc
# ..                                        ...                             ...
# 260             GRS:4FGL_J0251.0+2605[drc+21]                      FermiAssoc
# 261  GRS:4FGL_J1417.6-4403[fermi21],XRS:[scc+                      FermiAssoc
# 262            GRS:4FGL_J0248.4+6021[fermi21]                            misc
# 263                                       NaN  mol1,mol2,pks70,pkssw,htru_pks
# 264  GRS:4FGL_J1816.5+4510[fermi21],OPT:[kbv+                           gbncc
#
#             PSR
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 260  HE[cck+16]
# 261          HE
# 262  HE[tpc+11]
# 263         NaN
# 264  HE[ksr+12]
#
# [265 rows x 12 columns]
#               src_id num_obs        src_n      sepn instrument  \
# obs_id
# PL_0_obs_0      PL_0      13  J0024-7204W  0.419328       ACIS
# PL_0_obs_1      PL_0      13  J0024-7204W  0.419328       ACIS
# PL_0_obs_2      PL_0      13  J0024-7204W  0.419328       ACIS
# PL_0_obs_3      PL_0      13  J0024-7204W  0.419328       ACIS
# PL_0_obs_4      PL_0      13  J0024-7204W  0.419328       ACIS
# ...              ...     ...          ...       ...        ...
# PL_260_obs_0  PL_260       1   J0251+2606  0.486258       ACIS
# PL_261_obs_0  PL_261       1   J1417-4402  0.601756       ACIS
# PL_262_obs_0  PL_262       1   J0248+6021  0.468417       ACIS
# PL_263_obs_0  PL_263       1     B1451-68  0.690696       ACIS
# PL_264_obs_0  PL_264       1   J1816+4510  0.194803       ACIS
#
#                        detect_stack_id                    name          ra  \
# obs_id
# PL_0_obs_0    acisfJ0024178m720500_001   2CXO J002406.0-720449    6.025354
# PL_0_obs_1    acisfJ0024178m720500_001   2CXO J002406.0-720449    6.025354
# PL_0_obs_2    acisfJ0024178m720500_001   2CXO J002406.0-720449    6.025354
# PL_0_obs_3    acisfJ0024178m720500_001   2CXO J002406.0-720449    6.025354
# PL_0_obs_4    acisfJ0024178m720500_001   2CXO J002406.0-720449    6.025354
# ...                                ...                     ...         ...
# PL_260_obs_0  acisfJ1057559m522648_001   2CXO J105758.9-522656  164.495800
# PL_261_obs_0  acisfJ1417429m440727_001   2CXO J141730.5-440257  214.377300
# PL_262_obs_0  acisfJ0248159p602140_001   2CXO J024818.6+602134   42.077720
# PL_263_obs_0  acisfJ1456032m684332_001   2CXO J145600.0-684339  224.000100
# PL_264_obs_0  acisfJ1816367p451040_001   2CXO J181635.9+451033  274.149600
#
#                    dec  obsid  ...  var_inter_sigma_s var_inter_index_u  \
# obs_id                         ...
# PL_0_obs_0   -72.08032   3386  ...          1.328e-06               3.0
# PL_0_obs_1   -72.08032   3387  ...          1.328e-06               3.0
# PL_0_obs_2   -72.08032   3385  ...          1.328e-06               3.0
# PL_0_obs_3   -72.08032   3384  ...          1.328e-06               3.0
# PL_0_obs_4   -72.08032   2738  ...          1.328e-06               3.0
# ...                ...    ...  ...                ...               ...
# PL_260_obs_0 -52.44910  13789  ...                NaN               NaN
# PL_261_obs_0 -44.04924  12843  ...                NaN               NaN
# PL_262_obs_0  60.35971  13289  ...                NaN               NaN
# PL_263_obs_0 -68.72761  11822  ...                NaN               NaN
# PL_264_obs_0  45.17611  13724  ...                NaN               NaN
#
#              var_inter_prob_u var_inter_sigma_u acis_num acis_hetg_num  \
# obs_id
# PL_0_obs_0              0.438         6.257e-06       13             0
# PL_0_obs_1              0.438         6.257e-06       13             0
# PL_0_obs_2              0.438         6.257e-06       13             0
# PL_0_obs_3              0.438         6.257e-06       13             0
# PL_0_obs_4              0.438         6.257e-06       13             0
# ...                       ...               ...      ...           ...
# PL_260_obs_0              NaN               NaN        1             0
# PL_261_obs_0              NaN               NaN        1             0
# PL_262_obs_0              NaN               NaN        1             0
# PL_263_obs_0              NaN               NaN        1             0
# PL_264_obs_0              NaN               NaN        1             0
#
#              acis_letg_num hrc_num hrc_hetg_num hrc_letg_num
# obs_id
# PL_0_obs_0               0       0            0            0
# PL_0_obs_1               0       0            0            0
# PL_0_obs_2               0       0            0            0
# PL_0_obs_3               0       0            0            0
# PL_0_obs_4               0       0            0            0
# ...                    ...     ...          ...          ...
# PL_260_obs_0             0       0            0            0
# PL_261_obs_0             0       0            0            0
# PL_262_obs_0             0       0            0            0
# PL_263_obs_0             0       0            0            0
# PL_264_obs_0             0       0            0            0
#
# [1253 rows x 256 columns]

# %% [markdown]
# ## Save raw table

# %%
df_combined.replace(np.nan , '')
df_combined.to_csv('raw_data/pl_new_raw_data.csv' ,)

# %% [markdown]
# ## Filter flags

# %%
from features import col_to_drop

# %%
df = pd.read_csv('raw_data/pl_new_raw_data.csv' , index_col='obs_id')
filter_flags = [
    'pileup_flag',
    'mstr_sat_src_flag',
    'mstr_streak_src_flag',
    'sat_src_flag',
    'streak_src_flag',
    ]
df = df.replace({
    '  NAN' : np.nan , 
    '      NaN' : np.nan , 
    'FALSE' : False , 
    'False' : False , 
    ' TRUE' : True , 
    
    })
print('BEFORE FILTERING')
display(df)
for f in filter_flags:
    df = df[df[f]==False]
print('AFTER FILTERING')
#display(df)
df = df.drop(columns=col_to_drop)
df
# Out:
# BEFORE FILTERING
#               src_id  num_obs        src_n      sepn instrument  \
# obs_id
# PL_0_obs_0      PL_0       13  J0024-7204W  0.419328       ACIS
# PL_0_obs_1      PL_0       13  J0024-7204W  0.419328       ACIS
# PL_0_obs_2      PL_0       13  J0024-7204W  0.419328       ACIS
# PL_0_obs_3      PL_0       13  J0024-7204W  0.419328       ACIS
# PL_0_obs_4      PL_0       13  J0024-7204W  0.419328       ACIS
# ...              ...      ...          ...       ...        ...
# PL_260_obs_0  PL_260        1   J0251+2606  0.486258       ACIS
# PL_261_obs_0  PL_261        1   J1417-4402  0.601756       ACIS
# PL_262_obs_0  PL_262        1   J0248+6021  0.468417       ACIS
# PL_263_obs_0  PL_263        1     B1451-68  0.690696       ACIS
# PL_264_obs_0  PL_264        1   J1816+4510  0.194803       ACIS
#
#                        detect_stack_id                    name          ra  \
# obs_id
# PL_0_obs_0    acisfJ0024178m720500_001   2CXO J002406.0-720449    6.025354
# PL_0_obs_1    acisfJ0024178m720500_001   2CXO J002406.0-720449    6.025354
# PL_0_obs_2    acisfJ0024178m720500_001   2CXO J002406.0-720449    6.025354
# PL_0_obs_3    acisfJ0024178m720500_001   2CXO J002406.0-720449    6.025354
# PL_0_obs_4    acisfJ0024178m720500_001   2CXO J002406.0-720449    6.025354
# ...                                ...                     ...         ...
# PL_260_obs_0  acisfJ1057559m522648_001   2CXO J105758.9-522656  164.495800
# PL_261_obs_0  acisfJ1417429m440727_001   2CXO J141730.5-440257  214.377300
# PL_262_obs_0  acisfJ0248159p602140_001   2CXO J024818.6+602134   42.077720
# PL_263_obs_0  acisfJ1456032m684332_001   2CXO J145600.0-684339  224.000100
# PL_264_obs_0  acisfJ1816367p451040_001   2CXO J181635.9+451033  274.149600
#
#                    dec  obsid  ...  var_inter_sigma_s var_inter_index_u  \
# obs_id                         ...
# PL_0_obs_0   -72.08032   3386  ...          1.328e-06               3.0
# PL_0_obs_1   -72.08032   3387  ...          1.328e-06               3.0
# PL_0_obs_2   -72.08032   3385  ...          1.328e-06               3.0
# PL_0_obs_3   -72.08032   3384  ...          1.328e-06               3.0
# PL_0_obs_4   -72.08032   2738  ...          1.328e-06               3.0
# ...                ...    ...  ...                ...               ...
# PL_260_obs_0 -52.44910  13789  ...                NaN               NaN
# PL_261_obs_0 -44.04924  12843  ...                NaN               NaN
# PL_262_obs_0  60.35971  13289  ...                NaN               NaN
# PL_263_obs_0 -68.72761  11822  ...                NaN               NaN
# PL_264_obs_0  45.17611  13724  ...                NaN               NaN
#
#              var_inter_prob_u var_inter_sigma_u acis_num acis_hetg_num  \
# obs_id
# PL_0_obs_0              0.438         6.257e-06       13             0
# PL_0_obs_1              0.438         6.257e-06       13             0
# PL_0_obs_2              0.438         6.257e-06       13             0
# PL_0_obs_3              0.438         6.257e-06       13             0
# PL_0_obs_4              0.438         6.257e-06       13             0
# ...                       ...               ...      ...           ...
# PL_260_obs_0              NaN               NaN        1             0
# PL_261_obs_0              NaN               NaN        1             0
# PL_262_obs_0              NaN               NaN        1             0
# PL_263_obs_0              NaN               NaN        1             0
# PL_264_obs_0              NaN               NaN        1             0
#
#              acis_letg_num hrc_num hrc_hetg_num hrc_letg_num
# obs_id
# PL_0_obs_0               0       0            0            0
# PL_0_obs_1               0       0            0            0
# PL_0_obs_2               0       0            0            0
# PL_0_obs_3               0       0            0            0
# PL_0_obs_4               0       0            0            0
# ...                    ...     ...          ...          ...
# PL_260_obs_0             0       0            0            0
# PL_261_obs_0             0       0            0            0
# PL_262_obs_0             0       0            0            0
# PL_263_obs_0             0       0            0            0
# PL_264_obs_0             0       0            0            0
#
# [1253 rows x 256 columns]
# AFTER FILTERING
#               src_id  num_obs        src_n      sepn                    name  \
# obs_id
# PL_0_obs_0      PL_0       13  J0024-7204W  0.419328   2CXO J002406.0-720449
# PL_0_obs_1      PL_0       13  J0024-7204W  0.419328   2CXO J002406.0-720449
# PL_0_obs_2      PL_0       13  J0024-7204W  0.419328   2CXO J002406.0-720449
# PL_0_obs_3      PL_0       13  J0024-7204W  0.419328   2CXO J002406.0-720449
# PL_0_obs_4      PL_0       13  J0024-7204W  0.419328   2CXO J002406.0-720449
# ...              ...      ...          ...       ...                     ...
# PL_260_obs_0  PL_260        1   J0251+2606  0.486258   2CXO J105758.9-522656
# PL_261_obs_0  PL_261        1   J1417-4402  0.601756   2CXO J141730.5-440257
# PL_262_obs_0  PL_262        1   J0248+6021  0.468417   2CXO J024818.6+602134
# PL_263_obs_0  PL_263        1     B1451-68  0.690696   2CXO J145600.0-684339
# PL_264_obs_0  PL_264        1   J1816+4510  0.194803   2CXO J181635.9+451033
#
#                       ra       dec photflux_aper_s photflux_aper_lolim_s  \
# obs_id
# PL_0_obs_0      6.025354 -72.08032       2.395e-06             1.268e-06
# PL_0_obs_1      6.025354 -72.08032       0.000e+00             0.000e+00
# PL_0_obs_2      6.025354 -72.08032       0.000e+00             0.000e+00
# PL_0_obs_3      6.025354 -72.08032       1.484e-06             5.832e-07
# PL_0_obs_4      6.025354 -72.08032       1.214e-06             9.960e-07
# ...                  ...       ...             ...                   ...
# PL_260_obs_0  164.495800 -52.44910       9.867e-05             9.531e-05
# PL_261_obs_0  214.377300 -44.04924       3.962e-05             2.564e-05
# PL_262_obs_0   42.077720  60.35971       2.396e-06             1.057e-06
# PL_263_obs_0  224.000100 -68.72761       5.503e-06             4.828e-06
# PL_264_obs_0  274.149600  45.17611       6.273e-07             3.764e-07
#
#                photflux_aper_hilim_s  ... var_inter_sigma_h var_inter_index_m  \
# obs_id                                ...
# PL_0_obs_0                 3.522e-06  ...         3.671e-07               3.0
# PL_0_obs_1                 6.265e-07  ...         3.671e-07               3.0
# PL_0_obs_2                 1.994e-06  ...         3.671e-07               3.0
# PL_0_obs_3                 2.333e-06  ...         3.671e-07               3.0
# PL_0_obs_4                 1.433e-06  ...         3.671e-07               3.0
# ...                              ...  ...               ...               ...
# PL_260_obs_0  0.00010180000000000001  ...               NaN               NaN
# PL_261_obs_0               5.283e-05  ...               NaN               NaN
# PL_262_obs_0               3.735e-06  ...               NaN               NaN
# PL_263_obs_0   6.177999999999999e-06  ...               NaN               NaN
# PL_264_obs_0   8.781999999999999e-07  ...               NaN               NaN
#
#              var_inter_prob_m  var_inter_sigma_m var_inter_index_s  \
# obs_id
# PL_0_obs_0              0.496          1.741e-07               5.0
# PL_0_obs_1              0.496          1.741e-07               5.0
# PL_0_obs_2              0.496          1.741e-07               5.0
# PL_0_obs_3              0.496          1.741e-07               5.0
# PL_0_obs_4              0.496          1.741e-07               5.0
# ...                       ...                ...               ...
# PL_260_obs_0              NaN                NaN               NaN
# PL_261_obs_0              NaN                NaN               NaN
# PL_262_obs_0              NaN                NaN               NaN
# PL_263_obs_0              NaN                NaN               NaN
# PL_264_obs_0              NaN                NaN               NaN
#
#              var_inter_prob_s var_inter_sigma_s var_inter_index_u  \
# obs_id
# PL_0_obs_0              0.710         1.328e-06               3.0
# PL_0_obs_1              0.710         1.328e-06               3.0
# PL_0_obs_2              0.710         1.328e-06               3.0
# PL_0_obs_3              0.710         1.328e-06               3.0
# PL_0_obs_4              0.710         1.328e-06               3.0
# ...                       ...               ...               ...
# PL_260_obs_0              NaN               NaN               NaN
# PL_261_obs_0              NaN               NaN               NaN
# PL_262_obs_0              NaN               NaN               NaN
# PL_263_obs_0              NaN               NaN               NaN
# PL_264_obs_0              NaN               NaN               NaN
#
#              var_inter_prob_u  var_inter_sigma_u
# obs_id
# PL_0_obs_0              0.438          6.257e-06
# PL_0_obs_1              0.438          6.257e-06
# PL_0_obs_2              0.438          6.257e-06
# PL_0_obs_3              0.438          6.257e-06
# PL_0_obs_4              0.438          6.257e-06
# ...                       ...                ...
# PL_260_obs_0              NaN                NaN
# PL_261_obs_0              NaN                NaN
# PL_262_obs_0              NaN                NaN
# PL_263_obs_0              NaN                NaN
# PL_264_obs_0              NaN                NaN
#
# [1183 rows x 168 columns]

# %%
from features import arranged_cols  , id_cols

# %%
df_id = df[id_cols]
df_val = df.drop(columns=id_cols)
val_col_list = df_val.columns.to_list()
for v in val_col_list:
    df_val.loc[:,v] = pd.to_numeric(df_val.loc[:,v])
df_val
# Out:
#               photflux_aper_s  photflux_aper_lolim_s  photflux_aper_hilim_s  \
# obs_id
# PL_0_obs_0       2.395000e-06           1.268000e-06           3.522000e-06
# PL_0_obs_1       0.000000e+00           0.000000e+00           6.265000e-07
# PL_0_obs_2       0.000000e+00           0.000000e+00           1.994000e-06
# PL_0_obs_3       1.484000e-06           5.832000e-07           2.333000e-06
# PL_0_obs_4       1.214000e-06           9.960000e-07           1.433000e-06
# ...                       ...                    ...                    ...
# PL_260_obs_0     9.867000e-05           9.531000e-05           1.018000e-04
# PL_261_obs_0     3.962000e-05           2.564000e-05           5.283000e-05
# PL_262_obs_0     2.396000e-06           1.057000e-06           3.735000e-06
# PL_263_obs_0     5.503000e-06           4.828000e-06           6.178000e-06
# PL_264_obs_0     6.273000e-07           3.764000e-07           8.782000e-07
#
#                flux_aper_s  flux_aper_lolim_s  flux_aper_hilim_s  \
# obs_id
# PL_0_obs_0    4.071000e-15       2.155000e-15       5.987000e-15
# PL_0_obs_1    0.000000e+00       0.000000e+00       8.865000e-16
# PL_0_obs_2    0.000000e+00       0.000000e+00       2.836000e-15
# PL_0_obs_3    2.669000e-15       1.013000e-15       4.326000e-15
# PL_0_obs_4    2.118000e-15       1.737000e-15       2.498000e-15
# ...                    ...                ...                ...
# PL_260_obs_0  5.089000e-13       4.912000e-13       5.257000e-13
# PL_261_obs_0  3.679000e-14       2.380000e-14       4.905000e-14
# PL_262_obs_0  3.862000e-15       1.704000e-15       6.020000e-15
# PL_263_obs_0  9.245000e-15       8.043000e-15       1.038000e-14
# PL_264_obs_0  1.137000e-15       7.037000e-16       1.543000e-15
#
#               streak_src_flag  likelihood_b  likelihood_h  likelihood_m  ...  \
# obs_id                                                                   ...
# PL_0_obs_0              False         43.88           NaN         13.38  ...
# PL_0_obs_1              False           NaN           NaN           NaN  ...
# PL_0_obs_2              False         10.80           NaN           NaN  ...
# PL_0_obs_3              False         15.21           NaN           NaN  ...
# PL_0_obs_4              False        196.94         54.31         20.63  ...
# ...                       ...           ...           ...           ...  ...
# PL_260_obs_0            False       8381.46        669.58       1717.15  ...
# PL_261_obs_0            False        297.31        117.88        405.72  ...
# PL_262_obs_0            False         85.77           NaN           NaN  ...
# PL_263_obs_0            False       1004.25        122.67        396.78  ...
# PL_264_obs_0            False         49.19           NaN         90.48  ...
#
#               var_inter_sigma_h  var_inter_index_m  var_inter_prob_m  \
# obs_id
# PL_0_obs_0         3.671000e-07                3.0             0.496
# PL_0_obs_1         3.671000e-07                3.0             0.496
# PL_0_obs_2         3.671000e-07                3.0             0.496
# PL_0_obs_3         3.671000e-07                3.0             0.496
# PL_0_obs_4         3.671000e-07                3.0             0.496
# ...                         ...                ...               ...
# PL_260_obs_0                NaN                NaN               NaN
# PL_261_obs_0                NaN                NaN               NaN
# PL_262_obs_0                NaN                NaN               NaN
# PL_263_obs_0                NaN                NaN               NaN
# PL_264_obs_0                NaN                NaN               NaN
#
#               var_inter_sigma_m  var_inter_index_s  var_inter_prob_s  \
# obs_id
# PL_0_obs_0         1.741000e-07                5.0              0.71
# PL_0_obs_1         1.741000e-07                5.0              0.71
# PL_0_obs_2         1.741000e-07                5.0              0.71
# PL_0_obs_3         1.741000e-07                5.0              0.71
# PL_0_obs_4         1.741000e-07                5.0              0.71
# ...                         ...                ...               ...
# PL_260_obs_0                NaN                NaN               NaN
# PL_261_obs_0                NaN                NaN               NaN
# PL_262_obs_0                NaN                NaN               NaN
# PL_263_obs_0                NaN                NaN               NaN
# PL_264_obs_0                NaN                NaN               NaN
#
#               var_inter_sigma_s  var_inter_index_u  var_inter_prob_u  \
# obs_id
# PL_0_obs_0             0.000001                3.0             0.438
# PL_0_obs_1             0.000001                3.0             0.438
# PL_0_obs_2             0.000001                3.0             0.438
# PL_0_obs_3             0.000001                3.0             0.438
# PL_0_obs_4             0.000001                3.0             0.438
# ...                         ...                ...               ...
# PL_260_obs_0                NaN                NaN               NaN
# PL_261_obs_0                NaN                NaN               NaN
# PL_262_obs_0                NaN                NaN               NaN
# PL_263_obs_0                NaN                NaN               NaN
# PL_264_obs_0                NaN                NaN               NaN
#
#               var_inter_sigma_u
# obs_id
# PL_0_obs_0             0.000006
# PL_0_obs_1             0.000006
# PL_0_obs_2             0.000006
# PL_0_obs_3             0.000006
# PL_0_obs_4             0.000006
# ...                         ...
# PL_260_obs_0                NaN
# PL_261_obs_0                NaN
# PL_262_obs_0                NaN
# PL_263_obs_0                NaN
# PL_264_obs_0                NaN
#
# [1183 rows x 158 columns]

# %%
df_ok = pd.concat([df_id , df_val] , axis=1)
df_ok
# Out:
#               src_id  num_obs      sepn                    name        src_n  \
# obs_id
# PL_0_obs_0      PL_0       13  0.419328   2CXO J002406.0-720449  J0024-7204W
# PL_0_obs_1      PL_0       13  0.419328   2CXO J002406.0-720449  J0024-7204W
# PL_0_obs_2      PL_0       13  0.419328   2CXO J002406.0-720449  J0024-7204W
# PL_0_obs_3      PL_0       13  0.419328   2CXO J002406.0-720449  J0024-7204W
# PL_0_obs_4      PL_0       13  0.419328   2CXO J002406.0-720449  J0024-7204W
# ...              ...      ...       ...                     ...          ...
# PL_260_obs_0  PL_260        1  0.486258   2CXO J105758.9-522656   J0251+2606
# PL_261_obs_0  PL_261        1  0.601756   2CXO J141730.5-440257   J1417-4402
# PL_262_obs_0  PL_262        1  0.468417   2CXO J024818.6+602134   J0248+6021
# PL_263_obs_0  PL_263        1  0.690696   2CXO J145600.0-684339     B1451-68
# PL_264_obs_0  PL_264        1  0.194803   2CXO J181635.9+451033   J1816+4510
#
#                       ra       dec  livetime  significance  likelihood  ...  \
# obs_id                                                                  ...
# PL_0_obs_0      6.025354 -72.08032    5544.8         13.73   756.13850  ...
# PL_0_obs_1      6.025354 -72.08032    5734.6         13.73   756.13850  ...
# PL_0_obs_2      6.025354 -72.08032    1928.3         13.73   756.13850  ...
# PL_0_obs_3      6.025354 -72.08032    5307.0         13.73   756.13850  ...
# PL_0_obs_4      6.025354 -72.08032   68771.4         13.73   756.13850  ...
# ...                  ...       ...       ...           ...         ...  ...
# PL_260_obs_0  164.495800 -52.44910   56314.7         35.28  8831.33000  ...
# PL_261_obs_0  214.377300 -44.04924    2025.2          6.41   405.71660  ...
# PL_262_obs_0   42.077720  60.35971    9219.4          1.84    85.76846  ...
# PL_263_obs_0  224.000100 -68.72761   34694.2         12.31  1004.25000  ...
# PL_264_obs_0  274.149600  45.17611   33537.9          3.47    90.48394  ...
#
#               var_inter_sigma_h  var_inter_index_m  var_inter_prob_m  \
# obs_id
# PL_0_obs_0         3.671000e-07                3.0             0.496
# PL_0_obs_1         3.671000e-07                3.0             0.496
# PL_0_obs_2         3.671000e-07                3.0             0.496
# PL_0_obs_3         3.671000e-07                3.0             0.496
# PL_0_obs_4         3.671000e-07                3.0             0.496
# ...                         ...                ...               ...
# PL_260_obs_0                NaN                NaN               NaN
# PL_261_obs_0                NaN                NaN               NaN
# PL_262_obs_0                NaN                NaN               NaN
# PL_263_obs_0                NaN                NaN               NaN
# PL_264_obs_0                NaN                NaN               NaN
#
#               var_inter_sigma_m  var_inter_index_s  var_inter_prob_s  \
# obs_id
# PL_0_obs_0         1.741000e-07                5.0              0.71
# PL_0_obs_1         1.741000e-07                5.0              0.71
# PL_0_obs_2         1.741000e-07                5.0              0.71
# PL_0_obs_3         1.741000e-07                5.0              0.71
# PL_0_obs_4         1.741000e-07                5.0              0.71
# ...                         ...                ...               ...
# PL_260_obs_0                NaN                NaN               NaN
# PL_261_obs_0                NaN                NaN               NaN
# PL_262_obs_0                NaN                NaN               NaN
# PL_263_obs_0                NaN                NaN               NaN
# PL_264_obs_0                NaN                NaN               NaN
#
#               var_inter_sigma_s  var_inter_index_u  var_inter_prob_u  \
# obs_id
# PL_0_obs_0             0.000001                3.0             0.438
# PL_0_obs_1             0.000001                3.0             0.438
# PL_0_obs_2             0.000001                3.0             0.438
# PL_0_obs_3             0.000001                3.0             0.438
# PL_0_obs_4             0.000001                3.0             0.438
# ...                         ...                ...               ...
# PL_260_obs_0                NaN                NaN               NaN
# PL_261_obs_0                NaN                NaN               NaN
# PL_262_obs_0                NaN                NaN               NaN
# PL_263_obs_0                NaN                NaN               NaN
# PL_264_obs_0                NaN                NaN               NaN
#
#               var_inter_sigma_u
# obs_id
# PL_0_obs_0             0.000006
# PL_0_obs_1             0.000006
# PL_0_obs_2             0.000006
# PL_0_obs_3             0.000006
# PL_0_obs_4             0.000006
# ...                         ...
# PL_260_obs_0                NaN
# PL_261_obs_0                NaN
# PL_262_obs_0                NaN
# PL_263_obs_0                NaN
# PL_264_obs_0                NaN
#
# [1183 rows x 168 columns]

# %%
from features import phot_flux , phot_flux_hilim , phot_flux_lolim , en_flux , en_flux_hilim , en_flux_lolim
flux_cols =  en_flux + en_flux_hilim + en_flux_lolim 
df_flux_filt = df_ok.copy().replace(0 , np.nan).replace(np.nan , -9987)
for f in flux_cols:
    df_flux_filt = df_flux_filt.query(f+'<1e-12')
df_flux_filt = df_flux_filt.replace(-9987 , np.nan)
df_flux_filt = df_flux_filt.query('likelihood > 50')
df_flux_filt = df_flux_filt.query('significance > 3')
df_flux_filt
# Out:
#               src_id  num_obs       sepn                    name        src_n  \
# obs_id
# PL_0_obs_0      PL_0       13   0.419328   2CXO J002406.0-720449  J0024-7204W
# PL_0_obs_1      PL_0       13   0.419328   2CXO J002406.0-720449  J0024-7204W
# PL_0_obs_2      PL_0       13   0.419328   2CXO J002406.0-720449  J0024-7204W
# PL_0_obs_3      PL_0       13   0.419328   2CXO J002406.0-720449  J0024-7204W
# PL_0_obs_4      PL_0       13   0.419328   2CXO J002406.0-720449  J0024-7204W
# ...              ...      ...        ...                     ...          ...
# PL_258_obs_0  PL_258        1  10.819240   2CXO J042133.8+325557   J0421+3255
# PL_260_obs_0  PL_260        1   0.486258   2CXO J105758.9-522656   J0251+2606
# PL_261_obs_0  PL_261        1   0.601756   2CXO J141730.5-440257   J1417-4402
# PL_263_obs_0  PL_263        1   0.690696   2CXO J145600.0-684339     B1451-68
# PL_264_obs_0  PL_264        1   0.194803   2CXO J181635.9+451033   J1816+4510
#
#                       ra       dec  livetime  significance  likelihood  ...  \
# obs_id                                                                  ...
# PL_0_obs_0      6.025354 -72.08032    5544.8         13.73   756.13850  ...
# PL_0_obs_1      6.025354 -72.08032    5734.6         13.73   756.13850  ...
# PL_0_obs_2      6.025354 -72.08032    1928.3         13.73   756.13850  ...
# PL_0_obs_3      6.025354 -72.08032    5307.0         13.73   756.13850  ...
# PL_0_obs_4      6.025354 -72.08032   68771.4         13.73   756.13850  ...
# ...                  ...       ...       ...           ...         ...  ...
# PL_258_obs_0   65.390970  32.93258   18792.5          6.16   277.34070  ...
# PL_260_obs_0  164.495800 -52.44910   56314.7         35.28  8831.33000  ...
# PL_261_obs_0  214.377300 -44.04924    2025.2          6.41   405.71660  ...
# PL_263_obs_0  224.000100 -68.72761   34694.2         12.31  1004.25000  ...
# PL_264_obs_0  274.149600  45.17611   33537.9          3.47    90.48394  ...
#
#               var_inter_sigma_h  var_inter_index_m  var_inter_prob_m  \
# obs_id
# PL_0_obs_0         3.671000e-07                3.0             0.496
# PL_0_obs_1         3.671000e-07                3.0             0.496
# PL_0_obs_2         3.671000e-07                3.0             0.496
# PL_0_obs_3         3.671000e-07                3.0             0.496
# PL_0_obs_4         3.671000e-07                3.0             0.496
# ...                         ...                ...               ...
# PL_258_obs_0                NaN                NaN               NaN
# PL_260_obs_0                NaN                NaN               NaN
# PL_261_obs_0                NaN                NaN               NaN
# PL_263_obs_0                NaN                NaN               NaN
# PL_264_obs_0                NaN                NaN               NaN
#
#               var_inter_sigma_m  var_inter_index_s  var_inter_prob_s  \
# obs_id
# PL_0_obs_0         1.741000e-07                5.0              0.71
# PL_0_obs_1         1.741000e-07                5.0              0.71
# PL_0_obs_2         1.741000e-07                5.0              0.71
# PL_0_obs_3         1.741000e-07                5.0              0.71
# PL_0_obs_4         1.741000e-07                5.0              0.71
# ...                         ...                ...               ...
# PL_258_obs_0                NaN                NaN               NaN
# PL_260_obs_0                NaN                NaN               NaN
# PL_261_obs_0                NaN                NaN               NaN
# PL_263_obs_0                NaN                NaN               NaN
# PL_264_obs_0                NaN                NaN               NaN
#
#               var_inter_sigma_s  var_inter_index_u  var_inter_prob_u  \
# obs_id
# PL_0_obs_0             0.000001                3.0             0.438
# PL_0_obs_1             0.000001                3.0             0.438
# PL_0_obs_2             0.000001                3.0             0.438
# PL_0_obs_3             0.000001                3.0             0.438
# PL_0_obs_4             0.000001                3.0             0.438
# ...                         ...                ...               ...
# PL_258_obs_0                NaN                NaN               NaN
# PL_260_obs_0                NaN                NaN               NaN
# PL_261_obs_0                NaN                NaN               NaN
# PL_263_obs_0                NaN                NaN               NaN
# PL_264_obs_0                NaN                NaN               NaN
#
#               var_inter_sigma_u
# obs_id
# PL_0_obs_0             0.000006
# PL_0_obs_1             0.000006
# PL_0_obs_2             0.000006
# PL_0_obs_3             0.000006
# PL_0_obs_4             0.000006
# ...                         ...
# PL_258_obs_0                NaN
# PL_260_obs_0                NaN
# PL_261_obs_0                NaN
# PL_263_obs_0                NaN
# PL_264_obs_0                NaN
#
# [1000 rows x 168 columns]

# %%
df_flux_filt.to_csv('filtered_data/pl_new_data.csv')
